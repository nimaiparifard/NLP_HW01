# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import re

# Load the data
train = pd.read_csv("train.csv")
val = pd.read_csv("val.csv")
test = pd.read_csv("test.csv")

# %%
from hazm import Normalizer, word_tokenize
# Create a normalizer object
normalizer = Normalizer()

def remove_u200c(text):
    return text.replace('\u200c', '')

def preprocess_text(text):
    # Normalize the text
    text = normalizer.normalize(text)
    text = normalizer.remove_specials_chars(text)

    # Tokenize the text
    words = word_tokenize(text)
    words = [remove_u200c(word) for word in words]
    return words

# %%
train['content'] = train['content'].apply(preprocess_text)
val['content'] = val['content'].apply(preprocess_text)
test['content'] = test['content'].apply(preprocess_text)

# %%
print(f"Shape of the train data: {train.shape}")
print(f"Shape of the validation data: {val.shape}")
print(f"Shape of the test data: {test.shape}")
# Out:
# Shape of the train data: (13314, 2)
# Shape of the validation data: (1480, 2)
# Shape of the test data: (1644, 2)

# %%
class NgramLanguageModel:
    def __init__(self, n):
        self.number_of_minus_n_grams = None
        self.n = n
        self.counts = {}
        self.counts_minus_one_grams = {}
        self.vocab = set()


    def update_counts(self, tokens):
        n = self.n
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i + n])
            self.counts[ngram] = self.counts.get(ngram, 0) + 1
            for token in ngram:
                self.vocab.add(token)

        n = self.n - 1
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i + n])
            self.counts_minus_one_grams[ngram] = self.counts_minus_one_grams.get(ngram, 0) + 1
        self.number_of_minus_n_grams = sum(self.counts_minus_one_grams.values())

    def probability(self, token, context):
        context = tuple(context)
        ngram = context + (token,)
        if context in self.counts_minus_one_grams:
            context_count = self.counts_minus_one_grams[context]
            if ngram in self.counts:
                return self.counts[ngram] / context_count
        return 0

    def perplexity(self, test_data):
        ppl = 1
        total_ngrams = 0
        perplexity = []
        for i in range(len(test_data) - self.n + 1):
            context = tuple(test_data[i:i + self.n - 1])
            token = test_data[i + self.n - 1]
            prob = self.probability(token, context)
            ppl *= (1/prob)
            total_ngrams += 1
            if i % 10 == 0:
                perplexity.append(ppl ** (1/len(test_data)))
                ppl = 1
        perplex = 1
        for ppl in perplexity:
            perplex *= ppl
        return perplex

class BackoffSmoothing(NgramLanguageModel):
    def __init__(self, n, p_bg=0.001):
        super().__init__(n)
        self.p_bg = p_bg


    def probability(self, token, context):
        p = super().probability(token, context)
        if p == 0:
            p = self.p_bg
        return p


class AbsoluteDiscounting(NgramLanguageModel):
    def __init__(self, n, discount=0.5, p_bg=0.000001):
        super().__init__(n)
        self.discount = discount
        self.p_bg = p_bg
        self.applied_discounting = 1

    def probability(self, token, context):
        context = tuple(context)
        ngram = context + (token,)
        if context in self.counts_minus_one_grams:
            context_count = self.counts_minus_one_grams[context]
            ngram_count = self.counts.get(ngram, 0)
            if context_count > 0:
                self.applied_discounting += 1
            interpolation = self.discount * context_count / self.number_of_minus_n_grams
            return max(ngram_count - self.discount, 0) / context_count + interpolation * self.p_bg
        return  self.p_bg

# %%
# make all validation token in one list for tuning hyperparameters
validation_tokens = []
for i, content in enumerate(val['content']):
    for token in content:
        validation_tokens.append(token)

# %%
# unigram
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(1, 0.1)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 1349.9228160317841
# Perplexity of the 1 BackoffSmoothing model on the test data: 1406.2445790927306
# Perplexity of the 2 BackoffSmoothing model on the test data: 1158.788508054969
# Perplexity of the 3 BackoffSmoothing model on the test data: 1047.5144414777378
# Perplexity of the 4 BackoffSmoothing model on the test data: 1780.7903256552995
# Perplexity of the 5 BackoffSmoothing model on the test data: 1000.3506076531199
# Perplexity of the 6 BackoffSmoothing model on the test data: 974.2244899903602
# Perplexity of the 7 BackoffSmoothing model on the test data: 1110.191542958756
# Perplexity of the 8 BackoffSmoothing model on the test data: 1693.452380527151
# Perplexity of the 9 BackoffSmoothing model on the test data: 2212.6531823295454
# Perplexity of the 10 BackoffSmoothing model on the test data: 1913.2897950894715
# Perplexity of the 11 BackoffSmoothing model on the test data: 1308.0309511110197
# Perplexity of the 12 BackoffSmoothing model on the test data: 762.8049331117913
# Perplexity of the 13 BackoffSmoothing model on the test data: 3964.018692014109
# Perplexity of the 14 BackoffSmoothing model on the test data: 2053.490992170159
# Perplexity of the 15 BackoffSmoothing model on the test data: 842.2268589410431
# Perplexity of the 16 BackoffSmoothing model on the test data: 1927.2919143501856
# Perplexity of the 17 BackoffSmoothing model on the test data: 1158.7922454092575
# Perplexity of the 18 BackoffSmoothing model on the test data: 1227.0265014963902
# Perplexity of the 19 BackoffSmoothing model on the test data: 716.4996248719457
# Perplexity of the 20 BackoffSmoothing model on the test data: 946.2716912999354
# Perplexity of the 21 BackoffSmoothing model on the test data: 1570.1337789490108
# Perplexity of the 22 BackoffSmoothing model on the test data: 3279.3832854700368
# Perplexity of the 23 BackoffSmoothing model on the test data: 1900.0639809898914
# Perplexity of the 24 BackoffSmoothing model on the test data: 801.8350006204046
# Perplexity of the 25 BackoffSmoothing model on the test data: 1797.6897409593598
# Perplexity of the 26 BackoffSmoothing model on the test data: 1221.0248720326517
# Perplexity of the 27 BackoffSmoothing model on the test data: 912.2338258682664
# Perplexity of the 28 BackoffSmoothing model on the test data: 1888.5746153308182
# Perplexity of the 29 BackoffSmoothing model on the test data: 859.5466821577875
# Perplexity of the 30 BackoffSmoothing model on the test data: 1197.3946567049695
# Perplexity of the 31 BackoffSmoothing model on the test data: 938.2828105027461
# Perplexity of the 32 BackoffSmoothing model on the test data: 2386.453617457019
# Perplexity of the 33 BackoffSmoothing model on the test data: 2017.9328183627383
# Perplexity of the 34 BackoffSmoothing model on the test data: 2103.0512142641205
# Perplexity of the 35 BackoffSmoothing model on the test data: 2164.8528264432425
# Perplexity of the 36 BackoffSmoothing model on the test data: 1173.1349675699182
# Perplexity of the 37 BackoffSmoothing model on the test data: 1771.9402219970343
# Perplexity of the 38 BackoffSmoothing model on the test data: 1446.0510098551326
# Perplexity of the 39 BackoffSmoothing model on the test data: 952.286618129987
# Perplexity of the 40 BackoffSmoothing model on the test data: 1161.4407101902455
# Perplexity of the 41 BackoffSmoothing model on the test data: 976.425274096758
# Perplexity of the 42 BackoffSmoothing model on the test data: 1197.785575065883
# Perplexity of the 43 BackoffSmoothing model on the test data: 895.051897526448
# Perplexity of the 44 BackoffSmoothing model on the test data: 1365.4569557383752
# Perplexity of the 45 BackoffSmoothing model on the test data: 1039.9957122428366
# Perplexity of the 46 BackoffSmoothing model on the test data: 1020.152789408735
# Perplexity of the 47 BackoffSmoothing model on the test data: 1491.7521133038288
# Perplexity of the 48 BackoffSmoothing model on the test data: 1265.2710473898242
# Perplexity of the 49 BackoffSmoothing model on the test data: 1171.447310992856
# Perplexity of the 50 BackoffSmoothing model on the test data: 560.8170085408113
# Perplexity of the 51 BackoffSmoothing model on the test data: 1017.7947543041057
# Perplexity of the 52 BackoffSmoothing model on the test data: 1384.0081274881923
# Perplexity of the 53 BackoffSmoothing model on the test data: 1053.5021599336242
# Perplexity of the 54 BackoffSmoothing model on the test data: 1182.6513987984094
# Perplexity of the 55 BackoffSmoothing model on the test data: 2071.493004726575
# Perplexity of the 56 BackoffSmoothing model on the test data: 1554.1432377004862
# Perplexity of the 57 BackoffSmoothing model on the test data: 1324.889434572962
# Perplexity of the 58 BackoffSmoothing model on the test data: 805.9265370203918
# Perplexity of the 59 BackoffSmoothing model on the test data: 721.2765422440399
# Perplexity of the 60 BackoffSmoothing model on the test data: 1029.0809567160163
# Perplexity of the 61 BackoffSmoothing model on the test data: 830.7243298108723
# Perplexity of the 62 BackoffSmoothing model on the test data: 542.550936258054
# Perplexity of the 63 BackoffSmoothing model on the test data: 909.6354540148951
# Perplexity of the 64 BackoffSmoothing model on the test data: 701.0051704536604
# Perplexity of the 65 BackoffSmoothing model on the test data: 669.604061488728
# Perplexity of the 66 BackoffSmoothing model on the test data: 1572.1666086272103
# Perplexity of the 67 BackoffSmoothing model on the test data: 586.4517642968622
# Perplexity of the 68 BackoffSmoothing model on the test data: 711.903760425312
# Perplexity of the 69 BackoffSmoothing model on the test data: 1209.3975251075958
# Perplexity of the 70 BackoffSmoothing model on the test data: 870.6000711053584
# Perplexity of the 71 BackoffSmoothing model on the test data: 1259.3189247823566
# Perplexity of the 72 BackoffSmoothing model on the test data: 2681.0739305784878
# Perplexity of the 73 BackoffSmoothing model on the test data: 1446.23738231159
# Perplexity of the 74 BackoffSmoothing model on the test data: 1204.1032919253064
# Perplexity of the 75 BackoffSmoothing model on the test data: 650.1513574409267
# Perplexity of the 76 BackoffSmoothing model on the test data: 1151.2770654909284
# Perplexity of the 77 BackoffSmoothing model on the test data: 1321.9415645342722
# Perplexity of the 78 BackoffSmoothing model on the test data: 1052.3840447121381
# Perplexity of the 79 BackoffSmoothing model on the test data: 440.7881003319598
# Perplexity of the 80 BackoffSmoothing model on the test data: 907.8445022491504
# Perplexity of the 81 BackoffSmoothing model on the test data: 1086.6062022240967
# Perplexity of the 82 BackoffSmoothing model on the test data: 829.6457461078076
# Perplexity of the 83 BackoffSmoothing model on the test data: 865.6190841072597
# Perplexity of the 84 BackoffSmoothing model on the test data: 376.35976546104627
# Perplexity of the 85 BackoffSmoothing model on the test data: 1427.5246394857043
# Perplexity of the 86 BackoffSmoothing model on the test data: 1399.5389216987523
# Perplexity of the 87 BackoffSmoothing model on the test data: 947.3218185736164
# Perplexity of the 88 BackoffSmoothing model on the test data: 1514.1535800247284
# Perplexity of the 89 BackoffSmoothing model on the test data: 684.0251395528597
# Perplexity of the 90 BackoffSmoothing model on the test data: 1170.5301129785203
# Perplexity of the 91 BackoffSmoothing model on the test data: 1539.4789720262202
# Perplexity of the 92 BackoffSmoothing model on the test data: 1837.5847448548363
# Perplexity of the 93 BackoffSmoothing model on the test data: 1812.3626868295657
# Perplexity of the 94 BackoffSmoothing model on the test data: 1121.8663797331528
# Perplexity of the 95 BackoffSmoothing model on the test data: 767.4733383404367
# Perplexity of the 96 BackoffSmoothing model on the test data: 2977.6680272729486
# Perplexity of the 97 BackoffSmoothing model on the test data: 678.2226940772672
# Perplexity of the 98 BackoffSmoothing model on the test data: 1200.2412545179222
# Perplexity of the 99 BackoffSmoothing model on the test data: 997.3195703067099
# Perplexity of the 100 BackoffSmoothing model on the test data: 530.525072639907
# Perplexity of the 101 BackoffSmoothing model on the test data: 2157.9189071118426
# Perplexity of the 102 BackoffSmoothing model on the test data: 1794.0323632952347
# Perplexity of the 103 BackoffSmoothing model on the test data: 626.0705624224114
# Perplexity of the 104 BackoffSmoothing model on the test data: 1935.6733918122227
# Perplexity of the 105 BackoffSmoothing model on the test data: 906.1051304707729
# Perplexity of the 106 BackoffSmoothing model on the test data: 945.3878783670115
# Perplexity of the 107 BackoffSmoothing model on the test data: 2248.7754543163587
# Perplexity of the 108 BackoffSmoothing model on the test data: 1094.5100605106497
# Perplexity of the 109 BackoffSmoothing model on the test data: 1014.0858506528576
# Perplexity of the 110 BackoffSmoothing model on the test data: 1052.4978398619103
# Perplexity of the 111 BackoffSmoothing model on the test data: 1020.7540017921375
# Perplexity of the 112 BackoffSmoothing model on the test data: 624.1389499689282
# Perplexity of the 113 BackoffSmoothing model on the test data: 1202.5574336988147
# Perplexity of the 114 BackoffSmoothing model on the test data: 1409.2651252330481
# Perplexity of the 115 BackoffSmoothing model on the test data: 1501.8661765752802
# Perplexity of the 116 BackoffSmoothing model on the test data: 1268.2814012993506
# Perplexity of the 117 BackoffSmoothing model on the test data: 1418.1256371386062
# Perplexity of the 118 BackoffSmoothing model on the test data: 1025.124777404056
# Perplexity of the 119 BackoffSmoothing model on the test data: 848.9575964115402
# Perplexity of the 120 BackoffSmoothing model on the test data: 1150.5375343063367
# Perplexity of the 121 BackoffSmoothing model on the test data: 834.6549152484943
# Perplexity of the 122 BackoffSmoothing model on the test data: 989.3587959484024
# Perplexity of the 123 BackoffSmoothing model on the test data: 1802.3391492054775
# Perplexity of the 124 BackoffSmoothing model on the test data: 1007.5310001359109
# Perplexity of the 125 BackoffSmoothing model on the test data: 1044.0916537443713
# Perplexity of the 126 BackoffSmoothing model on the test data: 1301.0053122421175
# Perplexity of the 127 BackoffSmoothing model on the test data: 1086.8431893834365
# Perplexity of the 128 BackoffSmoothing model on the test data: 1535.0593669346883
# Perplexity of the 129 BackoffSmoothing model on the test data: 989.1025700164263
# Perplexity of the 130 BackoffSmoothing model on the test data: 1289.6586494067913
# Perplexity of the 131 BackoffSmoothing model on the test data: 705.4177536450201
# Perplexity of the 132 BackoffSmoothing model on the test data: 1799.5419416342886
# Perplexity of the 133 BackoffSmoothing model on the test data: 768.1415296819732
# Perplexity of the 134 BackoffSmoothing model on the test data: 1326.1331981951812
# Perplexity of the 135 BackoffSmoothing model on the test data: 1423.789774270498
# Perplexity of the 136 BackoffSmoothing model on the test data: 1043.7973522639534
# Perplexity of the 137 BackoffSmoothing model on the test data: 704.9182008890667
# Perplexity of the 138 BackoffSmoothing model on the test data: 1732.5359095434155
# Perplexity of the 139 BackoffSmoothing model on the test data: 935.42627187956
# Perplexity of the 140 BackoffSmoothing model on the test data: 1222.1599084265872
# Perplexity of the 141 BackoffSmoothing model on the test data: 1688.0360983549908
# Perplexity of the 142 BackoffSmoothing model on the test data: 1137.0751049704522
# Perplexity of the 143 BackoffSmoothing model on the test data: 1277.0589729584572
# Perplexity of the 144 BackoffSmoothing model on the test data: 873.1116614531012
# Perplexity of the 145 BackoffSmoothing model on the test data: 1665.4084603970505
# Perplexity of the 146 BackoffSmoothing model on the test data: 1240.6425816881426
# Perplexity of the 147 BackoffSmoothing model on the test data: 935.6155791093344
# Perplexity of the 148 BackoffSmoothing model on the test data: 1210.8354124221503
# Perplexity of the 149 BackoffSmoothing model on the test data: 798.7603864554038
# Perplexity of the 150 BackoffSmoothing model on the test data: 1069.795851375165
# Perplexity of the 151 BackoffSmoothing model on the test data: 2485.7746719189568
# Perplexity of the 152 BackoffSmoothing model on the test data: 1392.4227391145932
# Perplexity of the 153 BackoffSmoothing model on the test data: 1059.6038107269342
# Perplexity of the 154 BackoffSmoothing model on the test data: 816.3197064834862
# Perplexity of the 155 BackoffSmoothing model on the test data: 1363.7929476519785
# Perplexity of the 156 BackoffSmoothing model on the test data: 1632.1364892706777
# Perplexity of the 157 BackoffSmoothing model on the test data: 2251.006942968635
# Perplexity of the 158 BackoffSmoothing model on the test data: 1139.3846194143457
# Perplexity of the 159 BackoffSmoothing model on the test data: 960.0041316737539
# Perplexity of the 160 BackoffSmoothing model on the test data: 1527.527286599404
# Perplexity of the 161 BackoffSmoothing model on the test data: 843.5854833946346
# Perplexity of the 162 BackoffSmoothing model on the test data: 1111.27807202939
# Perplexity of the 163 BackoffSmoothing model on the test data: 767.3235801171847
# Perplexity of the 164 BackoffSmoothing model on the test data: 1121.3678183293207
# Perplexity of the 165 BackoffSmoothing model on the test data: 1646.0318581285128
# Perplexity of the 166 BackoffSmoothing model on the test data: 2429.252302963451
# Perplexity of the 167 BackoffSmoothing model on the test data: 782.7511858787235
# Perplexity of the 168 BackoffSmoothing model on the test data: 1802.9293133698325
# Perplexity of the 169 BackoffSmoothing model on the test data: 1121.5766039669081
# Perplexity of the 170 BackoffSmoothing model on the test data: 1016.9333706738713
# Perplexity of the 171 BackoffSmoothing model on the test data: 831.238711802451
# Perplexity of the 172 BackoffSmoothing model on the test data: 1418.9353977647015
# Perplexity of the 173 BackoffSmoothing model on the test data: 1571.2783334277224
# Perplexity of the 174 BackoffSmoothing model on the test data: 1107.538136142956
# Perplexity of the 175 BackoffSmoothing model on the test data: 1390.5922726279696
# Perplexity of the 176 BackoffSmoothing model on the test data: 1422.1621019394147
# Perplexity of the 177 BackoffSmoothing model on the test data: 1969.148963927857
# Perplexity of the 178 BackoffSmoothing model on the test data: 1448.605364593045
# Perplexity of the 179 BackoffSmoothing model on the test data: 1389.8735837926677
# Perplexity of the 180 BackoffSmoothing model on the test data: 1780.56654179567
# Perplexity of the 181 BackoffSmoothing model on the test data: 1336.5296937112232
# Perplexity of the 182 BackoffSmoothing model on the test data: 883.4442858377448
# Perplexity of the 183 BackoffSmoothing model on the test data: 761.3671798148497
# Perplexity of the 184 BackoffSmoothing model on the test data: 1381.1873558452028
# Perplexity of the 185 BackoffSmoothing model on the test data: 508.85665796010363
# Perplexity of the 186 BackoffSmoothing model on the test data: 1100.8388889966493
# Perplexity of the 187 BackoffSmoothing model on the test data: 1199.6123008549728
# Perplexity of the 188 BackoffSmoothing model on the test data: 2677.585159393621
# Perplexity of the 189 BackoffSmoothing model on the test data: 536.7033012124713
# Perplexity of the 190 BackoffSmoothing model on the test data: 1706.4854372216087
# Perplexity of the 191 BackoffSmoothing model on the test data: 2085.6690511049
# Perplexity of the 192 BackoffSmoothing model on the test data: 1103.9397965860344
# Perplexity of the 193 BackoffSmoothing model on the test data: 861.2698301657267
# Perplexity of the 194 BackoffSmoothing model on the test data: 1974.800481545429
# Perplexity of the 195 BackoffSmoothing model on the test data: 1152.4015757526836
# Perplexity of the 196 BackoffSmoothing model on the test data: 572.2794505518168
# Perplexity of the 197 BackoffSmoothing model on the test data: 1270.2268833773985
# Perplexity of the 198 BackoffSmoothing model on the test data: 1043.393208307888
# Perplexity of the 199 BackoffSmoothing model on the test data: 1581.269525507836
# Perplexity of the 200 BackoffSmoothing model on the test data: 1308.8244138351833
# Perplexity of the 201 BackoffSmoothing model on the test data: 1148.1875240377071
# Perplexity of the 202 BackoffSmoothing model on the test data: 1255.2769234749248
# Perplexity of the 203 BackoffSmoothing model on the test data: 877.8983155104634
# Perplexity of the 204 BackoffSmoothing model on the test data: 1047.4894259568896
# Perplexity of the 205 BackoffSmoothing model on the test data: 2043.2585257348112
# Perplexity of the 206 BackoffSmoothing model on the test data: 1318.4901459554528
# Perplexity of the 207 BackoffSmoothing model on the test data: 2144.187444193299
# Perplexity of the 208 BackoffSmoothing model on the test data: 720.2861969931013
# Perplexity of the 209 BackoffSmoothing model on the test data: 853.2886578746079
# Perplexity of the 210 BackoffSmoothing model on the test data: 865.38010458265
# Perplexity of the 211 BackoffSmoothing model on the test data: 515.1054500255198
# Perplexity of the 212 BackoffSmoothing model on the test data: 1336.201289521337
# Perplexity of the 213 BackoffSmoothing model on the test data: 1363.4259322273472
# Perplexity of the 214 BackoffSmoothing model on the test data: 1098.7740960134745
# Perplexity of the 215 BackoffSmoothing model on the test data: 1224.2146233811402
# Perplexity of the 216 BackoffSmoothing model on the test data: 1559.5592354633786
# Perplexity of the 217 BackoffSmoothing model on the test data: 1164.1667304727646
# Perplexity of the 218 BackoffSmoothing model on the test data: 844.7562801607087
# Perplexity of the 219 BackoffSmoothing model on the test data: 697.548291910206
# Perplexity of the 220 BackoffSmoothing model on the test data: 1921.9550561101455
# Perplexity of the 221 BackoffSmoothing model on the test data: 1216.619412646927
# Perplexity of the 222 BackoffSmoothing model on the test data: 665.79772474167
# Perplexity of the 223 BackoffSmoothing model on the test data: 900.2102193180931
# Perplexity of the 224 BackoffSmoothing model on the test data: 784.1960013895558
# Perplexity of the 225 BackoffSmoothing model on the test data: 1011.7218688979816
# Perplexity of the 226 BackoffSmoothing model on the test data: 929.1299127577851
# Perplexity of the 227 BackoffSmoothing model on the test data: 1526.1953230948454
# Perplexity of the 228 BackoffSmoothing model on the test data: 878.7767351727562
# Perplexity of the 229 BackoffSmoothing model on the test data: 1078.7903291837004
# Perplexity of the 230 BackoffSmoothing model on the test data: 641.5640165232566
# Perplexity of the 231 BackoffSmoothing model on the test data: 1238.231597471156
# Perplexity of the 232 BackoffSmoothing model on the test data: 1000.6011642324561
# Perplexity of the 233 BackoffSmoothing model on the test data: 1081.0226225047913
# Perplexity of the 234 BackoffSmoothing model on the test data: 844.2256587296047
# Perplexity of the 235 BackoffSmoothing model on the test data: 1876.264268151815
# Perplexity of the 236 BackoffSmoothing model on the test data: 1916.980547174751
# Perplexity of the 237 BackoffSmoothing model on the test data: 1655.0292195392071
# Perplexity of the 238 BackoffSmoothing model on the test data: 910.2113336563157
# Perplexity of the 239 BackoffSmoothing model on the test data: 1271.3301012363545
# Perplexity of the 240 BackoffSmoothing model on the test data: 1068.1047897528642
# Perplexity of the 241 BackoffSmoothing model on the test data: 1161.1919407749613
# Perplexity of the 242 BackoffSmoothing model on the test data: 1084.677251427897
# Perplexity of the 243 BackoffSmoothing model on the test data: 755.3988112366787
# Perplexity of the 244 BackoffSmoothing model on the test data: 955.7807319130718
# Perplexity of the 245 BackoffSmoothing model on the test data: 581.8060113722214
# Perplexity of the 246 BackoffSmoothing model on the test data: 726.2003041042186
# Perplexity of the 247 BackoffSmoothing model on the test data: 911.7557820844347
# Perplexity of the 248 BackoffSmoothing model on the test data: 1020.3444372975048
# Perplexity of the 249 BackoffSmoothing model on the test data: 1263.947281171456
# Perplexity of the 250 BackoffSmoothing model on the test data: 1290.3701211100667
# Perplexity of the 251 BackoffSmoothing model on the test data: 1496.4173570643643
# Perplexity of the 252 BackoffSmoothing model on the test data: 1037.4685705977924
# Perplexity of the 253 BackoffSmoothing model on the test data: 1506.8646465343945
# Perplexity of the 254 BackoffSmoothing model on the test data: 2204.9735346515035
# Perplexity of the 255 BackoffSmoothing model on the test data: 1867.6707427115668
# Perplexity of the 256 BackoffSmoothing model on the test data: 1581.4919437381325
# Perplexity of the 257 BackoffSmoothing model on the test data: 2044.6218327459203
# Perplexity of the 258 BackoffSmoothing model on the test data: 1470.2953547368047
# Perplexity of the 259 BackoffSmoothing model on the test data: 1417.2569515867726
# Perplexity of the 260 BackoffSmoothing model on the test data: 740.0252369962641
# Perplexity of the 261 BackoffSmoothing model on the test data: 904.6908554346365
# Perplexity of the 262 BackoffSmoothing model on the test data: 1147.9528662224654
# Perplexity of the 263 BackoffSmoothing model on the test data: 1480.0082797660514
# Perplexity of the 264 BackoffSmoothing model on the test data: 377.5476264976525
# Perplexity of the 265 BackoffSmoothing model on the test data: 1037.6073668363204
# Perplexity of the 266 BackoffSmoothing model on the test data: 1173.0629935039506
# Perplexity of the 267 BackoffSmoothing model on the test data: 2172.358078694346
# Perplexity of the 268 BackoffSmoothing model on the test data: 510.9887259394874
# Perplexity of the 269 BackoffSmoothing model on the test data: 385.4173453504748
# Perplexity of the 270 BackoffSmoothing model on the test data: 455.7997158816364
# Perplexity of the 271 BackoffSmoothing model on the test data: 579.8487138556418
# Perplexity of the 272 BackoffSmoothing model on the test data: 923.4753421226206
# Perplexity of the 273 BackoffSmoothing model on the test data: 1514.4866456473687
# Perplexity of the 274 BackoffSmoothing model on the test data: 1675.142583774246
# Perplexity of the 275 BackoffSmoothing model on the test data: 1347.597853516106
# Perplexity of the 276 BackoffSmoothing model on the test data: 1728.3253765542333
# Perplexity of the 277 BackoffSmoothing model on the test data: 977.4426538196873
# Perplexity of the 278 BackoffSmoothing model on the test data: 989.8116898294697
# Perplexity of the 279 BackoffSmoothing model on the test data: 993.9461224505468
# Perplexity of the 280 BackoffSmoothing model on the test data: 1022.8115235970631
# Perplexity of the 281 BackoffSmoothing model on the test data: 1228.1281783995196
# Perplexity of the 282 BackoffSmoothing model on the test data: 517.8593084537679
# Perplexity of the 283 BackoffSmoothing model on the test data: 999.949208208682
# Perplexity of the 284 BackoffSmoothing model on the test data: 754.4298086371309
# Perplexity of the 285 BackoffSmoothing model on the test data: 1441.9733208752289
# Perplexity of the 286 BackoffSmoothing model on the test data: 1117.2778629431186
# Perplexity of the 287 BackoffSmoothing model on the test data: 1125.0871579536013
# Perplexity of the 288 BackoffSmoothing model on the test data: 719.783553819341
# Perplexity of the 289 BackoffSmoothing model on the test data: 1331.3303503654454
# Perplexity of the 290 BackoffSmoothing model on the test data: 2758.855799119184
# Perplexity of the 291 BackoffSmoothing model on the test data: 1418.2588535964985
# Perplexity of the 292 BackoffSmoothing model on the test data: 1681.7244777144008
# Perplexity of the 293 BackoffSmoothing model on the test data: 1742.780377869821
# Perplexity of the 294 BackoffSmoothing model on the test data: 1183.1288442521973
# Perplexity of the 295 BackoffSmoothing model on the test data: 1885.2187914686178
# Perplexity of the 296 BackoffSmoothing model on the test data: 904.1050865089617
# Perplexity of the 297 BackoffSmoothing model on the test data: 825.9206327532237
# Perplexity of the 298 BackoffSmoothing model on the test data: 2094.1047591815695
# Perplexity of the 299 BackoffSmoothing model on the test data: 665.8235327904996
# Perplexity of the 300 BackoffSmoothing model on the test data: 1214.8512878866336
# Perplexity of the 301 BackoffSmoothing model on the test data: 965.3020962424879
# Perplexity of the 302 BackoffSmoothing model on the test data: 771.9345565654152
# Perplexity of the 303 BackoffSmoothing model on the test data: 1675.2853121520511
# Perplexity of the 304 BackoffSmoothing model on the test data: 1292.2151340696107
# Perplexity of the 305 BackoffSmoothing model on the test data: 2434.525231400974
# Perplexity of the 306 BackoffSmoothing model on the test data: 1020.5299001712096
# Perplexity of the 307 BackoffSmoothing model on the test data: 686.533357925289
# Perplexity of the 308 BackoffSmoothing model on the test data: 1677.835418294645
# Perplexity of the 309 BackoffSmoothing model on the test data: 753.6931849704765
# Perplexity of the 310 BackoffSmoothing model on the test data: 664.368980621329
# Perplexity of the 311 BackoffSmoothing model on the test data: 942.3722333949597
# Perplexity of the 312 BackoffSmoothing model on the test data: 1602.752789671725
# Perplexity of the 313 BackoffSmoothing model on the test data: 1633.7819143064144
# Perplexity of the 314 BackoffSmoothing model on the test data: 493.79945929853847
# Perplexity of the 315 BackoffSmoothing model on the test data: 908.2324465749971
# Perplexity of the 316 BackoffSmoothing model on the test data: 1470.0336401526172
# Perplexity of the 317 BackoffSmoothing model on the test data: 1012.2905215003888
# Perplexity of the 318 BackoffSmoothing model on the test data: 1618.748380835145
# Perplexity of the 319 BackoffSmoothing model on the test data: 2177.269811366736
# Perplexity of the 320 BackoffSmoothing model on the test data: 1817.1607353332677
# Perplexity of the 321 BackoffSmoothing model on the test data: 848.0873505135199
# Perplexity of the 322 BackoffSmoothing model on the test data: 1023.9157723957927
# Perplexity of the 323 BackoffSmoothing model on the test data: 872.1308457909457
# Perplexity of the 324 BackoffSmoothing model on the test data: 1762.133362752963
# Perplexity of the 325 BackoffSmoothing model on the test data: 1057.834183871743
# Perplexity of the 326 BackoffSmoothing model on the test data: 1886.4896411805498
# Perplexity of the 327 BackoffSmoothing model on the test data: 991.3880229143891
# Perplexity of the 328 BackoffSmoothing model on the test data: 1223.5703886957629
# Perplexity of the 329 BackoffSmoothing model on the test data: 1077.6670576961164
# Perplexity of the 330 BackoffSmoothing model on the test data: 1327.540986953592
# Perplexity of the 331 BackoffSmoothing model on the test data: 3106.742877889496
# Perplexity of the 332 BackoffSmoothing model on the test data: 1624.1586669992612
# Perplexity of the 333 BackoffSmoothing model on the test data: 1052.5161840855467
# Perplexity of the 334 BackoffSmoothing model on the test data: 853.7447307487015
# Perplexity of the 335 BackoffSmoothing model on the test data: 630.7364084749642
# Perplexity of the 336 BackoffSmoothing model on the test data: 1304.3385447808623
# Perplexity of the 337 BackoffSmoothing model on the test data: 4586.600600911189
# Perplexity of the 338 BackoffSmoothing model on the test data: 1396.6487498917409
# Perplexity of the 339 BackoffSmoothing model on the test data: 836.0296910526652
# Perplexity of the 340 BackoffSmoothing model on the test data: 1311.621313465225
# Perplexity of the 341 BackoffSmoothing model on the test data: 800.8441916813724
# Perplexity of the 342 BackoffSmoothing model on the test data: 816.4132052531813
# Perplexity of the 343 BackoffSmoothing model on the test data: 525.3490167342237
# Perplexity of the 344 BackoffSmoothing model on the test data: 1327.6019280219311
# Perplexity of the 345 BackoffSmoothing model on the test data: 1849.2783532685107
# Perplexity of the 346 BackoffSmoothing model on the test data: 1655.3880104054492
# Perplexity of the 347 BackoffSmoothing model on the test data: 1999.6202041869196
# Perplexity of the 348 BackoffSmoothing model on the test data: 749.7630787984025
# Perplexity of the 349 BackoffSmoothing model on the test data: 1063.2558155188565
# Perplexity of the 350 BackoffSmoothing model on the test data: 1437.2637341459003
# Perplexity of the 351 BackoffSmoothing model on the test data: 1912.135268985011
# Perplexity of the 352 BackoffSmoothing model on the test data: 1162.6152538726797
# Perplexity of the 353 BackoffSmoothing model on the test data: 768.7229425621006
# Perplexity of the 354 BackoffSmoothing model on the test data: 1127.7871027780243
# Perplexity of the 355 BackoffSmoothing model on the test data: 833.7252862660332
# Perplexity of the 356 BackoffSmoothing model on the test data: 757.830246245188
# Perplexity of the 357 BackoffSmoothing model on the test data: 1157.7870871208925
# Perplexity of the 358 BackoffSmoothing model on the test data: 652.6864168552825
# Perplexity of the 359 BackoffSmoothing model on the test data: 778.3982420190156
# Perplexity of the 360 BackoffSmoothing model on the test data: 1612.5862739841875
# Perplexity of the 361 BackoffSmoothing model on the test data: 868.2300920028214
# Perplexity of the 362 BackoffSmoothing model on the test data: 1271.4100388769948
# Perplexity of the 363 BackoffSmoothing model on the test data: 1035.0439950219043
# Perplexity of the 364 BackoffSmoothing model on the test data: 1118.6428350483502
# Perplexity of the 365 BackoffSmoothing model on the test data: 1630.2144174711757
# Perplexity of the 366 BackoffSmoothing model on the test data: 1722.0795557475842
# Perplexity of the 367 BackoffSmoothing model on the test data: 1224.7134186161372
# Perplexity of the 368 BackoffSmoothing model on the test data: 688.1622287004215
# Perplexity of the 369 BackoffSmoothing model on the test data: 1589.8221993790175
# Perplexity of the 370 BackoffSmoothing model on the test data: 1086.1911533752348
# Perplexity of the 371 BackoffSmoothing model on the test data: 1518.6890846237816
# Perplexity of the 372 BackoffSmoothing model on the test data: 636.525719489145
# Perplexity of the 373 BackoffSmoothing model on the test data: 1360.9661486042169
# Perplexity of the 374 BackoffSmoothing model on the test data: 1364.3162881319145
# Perplexity of the 375 BackoffSmoothing model on the test data: 1828.518721348855
# Perplexity of the 376 BackoffSmoothing model on the test data: 1475.243153761243
# Perplexity of the 377 BackoffSmoothing model on the test data: 1143.7358085210376
# Perplexity of the 378 BackoffSmoothing model on the test data: 1270.321018361414
# Perplexity of the 379 BackoffSmoothing model on the test data: 1210.8040810283835
# Perplexity of the 380 BackoffSmoothing model on the test data: 714.6671249652601
# Perplexity of the 381 BackoffSmoothing model on the test data: 1326.2901384024353
# Perplexity of the 382 BackoffSmoothing model on the test data: 1323.0393176065236
# Perplexity of the 383 BackoffSmoothing model on the test data: 425.5572689477885
# Perplexity of the 384 BackoffSmoothing model on the test data: 914.552484334044
# Perplexity of the 385 BackoffSmoothing model on the test data: 552.0337581902123
# Perplexity of the 386 BackoffSmoothing model on the test data: 794.6219071491004
# Perplexity of the 387 BackoffSmoothing model on the test data: 1625.0707832554697
# Perplexity of the 388 BackoffSmoothing model on the test data: 1327.3853262860011
# Perplexity of the 389 BackoffSmoothing model on the test data: 637.1544365691982
# Perplexity of the 390 BackoffSmoothing model on the test data: 1418.6963373472079
# Perplexity of the 391 BackoffSmoothing model on the test data: 1192.8453086705629
# Perplexity of the 392 BackoffSmoothing model on the test data: 1191.9375602673465
# Perplexity of the 393 BackoffSmoothing model on the test data: 577.771459139453
# Perplexity of the 394 BackoffSmoothing model on the test data: 925.1101897728806
# Perplexity of the 395 BackoffSmoothing model on the test data: 1303.3164884207308
# Perplexity of the 396 BackoffSmoothing model on the test data: 572.0522486432762
# Perplexity of the 397 BackoffSmoothing model on the test data: 371.2941975665092
# Perplexity of the 398 BackoffSmoothing model on the test data: 1363.4686221654067
# Perplexity of the 399 BackoffSmoothing model on the test data: 1761.3732345427936
# Perplexity of the 400 BackoffSmoothing model on the test data: 917.3248142019177
# Perplexity of the 401 BackoffSmoothing model on the test data: 1475.0821147290699
# Perplexity of the 402 BackoffSmoothing model on the test data: 1596.6365810296602
# Perplexity of the 403 BackoffSmoothing model on the test data: 674.8787441846578
# Perplexity of the 404 BackoffSmoothing model on the test data: 981.8722921533397
# Perplexity of the 405 BackoffSmoothing model on the test data: 1020.9586177387873
# Perplexity of the 406 BackoffSmoothing model on the test data: 1788.5630674767187
# Perplexity of the 407 BackoffSmoothing model on the test data: 1648.3582251059604
# Perplexity of the 408 BackoffSmoothing model on the test data: 918.1633721456839
# Perplexity of the 409 BackoffSmoothing model on the test data: 1184.1829997575505
# Perplexity of the 410 BackoffSmoothing model on the test data: 912.8280383186453
# Perplexity of the 411 BackoffSmoothing model on the test data: 1742.7611224260477
# Perplexity of the 412 BackoffSmoothing model on the test data: 2157.9506441714593
# Perplexity of the 413 BackoffSmoothing model on the test data: 1134.4415859206763
# Perplexity of the 414 BackoffSmoothing model on the test data: 1061.5701908795177
# Perplexity of the 415 BackoffSmoothing model on the test data: 801.3416921926108
# Perplexity of the 416 BackoffSmoothing model on the test data: 1850.6759579908946
# Perplexity of the 417 BackoffSmoothing model on the test data: 1043.5412520519142
# Perplexity of the 418 BackoffSmoothing model on the test data: 692.5241639963331
# Perplexity of the 419 BackoffSmoothing model on the test data: 958.2705280580656
# Perplexity of the 420 BackoffSmoothing model on the test data: 1680.6060172911336
# Perplexity of the 421 BackoffSmoothing model on the test data: 899.0975369865948
# Perplexity of the 422 BackoffSmoothing model on the test data: 1811.1269702114155
# Perplexity of the 423 BackoffSmoothing model on the test data: 828.1643676310995
# Perplexity of the 424 BackoffSmoothing model on the test data: 1212.0188836733073
# Perplexity of the 425 BackoffSmoothing model on the test data: 1009.8895300617031
# Perplexity of the 426 BackoffSmoothing model on the test data: 1102.4051948493575
# Perplexity of the 427 BackoffSmoothing model on the test data: 735.9614982672713
# Perplexity of the 428 BackoffSmoothing model on the test data: 803.1911497114695
# Perplexity of the 429 BackoffSmoothing model on the test data: 1334.1562592653431
# Perplexity of the 430 BackoffSmoothing model on the test data: 1173.4936699023453
# Perplexity of the 431 BackoffSmoothing model on the test data: 1467.9306338510942
# Perplexity of the 432 BackoffSmoothing model on the test data: 1107.1142682889943
# Perplexity of the 433 BackoffSmoothing model on the test data: 1073.5743384641858
# Perplexity of the 434 BackoffSmoothing model on the test data: 1061.081824674941
# Perplexity of the 435 BackoffSmoothing model on the test data: 1813.7371919930306
# Perplexity of the 436 BackoffSmoothing model on the test data: 1183.5711242395198
# Perplexity of the 437 BackoffSmoothing model on the test data: 1677.8911039694235
# Perplexity of the 438 BackoffSmoothing model on the test data: 1360.2363863428861
# Perplexity of the 439 BackoffSmoothing model on the test data: 1877.7776812821558
# Perplexity of the 440 BackoffSmoothing model on the test data: 946.0794377593269
# Perplexity of the 441 BackoffSmoothing model on the test data: 1090.819202271893
# Perplexity of the 442 BackoffSmoothing model on the test data: 571.8660892909018
# Perplexity of the 443 BackoffSmoothing model on the test data: 1204.3182151974088
# Perplexity of the 444 BackoffSmoothing model on the test data: 409.5165252956349
# Perplexity of the 445 BackoffSmoothing model on the test data: 1124.2102670011373
# Perplexity of the 446 BackoffSmoothing model on the test data: 3327.928899601847
# Perplexity of the 447 BackoffSmoothing model on the test data: 540.8743797534742
# Perplexity of the 448 BackoffSmoothing model on the test data: 1276.9968642634828
# Perplexity of the 449 BackoffSmoothing model on the test data: 628.5319505744765
# Perplexity of the 450 BackoffSmoothing model on the test data: 744.39253870663
# Perplexity of the 451 BackoffSmoothing model on the test data: 932.8435934994401
# Perplexity of the 452 BackoffSmoothing model on the test data: 1749.373300564276
# Perplexity of the 453 BackoffSmoothing model on the test data: 898.496445292136
# Perplexity of the 454 BackoffSmoothing model on the test data: 1163.1585817018674
# Perplexity of the 455 BackoffSmoothing model on the test data: 448.6452785831169
# Perplexity of the 456 BackoffSmoothing model on the test data: 1613.3205266511832
# Perplexity of the 457 BackoffSmoothing model on the test data: 1074.8391341749843
# Perplexity of the 458 BackoffSmoothing model on the test data: 520.9589744321675
# Perplexity of the 459 BackoffSmoothing model on the test data: 1509.6593174732366
# Perplexity of the 460 BackoffSmoothing model on the test data: 1827.6162161397503
# Perplexity of the 461 BackoffSmoothing model on the test data: 2349.695884213926
# Perplexity of the 462 BackoffSmoothing model on the test data: 839.2110171445026
# Perplexity of the 463 BackoffSmoothing model on the test data: 1219.6917336851918
# Perplexity of the 464 BackoffSmoothing model on the test data: 1538.3226640335256
# Perplexity of the 465 BackoffSmoothing model on the test data: 2131.2756811730333
# Perplexity of the 466 BackoffSmoothing model on the test data: 757.7795697385137
# Perplexity of the 467 BackoffSmoothing model on the test data: 1528.3613918361261
# Perplexity of the 468 BackoffSmoothing model on the test data: 1712.2027962632308
# Perplexity of the 469 BackoffSmoothing model on the test data: 831.617430488969
# Perplexity of the 470 BackoffSmoothing model on the test data: 1859.3908109213116
# Perplexity of the 471 BackoffSmoothing model on the test data: 550.1215292147632
# Perplexity of the 472 BackoffSmoothing model on the test data: 1665.9259107457942
# Perplexity of the 473 BackoffSmoothing model on the test data: 1237.7505332845992
# Perplexity of the 474 BackoffSmoothing model on the test data: 844.3738541312742
# Perplexity of the 475 BackoffSmoothing model on the test data: 1044.7707652493282
# Perplexity of the 476 BackoffSmoothing model on the test data: 859.5826221039196
# Perplexity of the 477 BackoffSmoothing model on the test data: 808.0062710761765
# Perplexity of the 478 BackoffSmoothing model on the test data: 1352.3163858650457
# Perplexity of the 479 BackoffSmoothing model on the test data: 2215.210322119567
# Perplexity of the 480 BackoffSmoothing model on the test data: 2312.9854333663266
# Perplexity of the 481 BackoffSmoothing model on the test data: 991.2212818282599
# Perplexity of the 482 BackoffSmoothing model on the test data: 1179.1178054555546
# Perplexity of the 483 BackoffSmoothing model on the test data: 1036.627313762792
# Perplexity of the 484 BackoffSmoothing model on the test data: 1370.8671848435426
# Perplexity of the 485 BackoffSmoothing model on the test data: 1142.7263538413245
# Perplexity of the 486 BackoffSmoothing model on the test data: 711.7583526640653
# Perplexity of the 487 BackoffSmoothing model on the test data: 1607.1221088281502
# Perplexity of the 488 BackoffSmoothing model on the test data: 906.110352975671
# Perplexity of the 489 BackoffSmoothing model on the test data: 784.8216537895006
# Perplexity of the 490 BackoffSmoothing model on the test data: 1288.7627270544995
# Perplexity of the 491 BackoffSmoothing model on the test data: 1106.785726196046
# Perplexity of the 492 BackoffSmoothing model on the test data: 819.4591325178343
# Perplexity of the 493 BackoffSmoothing model on the test data: 1517.4625996942116
# Perplexity of the 494 BackoffSmoothing model on the test data: 1519.5517771703514
# Perplexity of the 495 BackoffSmoothing model on the test data: 1399.5263537842334
# Perplexity of the 496 BackoffSmoothing model on the test data: 877.4121570842595
# Perplexity of the 497 BackoffSmoothing model on the test data: 943.5565024530044
# Perplexity of the 498 BackoffSmoothing model on the test data: 910.3567047412886
# Perplexity of the 499 BackoffSmoothing model on the test data: 570.2901065472764
# Perplexity of the 500 BackoffSmoothing model on the test data: 2131.8009386432022
# Perplexity of the 501 BackoffSmoothing model on the test data: 1153.2254756320478
# Perplexity of the 502 BackoffSmoothing model on the test data: 1554.1936787709383
# Perplexity of the 503 BackoffSmoothing model on the test data: 717.7752172056224
# Perplexity of the 504 BackoffSmoothing model on the test data: 1140.0698614936389
# Perplexity of the 505 BackoffSmoothing model on the test data: 1015.142529540498
# Perplexity of the 506 BackoffSmoothing model on the test data: 1159.7865435678482
# Perplexity of the 507 BackoffSmoothing model on the test data: 1610.6188741726476
# Perplexity of the 508 BackoffSmoothing model on the test data: 817.1598865844725
# Perplexity of the 509 BackoffSmoothing model on the test data: 1835.9951393847446
# Perplexity of the 510 BackoffSmoothing model on the test data: 1019.0742613762526
# Perplexity of the 511 BackoffSmoothing model on the test data: 709.2465280638431
# Perplexity of the 512 BackoffSmoothing model on the test data: 1570.043210888121
# Perplexity of the 513 BackoffSmoothing model on the test data: 686.5775254277127
# Perplexity of the 514 BackoffSmoothing model on the test data: 1934.7232780546326
# Perplexity of the 515 BackoffSmoothing model on the test data: 864.6298597940039
# Perplexity of the 516 BackoffSmoothing model on the test data: 793.2177692723117
# Perplexity of the 517 BackoffSmoothing model on the test data: 1013.2370171178492
# Perplexity of the 518 BackoffSmoothing model on the test data: 921.3511437079801
# Perplexity of the 519 BackoffSmoothing model on the test data: 1219.5765799754968
# Perplexity of the 520 BackoffSmoothing model on the test data: 1242.5443014388127
# Perplexity of the 521 BackoffSmoothing model on the test data: 789.6839530951567
# Perplexity of the 522 BackoffSmoothing model on the test data: 1972.3804667901277
# Perplexity of the 523 BackoffSmoothing model on the test data: 1319.6489566778173
# Perplexity of the 524 BackoffSmoothing model on the test data: 1076.6569147937414
# Perplexity of the 525 BackoffSmoothing model on the test data: 858.5680214117299
# Perplexity of the 526 BackoffSmoothing model on the test data: 2149.293678613158
# Perplexity of the 527 BackoffSmoothing model on the test data: 1348.75193264847
# Perplexity of the 528 BackoffSmoothing model on the test data: 944.7554914980046
# Perplexity of the 529 BackoffSmoothing model on the test data: 1607.7681632245417
# Perplexity of the 530 BackoffSmoothing model on the test data: 836.5072330935815
# Perplexity of the 531 BackoffSmoothing model on the test data: 996.1524396869174
# Perplexity of the 532 BackoffSmoothing model on the test data: 695.2173186883878
# Perplexity of the 533 BackoffSmoothing model on the test data: 1203.3100595394205
# Perplexity of the 534 BackoffSmoothing model on the test data: 1482.972970817275
# Perplexity of the 535 BackoffSmoothing model on the test data: 778.4528200428745
# Perplexity of the 536 BackoffSmoothing model on the test data: 1387.8990735700386
# Perplexity of the 537 BackoffSmoothing model on the test data: 983.425062771846
# Perplexity of the 538 BackoffSmoothing model on the test data: 974.2817162511994
# Perplexity of the 539 BackoffSmoothing model on the test data: 2321.6312660867584
# Perplexity of the 540 BackoffSmoothing model on the test data: 919.6666127844439
# Perplexity of the 541 BackoffSmoothing model on the test data: 1561.6376898642695
# Perplexity of the 542 BackoffSmoothing model on the test data: 918.3279743719022
# Perplexity of the 543 BackoffSmoothing model on the test data: 1226.0877617358622
# Perplexity of the 544 BackoffSmoothing model on the test data: 1618.221932160517
# Perplexity of the 545 BackoffSmoothing model on the test data: 1304.2299429973473
# Perplexity of the 546 BackoffSmoothing model on the test data: 1632.7177071911094
# Perplexity of the 547 BackoffSmoothing model on the test data: 1227.2667850298349
# Perplexity of the 548 BackoffSmoothing model on the test data: 1708.4932485474587
# Perplexity of the 549 BackoffSmoothing model on the test data: 1374.2554464135494
# Perplexity of the 550 BackoffSmoothing model on the test data: 984.6865827495701
# Perplexity of the 551 BackoffSmoothing model on the test data: 2157.6623302813146
# Perplexity of the 552 BackoffSmoothing model on the test data: 1602.6408027323998
# Perplexity of the 553 BackoffSmoothing model on the test data: 336.0588195868558
# Perplexity of the 554 BackoffSmoothing model on the test data: 691.1558996727447
# Perplexity of the 555 BackoffSmoothing model on the test data: 918.0521155347187
# Perplexity of the 556 BackoffSmoothing model on the test data: 845.7970419641964
# Perplexity of the 557 BackoffSmoothing model on the test data: 1260.7123173893306
# Perplexity of the 558 BackoffSmoothing model on the test data: 1000.0249342682904
# Perplexity of the 559 BackoffSmoothing model on the test data: 855.2158584590406
# Perplexity of the 560 BackoffSmoothing model on the test data: 722.7308839133946
# Perplexity of the 561 BackoffSmoothing model on the test data: 2304.0757331198315
# Perplexity of the 562 BackoffSmoothing model on the test data: 1311.886622489574
# Perplexity of the 563 BackoffSmoothing model on the test data: 885.5244381786765
# Perplexity of the 564 BackoffSmoothing model on the test data: 982.506579067801
# Perplexity of the 565 BackoffSmoothing model on the test data: 1283.9267272870973
# Perplexity of the 566 BackoffSmoothing model on the test data: 560.6145408147604
# Perplexity of the 567 BackoffSmoothing model on the test data: 1515.066221635504
# Perplexity of the 568 BackoffSmoothing model on the test data: 1536.0308531203907
# Perplexity of the 569 BackoffSmoothing model on the test data: 742.0669852494732
# Perplexity of the 570 BackoffSmoothing model on the test data: 1449.509433668541
# Perplexity of the 571 BackoffSmoothing model on the test data: 1063.0250379247125
# Perplexity of the 572 BackoffSmoothing model on the test data: 1075.4279194943133
# Perplexity of the 573 BackoffSmoothing model on the test data: 748.11092296083
# Perplexity of the 574 BackoffSmoothing model on the test data: 1527.3414058838566
# Perplexity of the 575 BackoffSmoothing model on the test data: 982.3263316272404
# Perplexity of the 576 BackoffSmoothing model on the test data: 1265.3484018480565
# Perplexity of the 577 BackoffSmoothing model on the test data: 761.6189137801479
# Perplexity of the 578 BackoffSmoothing model on the test data: 1665.0797265141803
# Perplexity of the 579 BackoffSmoothing model on the test data: 915.9365600882849
# Perplexity of the 580 BackoffSmoothing model on the test data: 1739.7387417460234
# Perplexity of the 581 BackoffSmoothing model on the test data: 869.6590489509356
# Perplexity of the 582 BackoffSmoothing model on the test data: 1329.8949840980315
# Perplexity of the 583 BackoffSmoothing model on the test data: 1427.1156968739315
# Perplexity of the 584 BackoffSmoothing model on the test data: 906.1743889845936
# Perplexity of the 585 BackoffSmoothing model on the test data: 2100.6388203695465
# Perplexity of the 586 BackoffSmoothing model on the test data: 3766.6921511625014
# Perplexity of the 587 BackoffSmoothing model on the test data: 1238.9316769600873
# Perplexity of the 588 BackoffSmoothing model on the test data: 893.9129976973685
# Perplexity of the 589 BackoffSmoothing model on the test data: 1256.4527949182188
# ...
# Perplexity of the 1451 BackoffSmoothing model on the test data: 1185.2399189398936
# Perplexity of the 1452 BackoffSmoothing model on the test data: 850.6403399349698
# Perplexity of the 1453 BackoffSmoothing model on the test data: 1559.273095828448
# Perplexity of the 1454 BackoffSmoothing model on the test data: 2451.264476133795
# Perplexity of the 1455 BackoffSmoothing model on the test data: 954.5516615579232
# Perplexity of the 1456 BackoffSmoothing model on the test data: 1741.8016036765232
# Perplexity of the 1457 BackoffSmoothing model on the test data: 6329.910553456855
# Perplexity of the 1458 BackoffSmoothing model on the test data: 358.18953530145905
# Perplexity of the 1459 BackoffSmoothing model on the test data: 1694.958296763801
# Perplexity of the 1460 BackoffSmoothing model on the test data: 732.9666237172002
# Perplexity of the 1461 BackoffSmoothing model on the test data: 1361.713588880366
# Perplexity of the 1462 BackoffSmoothing model on the test data: 540.1097233201551
# Perplexity of the 1463 BackoffSmoothing model on the test data: 888.8812354424138
# Perplexity of the 1464 BackoffSmoothing model on the test data: 1335.2641776830424
# Perplexity of the 1465 BackoffSmoothing model on the test data: 1073.460565097171
# Perplexity of the 1466 BackoffSmoothing model on the test data: 8041.826543047793
# Perplexity of the 1467 BackoffSmoothing model on the test data: 1479.2167971739211
# Perplexity of the 1468 BackoffSmoothing model on the test data: 1407.1425280695369
# Perplexity of the 1469 BackoffSmoothing model on the test data: 1883.3724324837026
# Perplexity of the 1470 BackoffSmoothing model on the test data: 1257.0305861960362
# Perplexity of the 1471 BackoffSmoothing model on the test data: 1127.5046085766312
# Perplexity of the 1472 BackoffSmoothing model on the test data: 1230.5730295474618
# Perplexity of the 1473 BackoffSmoothing model on the test data: 1324.5014068502733
# Perplexity of the 1474 BackoffSmoothing model on the test data: 1203.5190157579548
# Perplexity of the 1475 BackoffSmoothing model on the test data: 759.6083747833248
# Perplexity of the 1476 BackoffSmoothing model on the test data: 443.75278899362115
# Perplexity of the 1477 BackoffSmoothing model on the test data: 1009.2112992854014
# Perplexity of the 1478 BackoffSmoothing model on the test data: 1047.1372601381995
# Perplexity of the 1479 BackoffSmoothing model on the test data: 1027.0545733041884
# Perplexity of the 1480 BackoffSmoothing model on the test data: 1927.126133609509
# Perplexity of the 1481 BackoffSmoothing model on the test data: 1131.1124868446225
# Perplexity of the 1482 BackoffSmoothing model on the test data: 1314.7322572884739
# Perplexity of the 1483 BackoffSmoothing model on the test data: 1106.0282314270096
# Perplexity of the 1484 BackoffSmoothing model on the test data: 866.548896169052
# Perplexity of the 1485 BackoffSmoothing model on the test data: 937.9287012985951
# Perplexity of the 1486 BackoffSmoothing model on the test data: 1791.6933128831354
# Perplexity of the 1487 BackoffSmoothing model on the test data: 1017.4468197852384
# Perplexity of the 1488 BackoffSmoothing model on the test data: 1358.5641625774106
# Perplexity of the 1489 BackoffSmoothing model on the test data: 898.1991555359292
# Perplexity of the 1490 BackoffSmoothing model on the test data: 1376.041113053965
# Perplexity of the 1491 BackoffSmoothing model on the test data: 1171.344311209058
# Perplexity of the 1492 BackoffSmoothing model on the test data: 1033.0625578120857
# Perplexity of the 1493 BackoffSmoothing model on the test data: 840.3437374813809
# Perplexity of the 1494 BackoffSmoothing model on the test data: 1412.8682447960596
# Perplexity of the 1495 BackoffSmoothing model on the test data: 1091.0143596107384
# Perplexity of the 1496 BackoffSmoothing model on the test data: 1188.5105538409343
# Perplexity of the 1497 BackoffSmoothing model on the test data: 1315.6089600609516
# Perplexity of the 1498 BackoffSmoothing model on the test data: 1141.949947527106
# Perplexity of the 1499 BackoffSmoothing model on the test data: 1426.0663391187027
# Perplexity of the 1500 BackoffSmoothing model on the test data: 1051.343456785207
# Perplexity of the 1501 BackoffSmoothing model on the test data: 447.74370603537005
# Perplexity of the 1502 BackoffSmoothing model on the test data: 869.9953366771333
# Perplexity of the 1503 BackoffSmoothing model on the test data: 1098.120723559503
# Perplexity of the 1504 BackoffSmoothing model on the test data: 981.0233429969635
# Perplexity of the 1505 BackoffSmoothing model on the test data: 1554.9720752394499
# Perplexity of the 1506 BackoffSmoothing model on the test data: 2193.2216771209123
# Perplexity of the 1507 BackoffSmoothing model on the test data: 824.3417738049984
# Perplexity of the 1508 BackoffSmoothing model on the test data: 812.7163826171152
# Perplexity of the 1509 BackoffSmoothing model on the test data: 718.1593310893126
# Perplexity of the 1510 BackoffSmoothing model on the test data: 1760.00189931074
# Perplexity of the 1511 BackoffSmoothing model on the test data: 1301.6685697471128
# Perplexity of the 1512 BackoffSmoothing model on the test data: 1530.3805961329042
# Perplexity of the 1513 BackoffSmoothing model on the test data: 1208.850935027573
# Perplexity of the 1514 BackoffSmoothing model on the test data: 810.4946314062738
# Perplexity of the 1515 BackoffSmoothing model on the test data: 877.5211752078728
# Perplexity of the 1516 BackoffSmoothing model on the test data: 728.7929308087824
# Perplexity of the 1517 BackoffSmoothing model on the test data: 1580.304480863068
# Perplexity of the 1518 BackoffSmoothing model on the test data: 968.321505792949
# Perplexity of the 1519 BackoffSmoothing model on the test data: 1119.9426847563002
# Perplexity of the 1520 BackoffSmoothing model on the test data: 1381.6856304744367
# Perplexity of the 1521 BackoffSmoothing model on the test data: 772.3264625221194
# Perplexity of the 1522 BackoffSmoothing model on the test data: 1669.6801524737568
# Perplexity of the 1523 BackoffSmoothing model on the test data: 699.7888428290996
# Perplexity of the 1524 BackoffSmoothing model on the test data: 1320.2839080407352
# Perplexity of the 1525 BackoffSmoothing model on the test data: 1380.0965951059661
# Perplexity of the 1526 BackoffSmoothing model on the test data: 1861.94480297554
# Perplexity of the 1527 BackoffSmoothing model on the test data: 1556.5816757728044
# Perplexity of the 1528 BackoffSmoothing model on the test data: 1951.3874026946764
# Perplexity of the 1529 BackoffSmoothing model on the test data: 749.3127621110277
# Perplexity of the 1530 BackoffSmoothing model on the test data: 1381.5570060901134
# Perplexity of the 1531 BackoffSmoothing model on the test data: 859.1520145693713
# Perplexity of the 1532 BackoffSmoothing model on the test data: 1810.7934213325052
# Perplexity of the 1533 BackoffSmoothing model on the test data: 1594.3513605520836
# Perplexity of the 1534 BackoffSmoothing model on the test data: 903.372313476229
# Perplexity of the 1535 BackoffSmoothing model on the test data: 1700.084912838868
# Perplexity of the 1536 BackoffSmoothing model on the test data: 1517.1368490351895
# Perplexity of the 1537 BackoffSmoothing model on the test data: 1026.8795179815163
# Perplexity of the 1538 BackoffSmoothing model on the test data: 1477.3796251487663
# Perplexity of the 1539 BackoffSmoothing model on the test data: 1273.2938067637542
# Perplexity of the 1540 BackoffSmoothing model on the test data: 1261.7585267369873
# Perplexity of the 1541 BackoffSmoothing model on the test data: 987.2641987809056
# Perplexity of the 1542 BackoffSmoothing model on the test data: 1800.209202274548
# Perplexity of the 1543 BackoffSmoothing model on the test data: 1219.440301863693
# Perplexity of the 1544 BackoffSmoothing model on the test data: 960.4247528132531
# Perplexity of the 1545 BackoffSmoothing model on the test data: 1574.6123155875714
# Perplexity of the 1546 BackoffSmoothing model on the test data: 1106.7673940263314
# Perplexity of the 1547 BackoffSmoothing model on the test data: 1047.4864967638198
# Perplexity of the 1548 BackoffSmoothing model on the test data: 1844.9490754229778
# Perplexity of the 1549 BackoffSmoothing model on the test data: 729.9004783552175
# Perplexity of the 1550 BackoffSmoothing model on the test data: 2645.397769498153
# Perplexity of the 1551 BackoffSmoothing model on the test data: 1360.5497681814763
# Perplexity of the 1552 BackoffSmoothing model on the test data: 1092.0688202919546
# Perplexity of the 1553 BackoffSmoothing model on the test data: 1718.0898459713208
# Perplexity of the 1554 BackoffSmoothing model on the test data: 1430.7172883755916
# Perplexity of the 1555 BackoffSmoothing model on the test data: 1039.0108655013382
# Perplexity of the 1556 BackoffSmoothing model on the test data: 1440.4557516525147
# Perplexity of the 1557 BackoffSmoothing model on the test data: 852.7912968326198
# Perplexity of the 1558 BackoffSmoothing model on the test data: 1197.5444366579602
# Perplexity of the 1559 BackoffSmoothing model on the test data: 1223.6756833821564
# Perplexity of the 1560 BackoffSmoothing model on the test data: 635.0609520344331
# Perplexity of the 1561 BackoffSmoothing model on the test data: 2862.7788516790733
# Perplexity of the 1562 BackoffSmoothing model on the test data: 816.4166710180183
# Perplexity of the 1563 BackoffSmoothing model on the test data: 1298.8603996661227
# Perplexity of the 1564 BackoffSmoothing model on the test data: 772.1831984383837
# Perplexity of the 1565 BackoffSmoothing model on the test data: 649.8985839355001
# Perplexity of the 1566 BackoffSmoothing model on the test data: 1550.6732605654222
# Perplexity of the 1567 BackoffSmoothing model on the test data: 1102.2551620508086
# Perplexity of the 1568 BackoffSmoothing model on the test data: 1532.143094749001
# Perplexity of the 1569 BackoffSmoothing model on the test data: 937.3488660794492
# Perplexity of the 1570 BackoffSmoothing model on the test data: 819.0812278952442
# Perplexity of the 1571 BackoffSmoothing model on the test data: 1653.9254454179488
# Perplexity of the 1572 BackoffSmoothing model on the test data: 1507.9860476032106
# Perplexity of the 1573 BackoffSmoothing model on the test data: 978.9786667783496
# Perplexity of the 1574 BackoffSmoothing model on the test data: 1199.7895785486078
# Perplexity of the 1575 BackoffSmoothing model on the test data: 1516.4582015041326
# Perplexity of the 1576 BackoffSmoothing model on the test data: 668.4744375390876
# Perplexity of the 1577 BackoffSmoothing model on the test data: 1316.068299019931
# Perplexity of the 1578 BackoffSmoothing model on the test data: 1802.309554114736
# Perplexity of the 1579 BackoffSmoothing model on the test data: 1726.4745884866466
# Perplexity of the 1580 BackoffSmoothing model on the test data: 932.3790173518663
# Perplexity of the 1581 BackoffSmoothing model on the test data: 1688.4859407234144
# Perplexity of the 1582 BackoffSmoothing model on the test data: 1013.5864138113069
# Perplexity of the 1583 BackoffSmoothing model on the test data: 493.1094587433131
# Perplexity of the 1584 BackoffSmoothing model on the test data: 1311.635594881389
# Perplexity of the 1585 BackoffSmoothing model on the test data: 1631.180042095653
# Perplexity of the 1586 BackoffSmoothing model on the test data: 1590.2075302388523
# Perplexity of the 1587 BackoffSmoothing model on the test data: 1088.4262885191813
# Perplexity of the 1588 BackoffSmoothing model on the test data: 1315.8556888182172
# Perplexity of the 1589 BackoffSmoothing model on the test data: 1074.5206333208898
# Perplexity of the 1590 BackoffSmoothing model on the test data: 810.1549107773357
# Perplexity of the 1591 BackoffSmoothing model on the test data: 1551.2153722752923
# Perplexity of the 1592 BackoffSmoothing model on the test data: 900.3272758425112
# Perplexity of the 1593 BackoffSmoothing model on the test data: 1483.2418227563587
# Perplexity of the 1594 BackoffSmoothing model on the test data: 789.9955659657851
# Perplexity of the 1595 BackoffSmoothing model on the test data: 843.5002484667637
# Perplexity of the 1596 BackoffSmoothing model on the test data: 1151.5296484789048
# Perplexity of the 1597 BackoffSmoothing model on the test data: 679.0877264566291
# Perplexity of the 1598 BackoffSmoothing model on the test data: 1413.551548474102
# Perplexity of the 1599 BackoffSmoothing model on the test data: 1557.426459786804
# Perplexity of the 1600 BackoffSmoothing model on the test data: 1208.9722009374464
# Perplexity of the 1601 BackoffSmoothing model on the test data: 2783.4644463640516
# Perplexity of the 1602 BackoffSmoothing model on the test data: 584.1475851556457
# Perplexity of the 1603 BackoffSmoothing model on the test data: 1816.593209308597
# Perplexity of the 1604 BackoffSmoothing model on the test data: 1676.633755506776
# Perplexity of the 1605 BackoffSmoothing model on the test data: 1007.7137016221916
# Perplexity of the 1606 BackoffSmoothing model on the test data: 1234.5450402156625
# Perplexity of the 1607 BackoffSmoothing model on the test data: 2404.1933175660906
# Perplexity of the 1608 BackoffSmoothing model on the test data: 1238.2669820198303
# Perplexity of the 1609 BackoffSmoothing model on the test data: 628.7636492086085
# Perplexity of the 1610 BackoffSmoothing model on the test data: 1077.3296987395295
# Perplexity of the 1611 BackoffSmoothing model on the test data: 669.0353538496198
# Perplexity of the 1612 BackoffSmoothing model on the test data: 1977.4790919253865
# Perplexity of the 1613 BackoffSmoothing model on the test data: 1097.8480274136937
# Perplexity of the 1614 BackoffSmoothing model on the test data: 1298.2898017445666
# Perplexity of the 1615 BackoffSmoothing model on the test data: 1259.3639970748907
# Perplexity of the 1616 BackoffSmoothing model on the test data: 1151.8606871933403
# Perplexity of the 1617 BackoffSmoothing model on the test data: 1308.5174227853536
# Perplexity of the 1618 BackoffSmoothing model on the test data: 970.5045878536432
# Perplexity of the 1619 BackoffSmoothing model on the test data: 928.376372532166
# Perplexity of the 1620 BackoffSmoothing model on the test data: 1046.0180066683824
# Perplexity of the 1621 BackoffSmoothing model on the test data: 1521.1781485897773
# Perplexity of the 1622 BackoffSmoothing model on the test data: 1466.3176142291122
# Perplexity of the 1623 BackoffSmoothing model on the test data: 638.5577314644905
# Perplexity of the 1624 BackoffSmoothing model on the test data: 1363.616548649808
# Perplexity of the 1625 BackoffSmoothing model on the test data: 1196.6560129578625
# Perplexity of the 1626 BackoffSmoothing model on the test data: 1335.6269949540233
# Perplexity of the 1627 BackoffSmoothing model on the test data: 1183.310491892308
# Perplexity of the 1628 BackoffSmoothing model on the test data: 1805.664774062642
# Perplexity of the 1629 BackoffSmoothing model on the test data: 1032.5098446978652
# Perplexity of the 1630 BackoffSmoothing model on the test data: 587.6953910724039
# Perplexity of the 1631 BackoffSmoothing model on the test data: 988.5705427589331
# Perplexity of the 1632 BackoffSmoothing model on the test data: 1177.880893740688
# Perplexity of the 1633 BackoffSmoothing model on the test data: 1663.0915097055974
# Perplexity of the 1634 BackoffSmoothing model on the test data: 1439.5321420798225
# Perplexity of the 1635 BackoffSmoothing model on the test data: 1287.414905766924
# Perplexity of the 1636 BackoffSmoothing model on the test data: 1287.8518812738082
# Perplexity of the 1637 BackoffSmoothing model on the test data: 1077.6870769217767
# Perplexity of the 1638 BackoffSmoothing model on the test data: 899.2256450287684
# Perplexity of the 1639 BackoffSmoothing model on the test data: 1402.9986362540453
# Perplexity of the 1640 BackoffSmoothing model on the test data: 1056.1878587552903
# Perplexity of the 1641 BackoffSmoothing model on the test data: 2387.7384355379722
# Perplexity of the 1642 BackoffSmoothing model on the test data: 3639.615062219992
# Perplexity of the 1643 BackoffSmoothing model on the test data: 1028.1331334734398

# %%
# bigrams
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(2, 0.1)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 70.5227469349564
# Perplexity of the 1 BackoffSmoothing model on the test data: 49.65286204618913
# Perplexity of the 2 BackoffSmoothing model on the test data: 48.858444156159024
# Perplexity of the 3 BackoffSmoothing model on the test data: 52.06183351233344
# Perplexity of the 4 BackoffSmoothing model on the test data: 38.01476634405145
# Perplexity of the 5 BackoffSmoothing model on the test data: 34.2079527029678
# Perplexity of the 6 BackoffSmoothing model on the test data: 60.21352797187265
# Perplexity of the 7 BackoffSmoothing model on the test data: 72.54333430932572
# Perplexity of the 8 BackoffSmoothing model on the test data: 67.63028622248548
# Perplexity of the 9 BackoffSmoothing model on the test data: 60.015126881363486
# Perplexity of the 10 BackoffSmoothing model on the test data: 55.36632085250772
# Perplexity of the 11 BackoffSmoothing model on the test data: 49.95851239946242
# Perplexity of the 12 BackoffSmoothing model on the test data: 60.49217318185319
# Perplexity of the 13 BackoffSmoothing model on the test data: 43.82079094122579
# Perplexity of the 14 BackoffSmoothing model on the test data: 47.891571307007155
# Perplexity of the 15 BackoffSmoothing model on the test data: 50.873168537483174
# Perplexity of the 16 BackoffSmoothing model on the test data: 54.92251586475781
# Perplexity of the 17 BackoffSmoothing model on the test data: 47.90919937499068
# Perplexity of the 18 BackoffSmoothing model on the test data: 67.60315425920035
# Perplexity of the 19 BackoffSmoothing model on the test data: 38.459379348876105
# Perplexity of the 20 BackoffSmoothing model on the test data: 52.39826702283033
# Perplexity of the 21 BackoffSmoothing model on the test data: 32.14590621703547
# Perplexity of the 22 BackoffSmoothing model on the test data: 37.553994013436444
# Perplexity of the 23 BackoffSmoothing model on the test data: 53.04611271014532
# Perplexity of the 24 BackoffSmoothing model on the test data: 44.151996961522464
# Perplexity of the 25 BackoffSmoothing model on the test data: 42.3446822161567
# Perplexity of the 26 BackoffSmoothing model on the test data: 68.20991371833482
# Perplexity of the 27 BackoffSmoothing model on the test data: 76.58784121010457
# Perplexity of the 28 BackoffSmoothing model on the test data: 55.11389400027911
# Perplexity of the 29 BackoffSmoothing model on the test data: 39.13230707696577
# Perplexity of the 30 BackoffSmoothing model on the test data: 46.281765319730525
# Perplexity of the 31 BackoffSmoothing model on the test data: 44.85747523231762
# Perplexity of the 32 BackoffSmoothing model on the test data: 44.07535372810699
# Perplexity of the 33 BackoffSmoothing model on the test data: 20.555686596508007
# Perplexity of the 34 BackoffSmoothing model on the test data: 50.46070893717719
# Perplexity of the 35 BackoffSmoothing model on the test data: 41.78003478613884
# Perplexity of the 36 BackoffSmoothing model on the test data: 29.917150526003752
# Perplexity of the 37 BackoffSmoothing model on the test data: 48.69233777939427
# Perplexity of the 38 BackoffSmoothing model on the test data: 45.91610680300944
# Perplexity of the 39 BackoffSmoothing model on the test data: 36.75541555808294
# Perplexity of the 40 BackoffSmoothing model on the test data: 54.08444613084772
# Perplexity of the 41 BackoffSmoothing model on the test data: 51.633254319875796
# Perplexity of the 42 BackoffSmoothing model on the test data: 53.67796769100755
# Perplexity of the 43 BackoffSmoothing model on the test data: 62.11252540686648
# Perplexity of the 44 BackoffSmoothing model on the test data: 36.661224204311026
# Perplexity of the 45 BackoffSmoothing model on the test data: 57.95759910577451
# Perplexity of the 46 BackoffSmoothing model on the test data: 50.6558701761916
# Perplexity of the 47 BackoffSmoothing model on the test data: 53.32212350333818
# Perplexity of the 48 BackoffSmoothing model on the test data: 54.82281414901168
# Perplexity of the 49 BackoffSmoothing model on the test data: 48.577598698224605
# Perplexity of the 50 BackoffSmoothing model on the test data: 28.590088690877657
# Perplexity of the 51 BackoffSmoothing model on the test data: 28.22035520182178
# Perplexity of the 52 BackoffSmoothing model on the test data: 55.51016573327193
# Perplexity of the 53 BackoffSmoothing model on the test data: 58.22559180914884
# Perplexity of the 54 BackoffSmoothing model on the test data: 62.03469780622148
# Perplexity of the 55 BackoffSmoothing model on the test data: 53.790262623718334
# Perplexity of the 56 BackoffSmoothing model on the test data: 49.016471970126986
# Perplexity of the 57 BackoffSmoothing model on the test data: 38.09646775820909
# Perplexity of the 58 BackoffSmoothing model on the test data: 45.070250631178006
# Perplexity of the 59 BackoffSmoothing model on the test data: 37.88910200970941
# Perplexity of the 60 BackoffSmoothing model on the test data: 48.90810680465628
# Perplexity of the 61 BackoffSmoothing model on the test data: 53.296397802230466
# Perplexity of the 62 BackoffSmoothing model on the test data: 25.129817852237444
# Perplexity of the 63 BackoffSmoothing model on the test data: 53.33516967328406
# Perplexity of the 64 BackoffSmoothing model on the test data: 42.56377333914199
# Perplexity of the 65 BackoffSmoothing model on the test data: 40.48975509089964
# Perplexity of the 66 BackoffSmoothing model on the test data: 59.21632913538041
# Perplexity of the 67 BackoffSmoothing model on the test data: 26.361793857114726
# Perplexity of the 68 BackoffSmoothing model on the test data: 39.046441082398346
# Perplexity of the 69 BackoffSmoothing model on the test data: 50.40037311034254
# Perplexity of the 70 BackoffSmoothing model on the test data: 25.959445409836157
# Perplexity of the 71 BackoffSmoothing model on the test data: 39.612817209808455
# Perplexity of the 72 BackoffSmoothing model on the test data: 66.88590771742062
# Perplexity of the 73 BackoffSmoothing model on the test data: 61.813509093368246
# Perplexity of the 74 BackoffSmoothing model on the test data: 49.72584279166203
# Perplexity of the 75 BackoffSmoothing model on the test data: 45.6929325932239
# Perplexity of the 76 BackoffSmoothing model on the test data: 38.60157489208914
# Perplexity of the 77 BackoffSmoothing model on the test data: 61.58981583094852
# Perplexity of the 78 BackoffSmoothing model on the test data: 51.04269996310847
# Perplexity of the 79 BackoffSmoothing model on the test data: 18.34383239034479
# Perplexity of the 80 BackoffSmoothing model on the test data: 46.595316345432785
# Perplexity of the 81 BackoffSmoothing model on the test data: 43.890940053430505
# Perplexity of the 82 BackoffSmoothing model on the test data: 42.477248018975295
# Perplexity of the 83 BackoffSmoothing model on the test data: 48.66829117190362
# Perplexity of the 84 BackoffSmoothing model on the test data: 24.549254110509647
# Perplexity of the 85 BackoffSmoothing model on the test data: 41.82051375693724
# Perplexity of the 86 BackoffSmoothing model on the test data: 45.22064494185065
# Perplexity of the 87 BackoffSmoothing model on the test data: 48.413355832228476
# Perplexity of the 88 BackoffSmoothing model on the test data: 39.71897721830322
# Perplexity of the 89 BackoffSmoothing model on the test data: 40.96615518941503
# Perplexity of the 90 BackoffSmoothing model on the test data: 36.34757695133041
# Perplexity of the 91 BackoffSmoothing model on the test data: 50.893930187555654
# Perplexity of the 92 BackoffSmoothing model on the test data: 62.6786902982675
# Perplexity of the 93 BackoffSmoothing model on the test data: 56.703733896840525
# Perplexity of the 94 BackoffSmoothing model on the test data: 53.656094542914246
# Perplexity of the 95 BackoffSmoothing model on the test data: 26.021399103010644
# Perplexity of the 96 BackoffSmoothing model on the test data: 76.5086185325871
# Perplexity of the 97 BackoffSmoothing model on the test data: 51.991988264613084
# Perplexity of the 98 BackoffSmoothing model on the test data: 47.50907960849164
# Perplexity of the 99 BackoffSmoothing model on the test data: 54.93343345126368
# Perplexity of the 100 BackoffSmoothing model on the test data: 41.9331222203649
# Perplexity of the 101 BackoffSmoothing model on the test data: 33.62106728986184
# Perplexity of the 102 BackoffSmoothing model on the test data: 60.24946488786699
# Perplexity of the 103 BackoffSmoothing model on the test data: 48.48589821894308
# Perplexity of the 104 BackoffSmoothing model on the test data: 45.76370446067039
# Perplexity of the 105 BackoffSmoothing model on the test data: 41.881987472045545
# Perplexity of the 106 BackoffSmoothing model on the test data: 30.983490995407298
# Perplexity of the 107 BackoffSmoothing model on the test data: 48.78299453721412
# Perplexity of the 108 BackoffSmoothing model on the test data: 47.668696651962165
# Perplexity of the 109 BackoffSmoothing model on the test data: 50.88997427009465
# Perplexity of the 110 BackoffSmoothing model on the test data: 45.13025006447911
# Perplexity of the 111 BackoffSmoothing model on the test data: 41.018195054946844
# Perplexity of the 112 BackoffSmoothing model on the test data: 32.85970160054039
# Perplexity of the 113 BackoffSmoothing model on the test data: 58.190624277190366
# Perplexity of the 114 BackoffSmoothing model on the test data: 53.76104056526398
# Perplexity of the 115 BackoffSmoothing model on the test data: 46.57865765073866
# Perplexity of the 116 BackoffSmoothing model on the test data: 45.18051419004945
# Perplexity of the 117 BackoffSmoothing model on the test data: 41.142823630763104
# Perplexity of the 118 BackoffSmoothing model on the test data: 46.74632291602601
# Perplexity of the 119 BackoffSmoothing model on the test data: 40.041367351279334
# Perplexity of the 120 BackoffSmoothing model on the test data: 60.52612887314292
# Perplexity of the 121 BackoffSmoothing model on the test data: 44.7904041602341
# Perplexity of the 122 BackoffSmoothing model on the test data: 61.8797472694168
# Perplexity of the 123 BackoffSmoothing model on the test data: 47.700504589144494
# Perplexity of the 124 BackoffSmoothing model on the test data: 33.40224735310958
# Perplexity of the 125 BackoffSmoothing model on the test data: 52.84292876818046
# Perplexity of the 126 BackoffSmoothing model on the test data: 53.508443451426984
# Perplexity of the 127 BackoffSmoothing model on the test data: 43.26846118552854
# Perplexity of the 128 BackoffSmoothing model on the test data: 44.27747708017627
# Perplexity of the 129 BackoffSmoothing model on the test data: 44.37212029680765
# Perplexity of the 130 BackoffSmoothing model on the test data: 49.14933930817949
# Perplexity of the 131 BackoffSmoothing model on the test data: 27.10683523377658
# Perplexity of the 132 BackoffSmoothing model on the test data: 60.3551060117839
# Perplexity of the 133 BackoffSmoothing model on the test data: 37.02532623722466
# Perplexity of the 134 BackoffSmoothing model on the test data: 46.79117841041052
# Perplexity of the 135 BackoffSmoothing model on the test data: 54.72765546477479
# Perplexity of the 136 BackoffSmoothing model on the test data: 52.76837759016939
# Perplexity of the 137 BackoffSmoothing model on the test data: 34.949287513632676
# Perplexity of the 138 BackoffSmoothing model on the test data: 45.11112681365061
# Perplexity of the 139 BackoffSmoothing model on the test data: 28.92213820019296
# Perplexity of the 140 BackoffSmoothing model on the test data: 43.62262161368456
# Perplexity of the 141 BackoffSmoothing model on the test data: 63.69745749010928
# Perplexity of the 142 BackoffSmoothing model on the test data: 49.37848577652523
# Perplexity of the 143 BackoffSmoothing model on the test data: 40.94212739732225
# Perplexity of the 144 BackoffSmoothing model on the test data: 54.859518732272704
# Perplexity of the 145 BackoffSmoothing model on the test data: 56.05132805297892
# Perplexity of the 146 BackoffSmoothing model on the test data: 42.802050354795945
# Perplexity of the 147 BackoffSmoothing model on the test data: 67.54851075454621
# Perplexity of the 148 BackoffSmoothing model on the test data: 42.51120134994838
# Perplexity of the 149 BackoffSmoothing model on the test data: 37.677399957427575
# Perplexity of the 150 BackoffSmoothing model on the test data: 67.34461517093072
# Perplexity of the 151 BackoffSmoothing model on the test data: 54.473191976279416
# Perplexity of the 152 BackoffSmoothing model on the test data: 41.93042864232422
# Perplexity of the 153 BackoffSmoothing model on the test data: 46.09898741764596
# Perplexity of the 154 BackoffSmoothing model on the test data: 65.31518035492378
# Perplexity of the 155 BackoffSmoothing model on the test data: 47.64299124568467
# Perplexity of the 156 BackoffSmoothing model on the test data: 45.689835384729214
# Perplexity of the 157 BackoffSmoothing model on the test data: 32.889909533750085
# Perplexity of the 158 BackoffSmoothing model on the test data: 29.604945431400996
# Perplexity of the 159 BackoffSmoothing model on the test data: 50.00800312534312
# Perplexity of the 160 BackoffSmoothing model on the test data: 65.63519933646477
# Perplexity of the 161 BackoffSmoothing model on the test data: 36.52370176650491
# Perplexity of the 162 BackoffSmoothing model on the test data: 48.40537203277136
# Perplexity of the 163 BackoffSmoothing model on the test data: 22.2373141266818
# Perplexity of the 164 BackoffSmoothing model on the test data: 65.07871419877058
# Perplexity of the 165 BackoffSmoothing model on the test data: 60.902865134016146
# Perplexity of the 166 BackoffSmoothing model on the test data: 53.20381383524548
# Perplexity of the 167 BackoffSmoothing model on the test data: 40.53333684485733
# Perplexity of the 168 BackoffSmoothing model on the test data: 47.57175612121579
# Perplexity of the 169 BackoffSmoothing model on the test data: 58.64946483304171
# Perplexity of the 170 BackoffSmoothing model on the test data: 44.279990030138016
# Perplexity of the 171 BackoffSmoothing model on the test data: 59.71966382073629
# Perplexity of the 172 BackoffSmoothing model on the test data: 57.65695625372355
# Perplexity of the 173 BackoffSmoothing model on the test data: 55.17718681930277
# Perplexity of the 174 BackoffSmoothing model on the test data: 51.890778114243496
# Perplexity of the 175 BackoffSmoothing model on the test data: 51.83239880800932
# Perplexity of the 176 BackoffSmoothing model on the test data: 50.53194568604704
# Perplexity of the 177 BackoffSmoothing model on the test data: 56.864302094518834
# Perplexity of the 178 BackoffSmoothing model on the test data: 42.411286767779934
# Perplexity of the 179 BackoffSmoothing model on the test data: 75.12036120288828
# Perplexity of the 180 BackoffSmoothing model on the test data: 42.5135984896402
# Perplexity of the 181 BackoffSmoothing model on the test data: 46.29703014569412
# Perplexity of the 182 BackoffSmoothing model on the test data: 34.17720813427632
# Perplexity of the 183 BackoffSmoothing model on the test data: 57.95089213326559
# Perplexity of the 184 BackoffSmoothing model on the test data: 56.44748488954244
# Perplexity of the 185 BackoffSmoothing model on the test data: 32.626029599646465
# Perplexity of the 186 BackoffSmoothing model on the test data: 51.00596758987101
# Perplexity of the 187 BackoffSmoothing model on the test data: 75.57693135989155
# Perplexity of the 188 BackoffSmoothing model on the test data: 56.46366527202797
# Perplexity of the 189 BackoffSmoothing model on the test data: 50.78102205923566
# Perplexity of the 190 BackoffSmoothing model on the test data: 59.264175655629394
# Perplexity of the 191 BackoffSmoothing model on the test data: 62.278374022919195
# Perplexity of the 192 BackoffSmoothing model on the test data: 53.26937174459797
# Perplexity of the 193 BackoffSmoothing model on the test data: 48.38012578059363
# Perplexity of the 194 BackoffSmoothing model on the test data: 63.1932989001565
# Perplexity of the 195 BackoffSmoothing model on the test data: 46.18588882991437
# Perplexity of the 196 BackoffSmoothing model on the test data: 41.76135421265882
# Perplexity of the 197 BackoffSmoothing model on the test data: 43.409951623290354
# Perplexity of the 198 BackoffSmoothing model on the test data: 29.940754439655024
# Perplexity of the 199 BackoffSmoothing model on the test data: 53.32385214394694
# Perplexity of the 200 BackoffSmoothing model on the test data: 52.875170063510446
# Perplexity of the 201 BackoffSmoothing model on the test data: 67.67618073830484
# Perplexity of the 202 BackoffSmoothing model on the test data: 52.463439156165094
# Perplexity of the 203 BackoffSmoothing model on the test data: 27.163497752061982
# Perplexity of the 204 BackoffSmoothing model on the test data: 62.307252349351515
# Perplexity of the 205 BackoffSmoothing model on the test data: 53.536625821608745
# Perplexity of the 206 BackoffSmoothing model on the test data: 42.603434933961154
# Perplexity of the 207 BackoffSmoothing model on the test data: 55.45796254942879
# Perplexity of the 208 BackoffSmoothing model on the test data: 43.44317210242584
# Perplexity of the 209 BackoffSmoothing model on the test data: 42.00799894885674
# Perplexity of the 210 BackoffSmoothing model on the test data: 50.241270134095146
# Perplexity of the 211 BackoffSmoothing model on the test data: 26.20416014630979
# Perplexity of the 212 BackoffSmoothing model on the test data: 57.892804924082704
# Perplexity of the 213 BackoffSmoothing model on the test data: 46.53051064135986
# Perplexity of the 214 BackoffSmoothing model on the test data: 44.8938233242058
# Perplexity of the 215 BackoffSmoothing model on the test data: 52.570240187593335
# Perplexity of the 216 BackoffSmoothing model on the test data: 68.8272952393614
# Perplexity of the 217 BackoffSmoothing model on the test data: 43.95165520974053
# Perplexity of the 218 BackoffSmoothing model on the test data: 34.13467617441875
# Perplexity of the 219 BackoffSmoothing model on the test data: 53.081827885930196
# Perplexity of the 220 BackoffSmoothing model on the test data: 58.883096429778284
# Perplexity of the 221 BackoffSmoothing model on the test data: 52.41498535689613
# Perplexity of the 222 BackoffSmoothing model on the test data: 30.781225240424778
# Perplexity of the 223 BackoffSmoothing model on the test data: 79.66354692479523
# Perplexity of the 224 BackoffSmoothing model on the test data: 67.94159444849264
# Perplexity of the 225 BackoffSmoothing model on the test data: 54.2270894720321
# Perplexity of the 226 BackoffSmoothing model on the test data: 53.517489219523455
# Perplexity of the 227 BackoffSmoothing model on the test data: 51.726436903687635
# Perplexity of the 228 BackoffSmoothing model on the test data: 44.45393309145763
# Perplexity of the 229 BackoffSmoothing model on the test data: 55.05103055490988
# Perplexity of the 230 BackoffSmoothing model on the test data: 35.22482682030691
# Perplexity of the 231 BackoffSmoothing model on the test data: 58.65828609114117
# Perplexity of the 232 BackoffSmoothing model on the test data: 44.87000583398302
# Perplexity of the 233 BackoffSmoothing model on the test data: 59.256328429376616
# Perplexity of the 234 BackoffSmoothing model on the test data: 62.71895148875461
# Perplexity of the 235 BackoffSmoothing model on the test data: 47.890554637436054
# Perplexity of the 236 BackoffSmoothing model on the test data: 57.98872250291344
# Perplexity of the 237 BackoffSmoothing model on the test data: 56.22953745669708
# Perplexity of the 238 BackoffSmoothing model on the test data: 37.75228591152453
# Perplexity of the 239 BackoffSmoothing model on the test data: 47.121654617785055
# Perplexity of the 240 BackoffSmoothing model on the test data: 56.034480531859934
# Perplexity of the 241 BackoffSmoothing model on the test data: 52.2239615831989
# Perplexity of the 242 BackoffSmoothing model on the test data: 43.280310418138754
# Perplexity of the 243 BackoffSmoothing model on the test data: 26.16053686767809
# Perplexity of the 244 BackoffSmoothing model on the test data: 36.62549611046188
# Perplexity of the 245 BackoffSmoothing model on the test data: 48.54168148637499
# Perplexity of the 246 BackoffSmoothing model on the test data: 48.134594873018905
# Perplexity of the 247 BackoffSmoothing model on the test data: 46.8440765894843
# Perplexity of the 248 BackoffSmoothing model on the test data: 37.593091901845185
# Perplexity of the 249 BackoffSmoothing model on the test data: 46.49318912212738
# Perplexity of the 250 BackoffSmoothing model on the test data: 51.515457305898494
# Perplexity of the 251 BackoffSmoothing model on the test data: 65.30016786518614
# Perplexity of the 252 BackoffSmoothing model on the test data: 56.732880166302984
# Perplexity of the 253 BackoffSmoothing model on the test data: 33.929667468821485
# Perplexity of the 254 BackoffSmoothing model on the test data: 61.540127287938006
# Perplexity of the 255 BackoffSmoothing model on the test data: 58.66674994386965
# Perplexity of the 256 BackoffSmoothing model on the test data: 44.631936639964536
# Perplexity of the 257 BackoffSmoothing model on the test data: 54.8782292618905
# Perplexity of the 258 BackoffSmoothing model on the test data: 49.314218578086866
# Perplexity of the 259 BackoffSmoothing model on the test data: 60.42392328623594
# Perplexity of the 260 BackoffSmoothing model on the test data: 25.19355588062775
# Perplexity of the 261 BackoffSmoothing model on the test data: 38.38547670199704
# Perplexity of the 262 BackoffSmoothing model on the test data: 62.631601630471636
# Perplexity of the 263 BackoffSmoothing model on the test data: 66.87961309628622
# Perplexity of the 264 BackoffSmoothing model on the test data: 42.37378181258229
# Perplexity of the 265 BackoffSmoothing model on the test data: 71.7326674920462
# Perplexity of the 266 BackoffSmoothing model on the test data: 42.019430000885166
# Perplexity of the 267 BackoffSmoothing model on the test data: 39.11346247483889
# Perplexity of the 268 BackoffSmoothing model on the test data: 14.536578647399073
# Perplexity of the 269 BackoffSmoothing model on the test data: 30.551938665076882
# Perplexity of the 270 BackoffSmoothing model on the test data: 33.96158807941542
# Perplexity of the 271 BackoffSmoothing model on the test data: 29.179430575054184
# Perplexity of the 272 BackoffSmoothing model on the test data: 25.166835830976588
# Perplexity of the 273 BackoffSmoothing model on the test data: 29.323797565807496
# Perplexity of the 274 BackoffSmoothing model on the test data: 43.35181180300318
# Perplexity of the 275 BackoffSmoothing model on the test data: 40.570051904515196
# Perplexity of the 276 BackoffSmoothing model on the test data: 50.87198916468422
# Perplexity of the 277 BackoffSmoothing model on the test data: 57.47514522705027
# Perplexity of the 278 BackoffSmoothing model on the test data: 40.59017752770306
# Perplexity of the 279 BackoffSmoothing model on the test data: 38.385810930269535
# Perplexity of the 280 BackoffSmoothing model on the test data: 39.28512009215527
# Perplexity of the 281 BackoffSmoothing model on the test data: 41.06384412621665
# Perplexity of the 282 BackoffSmoothing model on the test data: 29.109075077321663
# Perplexity of the 283 BackoffSmoothing model on the test data: 26.767847183800114
# Perplexity of the 284 BackoffSmoothing model on the test data: 43.10736943512338
# Perplexity of the 285 BackoffSmoothing model on the test data: 43.16371702377581
# Perplexity of the 286 BackoffSmoothing model on the test data: 52.86719214589049
# Perplexity of the 287 BackoffSmoothing model on the test data: 46.36973611993539
# Perplexity of the 288 BackoffSmoothing model on the test data: 31.31940654729989
# Perplexity of the 289 BackoffSmoothing model on the test data: 63.34586508429323
# Perplexity of the 290 BackoffSmoothing model on the test data: 40.75902021841267
# Perplexity of the 291 BackoffSmoothing model on the test data: 40.56051386129767
# Perplexity of the 292 BackoffSmoothing model on the test data: 68.01128211805269
# Perplexity of the 293 BackoffSmoothing model on the test data: 49.29734437499936
# Perplexity of the 294 BackoffSmoothing model on the test data: 37.3205583670633
# Perplexity of the 295 BackoffSmoothing model on the test data: 53.73538160387256
# Perplexity of the 296 BackoffSmoothing model on the test data: 41.92959958249157
# Perplexity of the 297 BackoffSmoothing model on the test data: 33.715947553714
# Perplexity of the 298 BackoffSmoothing model on the test data: 47.70123214936946
# Perplexity of the 299 BackoffSmoothing model on the test data: 39.908016802422836
# Perplexity of the 300 BackoffSmoothing model on the test data: 57.934332456508315
# Perplexity of the 301 BackoffSmoothing model on the test data: 26.24786566833798
# Perplexity of the 302 BackoffSmoothing model on the test data: 30.978884627404156
# Perplexity of the 303 BackoffSmoothing model on the test data: 61.30899482041836
# Perplexity of the 304 BackoffSmoothing model on the test data: 43.27935772442437
# Perplexity of the 305 BackoffSmoothing model on the test data: 31.246935737852134
# Perplexity of the 306 BackoffSmoothing model on the test data: 51.595572170742635
# Perplexity of the 307 BackoffSmoothing model on the test data: 42.776110566414495
# Perplexity of the 308 BackoffSmoothing model on the test data: 47.462910782577815
# Perplexity of the 309 BackoffSmoothing model on the test data: 49.59845488411777
# Perplexity of the 310 BackoffSmoothing model on the test data: 35.15978091872435
# Perplexity of the 311 BackoffSmoothing model on the test data: 40.76950322511233
# Perplexity of the 312 BackoffSmoothing model on the test data: 46.0011914066151
# Perplexity of the 313 BackoffSmoothing model on the test data: 66.47485352892677
# Perplexity of the 314 BackoffSmoothing model on the test data: 20.972875208510786
# Perplexity of the 315 BackoffSmoothing model on the test data: 43.45100527828713
# Perplexity of the 316 BackoffSmoothing model on the test data: 46.68602270826875
# Perplexity of the 317 BackoffSmoothing model on the test data: 41.20258919037867
# Perplexity of the 318 BackoffSmoothing model on the test data: 46.63807628592087
# Perplexity of the 319 BackoffSmoothing model on the test data: 50.92997310392118
# Perplexity of the 320 BackoffSmoothing model on the test data: 56.96595987436359
# Perplexity of the 321 BackoffSmoothing model on the test data: 47.52212859742765
# Perplexity of the 322 BackoffSmoothing model on the test data: 57.54349070953172
# Perplexity of the 323 BackoffSmoothing model on the test data: 58.69149052720086
# Perplexity of the 324 BackoffSmoothing model on the test data: 38.92312952673063
# Perplexity of the 325 BackoffSmoothing model on the test data: 56.15782199136337
# Perplexity of the 326 BackoffSmoothing model on the test data: 38.81859657609955
# Perplexity of the 327 BackoffSmoothing model on the test data: 64.4128325819247
# Perplexity of the 328 BackoffSmoothing model on the test data: 54.85384442683792
# Perplexity of the 329 BackoffSmoothing model on the test data: 29.2015928967039
# Perplexity of the 330 BackoffSmoothing model on the test data: 80.31860346497571
# Perplexity of the 331 BackoffSmoothing model on the test data: 58.73808072770799
# Perplexity of the 332 BackoffSmoothing model on the test data: 55.91481738716039
# Perplexity of the 333 BackoffSmoothing model on the test data: 49.00606291132311
# Perplexity of the 334 BackoffSmoothing model on the test data: 62.330670017979514
# Perplexity of the 335 BackoffSmoothing model on the test data: 43.595464592791544
# Perplexity of the 336 BackoffSmoothing model on the test data: 50.51000224041516
# Perplexity of the 337 BackoffSmoothing model on the test data: 36.55644323885983
# Perplexity of the 338 BackoffSmoothing model on the test data: 48.40726095665081
# Perplexity of the 339 BackoffSmoothing model on the test data: 52.171151918888924
# Perplexity of the 340 BackoffSmoothing model on the test data: 60.4755179360531
# Perplexity of the 341 BackoffSmoothing model on the test data: 64.42707502174633
# Perplexity of the 342 BackoffSmoothing model on the test data: 59.73359252434955
# Perplexity of the 343 BackoffSmoothing model on the test data: 39.20946830912784
# Perplexity of the 344 BackoffSmoothing model on the test data: 60.865312561311555
# Perplexity of the 345 BackoffSmoothing model on the test data: 60.98293828345828
# Perplexity of the 346 BackoffSmoothing model on the test data: 50.23564529673362
# Perplexity of the 347 BackoffSmoothing model on the test data: 68.04693197783673
# Perplexity of the 348 BackoffSmoothing model on the test data: 31.117957538745173
# Perplexity of the 349 BackoffSmoothing model on the test data: 66.4631960283756
# Perplexity of the 350 BackoffSmoothing model on the test data: 57.73484108037512
# Perplexity of the 351 BackoffSmoothing model on the test data: 73.9877180047136
# Perplexity of the 352 BackoffSmoothing model on the test data: 75.7844985261469
# Perplexity of the 353 BackoffSmoothing model on the test data: 37.6911684846618
# Perplexity of the 354 BackoffSmoothing model on the test data: 58.58998151596057
# Perplexity of the 355 BackoffSmoothing model on the test data: 37.56059024825308
# Perplexity of the 356 BackoffSmoothing model on the test data: 52.89274416834871
# Perplexity of the 357 BackoffSmoothing model on the test data: 55.543703756469434
# Perplexity of the 358 BackoffSmoothing model on the test data: 26.951816713144275
# Perplexity of the 359 BackoffSmoothing model on the test data: 35.58286868290232
# Perplexity of the 360 BackoffSmoothing model on the test data: 60.92851011690352
# Perplexity of the 361 BackoffSmoothing model on the test data: 47.333461005767084
# Perplexity of the 362 BackoffSmoothing model on the test data: 59.37302425456221
# Perplexity of the 363 BackoffSmoothing model on the test data: 44.94999224652149
# Perplexity of the 364 BackoffSmoothing model on the test data: 52.78539461966081
# Perplexity of the 365 BackoffSmoothing model on the test data: 58.01191652916561
# Perplexity of the 366 BackoffSmoothing model on the test data: 79.18700625630045
# Perplexity of the 367 BackoffSmoothing model on the test data: 44.39508162101613
# Perplexity of the 368 BackoffSmoothing model on the test data: 52.33720255513927
# Perplexity of the 369 BackoffSmoothing model on the test data: 44.80752326293668
# Perplexity of the 370 BackoffSmoothing model on the test data: 64.59537728148513
# Perplexity of the 371 BackoffSmoothing model on the test data: 59.57849111000224
# Perplexity of the 372 BackoffSmoothing model on the test data: 27.772031871278408
# Perplexity of the 373 BackoffSmoothing model on the test data: 52.515923843546744
# Perplexity of the 374 BackoffSmoothing model on the test data: 60.74898261860273
# Perplexity of the 375 BackoffSmoothing model on the test data: 42.96223671512502
# Perplexity of the 376 BackoffSmoothing model on the test data: 57.691804600827886
# Perplexity of the 377 BackoffSmoothing model on the test data: 40.69965834922901
# Perplexity of the 378 BackoffSmoothing model on the test data: 47.60118117657339
# Perplexity of the 379 BackoffSmoothing model on the test data: 53.50266512956471
# Perplexity of the 380 BackoffSmoothing model on the test data: 45.23737968355589
# Perplexity of the 381 BackoffSmoothing model on the test data: 49.88017419534301
# Perplexity of the 382 BackoffSmoothing model on the test data: 64.00532591667015
# Perplexity of the 383 BackoffSmoothing model on the test data: 17.113286249298227
# Perplexity of the 384 BackoffSmoothing model on the test data: 58.111878611451196
# Perplexity of the 385 BackoffSmoothing model on the test data: 18.110697837619277
# Perplexity of the 386 BackoffSmoothing model on the test data: 59.21228882887801
# Perplexity of the 387 BackoffSmoothing model on the test data: 53.23694631358357
# Perplexity of the 388 BackoffSmoothing model on the test data: 46.30660182151593
# Perplexity of the 389 BackoffSmoothing model on the test data: 31.246473492441776
# Perplexity of the 390 BackoffSmoothing model on the test data: 64.39647617486584
# Perplexity of the 391 BackoffSmoothing model on the test data: 43.57532357209269
# Perplexity of the 392 BackoffSmoothing model on the test data: 43.58045848593942
# Perplexity of the 393 BackoffSmoothing model on the test data: 33.044359367209466
# Perplexity of the 394 BackoffSmoothing model on the test data: 52.03370761353152
# Perplexity of the 395 BackoffSmoothing model on the test data: 47.91783983070144
# Perplexity of the 396 BackoffSmoothing model on the test data: 33.859738895280174
# Perplexity of the 397 BackoffSmoothing model on the test data: 27.381528153831322
# Perplexity of the 398 BackoffSmoothing model on the test data: 54.26051529858856
# Perplexity of the 399 BackoffSmoothing model on the test data: 46.353094220579734
# Perplexity of the 400 BackoffSmoothing model on the test data: 59.438989758579716
# Perplexity of the 401 BackoffSmoothing model on the test data: 54.3513082252224
# Perplexity of the 402 BackoffSmoothing model on the test data: 51.94082902775988
# Perplexity of the 403 BackoffSmoothing model on the test data: 30.670692159662526
# Perplexity of the 404 BackoffSmoothing model on the test data: 53.523628847797504
# Perplexity of the 405 BackoffSmoothing model on the test data: 56.20163092748293
# Perplexity of the 406 BackoffSmoothing model on the test data: 47.15192278779064
# Perplexity of the 407 BackoffSmoothing model on the test data: 52.56806115039981
# Perplexity of the 408 BackoffSmoothing model on the test data: 48.301596997462916
# Perplexity of the 409 BackoffSmoothing model on the test data: 44.57375159982235
# Perplexity of the 410 BackoffSmoothing model on the test data: 40.45054264603829
# Perplexity of the 411 BackoffSmoothing model on the test data: 57.6904750404486
# Perplexity of the 412 BackoffSmoothing model on the test data: 60.210536219184874
# Perplexity of the 413 BackoffSmoothing model on the test data: 47.74272631338569
# Perplexity of the 414 BackoffSmoothing model on the test data: 51.83888661292746
# Perplexity of the 415 BackoffSmoothing model on the test data: 63.16415718641873
# Perplexity of the 416 BackoffSmoothing model on the test data: 54.55091802895324
# Perplexity of the 417 BackoffSmoothing model on the test data: 48.27287808896553
# Perplexity of the 418 BackoffSmoothing model on the test data: 36.789140375135304
# Perplexity of the 419 BackoffSmoothing model on the test data: 55.400710245260356
# Perplexity of the 420 BackoffSmoothing model on the test data: 65.40991790095369
# Perplexity of the 421 BackoffSmoothing model on the test data: 47.04037376985376
# Perplexity of the 422 BackoffSmoothing model on the test data: 45.32932651763964
# Perplexity of the 423 BackoffSmoothing model on the test data: 55.527816087496824
# Perplexity of the 424 BackoffSmoothing model on the test data: 60.298641941116514
# Perplexity of the 425 BackoffSmoothing model on the test data: 49.160105967588414
# Perplexity of the 426 BackoffSmoothing model on the test data: 49.034337976839055
# Perplexity of the 427 BackoffSmoothing model on the test data: 37.683755067386834
# Perplexity of the 428 BackoffSmoothing model on the test data: 49.414577241775326
# Perplexity of the 429 BackoffSmoothing model on the test data: 53.8483534597602
# Perplexity of the 430 BackoffSmoothing model on the test data: 42.34089463430219
# Perplexity of the 431 BackoffSmoothing model on the test data: 66.05159953307964
# Perplexity of the 432 BackoffSmoothing model on the test data: 59.91959414003327
# Perplexity of the 433 BackoffSmoothing model on the test data: 29.47998018165334
# Perplexity of the 434 BackoffSmoothing model on the test data: 78.0223273405037
# Perplexity of the 435 BackoffSmoothing model on the test data: 55.47546041216709
# Perplexity of the 436 BackoffSmoothing model on the test data: 66.82923159047073
# Perplexity of the 437 BackoffSmoothing model on the test data: 53.51948756753351
# Perplexity of the 438 BackoffSmoothing model on the test data: 43.00309357072092
# Perplexity of the 439 BackoffSmoothing model on the test data: 35.87448483597152
# Perplexity of the 440 BackoffSmoothing model on the test data: 29.10706683235923
# Perplexity of the 441 BackoffSmoothing model on the test data: 44.8359770399547
# Perplexity of the 442 BackoffSmoothing model on the test data: 41.858716776893196
# Perplexity of the 443 BackoffSmoothing model on the test data: 47.227214654741466
# Perplexity of the 444 BackoffSmoothing model on the test data: 38.46485875279322
# Perplexity of the 445 BackoffSmoothing model on the test data: 66.89507904670002
# Perplexity of the 446 BackoffSmoothing model on the test data: 56.98390423044273
# Perplexity of the 447 BackoffSmoothing model on the test data: 28.44316090027941
# Perplexity of the 448 BackoffSmoothing model on the test data: 29.027864589132633
# Perplexity of the 449 BackoffSmoothing model on the test data: 34.23418581501635
# Perplexity of the 450 BackoffSmoothing model on the test data: 51.63125296496847
# Perplexity of the 451 BackoffSmoothing model on the test data: 47.70900443574213
# Perplexity of the 452 BackoffSmoothing model on the test data: 48.39981637970603
# Perplexity of the 453 BackoffSmoothing model on the test data: 44.52185896274172
# Perplexity of the 454 BackoffSmoothing model on the test data: 65.0228205809853
# Perplexity of the 455 BackoffSmoothing model on the test data: 37.63420342641227
# Perplexity of the 456 BackoffSmoothing model on the test data: 71.4111150673579
# Perplexity of the 457 BackoffSmoothing model on the test data: 47.434772674688425
# Perplexity of the 458 BackoffSmoothing model on the test data: 36.63695607898798
# Perplexity of the 459 BackoffSmoothing model on the test data: 44.29062526177856
# Perplexity of the 460 BackoffSmoothing model on the test data: 60.386121178992
# Perplexity of the 461 BackoffSmoothing model on the test data: 59.31646792757965
# Perplexity of the 462 BackoffSmoothing model on the test data: 36.98730799583005
# Perplexity of the 463 BackoffSmoothing model on the test data: 64.64707042284475
# Perplexity of the 464 BackoffSmoothing model on the test data: 34.0147240202167
# Perplexity of the 465 BackoffSmoothing model on the test data: 57.12753446980697
# Perplexity of the 466 BackoffSmoothing model on the test data: 33.562545925339975
# Perplexity of the 467 BackoffSmoothing model on the test data: 37.314828792077684
# Perplexity of the 468 BackoffSmoothing model on the test data: 45.45195703755026
# Perplexity of the 469 BackoffSmoothing model on the test data: 38.03650766796842
# Perplexity of the 470 BackoffSmoothing model on the test data: 59.25258805640895
# Perplexity of the 471 BackoffSmoothing model on the test data: 33.42294104783521
# Perplexity of the 472 BackoffSmoothing model on the test data: 38.68169188905978
# Perplexity of the 473 BackoffSmoothing model on the test data: 59.62173250461916
# Perplexity of the 474 BackoffSmoothing model on the test data: 61.832172944166594
# Perplexity of the 475 BackoffSmoothing model on the test data: 46.75300284752608
# Perplexity of the 476 BackoffSmoothing model on the test data: 59.150565541836244
# Perplexity of the 477 BackoffSmoothing model on the test data: 56.42375101905099
# Perplexity of the 478 BackoffSmoothing model on the test data: 67.01539104482806
# Perplexity of the 479 BackoffSmoothing model on the test data: 42.00025245367937
# Perplexity of the 480 BackoffSmoothing model on the test data: 55.858145446464235
# Perplexity of the 481 BackoffSmoothing model on the test data: 33.097372774598476
# Perplexity of the 482 BackoffSmoothing model on the test data: 43.01568523064635
# Perplexity of the 483 BackoffSmoothing model on the test data: 49.13365159238796
# Perplexity of the 484 BackoffSmoothing model on the test data: 68.14271092891275
# Perplexity of the 485 BackoffSmoothing model on the test data: 48.9583896154488
# Perplexity of the 486 BackoffSmoothing model on the test data: 48.83895391422221
# Perplexity of the 487 BackoffSmoothing model on the test data: 45.982740317736734
# Perplexity of the 488 BackoffSmoothing model on the test data: 36.45130288552275
# Perplexity of the 489 BackoffSmoothing model on the test data: 40.79185063832698
# Perplexity of the 490 BackoffSmoothing model on the test data: 43.12687428332672
# Perplexity of the 491 BackoffSmoothing model on the test data: 52.94095510490778
# Perplexity of the 492 BackoffSmoothing model on the test data: 44.92989283938766
# Perplexity of the 493 BackoffSmoothing model on the test data: 47.2447707018244
# Perplexity of the 494 BackoffSmoothing model on the test data: 57.68872838828978
# Perplexity of the 495 BackoffSmoothing model on the test data: 48.0597159797068
# Perplexity of the 496 BackoffSmoothing model on the test data: 36.929147805500335
# Perplexity of the 497 BackoffSmoothing model on the test data: 43.07649245535095
# Perplexity of the 498 BackoffSmoothing model on the test data: 69.90224768695387
# Perplexity of the 499 BackoffSmoothing model on the test data: 48.002319769542666
# Perplexity of the 500 BackoffSmoothing model on the test data: 67.82519414057259
# Perplexity of the 501 BackoffSmoothing model on the test data: 63.05396818832512
# Perplexity of the 502 BackoffSmoothing model on the test data: 63.173663534408234
# Perplexity of the 503 BackoffSmoothing model on the test data: 37.64423929437483
# Perplexity of the 504 BackoffSmoothing model on the test data: 39.98114244787613
# Perplexity of the 505 BackoffSmoothing model on the test data: 53.913505762680344
# Perplexity of the 506 BackoffSmoothing model on the test data: 56.57606074836992
# Perplexity of the 507 BackoffSmoothing model on the test data: 49.791046367739696
# Perplexity of the 508 BackoffSmoothing model on the test data: 57.73360610391166
# Perplexity of the 509 BackoffSmoothing model on the test data: 54.95360446308308
# Perplexity of the 510 BackoffSmoothing model on the test data: 44.981206682924835
# Perplexity of the 511 BackoffSmoothing model on the test data: 36.84332995492911
# Perplexity of the 512 BackoffSmoothing model on the test data: 68.52413414042321
# Perplexity of the 513 BackoffSmoothing model on the test data: 56.28456735091886
# Perplexity of the 514 BackoffSmoothing model on the test data: 49.04907260042676
# Perplexity of the 515 BackoffSmoothing model on the test data: 49.81066601895592
# Perplexity of the 516 BackoffSmoothing model on the test data: 43.93743667809257
# Perplexity of the 517 BackoffSmoothing model on the test data: 41.79505151079808
# Perplexity of the 518 BackoffSmoothing model on the test data: 51.846410109428064
# Perplexity of the 519 BackoffSmoothing model on the test data: 41.03995286356376
# Perplexity of the 520 BackoffSmoothing model on the test data: 72.27858038692239
# Perplexity of the 521 BackoffSmoothing model on the test data: 37.792413426450004
# Perplexity of the 522 BackoffSmoothing model on the test data: 49.12705398468144
# Perplexity of the 523 BackoffSmoothing model on the test data: 54.166590589877295
# Perplexity of the 524 BackoffSmoothing model on the test data: 48.50694600259833
# Perplexity of the 525 BackoffSmoothing model on the test data: 51.71197024006368
# Perplexity of the 526 BackoffSmoothing model on the test data: 45.395055302507814
# Perplexity of the 527 BackoffSmoothing model on the test data: 62.46925972196889
# Perplexity of the 528 BackoffSmoothing model on the test data: 39.67018657584169
# Perplexity of the 529 BackoffSmoothing model on the test data: 60.433284670102076
# Perplexity of the 530 BackoffSmoothing model on the test data: 39.89955518149007
# Perplexity of the 531 BackoffSmoothing model on the test data: 57.515872602555795
# Perplexity of the 532 BackoffSmoothing model on the test data: 43.06947024756544
# Perplexity of the 533 BackoffSmoothing model on the test data: 60.951548328618486
# Perplexity of the 534 BackoffSmoothing model on the test data: 41.37638670385279
# Perplexity of the 535 BackoffSmoothing model on the test data: 71.77458237072749
# Perplexity of the 536 BackoffSmoothing model on the test data: 68.6205671533187
# Perplexity of the 537 BackoffSmoothing model on the test data: 35.9935923317399
# Perplexity of the 538 BackoffSmoothing model on the test data: 42.672452513179515
# Perplexity of the 539 BackoffSmoothing model on the test data: 40.51505350580857
# Perplexity of the 540 BackoffSmoothing model on the test data: 54.29127177680798
# Perplexity of the 541 BackoffSmoothing model on the test data: 45.07258665977339
# Perplexity of the 542 BackoffSmoothing model on the test data: 75.70756332054381
# Perplexity of the 543 BackoffSmoothing model on the test data: 84.8809308835511
# Perplexity of the 544 BackoffSmoothing model on the test data: 58.69146134932045
# Perplexity of the 545 BackoffSmoothing model on the test data: 40.58884615326165
# Perplexity of the 546 BackoffSmoothing model on the test data: 60.900903829800924
# Perplexity of the 547 BackoffSmoothing model on the test data: 32.64481204516237
# Perplexity of the 548 BackoffSmoothing model on the test data: 57.79795384925391
# Perplexity of the 549 BackoffSmoothing model on the test data: 55.02617604307091
# Perplexity of the 550 BackoffSmoothing model on the test data: 53.23882141751541
# Perplexity of the 551 BackoffSmoothing model on the test data: 58.58010884093035
# Perplexity of the 552 BackoffSmoothing model on the test data: 41.99901277140425
# Perplexity of the 553 BackoffSmoothing model on the test data: 30.294974952138315
# Perplexity of the 554 BackoffSmoothing model on the test data: 31.705499854916944
# Perplexity of the 555 BackoffSmoothing model on the test data: 56.173041815750096
# Perplexity of the 556 BackoffSmoothing model on the test data: 50.2682739710979
# Perplexity of the 557 BackoffSmoothing model on the test data: 58.89590469906565
# Perplexity of the 558 BackoffSmoothing model on the test data: 55.83162923615753
# Perplexity of the 559 BackoffSmoothing model on the test data: 69.36278555067001
# Perplexity of the 560 BackoffSmoothing model on the test data: 38.20053072059377
# Perplexity of the 561 BackoffSmoothing model on the test data: 58.76227469134031
# Perplexity of the 562 BackoffSmoothing model on the test data: 49.41552363904421
# Perplexity of the 563 BackoffSmoothing model on the test data: 35.563637436509254
# Perplexity of the 564 BackoffSmoothing model on the test data: 38.42811808667804
# Perplexity of the 565 BackoffSmoothing model on the test data: 44.31368045093377
# Perplexity of the 566 BackoffSmoothing model on the test data: 35.96908810312932
# Perplexity of the 567 BackoffSmoothing model on the test data: 62.410296052244504
# Perplexity of the 568 BackoffSmoothing model on the test data: 82.73344390148893
# Perplexity of the 569 BackoffSmoothing model on the test data: 38.22620282508946
# Perplexity of the 570 BackoffSmoothing model on the test data: 52.11458047721386
# Perplexity of the 571 BackoffSmoothing model on the test data: 65.07955284420115
# Perplexity of the 572 BackoffSmoothing model on the test data: 36.422101368052466
# Perplexity of the 573 BackoffSmoothing model on the test data: 30.747744161870433
# Perplexity of the 574 BackoffSmoothing model on the test data: 41.33530523259427
# Perplexity of the 575 BackoffSmoothing model on the test data: 53.97808472436232
# Perplexity of the 576 BackoffSmoothing model on the test data: 49.216357785514745
# Perplexity of the 577 BackoffSmoothing model on the test data: 37.67211963749302
# Perplexity of the 578 BackoffSmoothing model on the test data: 44.621400987970155
# Perplexity of the 579 BackoffSmoothing model on the test data: 41.764946515076
# Perplexity of the 580 BackoffSmoothing model on the test data: 49.14133486258187
# Perplexity of the 581 BackoffSmoothing model on the test data: 63.52668393294756
# Perplexity of the 582 BackoffSmoothing model on the test data: 43.49786378354083
# Perplexity of the 583 BackoffSmoothing model on the test data: 54.73509632097477
# Perplexity of the 584 BackoffSmoothing model on the test data: 54.46521442544982
# Perplexity of the 585 BackoffSmoothing model on the test data: 40.78315145411738
# Perplexity of the 586 BackoffSmoothing model on the test data: 48.32662474230393
# Perplexity of the 587 BackoffSmoothing model on the test data: 41.167056417292336
# Perplexity of the 588 BackoffSmoothing model on the test data: 30.100357217703923
# Perplexity of the 589 BackoffSmoothing model on the test data: 53.04413091091081
# Perplexity of the 590 BackoffSmoothing model on the test data: 45.91170285842302
# Perplexity of the 591 BackoffSmoothing model on the test data: 56.67655366696727
# ...
# Perplexity of the 1450 BackoffSmoothing model on the test data: 34.81674589015878
# Perplexity of the 1451 BackoffSmoothing model on the test data: 65.14366773163609
# Perplexity of the 1452 BackoffSmoothing model on the test data: 61.01794766097506
# Perplexity of the 1453 BackoffSmoothing model on the test data: 61.395790342911454
# Perplexity of the 1454 BackoffSmoothing model on the test data: 36.30304955478125
# Perplexity of the 1455 BackoffSmoothing model on the test data: 42.87764964131469
# Perplexity of the 1456 BackoffSmoothing model on the test data: 50.1615235958198
# Perplexity of the 1457 BackoffSmoothing model on the test data: 39.37479388912347
# Perplexity of the 1458 BackoffSmoothing model on the test data: 44.64586778970492
# Perplexity of the 1459 BackoffSmoothing model on the test data: 54.20503370754899
# Perplexity of the 1460 BackoffSmoothing model on the test data: 46.80702635644012
# Perplexity of the 1461 BackoffSmoothing model on the test data: 59.91558977785939
# Perplexity of the 1462 BackoffSmoothing model on the test data: 39.16409384935601
# Perplexity of the 1463 BackoffSmoothing model on the test data: 49.08019755451611
# Perplexity of the 1464 BackoffSmoothing model on the test data: 48.16875414500726
# Perplexity of the 1465 BackoffSmoothing model on the test data: 58.24026164054219
# Perplexity of the 1466 BackoffSmoothing model on the test data: 14.659338143772702
# Perplexity of the 1467 BackoffSmoothing model on the test data: 46.38307869484193
# Perplexity of the 1468 BackoffSmoothing model on the test data: 41.62057772272551
# Perplexity of the 1469 BackoffSmoothing model on the test data: 55.82972349751985
# Perplexity of the 1470 BackoffSmoothing model on the test data: 61.97430787288222
# Perplexity of the 1471 BackoffSmoothing model on the test data: 71.34440382736535
# Perplexity of the 1472 BackoffSmoothing model on the test data: 42.53704866533078
# Perplexity of the 1473 BackoffSmoothing model on the test data: 58.79086601124919
# Perplexity of the 1474 BackoffSmoothing model on the test data: 32.01141255361979
# Perplexity of the 1475 BackoffSmoothing model on the test data: 47.725250889814056
# Perplexity of the 1476 BackoffSmoothing model on the test data: 31.11502957581815
# Perplexity of the 1477 BackoffSmoothing model on the test data: 45.3230273821906
# Perplexity of the 1478 BackoffSmoothing model on the test data: 46.818425781140405
# Perplexity of the 1479 BackoffSmoothing model on the test data: 47.1933783652678
# Perplexity of the 1480 BackoffSmoothing model on the test data: 48.88964279291413
# Perplexity of the 1481 BackoffSmoothing model on the test data: 62.58801153756656
# Perplexity of the 1482 BackoffSmoothing model on the test data: 70.24537930445187
# Perplexity of the 1483 BackoffSmoothing model on the test data: 81.86984139776816
# Perplexity of the 1484 BackoffSmoothing model on the test data: 43.05930524623221
# Perplexity of the 1485 BackoffSmoothing model on the test data: 54.44593371711331
# Perplexity of the 1486 BackoffSmoothing model on the test data: 55.94895389445659
# Perplexity of the 1487 BackoffSmoothing model on the test data: 58.07921160699409
# Perplexity of the 1488 BackoffSmoothing model on the test data: 40.24360796876921
# Perplexity of the 1489 BackoffSmoothing model on the test data: 51.835305812640186
# Perplexity of the 1490 BackoffSmoothing model on the test data: 79.96360390756942
# Perplexity of the 1491 BackoffSmoothing model on the test data: 72.06163488673498
# Perplexity of the 1492 BackoffSmoothing model on the test data: 41.37160445020414
# Perplexity of the 1493 BackoffSmoothing model on the test data: 41.857466200663794
# Perplexity of the 1494 BackoffSmoothing model on the test data: 41.55190781369235
# Perplexity of the 1495 BackoffSmoothing model on the test data: 35.930726404200186
# Perplexity of the 1496 BackoffSmoothing model on the test data: 81.48478886563375
# Perplexity of the 1497 BackoffSmoothing model on the test data: 47.13623561422284
# Perplexity of the 1498 BackoffSmoothing model on the test data: 48.60582175100008
# Perplexity of the 1499 BackoffSmoothing model on the test data: 45.40170248197701
# Perplexity of the 1500 BackoffSmoothing model on the test data: 60.7505016259847
# Perplexity of the 1501 BackoffSmoothing model on the test data: 24.653510990353432
# Perplexity of the 1502 BackoffSmoothing model on the test data: 40.02003635808144
# Perplexity of the 1503 BackoffSmoothing model on the test data: 40.85960534357598
# Perplexity of the 1504 BackoffSmoothing model on the test data: 40.84668838228277
# Perplexity of the 1505 BackoffSmoothing model on the test data: 50.18941957546363
# Perplexity of the 1506 BackoffSmoothing model on the test data: 55.77188821118298
# Perplexity of the 1507 BackoffSmoothing model on the test data: 50.5561834534869
# Perplexity of the 1508 BackoffSmoothing model on the test data: 56.02608263930647
# Perplexity of the 1509 BackoffSmoothing model on the test data: 22.954200797273653
# Perplexity of the 1510 BackoffSmoothing model on the test data: 67.7050325296723
# Perplexity of the 1511 BackoffSmoothing model on the test data: 50.69058932729412
# Perplexity of the 1512 BackoffSmoothing model on the test data: 62.92910975958855
# Perplexity of the 1513 BackoffSmoothing model on the test data: 65.47408842430721
# Perplexity of the 1514 BackoffSmoothing model on the test data: 48.15951475464579
# Perplexity of the 1515 BackoffSmoothing model on the test data: 57.25310431763355
# Perplexity of the 1516 BackoffSmoothing model on the test data: 64.35514707907902
# Perplexity of the 1517 BackoffSmoothing model on the test data: 52.83590543617964
# Perplexity of the 1518 BackoffSmoothing model on the test data: 42.648630931230635
# Perplexity of the 1519 BackoffSmoothing model on the test data: 34.35983199325927
# Perplexity of the 1520 BackoffSmoothing model on the test data: 73.03613012186116
# Perplexity of the 1521 BackoffSmoothing model on the test data: 53.668092702230204
# Perplexity of the 1522 BackoffSmoothing model on the test data: 43.90717070620456
# Perplexity of the 1523 BackoffSmoothing model on the test data: 26.065589880853228
# Perplexity of the 1524 BackoffSmoothing model on the test data: 47.84279132645427
# Perplexity of the 1525 BackoffSmoothing model on the test data: 32.92462484271598
# Perplexity of the 1526 BackoffSmoothing model on the test data: 32.35717600456119
# Perplexity of the 1527 BackoffSmoothing model on the test data: 78.95959916436362
# Perplexity of the 1528 BackoffSmoothing model on the test data: 35.46416929815389
# Perplexity of the 1529 BackoffSmoothing model on the test data: 61.93391523638991
# Perplexity of the 1530 BackoffSmoothing model on the test data: 47.02961945469678
# Perplexity of the 1531 BackoffSmoothing model on the test data: 20.759434090812956
# Perplexity of the 1532 BackoffSmoothing model on the test data: 49.56484145504684
# Perplexity of the 1533 BackoffSmoothing model on the test data: 51.466793686930366
# Perplexity of the 1534 BackoffSmoothing model on the test data: 39.792608125428664
# Perplexity of the 1535 BackoffSmoothing model on the test data: 40.25580572815504
# Perplexity of the 1536 BackoffSmoothing model on the test data: 39.839906235275635
# Perplexity of the 1537 BackoffSmoothing model on the test data: 41.42385763792471
# Perplexity of the 1538 BackoffSmoothing model on the test data: 53.39862735202874
# Perplexity of the 1539 BackoffSmoothing model on the test data: 61.956954665214184
# Perplexity of the 1540 BackoffSmoothing model on the test data: 71.46526277679057
# Perplexity of the 1541 BackoffSmoothing model on the test data: 43.47316536966267
# Perplexity of the 1542 BackoffSmoothing model on the test data: 51.40720520222601
# Perplexity of the 1543 BackoffSmoothing model on the test data: 51.02554774167363
# Perplexity of the 1544 BackoffSmoothing model on the test data: 30.573484359167633
# Perplexity of the 1545 BackoffSmoothing model on the test data: 60.227633965852625
# Perplexity of the 1546 BackoffSmoothing model on the test data: 41.196345131089416
# Perplexity of the 1547 BackoffSmoothing model on the test data: 62.388168808658556
# Perplexity of the 1548 BackoffSmoothing model on the test data: 63.0446518103179
# Perplexity of the 1549 BackoffSmoothing model on the test data: 48.38863826157263
# Perplexity of the 1550 BackoffSmoothing model on the test data: 44.22755751229045
# Perplexity of the 1551 BackoffSmoothing model on the test data: 63.82452410945753
# Perplexity of the 1552 BackoffSmoothing model on the test data: 38.419427108222486
# Perplexity of the 1553 BackoffSmoothing model on the test data: 43.77922432521921
# Perplexity of the 1554 BackoffSmoothing model on the test data: 48.37268211954619
# Perplexity of the 1555 BackoffSmoothing model on the test data: 39.70604491064154
# Perplexity of the 1556 BackoffSmoothing model on the test data: 38.64023273842492
# Perplexity of the 1557 BackoffSmoothing model on the test data: 69.23871972769618
# Perplexity of the 1558 BackoffSmoothing model on the test data: 48.07907622480364
# Perplexity of the 1559 BackoffSmoothing model on the test data: 25.070981088053042
# Perplexity of the 1560 BackoffSmoothing model on the test data: 39.28633984395288
# Perplexity of the 1561 BackoffSmoothing model on the test data: 36.93084637216917
# Perplexity of the 1562 BackoffSmoothing model on the test data: 45.00709970827099
# Perplexity of the 1563 BackoffSmoothing model on the test data: 47.53068144039407
# Perplexity of the 1564 BackoffSmoothing model on the test data: 43.42399986834886
# Perplexity of the 1565 BackoffSmoothing model on the test data: 59.49726923170774
# Perplexity of the 1566 BackoffSmoothing model on the test data: 56.02666224562605
# Perplexity of the 1567 BackoffSmoothing model on the test data: 73.31503103548987
# Perplexity of the 1568 BackoffSmoothing model on the test data: 44.081677566625146
# Perplexity of the 1569 BackoffSmoothing model on the test data: 61.52350656717323
# Perplexity of the 1570 BackoffSmoothing model on the test data: 41.927382078425666
# Perplexity of the 1571 BackoffSmoothing model on the test data: 39.81981656199803
# Perplexity of the 1572 BackoffSmoothing model on the test data: 62.882125825581845
# Perplexity of the 1573 BackoffSmoothing model on the test data: 37.665969209881744
# Perplexity of the 1574 BackoffSmoothing model on the test data: 49.61750154756199
# Perplexity of the 1575 BackoffSmoothing model on the test data: 57.077565097475436
# Perplexity of the 1576 BackoffSmoothing model on the test data: 28.02037608072718
# Perplexity of the 1577 BackoffSmoothing model on the test data: 53.26753718573499
# Perplexity of the 1578 BackoffSmoothing model on the test data: 59.24649130999294
# Perplexity of the 1579 BackoffSmoothing model on the test data: 55.699529564006454
# Perplexity of the 1580 BackoffSmoothing model on the test data: 58.06513953496341
# Perplexity of the 1581 BackoffSmoothing model on the test data: 54.36330603158657
# Perplexity of the 1582 BackoffSmoothing model on the test data: 48.06378737902744
# Perplexity of the 1583 BackoffSmoothing model on the test data: 31.792862173898744
# Perplexity of the 1584 BackoffSmoothing model on the test data: 53.026807474815485
# Perplexity of the 1585 BackoffSmoothing model on the test data: 55.50271457520995
# Perplexity of the 1586 BackoffSmoothing model on the test data: 66.41577861005625
# Perplexity of the 1587 BackoffSmoothing model on the test data: 56.79285991919574
# Perplexity of the 1588 BackoffSmoothing model on the test data: 36.92212717591346
# Perplexity of the 1589 BackoffSmoothing model on the test data: 36.690873992522874
# Perplexity of the 1590 BackoffSmoothing model on the test data: 49.18166236798278
# Perplexity of the 1591 BackoffSmoothing model on the test data: 57.66046691151924
# Perplexity of the 1592 BackoffSmoothing model on the test data: 49.546506507316174
# Perplexity of the 1593 BackoffSmoothing model on the test data: 45.78766758004899
# Perplexity of the 1594 BackoffSmoothing model on the test data: 35.652762391519296
# Perplexity of the 1595 BackoffSmoothing model on the test data: 44.436458770174575
# Perplexity of the 1596 BackoffSmoothing model on the test data: 70.57813280017672
# Perplexity of the 1597 BackoffSmoothing model on the test data: 39.910349621196985
# Perplexity of the 1598 BackoffSmoothing model on the test data: 52.634972212523124
# Perplexity of the 1599 BackoffSmoothing model on the test data: 72.37693689181516
# Perplexity of the 1600 BackoffSmoothing model on the test data: 62.293154924199456
# Perplexity of the 1601 BackoffSmoothing model on the test data: 30.51436571135544
# Perplexity of the 1602 BackoffSmoothing model on the test data: 37.04044209795943
# Perplexity of the 1603 BackoffSmoothing model on the test data: 66.97298510122033
# Perplexity of the 1604 BackoffSmoothing model on the test data: 64.56262823590873
# Perplexity of the 1605 BackoffSmoothing model on the test data: 52.28959952793434
# Perplexity of the 1606 BackoffSmoothing model on the test data: 44.16648696508775
# Perplexity of the 1607 BackoffSmoothing model on the test data: 49.99915314968176
# Perplexity of the 1608 BackoffSmoothing model on the test data: 57.15205438365199
# Perplexity of the 1609 BackoffSmoothing model on the test data: 36.94153375056622
# Perplexity of the 1610 BackoffSmoothing model on the test data: 62.14905050342277
# Perplexity of the 1611 BackoffSmoothing model on the test data: 58.19840870763399
# Perplexity of the 1612 BackoffSmoothing model on the test data: 62.39643678493469
# Perplexity of the 1613 BackoffSmoothing model on the test data: 69.7999547671768
# Perplexity of the 1614 BackoffSmoothing model on the test data: 51.842660456641994
# Perplexity of the 1615 BackoffSmoothing model on the test data: 43.019081016191556
# Perplexity of the 1616 BackoffSmoothing model on the test data: 35.60950042954818
# Perplexity of the 1617 BackoffSmoothing model on the test data: 57.57800394107465
# Perplexity of the 1618 BackoffSmoothing model on the test data: 50.48206897369488
# Perplexity of the 1619 BackoffSmoothing model on the test data: 44.52631786953395
# Perplexity of the 1620 BackoffSmoothing model on the test data: 55.39463443648465
# Perplexity of the 1621 BackoffSmoothing model on the test data: 63.05455291429029
# Perplexity of the 1622 BackoffSmoothing model on the test data: 44.23750777425006
# Perplexity of the 1623 BackoffSmoothing model on the test data: 51.13179640884119
# Perplexity of the 1624 BackoffSmoothing model on the test data: 46.34332332376673
# Perplexity of the 1625 BackoffSmoothing model on the test data: 54.23384609737397
# Perplexity of the 1626 BackoffSmoothing model on the test data: 50.96886143471009
# Perplexity of the 1627 BackoffSmoothing model on the test data: 43.34643346723195
# Perplexity of the 1628 BackoffSmoothing model on the test data: 34.77995341526594
# Perplexity of the 1629 BackoffSmoothing model on the test data: 53.93815369647988
# Perplexity of the 1630 BackoffSmoothing model on the test data: 29.26935851108547
# Perplexity of the 1631 BackoffSmoothing model on the test data: 39.07451058684121
# Perplexity of the 1632 BackoffSmoothing model on the test data: 48.403401474309064
# Perplexity of the 1633 BackoffSmoothing model on the test data: 42.23446171392146
# Perplexity of the 1634 BackoffSmoothing model on the test data: 51.017820987221626
# Perplexity of the 1635 BackoffSmoothing model on the test data: 41.476611860581436
# Perplexity of the 1636 BackoffSmoothing model on the test data: 41.69583293565603
# Perplexity of the 1637 BackoffSmoothing model on the test data: 36.599463541760656
# Perplexity of the 1638 BackoffSmoothing model on the test data: 50.08455151309088
# Perplexity of the 1639 BackoffSmoothing model on the test data: 74.1437056564126
# Perplexity of the 1640 BackoffSmoothing model on the test data: 64.34470188233223
# Perplexity of the 1641 BackoffSmoothing model on the test data: 52.6051182382597
# Perplexity of the 1642 BackoffSmoothing model on the test data: 23.371846781565623
# Perplexity of the 1643 BackoffSmoothing model on the test data: 65.17282360582014

# %%
# trigrams
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(3, 0.1)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 9.871543943266678
# Perplexity of the 1 BackoffSmoothing model on the test data: 9.043438578631829
# Perplexity of the 2 BackoffSmoothing model on the test data: 9.857035474128047
# Perplexity of the 3 BackoffSmoothing model on the test data: 9.475998086120496
# Perplexity of the 4 BackoffSmoothing model on the test data: 10.188019105119176
# Perplexity of the 5 BackoffSmoothing model on the test data: 8.730203205165513
# Perplexity of the 6 BackoffSmoothing model on the test data: 11.158955541757365
# Perplexity of the 7 BackoffSmoothing model on the test data: 11.243346546633038
# Perplexity of the 8 BackoffSmoothing model on the test data: 9.190444257023659
# Perplexity of the 9 BackoffSmoothing model on the test data: 11.27518939406537
# Perplexity of the 10 BackoffSmoothing model on the test data: 11.418602944201087
# Perplexity of the 11 BackoffSmoothing model on the test data: 6.963989960356826
# Perplexity of the 12 BackoffSmoothing model on the test data: 11.11159328296889
# Perplexity of the 13 BackoffSmoothing model on the test data: 7.86264857972288
# Perplexity of the 14 BackoffSmoothing model on the test data: 9.673363988480347
# Perplexity of the 15 BackoffSmoothing model on the test data: 13.605949412189714
# Perplexity of the 16 BackoffSmoothing model on the test data: 9.938407527252707
# Perplexity of the 17 BackoffSmoothing model on the test data: 11.228298154543841
# Perplexity of the 18 BackoffSmoothing model on the test data: 12.82830666129131
# Perplexity of the 19 BackoffSmoothing model on the test data: 9.037872723217163
# Perplexity of the 20 BackoffSmoothing model on the test data: 9.580184970132853
# Perplexity of the 21 BackoffSmoothing model on the test data: 8.47602910508402
# Perplexity of the 22 BackoffSmoothing model on the test data: 9.182890950809524
# Perplexity of the 23 BackoffSmoothing model on the test data: 8.773306473461918
# Perplexity of the 24 BackoffSmoothing model on the test data: 7.899962621783405
# Perplexity of the 25 BackoffSmoothing model on the test data: 9.996622665047665
# Perplexity of the 26 BackoffSmoothing model on the test data: 12.764627770262203
# Perplexity of the 27 BackoffSmoothing model on the test data: 11.060349216842653
# Perplexity of the 28 BackoffSmoothing model on the test data: 10.425921063294597
# Perplexity of the 29 BackoffSmoothing model on the test data: 9.00379939528846
# Perplexity of the 30 BackoffSmoothing model on the test data: 9.071365063999863
# Perplexity of the 31 BackoffSmoothing model on the test data: 9.684518283255045
# Perplexity of the 32 BackoffSmoothing model on the test data: 10.942649501299892
# Perplexity of the 33 BackoffSmoothing model on the test data: 9.170426723986214
# Perplexity of the 34 BackoffSmoothing model on the test data: 11.178369469560717
# Perplexity of the 35 BackoffSmoothing model on the test data: 11.547099044995814
# Perplexity of the 36 BackoffSmoothing model on the test data: 7.048417331883205
# Perplexity of the 37 BackoffSmoothing model on the test data: 11.087880781836995
# Perplexity of the 38 BackoffSmoothing model on the test data: 9.906208558466433
# Perplexity of the 39 BackoffSmoothing model on the test data: 9.775535317850446
# Perplexity of the 40 BackoffSmoothing model on the test data: 11.9209466066098
# Perplexity of the 41 BackoffSmoothing model on the test data: 9.299304006519078
# Perplexity of the 42 BackoffSmoothing model on the test data: 9.134307441323815
# Perplexity of the 43 BackoffSmoothing model on the test data: 9.568224352577268
# Perplexity of the 44 BackoffSmoothing model on the test data: 8.565909809695363
# Perplexity of the 45 BackoffSmoothing model on the test data: 10.4921262332011
# Perplexity of the 46 BackoffSmoothing model on the test data: 9.038330975130043
# Perplexity of the 47 BackoffSmoothing model on the test data: 12.186811195206424
# Perplexity of the 48 BackoffSmoothing model on the test data: 11.362311914879031
# Perplexity of the 49 BackoffSmoothing model on the test data: 10.837825842823262
# Perplexity of the 50 BackoffSmoothing model on the test data: 7.3318825757286135
# Perplexity of the 51 BackoffSmoothing model on the test data: 9.600137503630394
# Perplexity of the 52 BackoffSmoothing model on the test data: 10.978122898226943
# Perplexity of the 53 BackoffSmoothing model on the test data: 10.57225725514565
# Perplexity of the 54 BackoffSmoothing model on the test data: 11.503747919188815
# Perplexity of the 55 BackoffSmoothing model on the test data: 11.712129148040061
# Perplexity of the 56 BackoffSmoothing model on the test data: 9.949046618331115
# Perplexity of the 57 BackoffSmoothing model on the test data: 8.622460015108581
# Perplexity of the 58 BackoffSmoothing model on the test data: 8.702216054698148
# Perplexity of the 59 BackoffSmoothing model on the test data: 8.315944654655295
# Perplexity of the 60 BackoffSmoothing model on the test data: 8.894253528684617
# Perplexity of the 61 BackoffSmoothing model on the test data: 12.135180348681738
# Perplexity of the 62 BackoffSmoothing model on the test data: 8.287685363570057
# Perplexity of the 63 BackoffSmoothing model on the test data: 11.555125699874562
# Perplexity of the 64 BackoffSmoothing model on the test data: 9.295299110374646
# Perplexity of the 65 BackoffSmoothing model on the test data: 10.951817663414944
# Perplexity of the 66 BackoffSmoothing model on the test data: 10.753420783741827
# Perplexity of the 67 BackoffSmoothing model on the test data: 8.258752684641626
# Perplexity of the 68 BackoffSmoothing model on the test data: 9.241750458402091
# Perplexity of the 69 BackoffSmoothing model on the test data: 10.125508475861617
# Perplexity of the 70 BackoffSmoothing model on the test data: 6.091049764943963
# Perplexity of the 71 BackoffSmoothing model on the test data: 9.924613966597962
# Perplexity of the 72 BackoffSmoothing model on the test data: 8.889249439043263
# Perplexity of the 73 BackoffSmoothing model on the test data: 11.555543459993894
# Perplexity of the 74 BackoffSmoothing model on the test data: 7.997944877139627
# Perplexity of the 75 BackoffSmoothing model on the test data: 9.198431306974298
# Perplexity of the 76 BackoffSmoothing model on the test data: 9.769812527475722
# Perplexity of the 77 BackoffSmoothing model on the test data: 11.002111937459919
# Perplexity of the 78 BackoffSmoothing model on the test data: 11.630149353217025
# Perplexity of the 79 BackoffSmoothing model on the test data: 7.090693848544522
# Perplexity of the 80 BackoffSmoothing model on the test data: 9.14220867222944
# Perplexity of the 81 BackoffSmoothing model on the test data: 10.912451455691825
# Perplexity of the 82 BackoffSmoothing model on the test data: 11.382230811105016
# Perplexity of the 83 BackoffSmoothing model on the test data: 11.03155764131037
# Perplexity of the 84 BackoffSmoothing model on the test data: 6.317636489254602
# Perplexity of the 85 BackoffSmoothing model on the test data: 10.185767588492158
# Perplexity of the 86 BackoffSmoothing model on the test data: 10.153890268258746
# Perplexity of the 87 BackoffSmoothing model on the test data: 10.252041666639402
# Perplexity of the 88 BackoffSmoothing model on the test data: 10.094288525534711
# Perplexity of the 89 BackoffSmoothing model on the test data: 10.478500888992166
# Perplexity of the 90 BackoffSmoothing model on the test data: 8.616704714953682
# Perplexity of the 91 BackoffSmoothing model on the test data: 10.354051687442626
# Perplexity of the 92 BackoffSmoothing model on the test data: 10.46653183742626
# Perplexity of the 93 BackoffSmoothing model on the test data: 11.271091635120976
# Perplexity of the 94 BackoffSmoothing model on the test data: 10.086197012714997
# Perplexity of the 95 BackoffSmoothing model on the test data: 7.837483488453843
# Perplexity of the 96 BackoffSmoothing model on the test data: 9.131632762468316
# Perplexity of the 97 BackoffSmoothing model on the test data: 11.241246063905505
# Perplexity of the 98 BackoffSmoothing model on the test data: 9.801618304761119
# Perplexity of the 99 BackoffSmoothing model on the test data: 10.057829271565138
# Perplexity of the 100 BackoffSmoothing model on the test data: 8.016217184663487
# Perplexity of the 101 BackoffSmoothing model on the test data: 4.8536104273978715
# Perplexity of the 102 BackoffSmoothing model on the test data: 11.386662260523472
# Perplexity of the 103 BackoffSmoothing model on the test data: 9.502787155130768
# Perplexity of the 104 BackoffSmoothing model on the test data: 8.677820185102266
# Perplexity of the 105 BackoffSmoothing model on the test data: 8.589345505899262
# Perplexity of the 106 BackoffSmoothing model on the test data: 7.33133118601316
# Perplexity of the 107 BackoffSmoothing model on the test data: 9.462559387330968
# Perplexity of the 108 BackoffSmoothing model on the test data: 6.807075233201676
# Perplexity of the 109 BackoffSmoothing model on the test data: 9.956325620350306
# Perplexity of the 110 BackoffSmoothing model on the test data: 9.066059101700365
# Perplexity of the 111 BackoffSmoothing model on the test data: 9.692155165021383
# Perplexity of the 112 BackoffSmoothing model on the test data: 9.423266421467412
# Perplexity of the 113 BackoffSmoothing model on the test data: 11.07311249719127
# Perplexity of the 114 BackoffSmoothing model on the test data: 7.1349412682841695
# Perplexity of the 115 BackoffSmoothing model on the test data: 11.584895393912811
# Perplexity of the 116 BackoffSmoothing model on the test data: 7.987547995040254
# Perplexity of the 117 BackoffSmoothing model on the test data: 11.054850353547584
# Perplexity of the 118 BackoffSmoothing model on the test data: 10.536782021940208
# Perplexity of the 119 BackoffSmoothing model on the test data: 9.813248347072216
# Perplexity of the 120 BackoffSmoothing model on the test data: 11.25220948397312
# Perplexity of the 121 BackoffSmoothing model on the test data: 9.043912705661144
# Perplexity of the 122 BackoffSmoothing model on the test data: 11.414804218929078
# Perplexity of the 123 BackoffSmoothing model on the test data: 9.940574409581394
# Perplexity of the 124 BackoffSmoothing model on the test data: 10.456445802550185
# Perplexity of the 125 BackoffSmoothing model on the test data: 11.789915802753002
# Perplexity of the 126 BackoffSmoothing model on the test data: 11.4554584845135
# Perplexity of the 127 BackoffSmoothing model on the test data: 8.589057411873958
# Perplexity of the 128 BackoffSmoothing model on the test data: 9.290708368871908
# Perplexity of the 129 BackoffSmoothing model on the test data: 10.655204721559723
# Perplexity of the 130 BackoffSmoothing model on the test data: 10.342840053677635
# Perplexity of the 131 BackoffSmoothing model on the test data: 7.776001987107704
# Perplexity of the 132 BackoffSmoothing model on the test data: 9.319894711572774
# Perplexity of the 133 BackoffSmoothing model on the test data: 9.816893058415914
# Perplexity of the 134 BackoffSmoothing model on the test data: 9.519802661613163
# Perplexity of the 135 BackoffSmoothing model on the test data: 11.948696697188732
# Perplexity of the 136 BackoffSmoothing model on the test data: 9.768309283632778
# Perplexity of the 137 BackoffSmoothing model on the test data: 9.92457419775467
# Perplexity of the 138 BackoffSmoothing model on the test data: 8.820428069464645
# Perplexity of the 139 BackoffSmoothing model on the test data: 8.222381557582537
# Perplexity of the 140 BackoffSmoothing model on the test data: 10.767223533325856
# Perplexity of the 141 BackoffSmoothing model on the test data: 11.529289512793678
# Perplexity of the 142 BackoffSmoothing model on the test data: 8.8943900587877
# Perplexity of the 143 BackoffSmoothing model on the test data: 9.090295930784718
# Perplexity of the 144 BackoffSmoothing model on the test data: 10.503895377489576
# Perplexity of the 145 BackoffSmoothing model on the test data: 10.581748270898816
# Perplexity of the 146 BackoffSmoothing model on the test data: 10.405825051517397
# Perplexity of the 147 BackoffSmoothing model on the test data: 8.818876979433767
# Perplexity of the 148 BackoffSmoothing model on the test data: 8.55146544106496
# Perplexity of the 149 BackoffSmoothing model on the test data: 9.71996455616454
# Perplexity of the 150 BackoffSmoothing model on the test data: 12.516425900400327
# Perplexity of the 151 BackoffSmoothing model on the test data: 10.074560728688512
# Perplexity of the 152 BackoffSmoothing model on the test data: 10.864036562542964
# Perplexity of the 153 BackoffSmoothing model on the test data: 9.597036968946659
# Perplexity of the 154 BackoffSmoothing model on the test data: 8.877004755400634
# Perplexity of the 155 BackoffSmoothing model on the test data: 10.44951615692984
# Perplexity of the 156 BackoffSmoothing model on the test data: 11.367820037142506
# Perplexity of the 157 BackoffSmoothing model on the test data: 10.241108275660327
# Perplexity of the 158 BackoffSmoothing model on the test data: 8.392551209522585
# Perplexity of the 159 BackoffSmoothing model on the test data: 9.277557068562631
# Perplexity of the 160 BackoffSmoothing model on the test data: 11.72188808221911
# Perplexity of the 161 BackoffSmoothing model on the test data: 9.865017427653271
# Perplexity of the 162 BackoffSmoothing model on the test data: 10.314387324177998
# Perplexity of the 163 BackoffSmoothing model on the test data: 8.82423434481002
# Perplexity of the 164 BackoffSmoothing model on the test data: 11.969412395120512
# Perplexity of the 165 BackoffSmoothing model on the test data: 11.694295040545978
# Perplexity of the 166 BackoffSmoothing model on the test data: 10.297839126830397
# Perplexity of the 167 BackoffSmoothing model on the test data: 7.010860916892361
# Perplexity of the 168 BackoffSmoothing model on the test data: 10.469158365950875
# Perplexity of the 169 BackoffSmoothing model on the test data: 10.047006272936237
# Perplexity of the 170 BackoffSmoothing model on the test data: 10.282492602788857
# Perplexity of the 171 BackoffSmoothing model on the test data: 9.697647561082539
# Perplexity of the 172 BackoffSmoothing model on the test data: 11.231267085429732
# Perplexity of the 173 BackoffSmoothing model on the test data: 8.548987270535076
# Perplexity of the 174 BackoffSmoothing model on the test data: 10.427405828397811
# Perplexity of the 175 BackoffSmoothing model on the test data: 10.90372968679841
# Perplexity of the 176 BackoffSmoothing model on the test data: 11.349198694454799
# Perplexity of the 177 BackoffSmoothing model on the test data: 8.580562454748096
# Perplexity of the 178 BackoffSmoothing model on the test data: 9.695238069617176
# Perplexity of the 179 BackoffSmoothing model on the test data: 11.122243825937487
# Perplexity of the 180 BackoffSmoothing model on the test data: 10.044621454717927
# Perplexity of the 181 BackoffSmoothing model on the test data: 10.785988054688959
# Perplexity of the 182 BackoffSmoothing model on the test data: 10.782803038691247
# Perplexity of the 183 BackoffSmoothing model on the test data: 8.972259689246616
# Perplexity of the 184 BackoffSmoothing model on the test data: 11.551092747255597
# Perplexity of the 185 BackoffSmoothing model on the test data: 7.081881414557185
# Perplexity of the 186 BackoffSmoothing model on the test data: 12.03592314259235
# Perplexity of the 187 BackoffSmoothing model on the test data: 12.093999002416588
# Perplexity of the 188 BackoffSmoothing model on the test data: 7.2844365647026015
# Perplexity of the 189 BackoffSmoothing model on the test data: 12.916078724569717
# Perplexity of the 190 BackoffSmoothing model on the test data: 8.511537156868695
# Perplexity of the 191 BackoffSmoothing model on the test data: 11.754820125172605
# Perplexity of the 192 BackoffSmoothing model on the test data: 6.733768893142826
# Perplexity of the 193 BackoffSmoothing model on the test data: 9.304913025463314
# Perplexity of the 194 BackoffSmoothing model on the test data: 10.261988047050721
# Perplexity of the 195 BackoffSmoothing model on the test data: 9.46410092486897
# Perplexity of the 196 BackoffSmoothing model on the test data: 9.186446866415093
# Perplexity of the 197 BackoffSmoothing model on the test data: 8.810031567974645
# Perplexity of the 198 BackoffSmoothing model on the test data: 7.261354771444528
# Perplexity of the 199 BackoffSmoothing model on the test data: 12.005010623480413
# Perplexity of the 200 BackoffSmoothing model on the test data: 10.203103197033014
# Perplexity of the 201 BackoffSmoothing model on the test data: 11.697299054894131
# Perplexity of the 202 BackoffSmoothing model on the test data: 10.023248956206935
# Perplexity of the 203 BackoffSmoothing model on the test data: 8.704899143759794
# Perplexity of the 204 BackoffSmoothing model on the test data: 12.151789039065784
# Perplexity of the 205 BackoffSmoothing model on the test data: 9.666421899805458
# Perplexity of the 206 BackoffSmoothing model on the test data: 7.337492877973498
# Perplexity of the 207 BackoffSmoothing model on the test data: 10.007195162179432
# Perplexity of the 208 BackoffSmoothing model on the test data: 8.03746984158902
# Perplexity of the 209 BackoffSmoothing model on the test data: 10.793481738653979
# Perplexity of the 210 BackoffSmoothing model on the test data: 11.17129267875068
# Perplexity of the 211 BackoffSmoothing model on the test data: 7.2701318693719115
# Perplexity of the 212 BackoffSmoothing model on the test data: 11.911972430234323
# Perplexity of the 213 BackoffSmoothing model on the test data: 10.503906659691403
# Perplexity of the 214 BackoffSmoothing model on the test data: 11.469929514203255
# Perplexity of the 215 BackoffSmoothing model on the test data: 12.502098568482817
# Perplexity of the 216 BackoffSmoothing model on the test data: 11.087417884035224
# Perplexity of the 217 BackoffSmoothing model on the test data: 10.242195508825505
# Perplexity of the 218 BackoffSmoothing model on the test data: 10.1300377805195
# Perplexity of the 219 BackoffSmoothing model on the test data: 10.636062071672228
# Perplexity of the 220 BackoffSmoothing model on the test data: 11.064700572759092
# Perplexity of the 221 BackoffSmoothing model on the test data: 11.591721469314951
# Perplexity of the 222 BackoffSmoothing model on the test data: 4.476799893586469
# Perplexity of the 223 BackoffSmoothing model on the test data: 10.778189398286798
# Perplexity of the 224 BackoffSmoothing model on the test data: 10.794713606059283
# Perplexity of the 225 BackoffSmoothing model on the test data: 8.4593559671629
# Perplexity of the 226 BackoffSmoothing model on the test data: 11.678691860955281
# Perplexity of the 227 BackoffSmoothing model on the test data: 10.51533043817884
# Perplexity of the 228 BackoffSmoothing model on the test data: 10.37463645703448
# Perplexity of the 229 BackoffSmoothing model on the test data: 10.68858460897712
# Perplexity of the 230 BackoffSmoothing model on the test data: 5.848380669761226
# Perplexity of the 231 BackoffSmoothing model on the test data: 11.273710685737926
# Perplexity of the 232 BackoffSmoothing model on the test data: 11.03496067317674
# Perplexity of the 233 BackoffSmoothing model on the test data: 10.348512587089257
# Perplexity of the 234 BackoffSmoothing model on the test data: 9.875462740297987
# Perplexity of the 235 BackoffSmoothing model on the test data: 8.968263008251505
# Perplexity of the 236 BackoffSmoothing model on the test data: 11.668797262706128
# Perplexity of the 237 BackoffSmoothing model on the test data: 11.984569876111207
# Perplexity of the 238 BackoffSmoothing model on the test data: 8.599656568370186
# Perplexity of the 239 BackoffSmoothing model on the test data: 11.86432141870552
# Perplexity of the 240 BackoffSmoothing model on the test data: 11.831142384552782
# Perplexity of the 241 BackoffSmoothing model on the test data: 9.862163967729705
# Perplexity of the 242 BackoffSmoothing model on the test data: 8.223838506258648
# Perplexity of the 243 BackoffSmoothing model on the test data: 7.796313164089575
# Perplexity of the 244 BackoffSmoothing model on the test data: 8.519996497023286
# Perplexity of the 245 BackoffSmoothing model on the test data: 10.64274410935366
# Perplexity of the 246 BackoffSmoothing model on the test data: 10.16956524927077
# Perplexity of the 247 BackoffSmoothing model on the test data: 10.214053418813856
# Perplexity of the 248 BackoffSmoothing model on the test data: 9.285952803882527
# Perplexity of the 249 BackoffSmoothing model on the test data: 11.119443599160117
# Perplexity of the 250 BackoffSmoothing model on the test data: 10.560685782075296
# Perplexity of the 251 BackoffSmoothing model on the test data: 11.349048130629821
# Perplexity of the 252 BackoffSmoothing model on the test data: 12.933273763004625
# Perplexity of the 253 BackoffSmoothing model on the test data: 10.059885917019036
# Perplexity of the 254 BackoffSmoothing model on the test data: 11.07415957527024
# Perplexity of the 255 BackoffSmoothing model on the test data: 11.077682420110927
# Perplexity of the 256 BackoffSmoothing model on the test data: 9.734789183022627
# Perplexity of the 257 BackoffSmoothing model on the test data: 11.04048429057412
# Perplexity of the 258 BackoffSmoothing model on the test data: 9.822484942346234
# Perplexity of the 259 BackoffSmoothing model on the test data: 9.553537729717972
# Perplexity of the 260 BackoffSmoothing model on the test data: 7.933290579805562
# Perplexity of the 261 BackoffSmoothing model on the test data: 9.746797925585538
# Perplexity of the 262 BackoffSmoothing model on the test data: 11.500463301413529
# Perplexity of the 263 BackoffSmoothing model on the test data: 10.203562567116807
# Perplexity of the 264 BackoffSmoothing model on the test data: 7.646358614878025
# Perplexity of the 265 BackoffSmoothing model on the test data: 7.921433968274922
# Perplexity of the 266 BackoffSmoothing model on the test data: 9.608892785914367
# Perplexity of the 267 BackoffSmoothing model on the test data: 8.874359299334685
# Perplexity of the 268 BackoffSmoothing model on the test data: 6.718775863486152
# Perplexity of the 269 BackoffSmoothing model on the test data: 9.244180627860255
# Perplexity of the 270 BackoffSmoothing model on the test data: 7.618851012516335
# Perplexity of the 271 BackoffSmoothing model on the test data: 8.860561311352116
# Perplexity of the 272 BackoffSmoothing model on the test data: 9.090230601791392
# Perplexity of the 273 BackoffSmoothing model on the test data: 8.757960155695281
# Perplexity of the 274 BackoffSmoothing model on the test data: 9.549418734452244
# Perplexity of the 275 BackoffSmoothing model on the test data: 9.614125009146822
# Perplexity of the 276 BackoffSmoothing model on the test data: 10.606524277606896
# Perplexity of the 277 BackoffSmoothing model on the test data: 9.080955424188918
# Perplexity of the 278 BackoffSmoothing model on the test data: 9.074107094243686
# Perplexity of the 279 BackoffSmoothing model on the test data: 8.824653368500439
# Perplexity of the 280 BackoffSmoothing model on the test data: 7.695148140342302
# Perplexity of the 281 BackoffSmoothing model on the test data: 10.08742204105699
# Perplexity of the 282 BackoffSmoothing model on the test data: 8.326596478063937
# Perplexity of the 283 BackoffSmoothing model on the test data: 7.052075788535232
# Perplexity of the 284 BackoffSmoothing model on the test data: 9.27148407263745
# Perplexity of the 285 BackoffSmoothing model on the test data: 9.297514530354583
# Perplexity of the 286 BackoffSmoothing model on the test data: 12.056618167170397
# Perplexity of the 287 BackoffSmoothing model on the test data: 11.068728085954685
# Perplexity of the 288 BackoffSmoothing model on the test data: 8.605743843981806
# Perplexity of the 289 BackoffSmoothing model on the test data: 12.40405091032315
# Perplexity of the 290 BackoffSmoothing model on the test data: 9.378028726608033
# Perplexity of the 291 BackoffSmoothing model on the test data: 4.617659764638044
# Perplexity of the 292 BackoffSmoothing model on the test data: 11.041806293867756
# Perplexity of the 293 BackoffSmoothing model on the test data: 11.222423280122229
# Perplexity of the 294 BackoffSmoothing model on the test data: 6.452729171382156
# Perplexity of the 295 BackoffSmoothing model on the test data: 11.256408104897071
# Perplexity of the 296 BackoffSmoothing model on the test data: 9.79062636925638
# Perplexity of the 297 BackoffSmoothing model on the test data: 9.213425328368102
# Perplexity of the 298 BackoffSmoothing model on the test data: 9.144633165229104
# Perplexity of the 299 BackoffSmoothing model on the test data: 9.466970484509282
# Perplexity of the 300 BackoffSmoothing model on the test data: 10.030500707996861
# Perplexity of the 301 BackoffSmoothing model on the test data: 9.15343102364897
# Perplexity of the 302 BackoffSmoothing model on the test data: 7.204645748489912
# Perplexity of the 303 BackoffSmoothing model on the test data: 10.991989801665396
# Perplexity of the 304 BackoffSmoothing model on the test data: 9.661836659913664
# Perplexity of the 305 BackoffSmoothing model on the test data: 6.330453372481455
# Perplexity of the 306 BackoffSmoothing model on the test data: 8.011705393185961
# Perplexity of the 307 BackoffSmoothing model on the test data: 9.885615414843496
# Perplexity of the 308 BackoffSmoothing model on the test data: 10.244315022407601
# Perplexity of the 309 BackoffSmoothing model on the test data: 9.506293039357116
# Perplexity of the 310 BackoffSmoothing model on the test data: 7.832782812837374
# Perplexity of the 311 BackoffSmoothing model on the test data: 10.718210299118319
# Perplexity of the 312 BackoffSmoothing model on the test data: 11.700166235317985
# Perplexity of the 313 BackoffSmoothing model on the test data: 10.664976909905764
# Perplexity of the 314 BackoffSmoothing model on the test data: 5.514375550349205
# Perplexity of the 315 BackoffSmoothing model on the test data: 9.306073707208997
# Perplexity of the 316 BackoffSmoothing model on the test data: 9.451544675810718
# Perplexity of the 317 BackoffSmoothing model on the test data: 10.483950779710339
# Perplexity of the 318 BackoffSmoothing model on the test data: 11.571567242864752
# Perplexity of the 319 BackoffSmoothing model on the test data: 9.909451767191005
# Perplexity of the 320 BackoffSmoothing model on the test data: 11.522519040327358
# Perplexity of the 321 BackoffSmoothing model on the test data: 10.32681056608109
# Perplexity of the 322 BackoffSmoothing model on the test data: 9.633077615420165
# Perplexity of the 323 BackoffSmoothing model on the test data: 8.730499485406177
# Perplexity of the 324 BackoffSmoothing model on the test data: 10.402465558516939
# Perplexity of the 325 BackoffSmoothing model on the test data: 7.876783858546135
# Perplexity of the 326 BackoffSmoothing model on the test data: 10.409501145747507
# Perplexity of the 327 BackoffSmoothing model on the test data: 11.631917747495377
# Perplexity of the 328 BackoffSmoothing model on the test data: 10.224923425894154
# Perplexity of the 329 BackoffSmoothing model on the test data: 8.197328500793624
# Perplexity of the 330 BackoffSmoothing model on the test data: 12.271573480049558
# Perplexity of the 331 BackoffSmoothing model on the test data: 10.33457667600209
# Perplexity of the 332 BackoffSmoothing model on the test data: 10.570242558758038
# Perplexity of the 333 BackoffSmoothing model on the test data: 10.490042778072548
# Perplexity of the 334 BackoffSmoothing model on the test data: 13.236540392800457
# Perplexity of the 335 BackoffSmoothing model on the test data: 9.620542475485987
# Perplexity of the 336 BackoffSmoothing model on the test data: 11.671977243254874
# Perplexity of the 337 BackoffSmoothing model on the test data: 7.959283305436516
# Perplexity of the 338 BackoffSmoothing model on the test data: 7.357647680595149
# Perplexity of the 339 BackoffSmoothing model on the test data: 10.870081374003101
# Perplexity of the 340 BackoffSmoothing model on the test data: 8.218925460408197
# Perplexity of the 341 BackoffSmoothing model on the test data: 8.827280455803594
# Perplexity of the 342 BackoffSmoothing model on the test data: 10.063329430677106
# Perplexity of the 343 BackoffSmoothing model on the test data: 9.55866105631571
# Perplexity of the 344 BackoffSmoothing model on the test data: 12.169932231368414
# Perplexity of the 345 BackoffSmoothing model on the test data: 12.069067216777627
# Perplexity of the 346 BackoffSmoothing model on the test data: 11.266879459931788
# Perplexity of the 347 BackoffSmoothing model on the test data: 9.570908538835116
# Perplexity of the 348 BackoffSmoothing model on the test data: 9.553784581995592
# Perplexity of the 349 BackoffSmoothing model on the test data: 10.384837116200988
# Perplexity of the 350 BackoffSmoothing model on the test data: 11.944857246300694
# Perplexity of the 351 BackoffSmoothing model on the test data: 11.168955242864222
# Perplexity of the 352 BackoffSmoothing model on the test data: 11.034732668380112
# Perplexity of the 353 BackoffSmoothing model on the test data: 11.053824594240558
# Perplexity of the 354 BackoffSmoothing model on the test data: 10.899193079794818
# Perplexity of the 355 BackoffSmoothing model on the test data: 7.677820064397048
# Perplexity of the 356 BackoffSmoothing model on the test data: 8.883427267096112
# Perplexity of the 357 BackoffSmoothing model on the test data: 9.622304128338529
# Perplexity of the 358 BackoffSmoothing model on the test data: 7.38553392404787
# Perplexity of the 359 BackoffSmoothing model on the test data: 7.6303100934072745
# Perplexity of the 360 BackoffSmoothing model on the test data: 12.848909759698271
# Perplexity of the 361 BackoffSmoothing model on the test data: 9.996882884020494
# Perplexity of the 362 BackoffSmoothing model on the test data: 10.013848461107402
# Perplexity of the 363 BackoffSmoothing model on the test data: 10.174863192794007
# Perplexity of the 364 BackoffSmoothing model on the test data: 11.299999340059863
# Perplexity of the 365 BackoffSmoothing model on the test data: 10.709623641108681
# Perplexity of the 366 BackoffSmoothing model on the test data: 12.754565450716878
# Perplexity of the 367 BackoffSmoothing model on the test data: 9.855458983253701
# Perplexity of the 368 BackoffSmoothing model on the test data: 11.982627509015586
# Perplexity of the 369 BackoffSmoothing model on the test data: 12.412790609642204
# Perplexity of the 370 BackoffSmoothing model on the test data: 13.008164908346295
# Perplexity of the 371 BackoffSmoothing model on the test data: 11.54129600359154
# Perplexity of the 372 BackoffSmoothing model on the test data: 8.415110620216018
# Perplexity of the 373 BackoffSmoothing model on the test data: 11.530612694996323
# Perplexity of the 374 BackoffSmoothing model on the test data: 11.71312087173689
# Perplexity of the 375 BackoffSmoothing model on the test data: 9.02084931092855
# Perplexity of the 376 BackoffSmoothing model on the test data: 11.577955238308038
# Perplexity of the 377 BackoffSmoothing model on the test data: 9.625241367081623
# Perplexity of the 378 BackoffSmoothing model on the test data: 10.021415890983816
# Perplexity of the 379 BackoffSmoothing model on the test data: 11.12653456974127
# Perplexity of the 380 BackoffSmoothing model on the test data: 10.39968486115275
# Perplexity of the 381 BackoffSmoothing model on the test data: 9.902825911934396
# Perplexity of the 382 BackoffSmoothing model on the test data: 11.585910826444984
# Perplexity of the 383 BackoffSmoothing model on the test data: 6.7681781823632425
# Perplexity of the 384 BackoffSmoothing model on the test data: 11.184290812512783
# Perplexity of the 385 BackoffSmoothing model on the test data: 6.4959978713657165
# Perplexity of the 386 BackoffSmoothing model on the test data: 10.625983339122401
# Perplexity of the 387 BackoffSmoothing model on the test data: 11.245728463323273
# Perplexity of the 388 BackoffSmoothing model on the test data: 10.964349086770957
# Perplexity of the 389 BackoffSmoothing model on the test data: 7.126108550130815
# Perplexity of the 390 BackoffSmoothing model on the test data: 12.051914136535517
# Perplexity of the 391 BackoffSmoothing model on the test data: 9.181027840507088
# Perplexity of the 392 BackoffSmoothing model on the test data: 10.439130709475354
# Perplexity of the 393 BackoffSmoothing model on the test data: 8.601662085112583
# Perplexity of the 394 BackoffSmoothing model on the test data: 10.575873035893709
# Perplexity of the 395 BackoffSmoothing model on the test data: 12.067039305333337
# Perplexity of the 396 BackoffSmoothing model on the test data: 8.483771465767965
# Perplexity of the 397 BackoffSmoothing model on the test data: 8.086500062357077
# Perplexity of the 398 BackoffSmoothing model on the test data: 10.648140484381265
# Perplexity of the 399 BackoffSmoothing model on the test data: 12.583740963290497
# Perplexity of the 400 BackoffSmoothing model on the test data: 10.394688749223782
# Perplexity of the 401 BackoffSmoothing model on the test data: 11.190762374667235
# Perplexity of the 402 BackoffSmoothing model on the test data: 10.272730498342126
# Perplexity of the 403 BackoffSmoothing model on the test data: 11.361567310975659
# Perplexity of the 404 BackoffSmoothing model on the test data: 11.189314318766309
# Perplexity of the 405 BackoffSmoothing model on the test data: 11.016375276760964
# Perplexity of the 406 BackoffSmoothing model on the test data: 11.713679866558193
# Perplexity of the 407 BackoffSmoothing model on the test data: 9.989861201324876
# Perplexity of the 408 BackoffSmoothing model on the test data: 9.595846291874086
# Perplexity of the 409 BackoffSmoothing model on the test data: 12.282879056715712
# Perplexity of the 410 BackoffSmoothing model on the test data: 10.737330253617086
# Perplexity of the 411 BackoffSmoothing model on the test data: 11.751982493612656
# Perplexity of the 412 BackoffSmoothing model on the test data: 10.48723203659757
# Perplexity of the 413 BackoffSmoothing model on the test data: 10.278738165425633
# Perplexity of the 414 BackoffSmoothing model on the test data: 8.960806565979379
# Perplexity of the 415 BackoffSmoothing model on the test data: 11.884552609867818
# Perplexity of the 416 BackoffSmoothing model on the test data: 9.84533318705014
# Perplexity of the 417 BackoffSmoothing model on the test data: 11.071660830443458
# Perplexity of the 418 BackoffSmoothing model on the test data: 9.236440069318528
# Perplexity of the 419 BackoffSmoothing model on the test data: 12.2832140545278
# Perplexity of the 420 BackoffSmoothing model on the test data: 11.311114057253643
# Perplexity of the 421 BackoffSmoothing model on the test data: 9.762422141884347
# Perplexity of the 422 BackoffSmoothing model on the test data: 10.72454941917447
# Perplexity of the 423 BackoffSmoothing model on the test data: 10.177608835294693
# Perplexity of the 424 BackoffSmoothing model on the test data: 11.28061779475736
# Perplexity of the 425 BackoffSmoothing model on the test data: 11.030414722668883
# Perplexity of the 426 BackoffSmoothing model on the test data: 8.878051555819624
# Perplexity of the 427 BackoffSmoothing model on the test data: 8.916903200055819
# Perplexity of the 428 BackoffSmoothing model on the test data: 11.494270596773092
# Perplexity of the 429 BackoffSmoothing model on the test data: 12.394529215447454
# Perplexity of the 430 BackoffSmoothing model on the test data: 10.953203648489433
# Perplexity of the 431 BackoffSmoothing model on the test data: 10.754647021793685
# Perplexity of the 432 BackoffSmoothing model on the test data: 10.562319994081847
# Perplexity of the 433 BackoffSmoothing model on the test data: 7.993182534367384
# Perplexity of the 434 BackoffSmoothing model on the test data: 10.744943668221703
# Perplexity of the 435 BackoffSmoothing model on the test data: 12.129596089986052
# Perplexity of the 436 BackoffSmoothing model on the test data: 11.201879845782173
# Perplexity of the 437 BackoffSmoothing model on the test data: 8.92570560838128
# Perplexity of the 438 BackoffSmoothing model on the test data: 8.849986424174398
# Perplexity of the 439 BackoffSmoothing model on the test data: 9.456426399532983
# Perplexity of the 440 BackoffSmoothing model on the test data: 8.40784157181563
# Perplexity of the 441 BackoffSmoothing model on the test data: 8.621413276874899
# Perplexity of the 442 BackoffSmoothing model on the test data: 10.171378944979955
# Perplexity of the 443 BackoffSmoothing model on the test data: 9.199897723835527
# Perplexity of the 444 BackoffSmoothing model on the test data: 10.379311393436277
# Perplexity of the 445 BackoffSmoothing model on the test data: 12.136226470978489
# Perplexity of the 446 BackoffSmoothing model on the test data: 9.376910063909033
# Perplexity of the 447 BackoffSmoothing model on the test data: 7.913195016641157
# Perplexity of the 448 BackoffSmoothing model on the test data: 8.191944229016242
# Perplexity of the 449 BackoffSmoothing model on the test data: 8.211008040818175
# Perplexity of the 450 BackoffSmoothing model on the test data: 11.732836385323932
# Perplexity of the 451 BackoffSmoothing model on the test data: 11.659868626260346
# Perplexity of the 452 BackoffSmoothing model on the test data: 10.636333602333558
# Perplexity of the 453 BackoffSmoothing model on the test data: 10.444137973145736
# Perplexity of the 454 BackoffSmoothing model on the test data: 12.924511335266224
# Perplexity of the 455 BackoffSmoothing model on the test data: 9.447227621537163
# Perplexity of the 456 BackoffSmoothing model on the test data: 12.054821629493745
# Perplexity of the 457 BackoffSmoothing model on the test data: 11.506142294956987
# Perplexity of the 458 BackoffSmoothing model on the test data: 8.437392757607068
# Perplexity of the 459 BackoffSmoothing model on the test data: 10.43256361074263
# Perplexity of the 460 BackoffSmoothing model on the test data: 8.876967951733494
# Perplexity of the 461 BackoffSmoothing model on the test data: 10.899240513213794
# Perplexity of the 462 BackoffSmoothing model on the test data: 9.120699925563162
# Perplexity of the 463 BackoffSmoothing model on the test data: 8.085599713698894
# Perplexity of the 464 BackoffSmoothing model on the test data: 9.360408836691366
# Perplexity of the 465 BackoffSmoothing model on the test data: 9.5010735388348
# Perplexity of the 466 BackoffSmoothing model on the test data: 6.343094280359494
# Perplexity of the 467 BackoffSmoothing model on the test data: 7.823251025622829
# Perplexity of the 468 BackoffSmoothing model on the test data: 10.252709177131688
# Perplexity of the 469 BackoffSmoothing model on the test data: 11.181154820459172
# Perplexity of the 470 BackoffSmoothing model on the test data: 9.037750284047883
# Perplexity of the 471 BackoffSmoothing model on the test data: 9.158262779214969
# Perplexity of the 472 BackoffSmoothing model on the test data: 10.483705935278973
# Perplexity of the 473 BackoffSmoothing model on the test data: 10.785482490219536
# Perplexity of the 474 BackoffSmoothing model on the test data: 12.384321192235912
# Perplexity of the 475 BackoffSmoothing model on the test data: 11.656888541445339
# Perplexity of the 476 BackoffSmoothing model on the test data: 10.901119082520703
# Perplexity of the 477 BackoffSmoothing model on the test data: 9.505300337781401
# Perplexity of the 478 BackoffSmoothing model on the test data: 11.665380999273813
# Perplexity of the 479 BackoffSmoothing model on the test data: 9.5570918561321
# Perplexity of the 480 BackoffSmoothing model on the test data: 11.351495259009186
# Perplexity of the 481 BackoffSmoothing model on the test data: 8.750016377155607
# Perplexity of the 482 BackoffSmoothing model on the test data: 8.943501226039546
# Perplexity of the 483 BackoffSmoothing model on the test data: 11.53215051988758
# Perplexity of the 484 BackoffSmoothing model on the test data: 11.801068937919172
# Perplexity of the 485 BackoffSmoothing model on the test data: 10.119279631629466
# Perplexity of the 486 BackoffSmoothing model on the test data: 9.028320882691672
# Perplexity of the 487 BackoffSmoothing model on the test data: 8.063903678147238
# Perplexity of the 488 BackoffSmoothing model on the test data: 9.242996130523327
# Perplexity of the 489 BackoffSmoothing model on the test data: 8.811858715772546
# Perplexity of the 490 BackoffSmoothing model on the test data: 10.79447867784532
# Perplexity of the 491 BackoffSmoothing model on the test data: 10.86662426479658
# Perplexity of the 492 BackoffSmoothing model on the test data: 11.465629110166727
# Perplexity of the 493 BackoffSmoothing model on the test data: 10.378860729703584
# Perplexity of the 494 BackoffSmoothing model on the test data: 10.405098710531012
# Perplexity of the 495 BackoffSmoothing model on the test data: 10.461093444600117
# Perplexity of the 496 BackoffSmoothing model on the test data: 9.901145317019319
# Perplexity of the 497 BackoffSmoothing model on the test data: 9.836346298466955
# Perplexity of the 498 BackoffSmoothing model on the test data: 14.094621676012073
# Perplexity of the 499 BackoffSmoothing model on the test data: 11.63104728486785
# Perplexity of the 500 BackoffSmoothing model on the test data: 11.451889391868432
# Perplexity of the 501 BackoffSmoothing model on the test data: 11.149337272728564
# Perplexity of the 502 BackoffSmoothing model on the test data: 10.951080139503308
# Perplexity of the 503 BackoffSmoothing model on the test data: 8.297143062186969
# Perplexity of the 504 BackoffSmoothing model on the test data: 9.422958081800193
# Perplexity of the 505 BackoffSmoothing model on the test data: 11.470838575153877
# Perplexity of the 506 BackoffSmoothing model on the test data: 10.671102800965151
# Perplexity of the 507 BackoffSmoothing model on the test data: 12.82232604306941
# Perplexity of the 508 BackoffSmoothing model on the test data: 11.463460967334948
# Perplexity of the 509 BackoffSmoothing model on the test data: 11.46686150483698
# Perplexity of the 510 BackoffSmoothing model on the test data: 10.486026404857178
# Perplexity of the 511 BackoffSmoothing model on the test data: 8.748112575147509
# Perplexity of the 512 BackoffSmoothing model on the test data: 11.291549399639255
# Perplexity of the 513 BackoffSmoothing model on the test data: 9.050734862787953
# Perplexity of the 514 BackoffSmoothing model on the test data: 5.2727458731825045
# Perplexity of the 515 BackoffSmoothing model on the test data: 10.657843843688338
# Perplexity of the 516 BackoffSmoothing model on the test data: 10.016806531513554
# Perplexity of the 517 BackoffSmoothing model on the test data: 10.657803816560651
# Perplexity of the 518 BackoffSmoothing model on the test data: 10.276014322467754
# Perplexity of the 519 BackoffSmoothing model on the test data: 8.42888664139247
# Perplexity of the 520 BackoffSmoothing model on the test data: 11.913889597301894
# Perplexity of the 521 BackoffSmoothing model on the test data: 8.421774505483212
# Perplexity of the 522 BackoffSmoothing model on the test data: 10.490772758764322
# Perplexity of the 523 BackoffSmoothing model on the test data: 10.326927731702206
# Perplexity of the 524 BackoffSmoothing model on the test data: 12.585359501937807
# Perplexity of the 525 BackoffSmoothing model on the test data: 9.866527121116338
# Perplexity of the 526 BackoffSmoothing model on the test data: 9.796894906480492
# Perplexity of the 527 BackoffSmoothing model on the test data: 10.71046601579671
# Perplexity of the 528 BackoffSmoothing model on the test data: 9.281614244746322
# Perplexity of the 529 BackoffSmoothing model on the test data: 11.711410707811234
# Perplexity of the 530 BackoffSmoothing model on the test data: 9.37346536368737
# Perplexity of the 531 BackoffSmoothing model on the test data: 9.241206882440812
# Perplexity of the 532 BackoffSmoothing model on the test data: 8.902057794450117
# Perplexity of the 533 BackoffSmoothing model on the test data: 10.202925253499036
# Perplexity of the 534 BackoffSmoothing model on the test data: 6.372212677728462
# Perplexity of the 535 BackoffSmoothing model on the test data: 11.667438484792921
# Perplexity of the 536 BackoffSmoothing model on the test data: 12.166754962002454
# Perplexity of the 537 BackoffSmoothing model on the test data: 8.408240763641167
# Perplexity of the 538 BackoffSmoothing model on the test data: 10.355938438980282
# Perplexity of the 539 BackoffSmoothing model on the test data: 7.954597216356801
# Perplexity of the 540 BackoffSmoothing model on the test data: 10.808596996403917
# Perplexity of the 541 BackoffSmoothing model on the test data: 11.49399008681547
# Perplexity of the 542 BackoffSmoothing model on the test data: 7.783402703102639
# Perplexity of the 543 BackoffSmoothing model on the test data: 12.596323627900157
# Perplexity of the 544 BackoffSmoothing model on the test data: 9.662421249275749
# Perplexity of the 545 BackoffSmoothing model on the test data: 9.275499530420948
# Perplexity of the 546 BackoffSmoothing model on the test data: 11.425244191363308
# Perplexity of the 547 BackoffSmoothing model on the test data: 7.832754869276658
# Perplexity of the 548 BackoffSmoothing model on the test data: 10.358650718213186
# Perplexity of the 549 BackoffSmoothing model on the test data: 7.684733289475805
# Perplexity of the 550 BackoffSmoothing model on the test data: 10.50900920442869
# Perplexity of the 551 BackoffSmoothing model on the test data: 12.65742901305363
# Perplexity of the 552 BackoffSmoothing model on the test data: 7.862862570795428
# Perplexity of the 553 BackoffSmoothing model on the test data: 10.199916795852586
# Perplexity of the 554 BackoffSmoothing model on the test data: 9.112120302352253
# Perplexity of the 555 BackoffSmoothing model on the test data: 9.219633756973744
# Perplexity of the 556 BackoffSmoothing model on the test data: 10.600540648901841
# Perplexity of the 557 BackoffSmoothing model on the test data: 10.79393713390996
# Perplexity of the 558 BackoffSmoothing model on the test data: 11.86141891437428
# Perplexity of the 559 BackoffSmoothing model on the test data: 11.422777108327171
# Perplexity of the 560 BackoffSmoothing model on the test data: 9.454999845927862
# Perplexity of the 561 BackoffSmoothing model on the test data: 11.405019377939356
# Perplexity of the 562 BackoffSmoothing model on the test data: 12.269348157837893
# Perplexity of the 563 BackoffSmoothing model on the test data: 9.335862885344405
# Perplexity of the 564 BackoffSmoothing model on the test data: 9.049534728474384
# Perplexity of the 565 BackoffSmoothing model on the test data: 9.370989958523946
# Perplexity of the 566 BackoffSmoothing model on the test data: 11.668427993092072
# Perplexity of the 567 BackoffSmoothing model on the test data: 9.25658583962994
# Perplexity of the 568 BackoffSmoothing model on the test data: 11.839424942451451
# Perplexity of the 569 BackoffSmoothing model on the test data: 9.786358917651988
# Perplexity of the 570 BackoffSmoothing model on the test data: 9.992099447058807
# Perplexity of the 571 BackoffSmoothing model on the test data: 12.336656113691273
# Perplexity of the 572 BackoffSmoothing model on the test data: 10.203791393336301
# Perplexity of the 573 BackoffSmoothing model on the test data: 9.21808622760945
# Perplexity of the 574 BackoffSmoothing model on the test data: 9.83434955671296
# Perplexity of the 575 BackoffSmoothing model on the test data: 10.84849513580337
# Perplexity of the 576 BackoffSmoothing model on the test data: 8.991122890353765
# Perplexity of the 577 BackoffSmoothing model on the test data: 7.378943259388936
# Perplexity of the 578 BackoffSmoothing model on the test data: 11.209772265117643
# Perplexity of the 579 BackoffSmoothing model on the test data: 11.357141548466025
# Perplexity of the 580 BackoffSmoothing model on the test data: 10.916889644841683
# Perplexity of the 581 BackoffSmoothing model on the test data: 9.05609395473594
# Perplexity of the 582 BackoffSmoothing model on the test data: 10.951261926851505
# Perplexity of the 583 BackoffSmoothing model on the test data: 9.80819588217225
# Perplexity of the 584 BackoffSmoothing model on the test data: 11.6820053311563
# Perplexity of the 585 BackoffSmoothing model on the test data: 10.627320986570338
# Perplexity of the 586 BackoffSmoothing model on the test data: 9.109786907931687
# Perplexity of the 587 BackoffSmoothing model on the test data: 10.059715193655505
# Perplexity of the 588 BackoffSmoothing model on the test data: 7.348314270391514
# Perplexity of the 589 BackoffSmoothing model on the test data: 8.215681154650758
# Perplexity of the 590 BackoffSmoothing model on the test data: 10.37714627193856
# ...
# Perplexity of the 1450 BackoffSmoothing model on the test data: 7.866121124629505
# Perplexity of the 1451 BackoffSmoothing model on the test data: 11.116407010421703
# Perplexity of the 1452 BackoffSmoothing model on the test data: 12.417566564722682
# Perplexity of the 1453 BackoffSmoothing model on the test data: 12.947584723233835
# Perplexity of the 1454 BackoffSmoothing model on the test data: 10.881012186024018
# Perplexity of the 1455 BackoffSmoothing model on the test data: 10.871934177209406
# Perplexity of the 1456 BackoffSmoothing model on the test data: 9.371945689929989
# Perplexity of the 1457 BackoffSmoothing model on the test data: 8.426622248698672
# Perplexity of the 1458 BackoffSmoothing model on the test data: 8.673488631137424
# Perplexity of the 1459 BackoffSmoothing model on the test data: 9.561508423605089
# Perplexity of the 1460 BackoffSmoothing model on the test data: 10.529584500695961
# Perplexity of the 1461 BackoffSmoothing model on the test data: 12.055617735166118
# Perplexity of the 1462 BackoffSmoothing model on the test data: 6.773260690297556
# Perplexity of the 1463 BackoffSmoothing model on the test data: 11.431197347928158
# Perplexity of the 1464 BackoffSmoothing model on the test data: 11.325093329232242
# Perplexity of the 1465 BackoffSmoothing model on the test data: 9.811344212726441
# Perplexity of the 1466 BackoffSmoothing model on the test data: 7.577877529205384
# Perplexity of the 1467 BackoffSmoothing model on the test data: 9.0531896059353
# Perplexity of the 1468 BackoffSmoothing model on the test data: 11.396228407432549
# Perplexity of the 1469 BackoffSmoothing model on the test data: 11.928419765225495
# Perplexity of the 1470 BackoffSmoothing model on the test data: 9.787645621734518
# Perplexity of the 1471 BackoffSmoothing model on the test data: 11.139277635080077
# Perplexity of the 1472 BackoffSmoothing model on the test data: 10.188134661103176
# Perplexity of the 1473 BackoffSmoothing model on the test data: 10.55919722995727
# Perplexity of the 1474 BackoffSmoothing model on the test data: 11.307514022161046
# Perplexity of the 1475 BackoffSmoothing model on the test data: 10.093185750350939
# Perplexity of the 1476 BackoffSmoothing model on the test data: 7.81632486568638
# Perplexity of the 1477 BackoffSmoothing model on the test data: 10.267972457663385
# Perplexity of the 1478 BackoffSmoothing model on the test data: 9.378185912933953
# Perplexity of the 1479 BackoffSmoothing model on the test data: 8.94354684443343
# Perplexity of the 1480 BackoffSmoothing model on the test data: 11.90862821327334
# Perplexity of the 1481 BackoffSmoothing model on the test data: 11.251992743079061
# Perplexity of the 1482 BackoffSmoothing model on the test data: 10.357630335662238
# Perplexity of the 1483 BackoffSmoothing model on the test data: 12.153381655749149
# Perplexity of the 1484 BackoffSmoothing model on the test data: 9.493580981260628
# Perplexity of the 1485 BackoffSmoothing model on the test data: 9.565610752153408
# Perplexity of the 1486 BackoffSmoothing model on the test data: 10.185899426774837
# Perplexity of the 1487 BackoffSmoothing model on the test data: 11.552326260880607
# Perplexity of the 1488 BackoffSmoothing model on the test data: 10.610153259470176
# Perplexity of the 1489 BackoffSmoothing model on the test data: 9.14302565094783
# Perplexity of the 1490 BackoffSmoothing model on the test data: 13.536370652859308
# Perplexity of the 1491 BackoffSmoothing model on the test data: 12.323335571602822
# Perplexity of the 1492 BackoffSmoothing model on the test data: 9.399413032643297
# Perplexity of the 1493 BackoffSmoothing model on the test data: 9.30374084346533
# Perplexity of the 1494 BackoffSmoothing model on the test data: 8.819303059489803
# Perplexity of the 1495 BackoffSmoothing model on the test data: 7.7872780568779305
# Perplexity of the 1496 BackoffSmoothing model on the test data: 9.122621458700857
# Perplexity of the 1497 BackoffSmoothing model on the test data: 11.805862602956221
# Perplexity of the 1498 BackoffSmoothing model on the test data: 13.231409883672667
# Perplexity of the 1499 BackoffSmoothing model on the test data: 10.835035976032461
# Perplexity of the 1500 BackoffSmoothing model on the test data: 10.613969913885505
# Perplexity of the 1501 BackoffSmoothing model on the test data: 7.51025606601227
# Perplexity of the 1502 BackoffSmoothing model on the test data: 10.225572771775973
# Perplexity of the 1503 BackoffSmoothing model on the test data: 7.816946531471371
# Perplexity of the 1504 BackoffSmoothing model on the test data: 10.159451083253341
# Perplexity of the 1505 BackoffSmoothing model on the test data: 10.011657893099445
# Perplexity of the 1506 BackoffSmoothing model on the test data: 11.494399569574565
# Perplexity of the 1507 BackoffSmoothing model on the test data: 13.505087846024763
# Perplexity of the 1508 BackoffSmoothing model on the test data: 10.903835677751001
# Perplexity of the 1509 BackoffSmoothing model on the test data: 8.051560327109524
# Perplexity of the 1510 BackoffSmoothing model on the test data: 11.884347411223201
# Perplexity of the 1511 BackoffSmoothing model on the test data: 10.727558534742393
# Perplexity of the 1512 BackoffSmoothing model on the test data: 11.476073765086895
# Perplexity of the 1513 BackoffSmoothing model on the test data: 10.61198440066719
# Perplexity of the 1514 BackoffSmoothing model on the test data: 10.359510880591468
# Perplexity of the 1515 BackoffSmoothing model on the test data: 11.373499348566659
# Perplexity of the 1516 BackoffSmoothing model on the test data: 9.109834142846639
# Perplexity of the 1517 BackoffSmoothing model on the test data: 8.765059108090362
# Perplexity of the 1518 BackoffSmoothing model on the test data: 8.652712807102358
# Perplexity of the 1519 BackoffSmoothing model on the test data: 10.551601520564933
# Perplexity of the 1520 BackoffSmoothing model on the test data: 8.309643763404665
# Perplexity of the 1521 BackoffSmoothing model on the test data: 13.095156191803243
# Perplexity of the 1522 BackoffSmoothing model on the test data: 11.304411895496381
# Perplexity of the 1523 BackoffSmoothing model on the test data: 7.025324607359564
# Perplexity of the 1524 BackoffSmoothing model on the test data: 10.157920405230705
# Perplexity of the 1525 BackoffSmoothing model on the test data: 7.381020518179016
# Perplexity of the 1526 BackoffSmoothing model on the test data: 8.985122231991086
# Perplexity of the 1527 BackoffSmoothing model on the test data: 10.941238327358237
# Perplexity of the 1528 BackoffSmoothing model on the test data: 7.668476065822536
# Perplexity of the 1529 BackoffSmoothing model on the test data: 11.725903974475237
# Perplexity of the 1530 BackoffSmoothing model on the test data: 9.727005093927042
# Perplexity of the 1531 BackoffSmoothing model on the test data: 8.365744893162823
# Perplexity of the 1532 BackoffSmoothing model on the test data: 12.24935866477661
# Perplexity of the 1533 BackoffSmoothing model on the test data: 11.756122357449863
# Perplexity of the 1534 BackoffSmoothing model on the test data: 10.418166698222866
# Perplexity of the 1535 BackoffSmoothing model on the test data: 8.64387457488785
# Perplexity of the 1536 BackoffSmoothing model on the test data: 9.605370044423404
# Perplexity of the 1537 BackoffSmoothing model on the test data: 9.35855615967415
# Perplexity of the 1538 BackoffSmoothing model on the test data: 10.86466033241121
# Perplexity of the 1539 BackoffSmoothing model on the test data: 12.155946023168296
# Perplexity of the 1540 BackoffSmoothing model on the test data: 12.14348864499533
# Perplexity of the 1541 BackoffSmoothing model on the test data: 10.705992034718758
# Perplexity of the 1542 BackoffSmoothing model on the test data: 11.029560560279078
# Perplexity of the 1543 BackoffSmoothing model on the test data: 8.060280340970937
# Perplexity of the 1544 BackoffSmoothing model on the test data: 8.088526774211095
# Perplexity of the 1545 BackoffSmoothing model on the test data: 10.537204353320142
# Perplexity of the 1546 BackoffSmoothing model on the test data: 12.289458888201372
# Perplexity of the 1547 BackoffSmoothing model on the test data: 10.68379164288587
# Perplexity of the 1548 BackoffSmoothing model on the test data: 11.296120172267509
# Perplexity of the 1549 BackoffSmoothing model on the test data: 10.483085504260897
# Perplexity of the 1550 BackoffSmoothing model on the test data: 9.769955803052836
# Perplexity of the 1551 BackoffSmoothing model on the test data: 10.73230911202575
# Perplexity of the 1552 BackoffSmoothing model on the test data: 8.73883159613859
# Perplexity of the 1553 BackoffSmoothing model on the test data: 9.992585759834114
# Perplexity of the 1554 BackoffSmoothing model on the test data: 11.641097841368003
# Perplexity of the 1555 BackoffSmoothing model on the test data: 8.667294604221329
# Perplexity of the 1556 BackoffSmoothing model on the test data: 8.64077957522169
# Perplexity of the 1557 BackoffSmoothing model on the test data: 12.09541379218009
# Perplexity of the 1558 BackoffSmoothing model on the test data: 10.428166025527911
# Perplexity of the 1559 BackoffSmoothing model on the test data: 6.800957478231129
# Perplexity of the 1560 BackoffSmoothing model on the test data: 6.8300173343905435
# Perplexity of the 1561 BackoffSmoothing model on the test data: 9.917787072088338
# Perplexity of the 1562 BackoffSmoothing model on the test data: 8.936572212410418
# Perplexity of the 1563 BackoffSmoothing model on the test data: 10.058552938073536
# Perplexity of the 1564 BackoffSmoothing model on the test data: 9.418283552067624
# Perplexity of the 1565 BackoffSmoothing model on the test data: 13.073956467756096
# Perplexity of the 1566 BackoffSmoothing model on the test data: 11.916710351136812
# Perplexity of the 1567 BackoffSmoothing model on the test data: 11.830984482149223
# Perplexity of the 1568 BackoffSmoothing model on the test data: 12.890604816400518
# Perplexity of the 1569 BackoffSmoothing model on the test data: 12.260965139021156
# Perplexity of the 1570 BackoffSmoothing model on the test data: 10.539663264492635
# Perplexity of the 1571 BackoffSmoothing model on the test data: 7.227029206539273
# Perplexity of the 1572 BackoffSmoothing model on the test data: 10.2161257950142
# Perplexity of the 1573 BackoffSmoothing model on the test data: 6.873764682357793
# Perplexity of the 1574 BackoffSmoothing model on the test data: 11.651138076878434
# Perplexity of the 1575 BackoffSmoothing model on the test data: 8.979075390114906
# Perplexity of the 1576 BackoffSmoothing model on the test data: 10.703755717528558
# Perplexity of the 1577 BackoffSmoothing model on the test data: 11.162909716602464
# Perplexity of the 1578 BackoffSmoothing model on the test data: 9.671556147894055
# Perplexity of the 1579 BackoffSmoothing model on the test data: 11.962678343744932
# Perplexity of the 1580 BackoffSmoothing model on the test data: 11.759075103718194
# Perplexity of the 1581 BackoffSmoothing model on the test data: 11.416680717135062
# Perplexity of the 1582 BackoffSmoothing model on the test data: 8.778080739278165
# Perplexity of the 1583 BackoffSmoothing model on the test data: 8.74437968236362
# Perplexity of the 1584 BackoffSmoothing model on the test data: 10.679578343887746
# Perplexity of the 1585 BackoffSmoothing model on the test data: 10.786519738867629
# Perplexity of the 1586 BackoffSmoothing model on the test data: 9.476149209216874
# Perplexity of the 1587 BackoffSmoothing model on the test data: 11.446148643591648
# Perplexity of the 1588 BackoffSmoothing model on the test data: 9.046538137755721
# Perplexity of the 1589 BackoffSmoothing model on the test data: 7.827691612034894
# Perplexity of the 1590 BackoffSmoothing model on the test data: 10.032377813118414
# Perplexity of the 1591 BackoffSmoothing model on the test data: 11.6858165440473
# Perplexity of the 1592 BackoffSmoothing model on the test data: 10.842741986737748
# Perplexity of the 1593 BackoffSmoothing model on the test data: 8.695101056084129
# Perplexity of the 1594 BackoffSmoothing model on the test data: 9.333339644841208
# Perplexity of the 1595 BackoffSmoothing model on the test data: 9.692057325282454
# Perplexity of the 1596 BackoffSmoothing model on the test data: 11.663967569667117
# Perplexity of the 1597 BackoffSmoothing model on the test data: 9.254469186039316
# Perplexity of the 1598 BackoffSmoothing model on the test data: 11.955448458067968
# Perplexity of the 1599 BackoffSmoothing model on the test data: 11.380178763874952
# Perplexity of the 1600 BackoffSmoothing model on the test data: 10.446101652841167
# Perplexity of the 1601 BackoffSmoothing model on the test data: 8.117510571207609
# Perplexity of the 1602 BackoffSmoothing model on the test data: 10.185134121110508
# Perplexity of the 1603 BackoffSmoothing model on the test data: 11.651896580720921
# Perplexity of the 1604 BackoffSmoothing model on the test data: 7.9682779984313346
# Perplexity of the 1605 BackoffSmoothing model on the test data: 11.80184715302171
# Perplexity of the 1606 BackoffSmoothing model on the test data: 7.787151592219346
# Perplexity of the 1607 BackoffSmoothing model on the test data: 9.62395688684631
# Perplexity of the 1608 BackoffSmoothing model on the test data: 11.924116469329478
# Perplexity of the 1609 BackoffSmoothing model on the test data: 10.439718667895427
# Perplexity of the 1610 BackoffSmoothing model on the test data: 9.648327343217602
# Perplexity of the 1611 BackoffSmoothing model on the test data: 9.422537379824616
# Perplexity of the 1612 BackoffSmoothing model on the test data: 10.419139159744583
# Perplexity of the 1613 BackoffSmoothing model on the test data: 10.7136218213161
# Perplexity of the 1614 BackoffSmoothing model on the test data: 9.528322409782861
# Perplexity of the 1615 BackoffSmoothing model on the test data: 9.040781490972487
# Perplexity of the 1616 BackoffSmoothing model on the test data: 7.679877771083309
# Perplexity of the 1617 BackoffSmoothing model on the test data: 12.877807972182412
# Perplexity of the 1618 BackoffSmoothing model on the test data: 12.49174322897916
# Perplexity of the 1619 BackoffSmoothing model on the test data: 9.673500341266173
# Perplexity of the 1620 BackoffSmoothing model on the test data: 9.08506895175091
# Perplexity of the 1621 BackoffSmoothing model on the test data: 10.852116758349084
# Perplexity of the 1622 BackoffSmoothing model on the test data: 6.7816707931014095
# Perplexity of the 1623 BackoffSmoothing model on the test data: 11.496637909168015
# Perplexity of the 1624 BackoffSmoothing model on the test data: 10.642845231857846
# Perplexity of the 1625 BackoffSmoothing model on the test data: 11.216477158251712
# Perplexity of the 1626 BackoffSmoothing model on the test data: 12.024290974862893
# Perplexity of the 1627 BackoffSmoothing model on the test data: 7.994372768134285
# Perplexity of the 1628 BackoffSmoothing model on the test data: 6.7014399356233545
# Perplexity of the 1629 BackoffSmoothing model on the test data: 12.961663263079556
# Perplexity of the 1630 BackoffSmoothing model on the test data: 7.354353167527504
# Perplexity of the 1631 BackoffSmoothing model on the test data: 9.967544228324376
# Perplexity of the 1632 BackoffSmoothing model on the test data: 10.547259755106404
# Perplexity of the 1633 BackoffSmoothing model on the test data: 9.332889086874685
# Perplexity of the 1634 BackoffSmoothing model on the test data: 10.517619768280003
# Perplexity of the 1635 BackoffSmoothing model on the test data: 11.169032662439562
# Perplexity of the 1636 BackoffSmoothing model on the test data: 11.72653669771805
# Perplexity of the 1637 BackoffSmoothing model on the test data: 9.674645283440324
# Perplexity of the 1638 BackoffSmoothing model on the test data: 10.309313234508473
# Perplexity of the 1639 BackoffSmoothing model on the test data: 9.89370194021802
# Perplexity of the 1640 BackoffSmoothing model on the test data: 10.867137456697364
# Perplexity of the 1641 BackoffSmoothing model on the test data: 7.673066276253242
# Perplexity of the 1642 BackoffSmoothing model on the test data: 7.680833524721168
# Perplexity of the 1643 BackoffSmoothing model on the test data: 12.57925844739652

# %%
# unigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(1)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1, 0.3, 0.5, 0.7]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 1.8690577558729635
# Perplexity of the 1 Absolute Discounting model on the test data: 1317.9769454091102
# Perplexity of the 2 Absolute Discounting model on the test data: 1245.5994298288497
# Perplexity of the 3 Absolute Discounting model on the test data: 1060.2788774374537
# Perplexity of the 4 Absolute Discounting model on the test data: 3731.1422346932422
# Perplexity of the 5 Absolute Discounting model on the test data: 1542.959106538041
# Perplexity of the 6 Absolute Discounting model on the test data: 1092.1176935925334
# Perplexity of the 7 Absolute Discounting model on the test data: 1097.4354179485988
# Perplexity of the 8 Absolute Discounting model on the test data: 1597.1732566461742
# Perplexity of the 9 Absolute Discounting model on the test data: 2305.0866338389856
# Perplexity of the 10 Absolute Discounting model on the test data: 2009.29346138084
# Perplexity of the 11 Absolute Discounting model on the test data: 1434.0334021970043
# Perplexity of the 12 Absolute Discounting model on the test data: 927.3200875495419
# Perplexity of the 13 Absolute Discounting model on the test data: 4094.1937433601242
# Perplexity of the 14 Absolute Discounting model on the test data: 2200.747848924153
# Perplexity of the 15 Absolute Discounting model on the test data: 1422.9324366075614
# Perplexity of the 16 Absolute Discounting model on the test data: 1965.5243046927928
# Perplexity of the 17 Absolute Discounting model on the test data: 1137.7416338616986
# Perplexity of the 18 Absolute Discounting model on the test data: 1195.3772621011785
# Perplexity of the 19 Absolute Discounting model on the test data: 1027.2940595184218
# Perplexity of the 20 Absolute Discounting model on the test data: 949.2791592656979
# Perplexity of the 21 Absolute Discounting model on the test data: 1973.8212785374187
# Perplexity of the 22 Absolute Discounting model on the test data: 3244.2574606955077
# Perplexity of the 23 Absolute Discounting model on the test data: 2174.6183078263225
# Perplexity of the 24 Absolute Discounting model on the test data: 788.458808035265
# Perplexity of the 25 Absolute Discounting model on the test data: 1718.777931710143
# Perplexity of the 26 Absolute Discounting model on the test data: 1148.6432186824927
# Perplexity of the 27 Absolute Discounting model on the test data: 855.300304330671
# Perplexity of the 28 Absolute Discounting model on the test data: 1800.964806403643
# Perplexity of the 29 Absolute Discounting model on the test data: 816.1961191695781
# Perplexity of the 30 Absolute Discounting model on the test data: 1292.4064476944457
# Perplexity of the 31 Absolute Discounting model on the test data: 952.3289685312409
# Perplexity of the 32 Absolute Discounting model on the test data: 3849.248930382441
# Perplexity of the 33 Absolute Discounting model on the test data: 3600.020714995598
# Perplexity of the 34 Absolute Discounting model on the test data: 1987.7623384275682
# Perplexity of the 35 Absolute Discounting model on the test data: 2231.3602307158108
# Perplexity of the 36 Absolute Discounting model on the test data: 1144.3986481410777
# Perplexity of the 37 Absolute Discounting model on the test data: 2246.594675120577
# Perplexity of the 38 Absolute Discounting model on the test data: 1539.0756023364797
# Perplexity of the 39 Absolute Discounting model on the test data: 1140.3061487351404
# Perplexity of the 40 Absolute Discounting model on the test data: 1118.1228424832784
# Perplexity of the 41 Absolute Discounting model on the test data: 1012.3285635861963
# Perplexity of the 42 Absolute Discounting model on the test data: 1626.0739445973713
# Perplexity of the 43 Absolute Discounting model on the test data: 928.0558819923835
# Perplexity of the 44 Absolute Discounting model on the test data: 1440.337302599491
# Perplexity of the 45 Absolute Discounting model on the test data: 1127.8366831605724
# Perplexity of the 46 Absolute Discounting model on the test data: 1257.17569389192
# Perplexity of the 47 Absolute Discounting model on the test data: 1533.2161962772282
# Perplexity of the 48 Absolute Discounting model on the test data: 1253.3026675993817
# Perplexity of the 49 Absolute Discounting model on the test data: 1094.4632196750583
# Perplexity of the 50 Absolute Discounting model on the test data: 552.3215614078065
# Perplexity of the 51 Absolute Discounting model on the test data: 1114.3299381759923
# Perplexity of the 52 Absolute Discounting model on the test data: 1324.8005565614144
# Perplexity of the 53 Absolute Discounting model on the test data: 1130.120902926909
# Perplexity of the 54 Absolute Discounting model on the test data: 1116.9321546072192
# Perplexity of the 55 Absolute Discounting model on the test data: 2062.083700149341
# Perplexity of the 56 Absolute Discounting model on the test data: 2308.870741320428
# Perplexity of the 57 Absolute Discounting model on the test data: 1297.417313874604
# Perplexity of the 58 Absolute Discounting model on the test data: 760.4821590411248
# Perplexity of the 59 Absolute Discounting model on the test data: 711.454312431343
# Perplexity of the 60 Absolute Discounting model on the test data: 1113.669827448305
# Perplexity of the 61 Absolute Discounting model on the test data: 969.9156259144139
# Perplexity of the 62 Absolute Discounting model on the test data: 648.4412849461651
# Perplexity of the 63 Absolute Discounting model on the test data: 904.2936547313866
# Perplexity of the 64 Absolute Discounting model on the test data: 747.0045802378338
# Perplexity of the 65 Absolute Discounting model on the test data: 735.8705157187405
# Perplexity of the 66 Absolute Discounting model on the test data: 1521.651488020435
# Perplexity of the 67 Absolute Discounting model on the test data: 635.5473983434493
# Perplexity of the 68 Absolute Discounting model on the test data: 699.0484486859339
# Perplexity of the 69 Absolute Discounting model on the test data: 1207.160782313134
# Perplexity of the 70 Absolute Discounting model on the test data: 839.6237533302381
# Perplexity of the 71 Absolute Discounting model on the test data: 1327.5648903562942
# Perplexity of the 72 Absolute Discounting model on the test data: 2861.209551517388
# Perplexity of the 73 Absolute Discounting model on the test data: 1402.5458213342413
# Perplexity of the 74 Absolute Discounting model on the test data: 1160.2864970037135
# Perplexity of the 75 Absolute Discounting model on the test data: 761.5414754002355
# Perplexity of the 76 Absolute Discounting model on the test data: 1295.82718384717
# Perplexity of the 77 Absolute Discounting model on the test data: 1305.806427391856
# Perplexity of the 78 Absolute Discounting model on the test data: 999.2061387145878
# Perplexity of the 79 Absolute Discounting model on the test data: 436.1383676845614
# Perplexity of the 80 Absolute Discounting model on the test data: 970.5306502913367
# Perplexity of the 81 Absolute Discounting model on the test data: 1025.7689908600487
# Perplexity of the 82 Absolute Discounting model on the test data: 1448.8437287254887
# Perplexity of the 83 Absolute Discounting model on the test data: 918.1645850575358
# Perplexity of the 84 Absolute Discounting model on the test data: 373.29940447262976
# Perplexity of the 85 Absolute Discounting model on the test data: 1354.0111303228798
# Perplexity of the 86 Absolute Discounting model on the test data: 1461.0718262114299
# Perplexity of the 87 Absolute Discounting model on the test data: 1268.7832521230841
# Perplexity of the 88 Absolute Discounting model on the test data: 1849.3681658960265
# Perplexity of the 89 Absolute Discounting model on the test data: 816.9396796739017
# Perplexity of the 90 Absolute Discounting model on the test data: 1135.2872898410897
# Perplexity of the 91 Absolute Discounting model on the test data: 1905.7578993864604
# Perplexity of the 92 Absolute Discounting model on the test data: 1657.37619980442
# Perplexity of the 93 Absolute Discounting model on the test data: 1810.1037012295428
# Perplexity of the 94 Absolute Discounting model on the test data: 1364.263549062016
# Perplexity of the 95 Absolute Discounting model on the test data: 1831.25238636854
# Perplexity of the 96 Absolute Discounting model on the test data: 3419.7552763482104
# Perplexity of the 97 Absolute Discounting model on the test data: 677.5636724568504
# Perplexity of the 98 Absolute Discounting model on the test data: 1249.954452064335
# Perplexity of the 99 Absolute Discounting model on the test data: 1071.1890499166504
# Perplexity of the 100 Absolute Discounting model on the test data: 515.694485816656
# Perplexity of the 101 Absolute Discounting model on the test data: 1979.2780028386708
# Perplexity of the 102 Absolute Discounting model on the test data: 1834.55233909789
# Perplexity of the 103 Absolute Discounting model on the test data: 610.1642044397219
# Perplexity of the 104 Absolute Discounting model on the test data: 2181.3948800476655
# Perplexity of the 105 Absolute Discounting model on the test data: 889.2409017300081
# Perplexity of the 106 Absolute Discounting model on the test data: 899.7114160857165
# Perplexity of the 107 Absolute Discounting model on the test data: 2428.9091343019945
# Perplexity of the 108 Absolute Discounting model on the test data: 1074.617642196449
# Perplexity of the 109 Absolute Discounting model on the test data: 1412.0552562464193
# Perplexity of the 110 Absolute Discounting model on the test data: 1089.963657726475
# Perplexity of the 111 Absolute Discounting model on the test data: 1062.3661006785087
# Perplexity of the 112 Absolute Discounting model on the test data: 604.8507667668378
# Perplexity of the 113 Absolute Discounting model on the test data: 1144.0095728667322
# Perplexity of the 114 Absolute Discounting model on the test data: 1444.8053179167057
# Perplexity of the 115 Absolute Discounting model on the test data: 1768.0260209327075
# Perplexity of the 116 Absolute Discounting model on the test data: 1237.725248238373
# Perplexity of the 117 Absolute Discounting model on the test data: 1478.7218359774138
# Perplexity of the 118 Absolute Discounting model on the test data: 1123.5231364805375
# Perplexity of the 119 Absolute Discounting model on the test data: 877.5039881982583
# Perplexity of the 120 Absolute Discounting model on the test data: 1111.623313757991
# Perplexity of the 121 Absolute Discounting model on the test data: 859.0785014702423
# Perplexity of the 122 Absolute Discounting model on the test data: 957.1124779027865
# Perplexity of the 123 Absolute Discounting model on the test data: 1806.5804772091599
# Perplexity of the 124 Absolute Discounting model on the test data: 1048.1568149394407
# Perplexity of the 125 Absolute Discounting model on the test data: 1044.4434628457966
# Perplexity of the 126 Absolute Discounting model on the test data: 1342.9163405392658
# Perplexity of the 127 Absolute Discounting model on the test data: 1044.8995006447378
# Perplexity of the 128 Absolute Discounting model on the test data: 1541.229732069365
# Perplexity of the 129 Absolute Discounting model on the test data: 1173.6935072415524
# Perplexity of the 130 Absolute Discounting model on the test data: 1246.8323854416853
# Perplexity of the 131 Absolute Discounting model on the test data: 668.9629119441155
# Perplexity of the 132 Absolute Discounting model on the test data: 1661.2743261423946
# Perplexity of the 133 Absolute Discounting model on the test data: 931.6189469068498
# Perplexity of the 134 Absolute Discounting model on the test data: 1453.3089790126335
# Perplexity of the 135 Absolute Discounting model on the test data: 1420.6942126847655
# Perplexity of the 136 Absolute Discounting model on the test data: 1001.6433851650072
# Perplexity of the 137 Absolute Discounting model on the test data: 689.9591816924577
# Perplexity of the 138 Absolute Discounting model on the test data: 1940.050765552253
# Perplexity of the 139 Absolute Discounting model on the test data: 1384.7928955006603
# Perplexity of the 140 Absolute Discounting model on the test data: 1264.6010437460484
# Perplexity of the 141 Absolute Discounting model on the test data: 1540.5098679214022
# Perplexity of the 142 Absolute Discounting model on the test data: 1184.7391445793025
# Perplexity of the 143 Absolute Discounting model on the test data: 1590.3778903904144
# Perplexity of the 144 Absolute Discounting model on the test data: 819.0570390405685
# Perplexity of the 145 Absolute Discounting model on the test data: 1579.1380588726663
# Perplexity of the 146 Absolute Discounting model on the test data: 1605.5768181044975
# Perplexity of the 147 Absolute Discounting model on the test data: 927.189615350308
# Perplexity of the 148 Absolute Discounting model on the test data: 1254.515881259653
# Perplexity of the 149 Absolute Discounting model on the test data: 1062.1470389017109
# Perplexity of the 150 Absolute Discounting model on the test data: 1332.393911383063
# Perplexity of the 151 Absolute Discounting model on the test data: 2440.867069641612
# Perplexity of the 152 Absolute Discounting model on the test data: 2830.5680869307203
# Perplexity of the 153 Absolute Discounting model on the test data: 1035.6980053757295
# Perplexity of the 154 Absolute Discounting model on the test data: 804.7739341081664
# Perplexity of the 155 Absolute Discounting model on the test data: 1932.7672126164255
# Perplexity of the 156 Absolute Discounting model on the test data: 1790.977263093796
# Perplexity of the 157 Absolute Discounting model on the test data: 2136.5515802983773
# Perplexity of the 158 Absolute Discounting model on the test data: 1220.8497260133684
# Perplexity of the 159 Absolute Discounting model on the test data: 1455.57166861365
# Perplexity of the 160 Absolute Discounting model on the test data: 1549.772694262207
# Perplexity of the 161 Absolute Discounting model on the test data: 1031.4057717233936
# Perplexity of the 162 Absolute Discounting model on the test data: 1076.7663811383206
# Perplexity of the 163 Absolute Discounting model on the test data: 1665.114530893855
# Perplexity of the 164 Absolute Discounting model on the test data: 1072.015358835625
# Perplexity of the 165 Absolute Discounting model on the test data: 1376.6800455242692
# Perplexity of the 166 Absolute Discounting model on the test data: 2246.6487746692296
# Perplexity of the 167 Absolute Discounting model on the test data: 920.7523933015748
# Perplexity of the 168 Absolute Discounting model on the test data: 1713.308098130532
# Perplexity of the 169 Absolute Discounting model on the test data: 1239.3345562948875
# Perplexity of the 170 Absolute Discounting model on the test data: 1042.031804128778
# Perplexity of the 171 Absolute Discounting model on the test data: 850.5468902046298
# Perplexity of the 172 Absolute Discounting model on the test data: 1463.5289790842744
# Perplexity of the 173 Absolute Discounting model on the test data: 1805.7422581917376
# Perplexity of the 174 Absolute Discounting model on the test data: 1232.2302923611178
# Perplexity of the 175 Absolute Discounting model on the test data: 1592.1605658170154
# Perplexity of the 176 Absolute Discounting model on the test data: 1388.9176847073531
# Perplexity of the 177 Absolute Discounting model on the test data: 2029.619208049965
# Perplexity of the 178 Absolute Discounting model on the test data: 1596.5541193740335
# Perplexity of the 179 Absolute Discounting model on the test data: 1324.214289985221
# Perplexity of the 180 Absolute Discounting model on the test data: 3215.570270508625
# Perplexity of the 181 Absolute Discounting model on the test data: 1319.976830218061
# Perplexity of the 182 Absolute Discounting model on the test data: 1401.737163672412
# Perplexity of the 183 Absolute Discounting model on the test data: 752.4448150033074
# Perplexity of the 184 Absolute Discounting model on the test data: 1671.0577491635217
# Perplexity of the 185 Absolute Discounting model on the test data: 506.5065611239724
# Perplexity of the 186 Absolute Discounting model on the test data: 1034.476452751444
# Perplexity of the 187 Absolute Discounting model on the test data: 1238.6516432394772
# Perplexity of the 188 Absolute Discounting model on the test data: 2523.60280435292
# Perplexity of the 189 Absolute Discounting model on the test data: 526.9682002595872
# Perplexity of the 190 Absolute Discounting model on the test data: 1614.0988752407209
# Perplexity of the 191 Absolute Discounting model on the test data: 1923.9922747460776
# Perplexity of the 192 Absolute Discounting model on the test data: 1079.6655351833024
# Perplexity of the 193 Absolute Discounting model on the test data: 844.8933683777428
# Perplexity of the 194 Absolute Discounting model on the test data: 1890.3620551347246
# Perplexity of the 195 Absolute Discounting model on the test data: 1188.2833081659237
# Perplexity of the 196 Absolute Discounting model on the test data: 710.8183468146783
# Perplexity of the 197 Absolute Discounting model on the test data: 1552.477918595166
# Perplexity of the 198 Absolute Discounting model on the test data: 1033.6374592045743
# Perplexity of the 199 Absolute Discounting model on the test data: 1976.352005730629
# Perplexity of the 200 Absolute Discounting model on the test data: 1614.205366714442
# Perplexity of the 201 Absolute Discounting model on the test data: 1079.1999041303561
# Perplexity of the 202 Absolute Discounting model on the test data: 1414.5575800571273
# Perplexity of the 203 Absolute Discounting model on the test data: 1655.182965973812
# Perplexity of the 204 Absolute Discounting model on the test data: 1139.0903618885056
# Perplexity of the 205 Absolute Discounting model on the test data: 2020.4597964493942
# Perplexity of the 206 Absolute Discounting model on the test data: 1278.1545302298452
# Perplexity of the 207 Absolute Discounting model on the test data: 2405.8653039752785
# Perplexity of the 208 Absolute Discounting model on the test data: 854.0775612820214
# Perplexity of the 209 Absolute Discounting model on the test data: 866.7543662593002
# Perplexity of the 210 Absolute Discounting model on the test data: 925.2715197553168
# Perplexity of the 211 Absolute Discounting model on the test data: 497.98450555066415
# Perplexity of the 212 Absolute Discounting model on the test data: 1258.2339173329246
# Perplexity of the 213 Absolute Discounting model on the test data: 1292.441013463651
# Perplexity of the 214 Absolute Discounting model on the test data: 1114.8072154111946
# Perplexity of the 215 Absolute Discounting model on the test data: 1212.5296760728465
# Perplexity of the 216 Absolute Discounting model on the test data: 1487.4411888701197
# Perplexity of the 217 Absolute Discounting model on the test data: 1144.4737605567316
# Perplexity of the 218 Absolute Discounting model on the test data: 955.3310255447257
# Perplexity of the 219 Absolute Discounting model on the test data: 825.0906245811466
# Perplexity of the 220 Absolute Discounting model on the test data: 1832.1191875802572
# Perplexity of the 221 Absolute Discounting model on the test data: 1172.3376424018284
# Perplexity of the 222 Absolute Discounting model on the test data: 1163.93546463946
# Perplexity of the 223 Absolute Discounting model on the test data: 1118.5593699329709
# Perplexity of the 224 Absolute Discounting model on the test data: 839.1927648424703
# Perplexity of the 225 Absolute Discounting model on the test data: 1050.3587548991197
# Perplexity of the 226 Absolute Discounting model on the test data: 924.4895701377194
# Perplexity of the 227 Absolute Discounting model on the test data: 1431.286856490118
# Perplexity of the 228 Absolute Discounting model on the test data: 1618.0268765831452
# Perplexity of the 229 Absolute Discounting model on the test data: 1055.494120142106
# Perplexity of the 230 Absolute Discounting model on the test data: 699.9863637273703
# Perplexity of the 231 Absolute Discounting model on the test data: 1532.3899682079332
# Perplexity of the 232 Absolute Discounting model on the test data: 1086.528921879603
# Perplexity of the 233 Absolute Discounting model on the test data: 1082.7500713928325
# Perplexity of the 234 Absolute Discounting model on the test data: 942.3683830812422
# Perplexity of the 235 Absolute Discounting model on the test data: 1714.4447130574426
# Perplexity of the 236 Absolute Discounting model on the test data: 1353.1552185445803
# Perplexity of the 237 Absolute Discounting model on the test data: 1773.091213410163
# Perplexity of the 238 Absolute Discounting model on the test data: 1149.727526939169
# Perplexity of the 239 Absolute Discounting model on the test data: 1200.4661209717262
# Perplexity of the 240 Absolute Discounting model on the test data: 1009.7190958664586
# Perplexity of the 241 Absolute Discounting model on the test data: 1218.9139068373527
# Perplexity of the 242 Absolute Discounting model on the test data: 1042.1323605454595
# Perplexity of the 243 Absolute Discounting model on the test data: 837.8733895989251
# Perplexity of the 244 Absolute Discounting model on the test data: 981.3872041673205
# Perplexity of the 245 Absolute Discounting model on the test data: 737.3302441260511
# Perplexity of the 246 Absolute Discounting model on the test data: 713.1301227487658
# Perplexity of the 247 Absolute Discounting model on the test data: 877.3970512354999
# Perplexity of the 248 Absolute Discounting model on the test data: 1233.509888164663
# Perplexity of the 249 Absolute Discounting model on the test data: 1241.0728698432865
# Perplexity of the 250 Absolute Discounting model on the test data: 1340.8288282449803
# Perplexity of the 251 Absolute Discounting model on the test data: 1405.9574737749342
# Perplexity of the 252 Absolute Discounting model on the test data: 1107.5301947158218
# Perplexity of the 253 Absolute Discounting model on the test data: 1478.8649419578921
# Perplexity of the 254 Absolute Discounting model on the test data: 2284.156979911038
# Perplexity of the 255 Absolute Discounting model on the test data: 2169.09805989797
# Perplexity of the 256 Absolute Discounting model on the test data: 1655.6706154225737
# Perplexity of the 257 Absolute Discounting model on the test data: 2728.0649619730657
# Perplexity of the 258 Absolute Discounting model on the test data: 1460.6587969530856
# Perplexity of the 259 Absolute Discounting model on the test data: 1429.1184016943907
# Perplexity of the 260 Absolute Discounting model on the test data: 703.045864048602
# Perplexity of the 261 Absolute Discounting model on the test data: 913.85248913294
# Perplexity of the 262 Absolute Discounting model on the test data: 1091.7346966432506
# Perplexity of the 263 Absolute Discounting model on the test data: 1408.6818691989474
# Perplexity of the 264 Absolute Discounting model on the test data: 411.3906794872498
# Perplexity of the 265 Absolute Discounting model on the test data: 1025.2225362296883
# Perplexity of the 266 Absolute Discounting model on the test data: 1141.68036682219
# Perplexity of the 267 Absolute Discounting model on the test data: 2977.5577549268946
# Perplexity of the 268 Absolute Discounting model on the test data: 4493.644406990356
# Perplexity of the 269 Absolute Discounting model on the test data: 424.27565668225566
# Perplexity of the 270 Absolute Discounting model on the test data: 494.7677170317721
# Perplexity of the 271 Absolute Discounting model on the test data: 647.0199106041053
# Perplexity of the 272 Absolute Discounting model on the test data: 1170.2858424938954
# Perplexity of the 273 Absolute Discounting model on the test data: 1743.8561653403171
# Perplexity of the 274 Absolute Discounting model on the test data: 1702.746509309176
# Perplexity of the 275 Absolute Discounting model on the test data: 1367.7360925001697
# Perplexity of the 276 Absolute Discounting model on the test data: 2059.9369538315727
# Perplexity of the 277 Absolute Discounting model on the test data: 963.0393164326473
# Perplexity of the 278 Absolute Discounting model on the test data: 970.5360662803721
# Perplexity of the 279 Absolute Discounting model on the test data: 1285.1112243454654
# Perplexity of the 280 Absolute Discounting model on the test data: 1234.7706025324824
# Perplexity of the 281 Absolute Discounting model on the test data: 1183.2300573307596
# Perplexity of the 282 Absolute Discounting model on the test data: 606.8724811145232
# Perplexity of the 283 Absolute Discounting model on the test data: 987.0288389215077
# Perplexity of the 284 Absolute Discounting model on the test data: 755.8255148023273
# Perplexity of the 285 Absolute Discounting model on the test data: 1424.1016325611245
# Perplexity of the 286 Absolute Discounting model on the test data: 1202.4401428198012
# Perplexity of the 287 Absolute Discounting model on the test data: 1689.606470952271
# Perplexity of the 288 Absolute Discounting model on the test data: 845.8825999653214
# Perplexity of the 289 Absolute Discounting model on the test data: 1693.4169835151356
# Perplexity of the 290 Absolute Discounting model on the test data: 2534.560669150615
# Perplexity of the 291 Absolute Discounting model on the test data: 1289.0674312175288
# Perplexity of the 292 Absolute Discounting model on the test data: 2007.646947779789
# Perplexity of the 293 Absolute Discounting model on the test data: 2221.267253320097
# Perplexity of the 294 Absolute Discounting model on the test data: 1170.8130349957612
# Perplexity of the 295 Absolute Discounting model on the test data: 1804.342027324861
# Perplexity of the 296 Absolute Discounting model on the test data: 895.6942857554924
# Perplexity of the 297 Absolute Discounting model on the test data: 1157.112752218189
# Perplexity of the 298 Absolute Discounting model on the test data: 2178.04365772455
# Perplexity of the 299 Absolute Discounting model on the test data: 655.6842254598512
# Perplexity of the 300 Absolute Discounting model on the test data: 1327.5640621848345
# Perplexity of the 301 Absolute Discounting model on the test data: 1315.7155373683577
# Perplexity of the 302 Absolute Discounting model on the test data: 873.7340895275089
# Perplexity of the 303 Absolute Discounting model on the test data: 1612.098115732338
# Perplexity of the 304 Absolute Discounting model on the test data: 1551.6590599543465
# Perplexity of the 305 Absolute Discounting model on the test data: 2309.9958529044984
# Perplexity of the 306 Absolute Discounting model on the test data: 1471.9069195349002
# Perplexity of the 307 Absolute Discounting model on the test data: 857.3983605023074
# Perplexity of the 308 Absolute Discounting model on the test data: 1571.9004514853264
# Perplexity of the 309 Absolute Discounting model on the test data: 723.048463649041
# Perplexity of the 310 Absolute Discounting model on the test data: 977.2113752616406
# Perplexity of the 311 Absolute Discounting model on the test data: 1073.8437918969823
# Perplexity of the 312 Absolute Discounting model on the test data: 1855.6856946448631
# Perplexity of the 313 Absolute Discounting model on the test data: 1634.0414379781382
# Perplexity of the 314 Absolute Discounting model on the test data: 525.4438936886445
# Perplexity of the 315 Absolute Discounting model on the test data: 1052.5211822447611
# Perplexity of the 316 Absolute Discounting model on the test data: 1410.1408039924934
# Perplexity of the 317 Absolute Discounting model on the test data: 1390.8797426996825
# Perplexity of the 318 Absolute Discounting model on the test data: 1590.9190552969267
# Perplexity of the 319 Absolute Discounting model on the test data: 2134.318145758952
# Perplexity of the 320 Absolute Discounting model on the test data: 1720.0217774108662
# Perplexity of the 321 Absolute Discounting model on the test data: 1193.765866221966
# Perplexity of the 322 Absolute Discounting model on the test data: 1104.0073169234686
# Perplexity of the 323 Absolute Discounting model on the test data: 1104.727812691937
# Perplexity of the 324 Absolute Discounting model on the test data: 1533.1870459932857
# Perplexity of the 325 Absolute Discounting model on the test data: 1235.5456388815498
# Perplexity of the 326 Absolute Discounting model on the test data: 2188.2080074750843
# Perplexity of the 327 Absolute Discounting model on the test data: 1081.89941401821
# Perplexity of the 328 Absolute Discounting model on the test data: 1422.827813334469
# Perplexity of the 329 Absolute Discounting model on the test data: 1056.4545040988114
# Perplexity of the 330 Absolute Discounting model on the test data: 1190.6864896966626
# Perplexity of the 331 Absolute Discounting model on the test data: 3194.7253287211183
# Perplexity of the 332 Absolute Discounting model on the test data: 1659.1528941568133
# Perplexity of the 333 Absolute Discounting model on the test data: 1265.4336756646887
# Perplexity of the 334 Absolute Discounting model on the test data: 884.5260450649179
# Perplexity of the 335 Absolute Discounting model on the test data: 755.5269857886657
# Perplexity of the 336 Absolute Discounting model on the test data: 1303.2163192279068
# Perplexity of the 337 Absolute Discounting model on the test data: 5044.652458651587
# Perplexity of the 338 Absolute Discounting model on the test data: 1602.5350103514174
# Perplexity of the 339 Absolute Discounting model on the test data: 834.8094639937692
# Perplexity of the 340 Absolute Discounting model on the test data: 1490.691107040445
# Perplexity of the 341 Absolute Discounting model on the test data: 791.718767635461
# Perplexity of the 342 Absolute Discounting model on the test data: 796.0874208878538
# Perplexity of the 343 Absolute Discounting model on the test data: 522.6108877827706
# Perplexity of the 344 Absolute Discounting model on the test data: 1192.200944479034
# Perplexity of the 345 Absolute Discounting model on the test data: 1921.222600644567
# Perplexity of the 346 Absolute Discounting model on the test data: 2028.6792015911444
# Perplexity of the 347 Absolute Discounting model on the test data: 2150.2179879905398
# Perplexity of the 348 Absolute Discounting model on the test data: 935.9885315051954
# Perplexity of the 349 Absolute Discounting model on the test data: 1178.4627824246786
# Perplexity of the 350 Absolute Discounting model on the test data: 1787.7472144816347
# Perplexity of the 351 Absolute Discounting model on the test data: 1784.6271961542377
# Perplexity of the 352 Absolute Discounting model on the test data: 1126.908664594818
# Perplexity of the 353 Absolute Discounting model on the test data: 741.6034789852287
# Perplexity of the 354 Absolute Discounting model on the test data: 1270.8925844171993
# Perplexity of the 355 Absolute Discounting model on the test data: 867.4913278121875
# Perplexity of the 356 Absolute Discounting model on the test data: 860.6674574270912
# Perplexity of the 357 Absolute Discounting model on the test data: 1163.5036848153522
# Perplexity of the 358 Absolute Discounting model on the test data: 714.9173068751595
# Perplexity of the 359 Absolute Discounting model on the test data: 765.0258402611585
# Perplexity of the 360 Absolute Discounting model on the test data: 1423.7829306865417
# Perplexity of the 361 Absolute Discounting model on the test data: 892.4426144452287
# Perplexity of the 362 Absolute Discounting model on the test data: 1324.7523546697926
# Perplexity of the 363 Absolute Discounting model on the test data: 1099.0486081853326
# Perplexity of the 364 Absolute Discounting model on the test data: 1132.869438225644
# Perplexity of the 365 Absolute Discounting model on the test data: 1575.2895444774806
# Perplexity of the 366 Absolute Discounting model on the test data: 1734.9221258580683
# Perplexity of the 367 Absolute Discounting model on the test data: 1490.4173632083935
# Perplexity of the 368 Absolute Discounting model on the test data: 720.7907370775946
# Perplexity of the 369 Absolute Discounting model on the test data: 1486.2713917819685
# Perplexity of the 370 Absolute Discounting model on the test data: 1039.0034998550823
# Perplexity of the 371 Absolute Discounting model on the test data: 1880.0831845068524
# Perplexity of the 372 Absolute Discounting model on the test data: 620.9580995828445
# Perplexity of the 373 Absolute Discounting model on the test data: 1478.4081336115823
# Perplexity of the 374 Absolute Discounting model on the test data: 1244.803450118978
# Perplexity of the 375 Absolute Discounting model on the test data: 3717.6049893650043
# Perplexity of the 376 Absolute Discounting model on the test data: 1873.530138914087
# Perplexity of the 377 Absolute Discounting model on the test data: 1122.4151858671567
# Perplexity of the 378 Absolute Discounting model on the test data: 1263.8984336326407
# Perplexity of the 379 Absolute Discounting model on the test data: 1310.1824678799949
# Perplexity of the 380 Absolute Discounting model on the test data: 718.3304637517854
# Perplexity of the 381 Absolute Discounting model on the test data: 1277.9954942727857
# Perplexity of the 382 Absolute Discounting model on the test data: 1329.7831647342612
# Perplexity of the 383 Absolute Discounting model on the test data: 466.19309964170975
# Perplexity of the 384 Absolute Discounting model on the test data: 897.3024293597713
# Perplexity of the 385 Absolute Discounting model on the test data: 544.4249828483443
# Perplexity of the 386 Absolute Discounting model on the test data: 997.9098002889601
# Perplexity of the 387 Absolute Discounting model on the test data: 1599.3130841373272
# Perplexity of the 388 Absolute Discounting model on the test data: 1311.6276885711795
# Perplexity of the 389 Absolute Discounting model on the test data: 610.108916410842
# Perplexity of the 390 Absolute Discounting model on the test data: 1535.8614887016838
# Perplexity of the 391 Absolute Discounting model on the test data: 1184.7248470873492
# Perplexity of the 392 Absolute Discounting model on the test data: 1259.4502959843553
# Perplexity of the 393 Absolute Discounting model on the test data: 618.6381748001534
# Perplexity of the 394 Absolute Discounting model on the test data: 867.9396665107263
# Perplexity of the 395 Absolute Discounting model on the test data: 1371.2703136516404
# Perplexity of the 396 Absolute Discounting model on the test data: 637.8539912235369
# Perplexity of the 397 Absolute Discounting model on the test data: 369.184247131617
# Perplexity of the 398 Absolute Discounting model on the test data: 1765.002501731936
# Perplexity of the 399 Absolute Discounting model on the test data: 1697.5297384235441
# Perplexity of the 400 Absolute Discounting model on the test data: 1077.6405141777086
# Perplexity of the 401 Absolute Discounting model on the test data: 1542.1710924200706
# Perplexity of the 402 Absolute Discounting model on the test data: 2143.312356140817
# Perplexity of the 403 Absolute Discounting model on the test data: 728.9323661152318
# Perplexity of the 404 Absolute Discounting model on the test data: 941.9963324095016
# Perplexity of the 405 Absolute Discounting model on the test data: 1023.1267677029529
# Perplexity of the 406 Absolute Discounting model on the test data: 1544.0547927917341
# Perplexity of the 407 Absolute Discounting model on the test data: 1649.9943738749266
# Perplexity of the 408 Absolute Discounting model on the test data: 913.1999567299771
# Perplexity of the 409 Absolute Discounting model on the test data: 1311.7761292325836
# Perplexity of the 410 Absolute Discounting model on the test data: 953.8546398108841
# Perplexity of the 411 Absolute Discounting model on the test data: 1947.1092911916844
# Perplexity of the 412 Absolute Discounting model on the test data: 1963.2280085116204
# Perplexity of the 413 Absolute Discounting model on the test data: 1096.613738923983
# Perplexity of the 414 Absolute Discounting model on the test data: 1004.4555517124825
# Perplexity of the 415 Absolute Discounting model on the test data: 780.7743301795567
# Perplexity of the 416 Absolute Discounting model on the test data: 2417.2874085446206
# Perplexity of the 417 Absolute Discounting model on the test data: 1177.3589493149739
# Perplexity of the 418 Absolute Discounting model on the test data: 664.919059100804
# Perplexity of the 419 Absolute Discounting model on the test data: 944.8905980314267
# Perplexity of the 420 Absolute Discounting model on the test data: 1720.7775894412318
# Perplexity of the 421 Absolute Discounting model on the test data: 882.9346857141977
# Perplexity of the 422 Absolute Discounting model on the test data: 2351.32385405832
# Perplexity of the 423 Absolute Discounting model on the test data: 856.2890498277949
# Perplexity of the 424 Absolute Discounting model on the test data: 1152.5209124716341
# Perplexity of the 425 Absolute Discounting model on the test data: 1186.9120580509993
# Perplexity of the 426 Absolute Discounting model on the test data: 1072.6138959785992
# Perplexity of the 427 Absolute Discounting model on the test data: 787.9450886828193
# Perplexity of the 428 Absolute Discounting model on the test data: 884.8103532559925
# Perplexity of the 429 Absolute Discounting model on the test data: 1251.778945150617
# Perplexity of the 430 Absolute Discounting model on the test data: 1239.8609657845693
# Perplexity of the 431 Absolute Discounting model on the test data: 1397.0091330286884
# Perplexity of the 432 Absolute Discounting model on the test data: 1182.6895385476137
# Perplexity of the 433 Absolute Discounting model on the test data: 1372.465600445285
# Perplexity of the 434 Absolute Discounting model on the test data: 1001.127211664836
# Perplexity of the 435 Absolute Discounting model on the test data: 1713.8286475715615
# Perplexity of the 436 Absolute Discounting model on the test data: 1104.6935756606779
# Perplexity of the 437 Absolute Discounting model on the test data: 1615.6507021272785
# Perplexity of the 438 Absolute Discounting model on the test data: 1276.5292774596933
# Perplexity of the 439 Absolute Discounting model on the test data: 1868.5651021411732
# Perplexity of the 440 Absolute Discounting model on the test data: 933.8763768643163
# Perplexity of the 441 Absolute Discounting model on the test data: 1075.8893957801947
# Perplexity of the 442 Absolute Discounting model on the test data: 561.8159110411806
# Perplexity of the 443 Absolute Discounting model on the test data: 1168.1312395107252
# Perplexity of the 444 Absolute Discounting model on the test data: 404.5461046271809
# Perplexity of the 445 Absolute Discounting model on the test data: 1086.0706098865014
# Perplexity of the 446 Absolute Discounting model on the test data: 3849.8917680249397
# Perplexity of the 447 Absolute Discounting model on the test data: 716.3382835984224
# Perplexity of the 448 Absolute Discounting model on the test data: 1252.8574631858414
# Perplexity of the 449 Absolute Discounting model on the test data: 672.4680216138197
# Perplexity of the 450 Absolute Discounting model on the test data: 832.258673391424
# Perplexity of the 451 Absolute Discounting model on the test data: 900.1551222085162
# Perplexity of the 452 Absolute Discounting model on the test data: 1936.3416577640246
# Perplexity of the 453 Absolute Discounting model on the test data: 912.2585102918725
# Perplexity of the 454 Absolute Discounting model on the test data: 1035.9997583875704
# Perplexity of the 455 Absolute Discounting model on the test data: 1440.6338747306106
# Perplexity of the 456 Absolute Discounting model on the test data: 1548.0859490268804
# Perplexity of the 457 Absolute Discounting model on the test data: 1089.0382834773977
# Perplexity of the 458 Absolute Discounting model on the test data: 618.3093947256344
# Perplexity of the 459 Absolute Discounting model on the test data: 1753.598202378348
# Perplexity of the 460 Absolute Discounting model on the test data: 1926.3234151954036
# Perplexity of the 461 Absolute Discounting model on the test data: 2099.468601048208
# Perplexity of the 462 Absolute Discounting model on the test data: 1909.6161600006128
# Perplexity of the 463 Absolute Discounting model on the test data: 1201.290627627735
# Perplexity of the 464 Absolute Discounting model on the test data: 1642.4473585955122
# Perplexity of the 465 Absolute Discounting model on the test data: 1947.28269395675
# Perplexity of the 466 Absolute Discounting model on the test data: 753.2344386150249
# Perplexity of the 467 Absolute Discounting model on the test data: 1483.9752179487919
# Perplexity of the 468 Absolute Discounting model on the test data: 1656.175377260962
# Perplexity of the 469 Absolute Discounting model on the test data: 916.4989326603825
# Perplexity of the 470 Absolute Discounting model on the test data: 1740.2978410406395
# Perplexity of the 471 Absolute Discounting model on the test data: 730.8681838160755
# Perplexity of the 472 Absolute Discounting model on the test data: 2620.223518140348
# Perplexity of the 473 Absolute Discounting model on the test data: 1193.1886077961735
# Perplexity of the 474 Absolute Discounting model on the test data: 823.1557988532883
# Perplexity of the 475 Absolute Discounting model on the test data: 1030.8070240848294
# Perplexity of the 476 Absolute Discounting model on the test data: 818.9445040449681
# Perplexity of the 477 Absolute Discounting model on the test data: 841.6870951103599
# Perplexity of the 478 Absolute Discounting model on the test data: 2231.9768811134254
# Perplexity of the 479 Absolute Discounting model on the test data: 2207.1702445115984
# Perplexity of the 480 Absolute Discounting model on the test data: 2096.8983883305086
# Perplexity of the 481 Absolute Discounting model on the test data: 1042.7051546859907
# Perplexity of the 482 Absolute Discounting model on the test data: 1301.9061034986642
# Perplexity of the 483 Absolute Discounting model on the test data: 1140.5560919959587
# Perplexity of the 484 Absolute Discounting model on the test data: 1437.5339674651289
# Perplexity of the 485 Absolute Discounting model on the test data: 1168.1868554843882
# Perplexity of the 486 Absolute Discounting model on the test data: 696.0608536152502
# Perplexity of the 487 Absolute Discounting model on the test data: 1647.5205223466141
# Perplexity of the 488 Absolute Discounting model on the test data: 1022.9102028404113
# Perplexity of the 489 Absolute Discounting model on the test data: 981.5999405264732
# Perplexity of the 490 Absolute Discounting model on the test data: 1974.7209535055676
# Perplexity of the 491 Absolute Discounting model on the test data: 1208.7264695809522
# Perplexity of the 492 Absolute Discounting model on the test data: 942.1163539969829
# Perplexity of the 493 Absolute Discounting model on the test data: 3721.0476528744134
# Perplexity of the 494 Absolute Discounting model on the test data: 1522.674038880138
# Perplexity of the 495 Absolute Discounting model on the test data: 1401.5953957728998
# Perplexity of the 496 Absolute Discounting model on the test data: 933.2530029850279
# Perplexity of the 497 Absolute Discounting model on the test data: 1057.3784475908565
# Perplexity of the 498 Absolute Discounting model on the test data: 941.1385927090042
# Perplexity of the 499 Absolute Discounting model on the test data: 728.6840850772871
# Perplexity of the 500 Absolute Discounting model on the test data: 1805.7779349596165
# Perplexity of the 501 Absolute Discounting model on the test data: 990.570169434718
# Perplexity of the 502 Absolute Discounting model on the test data: 1738.4763244018143
# Perplexity of the 503 Absolute Discounting model on the test data: 769.2819085749993
# Perplexity of the 504 Absolute Discounting model on the test data: 1075.1805699316312
# Perplexity of the 505 Absolute Discounting model on the test data: 1062.6767869606595
# Perplexity of the 506 Absolute Discounting model on the test data: 1112.532441137329
# Perplexity of the 507 Absolute Discounting model on the test data: 1386.1913867760052
# Perplexity of the 508 Absolute Discounting model on the test data: 803.6077616451781
# Perplexity of the 509 Absolute Discounting model on the test data: 1585.0275021570687
# Perplexity of the 510 Absolute Discounting model on the test data: 1170.840961003452
# Perplexity of the 511 Absolute Discounting model on the test data: 695.9029793367675
# Perplexity of the 512 Absolute Discounting model on the test data: 1449.2714155324325
# Perplexity of the 513 Absolute Discounting model on the test data: 663.7767136048507
# Perplexity of the 514 Absolute Discounting model on the test data: 1768.7481489810539
# Perplexity of the 515 Absolute Discounting model on the test data: 848.3344506869124
# Perplexity of the 516 Absolute Discounting model on the test data: 774.3575524870253
# Perplexity of the 517 Absolute Discounting model on the test data: 980.0845081702088
# Perplexity of the 518 Absolute Discounting model on the test data: 898.7409663103734
# Perplexity of the 519 Absolute Discounting model on the test data: 1219.1594212387454
# Perplexity of the 520 Absolute Discounting model on the test data: 1336.6199768513115
# Perplexity of the 521 Absolute Discounting model on the test data: 783.5108030201186
# Perplexity of the 522 Absolute Discounting model on the test data: 2057.8769191014508
# Perplexity of the 523 Absolute Discounting model on the test data: 1687.311209000603
# Perplexity of the 524 Absolute Discounting model on the test data: 1126.4546510698049
# Perplexity of the 525 Absolute Discounting model on the test data: 910.3240273304843
# Perplexity of the 526 Absolute Discounting model on the test data: 2502.566900926716
# Perplexity of the 527 Absolute Discounting model on the test data: 1323.1907591583426
# Perplexity of the 528 Absolute Discounting model on the test data: 925.265945326259
# Perplexity of the 529 Absolute Discounting model on the test data: 2171.451690878717
# Perplexity of the 530 Absolute Discounting model on the test data: 916.4776349041697
# Perplexity of the 531 Absolute Discounting model on the test data: 979.8597380259138
# Perplexity of the 532 Absolute Discounting model on the test data: 778.644830001402
# Perplexity of the 533 Absolute Discounting model on the test data: 1255.2704573199549
# Perplexity of the 534 Absolute Discounting model on the test data: 1464.8016595626077
# Perplexity of the 535 Absolute Discounting model on the test data: 765.7650541226405
# Perplexity of the 536 Absolute Discounting model on the test data: 1277.4394862314143
# Perplexity of the 537 Absolute Discounting model on the test data: 967.3632983884016
# Perplexity of the 538 Absolute Discounting model on the test data: 1028.645469118946
# Perplexity of the 539 Absolute Discounting model on the test data: 2699.4150439870164
# Perplexity of the 540 Absolute Discounting model on the test data: 902.6202135290768
# Perplexity of the 541 Absolute Discounting model on the test data: 2682.265459536133
# Perplexity of the 542 Absolute Discounting model on the test data: 1101.0158021033508
# Perplexity of the 543 Absolute Discounting model on the test data: 1103.1637887394138
# Perplexity of the 544 Absolute Discounting model on the test data: 1672.052802144974
# Perplexity of the 545 Absolute Discounting model on the test data: 1704.429757778517
# Perplexity of the 546 Absolute Discounting model on the test data: 1483.2092825283203
# Perplexity of the 547 Absolute Discounting model on the test data: 1666.8239260535402
# Perplexity of the 548 Absolute Discounting model on the test data: 1756.2817962459458
# Perplexity of the 549 Absolute Discounting model on the test data: 1359.6075277879145
# Perplexity of the 550 Absolute Discounting model on the test data: 960.1584495593116
# Perplexity of the 551 Absolute Discounting model on the test data: 1993.665739844185
# Perplexity of the 552 Absolute Discounting model on the test data: 2313.1001762001883
# Perplexity of the 553 Absolute Discounting model on the test data: 540.7938172487321
# Perplexity of the 554 Absolute Discounting model on the test data: 686.997316874954
# Perplexity of the 555 Absolute Discounting model on the test data: 906.6929547733217
# Perplexity of the 556 Absolute Discounting model on the test data: 1521.530409902324
# Perplexity of the 557 Absolute Discounting model on the test data: 1500.6066193134393
# Perplexity of the 558 Absolute Discounting model on the test data: 991.0300380420738
# Perplexity of the 559 Absolute Discounting model on the test data: 828.8396720640754
# Perplexity of the 560 Absolute Discounting model on the test data: 891.1655039681845
# Perplexity of the 561 Absolute Discounting model on the test data: 2047.2001596098648
# ...
# Perplexity of the 1460 Absolute Discounting model on the test data: 926.0345307413176
# Perplexity of the 1461 Absolute Discounting model on the test data: 1335.6279124700504
# Perplexity of the 1462 Absolute Discounting model on the test data: 579.0200917443109
# Perplexity of the 1463 Absolute Discounting model on the test data: 915.3573721773871
# Perplexity of the 1464 Absolute Discounting model on the test data: 1372.6225294770566
# Perplexity of the 1465 Absolute Discounting model on the test data: 1023.244576289713
# Perplexity of the 1466 Absolute Discounting model on the test data: 13367.262721598034
# Perplexity of the 1467 Absolute Discounting model on the test data: 1586.2538651293949
# Perplexity of the 1468 Absolute Discounting model on the test data: 1829.2897825976436
# Perplexity of the 1469 Absolute Discounting model on the test data: 1882.1164978453853
# Perplexity of the 1470 Absolute Discounting model on the test data: 1352.6148226598716
# Perplexity of the 1471 Absolute Discounting model on the test data: 1176.9541062298115
# Perplexity of the 1472 Absolute Discounting model on the test data: 1213.386265614976
# Perplexity of the 1473 Absolute Discounting model on the test data: 1302.8940822937561
# Perplexity of the 1474 Absolute Discounting model on the test data: 1238.607138984516
# Perplexity of the 1475 Absolute Discounting model on the test data: 1024.7654579811256
# Perplexity of the 1476 Absolute Discounting model on the test data: 518.22087499751
# Perplexity of the 1477 Absolute Discounting model on the test data: 1145.13881513719
# Perplexity of the 1478 Absolute Discounting model on the test data: 1097.1549693131094
# Perplexity of the 1479 Absolute Discounting model on the test data: 1209.7961349216187
# Perplexity of the 1480 Absolute Discounting model on the test data: 2164.3778980153857
# Perplexity of the 1481 Absolute Discounting model on the test data: 1070.0882417090088
# Perplexity of the 1482 Absolute Discounting model on the test data: 1264.4624282100654
# Perplexity of the 1483 Absolute Discounting model on the test data: 1411.2809689505189
# Perplexity of the 1484 Absolute Discounting model on the test data: 947.6409175529662
# Perplexity of the 1485 Absolute Discounting model on the test data: 895.2333311085358
# Perplexity of the 1486 Absolute Discounting model on the test data: 2102.5486697147935
# Perplexity of the 1487 Absolute Discounting model on the test data: 1018.6948886598307
# Perplexity of the 1488 Absolute Discounting model on the test data: 1343.9852469104726
# Perplexity of the 1489 Absolute Discounting model on the test data: 1271.2884843663342
# Perplexity of the 1490 Absolute Discounting model on the test data: 1548.9796526157304
# Perplexity of the 1491 Absolute Discounting model on the test data: 1107.9989295585367
# Perplexity of the 1492 Absolute Discounting model on the test data: 1113.2898543707115
# Perplexity of the 1493 Absolute Discounting model on the test data: 1492.9729707604597
# Perplexity of the 1494 Absolute Discounting model on the test data: 1368.5110511430173
# Perplexity of the 1495 Absolute Discounting model on the test data: 1065.5241593431845
# Perplexity of the 1496 Absolute Discounting model on the test data: 1131.092057405951
# Perplexity of the 1497 Absolute Discounting model on the test data: 1292.6429833775207
# Perplexity of the 1498 Absolute Discounting model on the test data: 1613.789462985088
# Perplexity of the 1499 Absolute Discounting model on the test data: 1370.1069492326449
# Perplexity of the 1500 Absolute Discounting model on the test data: 1004.8793787214845
# Perplexity of the 1501 Absolute Discounting model on the test data: 446.1023022708135
# Perplexity of the 1502 Absolute Discounting model on the test data: 1094.6227306447277
# Perplexity of the 1503 Absolute Discounting model on the test data: 1146.8306912169378
# Perplexity of the 1504 Absolute Discounting model on the test data: 971.9494065885567
# Perplexity of the 1505 Absolute Discounting model on the test data: 1589.0602342608518
# Perplexity of the 1506 Absolute Discounting model on the test data: 2175.808390010251
# Perplexity of the 1507 Absolute Discounting model on the test data: 1083.9740149206978
# Perplexity of the 1508 Absolute Discounting model on the test data: 847.6611112975831
# Perplexity of the 1509 Absolute Discounting model on the test data: 1073.4284673540726
# Perplexity of the 1510 Absolute Discounting model on the test data: 1666.1175287694596
# Perplexity of the 1511 Absolute Discounting model on the test data: 1571.4363206237629
# Perplexity of the 1512 Absolute Discounting model on the test data: 1501.935343689545
# Perplexity of the 1513 Absolute Discounting model on the test data: 1178.5899861141706
# Perplexity of the 1514 Absolute Discounting model on the test data: 1178.9230447748596
# Perplexity of the 1515 Absolute Discounting model on the test data: 930.1069444672374
# Perplexity of the 1516 Absolute Discounting model on the test data: 883.7560916335043
# Perplexity of the 1517 Absolute Discounting model on the test data: 1529.7797795912568
# Perplexity of the 1518 Absolute Discounting model on the test data: 928.1114121180723
# Perplexity of the 1519 Absolute Discounting model on the test data: 1125.0164305643407
# Perplexity of the 1520 Absolute Discounting model on the test data: 1358.2278546937466
# Perplexity of the 1521 Absolute Discounting model on the test data: 787.6980609707134
# Perplexity of the 1522 Absolute Discounting model on the test data: 1952.9359383639203
# Perplexity of the 1523 Absolute Discounting model on the test data: 688.1942228675183
# Perplexity of the 1524 Absolute Discounting model on the test data: 1316.7608270408912
# Perplexity of the 1525 Absolute Discounting model on the test data: 1897.5382749993541
# Perplexity of the 1526 Absolute Discounting model on the test data: 2044.1298013052833
# Perplexity of the 1527 Absolute Discounting model on the test data: 1510.0101326585382
# Perplexity of the 1528 Absolute Discounting model on the test data: 1936.0118091872503
# Perplexity of the 1529 Absolute Discounting model on the test data: 779.5746034128447
# Perplexity of the 1530 Absolute Discounting model on the test data: 1449.5580711048035
# Perplexity of the 1531 Absolute Discounting model on the test data: 1169.4566830798753
# Perplexity of the 1532 Absolute Discounting model on the test data: 2085.2778989475687
# Perplexity of the 1533 Absolute Discounting model on the test data: 1899.428022607615
# Perplexity of the 1534 Absolute Discounting model on the test data: 1094.786434501845
# Perplexity of the 1535 Absolute Discounting model on the test data: 1662.0211409072572
# Perplexity of the 1536 Absolute Discounting model on the test data: 1765.689744829649
# Perplexity of the 1537 Absolute Discounting model on the test data: 1270.819434815945
# Perplexity of the 1538 Absolute Discounting model on the test data: 1577.1843462208992
# Perplexity of the 1539 Absolute Discounting model on the test data: 1157.0405206002756
# Perplexity of the 1540 Absolute Discounting model on the test data: 1148.3677385616309
# Perplexity of the 1541 Absolute Discounting model on the test data: 1048.9204666612713
# Perplexity of the 1542 Absolute Discounting model on the test data: 1645.671310505992
# Perplexity of the 1543 Absolute Discounting model on the test data: 1181.5804720637564
# Perplexity of the 1544 Absolute Discounting model on the test data: 1025.4469141357793
# Perplexity of the 1545 Absolute Discounting model on the test data: 1505.9997331177249
# Perplexity of the 1546 Absolute Discounting model on the test data: 1184.6811025682498
# Perplexity of the 1547 Absolute Discounting model on the test data: 1031.619085662702
# Perplexity of the 1548 Absolute Discounting model on the test data: 1787.6906770811718
# Perplexity of the 1549 Absolute Discounting model on the test data: 990.789546817845
# Perplexity of the 1550 Absolute Discounting model on the test data: 2689.0830682112505
# Perplexity of the 1551 Absolute Discounting model on the test data: 1227.457426805659
# Perplexity of the 1552 Absolute Discounting model on the test data: 1179.0159116011093
# Perplexity of the 1553 Absolute Discounting model on the test data: 2452.8823378496413
# Perplexity of the 1554 Absolute Discounting model on the test data: 1726.781152919214
# Perplexity of the 1555 Absolute Discounting model on the test data: 1077.9899587290843
# Perplexity of the 1556 Absolute Discounting model on the test data: 1624.5918127935627
# Perplexity of the 1557 Absolute Discounting model on the test data: 863.0633407255413
# Perplexity of the 1558 Absolute Discounting model on the test data: 1386.7695271395257
# Perplexity of the 1559 Absolute Discounting model on the test data: 1215.3586362158828
# Perplexity of the 1560 Absolute Discounting model on the test data: 729.1616653800706
# Perplexity of the 1561 Absolute Discounting model on the test data: 6450.001763212154
# Perplexity of the 1562 Absolute Discounting model on the test data: 793.9225526885709
# Perplexity of the 1563 Absolute Discounting model on the test data: 1298.407636383864
# Perplexity of the 1564 Absolute Discounting model on the test data: 885.3835681928188
# Perplexity of the 1565 Absolute Discounting model on the test data: 790.2322400491663
# Perplexity of the 1566 Absolute Discounting model on the test data: 1693.6047520165248
# Perplexity of the 1567 Absolute Discounting model on the test data: 1142.43137087696
# Perplexity of the 1568 Absolute Discounting model on the test data: 1543.7448363709188
# Perplexity of the 1569 Absolute Discounting model on the test data: 920.3048740860463
# Perplexity of the 1570 Absolute Discounting model on the test data: 867.9407897164339
# Perplexity of the 1571 Absolute Discounting model on the test data: 1917.1684296925346
# Perplexity of the 1572 Absolute Discounting model on the test data: 1481.5350289279907
# Perplexity of the 1573 Absolute Discounting model on the test data: 953.5724810698767
# Perplexity of the 1574 Absolute Discounting model on the test data: 1228.408351873157
# Perplexity of the 1575 Absolute Discounting model on the test data: 1564.96419939967
# Perplexity of the 1576 Absolute Discounting model on the test data: 976.9347793830151
# Perplexity of the 1577 Absolute Discounting model on the test data: 1248.1025593512368
# Perplexity of the 1578 Absolute Discounting model on the test data: 1885.6347531537158
# Perplexity of the 1579 Absolute Discounting model on the test data: 2029.7892460645799
# Perplexity of the 1580 Absolute Discounting model on the test data: 905.7396525034586
# Perplexity of the 1581 Absolute Discounting model on the test data: 1653.652176257668
# Perplexity of the 1582 Absolute Discounting model on the test data: 970.2313832875661
# Perplexity of the 1583 Absolute Discounting model on the test data: 545.069503639403
# Perplexity of the 1584 Absolute Discounting model on the test data: 1228.0225795984782
# Perplexity of the 1585 Absolute Discounting model on the test data: 2180.069825988205
# Perplexity of the 1586 Absolute Discounting model on the test data: 1522.1062858991884
# Perplexity of the 1587 Absolute Discounting model on the test data: 1285.0040674425452
# Perplexity of the 1588 Absolute Discounting model on the test data: 2611.4663533828766
# Perplexity of the 1589 Absolute Discounting model on the test data: 1099.7633395625357
# Perplexity of the 1590 Absolute Discounting model on the test data: 789.6950401071641
# Perplexity of the 1591 Absolute Discounting model on the test data: 1561.4524558607916
# Perplexity of the 1592 Absolute Discounting model on the test data: 875.041465449979
# Perplexity of the 1593 Absolute Discounting model on the test data: 1435.6870846109261
# Perplexity of the 1594 Absolute Discounting model on the test data: 771.8866248530443
# Perplexity of the 1595 Absolute Discounting model on the test data: 921.7654141031503
# Perplexity of the 1596 Absolute Discounting model on the test data: 1350.7010921667397
# Perplexity of the 1597 Absolute Discounting model on the test data: 785.4038293127295
# Perplexity of the 1598 Absolute Discounting model on the test data: 1515.308046628107
# Perplexity of the 1599 Absolute Discounting model on the test data: 1568.425120792298
# Perplexity of the 1600 Absolute Discounting model on the test data: 1369.7006052853856
# Perplexity of the 1601 Absolute Discounting model on the test data: 2714.117833677385
# Perplexity of the 1602 Absolute Discounting model on the test data: 721.0000288042804
# Perplexity of the 1603 Absolute Discounting model on the test data: 1778.0037369636802
# Perplexity of the 1604 Absolute Discounting model on the test data: 1942.532533666585
# Perplexity of the 1605 Absolute Discounting model on the test data: 946.7255061471158
# Perplexity of the 1606 Absolute Discounting model on the test data: 1202.803261629877
# Perplexity of the 1607 Absolute Discounting model on the test data: 2275.667183710891
# Perplexity of the 1608 Absolute Discounting model on the test data: 1108.4375682426107
# Perplexity of the 1609 Absolute Discounting model on the test data: 676.3072404755208
# Perplexity of the 1610 Absolute Discounting model on the test data: 1134.5033718510044
# Perplexity of the 1611 Absolute Discounting model on the test data: 659.7739948260806
# Perplexity of the 1612 Absolute Discounting model on the test data: 1857.4762418710684
# Perplexity of the 1613 Absolute Discounting model on the test data: 1033.3230545979984
# Perplexity of the 1614 Absolute Discounting model on the test data: 1768.188863080735
# Perplexity of the 1615 Absolute Discounting model on the test data: 1294.2437110667988
# Perplexity of the 1616 Absolute Discounting model on the test data: 1136.4872846918636
# Perplexity of the 1617 Absolute Discounting model on the test data: 1384.744633531222
# Perplexity of the 1618 Absolute Discounting model on the test data: 936.905787503889
# Perplexity of the 1619 Absolute Discounting model on the test data: 1089.300313616004
# Perplexity of the 1620 Absolute Discounting model on the test data: 1739.7830184512145
# Perplexity of the 1621 Absolute Discounting model on the test data: 1459.5842124234928
# Perplexity of the 1622 Absolute Discounting model on the test data: 1666.8168034891141
# Perplexity of the 1623 Absolute Discounting model on the test data: 681.5961867472126
# Perplexity of the 1624 Absolute Discounting model on the test data: 1742.7929869931552
# Perplexity of the 1625 Absolute Discounting model on the test data: 1069.0506725808539
# Perplexity of the 1626 Absolute Discounting model on the test data: 1254.6196591622227
# Perplexity of the 1627 Absolute Discounting model on the test data: 1189.452933567955
# Perplexity of the 1628 Absolute Discounting model on the test data: 2012.419801027653
# Perplexity of the 1629 Absolute Discounting model on the test data: 1077.7221008255517
# Perplexity of the 1630 Absolute Discounting model on the test data: 570.2369890369663
# Perplexity of the 1631 Absolute Discounting model on the test data: 1011.9092518221216
# Perplexity of the 1632 Absolute Discounting model on the test data: 1581.112675165315
# Perplexity of the 1633 Absolute Discounting model on the test data: 1602.5417644465322
# Perplexity of the 1634 Absolute Discounting model on the test data: 1375.1364895344875
# Perplexity of the 1635 Absolute Discounting model on the test data: 1856.5073406973631
# Perplexity of the 1636 Absolute Discounting model on the test data: 1316.17916931974
# Perplexity of the 1637 Absolute Discounting model on the test data: 1182.7322894450465
# Perplexity of the 1638 Absolute Discounting model on the test data: 903.7600278747748
# Perplexity of the 1639 Absolute Discounting model on the test data: 1355.4935958887281
# Perplexity of the 1640 Absolute Discounting model on the test data: 1027.1298529638939
# Perplexity of the 1641 Absolute Discounting model on the test data: 2360.686989590811
# Perplexity of the 1642 Absolute Discounting model on the test data: 13366.605062107163
# Perplexity of the 1643 Absolute Discounting model on the test data: 980.8135049927794

# %%
# bigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(2)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1, 0.3, 0.5, 0.7]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 0.0014364364311748412
# Perplexity of the 1 Absolute Discounting model on the test data: 38.561190056005664
# Perplexity of the 2 Absolute Discounting model on the test data: 42.66312864278921
# Perplexity of the 3 Absolute Discounting model on the test data: 39.39237406430953
# Perplexity of the 4 Absolute Discounting model on the test data: 27.201621161645402
# Perplexity of the 5 Absolute Discounting model on the test data: 54.668309231402944
# Perplexity of the 6 Absolute Discounting model on the test data: 57.265351042155494
# Perplexity of the 7 Absolute Discounting model on the test data: 55.79441045823652
# Perplexity of the 8 Absolute Discounting model on the test data: 39.050815518158856
# Perplexity of the 9 Absolute Discounting model on the test data: 25.93849383926754
# Perplexity of the 10 Absolute Discounting model on the test data: 36.40826584435013
# Perplexity of the 11 Absolute Discounting model on the test data: 58.44843443290822
# Perplexity of the 12 Absolute Discounting model on the test data: 56.31925143755702
# Perplexity of the 13 Absolute Discounting model on the test data: 41.51693996094144
# Perplexity of the 14 Absolute Discounting model on the test data: 37.70411060712737
# Perplexity of the 15 Absolute Discounting model on the test data: 70.30343088584493
# Perplexity of the 16 Absolute Discounting model on the test data: 41.40883990678195
# Perplexity of the 17 Absolute Discounting model on the test data: 43.331856869648696
# Perplexity of the 18 Absolute Discounting model on the test data: 32.15737177161567
# Perplexity of the 19 Absolute Discounting model on the test data: 43.842236482203305
# Perplexity of the 20 Absolute Discounting model on the test data: 57.52574485337568
# Perplexity of the 21 Absolute Discounting model on the test data: 42.77021506452788
# Perplexity of the 22 Absolute Discounting model on the test data: 33.82836809179097
# Perplexity of the 23 Absolute Discounting model on the test data: 49.5129037025374
# Perplexity of the 24 Absolute Discounting model on the test data: 44.27983720575692
# Perplexity of the 25 Absolute Discounting model on the test data: 36.009044339928224
# Perplexity of the 26 Absolute Discounting model on the test data: 30.994407879414165
# Perplexity of the 27 Absolute Discounting model on the test data: 50.19896238620206
# Perplexity of the 28 Absolute Discounting model on the test data: 42.486787110046336
# Perplexity of the 29 Absolute Discounting model on the test data: 35.220873600892816
# Perplexity of the 30 Absolute Discounting model on the test data: 41.61435856960025
# Perplexity of the 31 Absolute Discounting model on the test data: 50.41682308099825
# Perplexity of the 32 Absolute Discounting model on the test data: 56.62593434203809
# Perplexity of the 33 Absolute Discounting model on the test data: 43.54096042441291
# Perplexity of the 34 Absolute Discounting model on the test data: 21.174079370774436
# Perplexity of the 35 Absolute Discounting model on the test data: 46.85561048868553
# Perplexity of the 36 Absolute Discounting model on the test data: 30.652312596578067
# Perplexity of the 37 Absolute Discounting model on the test data: 16.640496620651895
# Perplexity of the 38 Absolute Discounting model on the test data: 39.97056987811664
# Perplexity of the 39 Absolute Discounting model on the test data: 53.0771717506888
# Perplexity of the 40 Absolute Discounting model on the test data: 37.68498562827571
# Perplexity of the 41 Absolute Discounting model on the test data: 65.271918605301
# Perplexity of the 42 Absolute Discounting model on the test data: 56.56514157202826
# Perplexity of the 43 Absolute Discounting model on the test data: 73.49296238770278
# Perplexity of the 44 Absolute Discounting model on the test data: 43.22569682322653
# Perplexity of the 45 Absolute Discounting model on the test data: 57.015668611820324
# Perplexity of the 46 Absolute Discounting model on the test data: 50.0090735860314
# Perplexity of the 47 Absolute Discounting model on the test data: 54.79843974458892
# Perplexity of the 48 Absolute Discounting model on the test data: 37.32406810880988
# Perplexity of the 49 Absolute Discounting model on the test data: 50.153894208267054
# Perplexity of the 50 Absolute Discounting model on the test data: 32.27260608235976
# Perplexity of the 51 Absolute Discounting model on the test data: 38.59204257907227
# Perplexity of the 52 Absolute Discounting model on the test data: 26.99163718504634
# Perplexity of the 53 Absolute Discounting model on the test data: 48.65456051176083
# Perplexity of the 54 Absolute Discounting model on the test data: 40.303706632400676
# Perplexity of the 55 Absolute Discounting model on the test data: 44.699754524253635
# Perplexity of the 56 Absolute Discounting model on the test data: 38.05685777508828
# Perplexity of the 57 Absolute Discounting model on the test data: 43.79430855888598
# Perplexity of the 58 Absolute Discounting model on the test data: 38.74169169108495
# Perplexity of the 59 Absolute Discounting model on the test data: 46.568565710286364
# Perplexity of the 60 Absolute Discounting model on the test data: 45.75186855004394
# Perplexity of the 61 Absolute Discounting model on the test data: 44.69643881534443
# Perplexity of the 62 Absolute Discounting model on the test data: 44.6692372085945
# Perplexity of the 63 Absolute Discounting model on the test data: 42.20685054756339
# Perplexity of the 64 Absolute Discounting model on the test data: 44.88777085713888
# Perplexity of the 65 Absolute Discounting model on the test data: 47.65984726904054
# Perplexity of the 66 Absolute Discounting model on the test data: 40.572558625605026
# Perplexity of the 67 Absolute Discounting model on the test data: 40.07372442648216
# Perplexity of the 68 Absolute Discounting model on the test data: 37.72459627522945
# Perplexity of the 69 Absolute Discounting model on the test data: 55.44809547764182
# Perplexity of the 70 Absolute Discounting model on the test data: 27.84594266737216
# Perplexity of the 71 Absolute Discounting model on the test data: 34.863109912067465
# Perplexity of the 72 Absolute Discounting model on the test data: 49.3267590005739
# Perplexity of the 73 Absolute Discounting model on the test data: 66.3661568008872
# Perplexity of the 74 Absolute Discounting model on the test data: 48.21818839585652
# Perplexity of the 75 Absolute Discounting model on the test data: 41.08987398056307
# Perplexity of the 76 Absolute Discounting model on the test data: 41.11007629674402
# Perplexity of the 77 Absolute Discounting model on the test data: 39.547865543949165
# Perplexity of the 78 Absolute Discounting model on the test data: 27.67023527007591
# Perplexity of the 79 Absolute Discounting model on the test data: 21.464568537377325
# Perplexity of the 80 Absolute Discounting model on the test data: 42.27807535365269
# Perplexity of the 81 Absolute Discounting model on the test data: 34.48377456405348
# Perplexity of the 82 Absolute Discounting model on the test data: 53.88958765336588
# Perplexity of the 83 Absolute Discounting model on the test data: 43.022306945920924
# Perplexity of the 84 Absolute Discounting model on the test data: 31.67391279421764
# Perplexity of the 85 Absolute Discounting model on the test data: 39.60120897963425
# Perplexity of the 86 Absolute Discounting model on the test data: 48.5469699717103
# Perplexity of the 87 Absolute Discounting model on the test data: 39.97752535023676
# Perplexity of the 88 Absolute Discounting model on the test data: 34.465381557043
# Perplexity of the 89 Absolute Discounting model on the test data: 44.16492544429583
# Perplexity of the 90 Absolute Discounting model on the test data: 45.868087352118586
# Perplexity of the 91 Absolute Discounting model on the test data: 46.62707761094889
# Perplexity of the 92 Absolute Discounting model on the test data: 34.62364233843384
# Perplexity of the 93 Absolute Discounting model on the test data: 43.2297108727916
# Perplexity of the 94 Absolute Discounting model on the test data: 56.18240565252798
# Perplexity of the 95 Absolute Discounting model on the test data: 44.66850125781772
# Perplexity of the 96 Absolute Discounting model on the test data: 61.61111649879382
# Perplexity of the 97 Absolute Discounting model on the test data: 46.06984132880402
# Perplexity of the 98 Absolute Discounting model on the test data: 36.911123365059076
# Perplexity of the 99 Absolute Discounting model on the test data: 53.37180531021179
# Perplexity of the 100 Absolute Discounting model on the test data: 29.87849304955239
# Perplexity of the 101 Absolute Discounting model on the test data: 10.582244242309077
# Perplexity of the 102 Absolute Discounting model on the test data: 42.93264351040954
# Perplexity of the 103 Absolute Discounting model on the test data: 53.061452647745504
# Perplexity of the 104 Absolute Discounting model on the test data: 57.84270268123834
# Perplexity of the 105 Absolute Discounting model on the test data: 48.612441063332845
# Perplexity of the 106 Absolute Discounting model on the test data: 44.472555646926395
# Perplexity of the 107 Absolute Discounting model on the test data: 41.032705762476
# Perplexity of the 108 Absolute Discounting model on the test data: 49.50470428951544
# Perplexity of the 109 Absolute Discounting model on the test data: 47.639944856762476
# Perplexity of the 110 Absolute Discounting model on the test data: 39.66768820920298
# Perplexity of the 111 Absolute Discounting model on the test data: 43.7352110093194
# Perplexity of the 112 Absolute Discounting model on the test data: 35.85633514766132
# Perplexity of the 113 Absolute Discounting model on the test data: 30.53320819187432
# Perplexity of the 114 Absolute Discounting model on the test data: 43.75253185264986
# Perplexity of the 115 Absolute Discounting model on the test data: 52.92206704552839
# Perplexity of the 116 Absolute Discounting model on the test data: 48.28858233805882
# Perplexity of the 117 Absolute Discounting model on the test data: 24.5732399613558
# Perplexity of the 118 Absolute Discounting model on the test data: 43.402773730703245
# Perplexity of the 119 Absolute Discounting model on the test data: 35.9187502768977
# Perplexity of the 120 Absolute Discounting model on the test data: 37.67206783102258
# Perplexity of the 121 Absolute Discounting model on the test data: 41.320152850228624
# Perplexity of the 122 Absolute Discounting model on the test data: 43.81868158864191
# Perplexity of the 123 Absolute Discounting model on the test data: 41.64633985645386
# Perplexity of the 124 Absolute Discounting model on the test data: 43.505127883153676
# Perplexity of the 125 Absolute Discounting model on the test data: 54.411404961663536
# Perplexity of the 126 Absolute Discounting model on the test data: 37.43206395642776
# Perplexity of the 127 Absolute Discounting model on the test data: 47.56423788161145
# Perplexity of the 128 Absolute Discounting model on the test data: 46.95599476326684
# Perplexity of the 129 Absolute Discounting model on the test data: 41.67526102385948
# Perplexity of the 130 Absolute Discounting model on the test data: 46.82113294632747
# Perplexity of the 131 Absolute Discounting model on the test data: 33.64108652407
# Perplexity of the 132 Absolute Discounting model on the test data: 35.90237111531992
# Perplexity of the 133 Absolute Discounting model on the test data: 39.57083485571621
# Perplexity of the 134 Absolute Discounting model on the test data: 33.62114512512693
# Perplexity of the 135 Absolute Discounting model on the test data: 43.01967962206473
# Perplexity of the 136 Absolute Discounting model on the test data: 44.569672916247335
# Perplexity of the 137 Absolute Discounting model on the test data: 43.15272881395871
# Perplexity of the 138 Absolute Discounting model on the test data: 42.14666072584155
# Perplexity of the 139 Absolute Discounting model on the test data: 39.541045568900046
# Perplexity of the 140 Absolute Discounting model on the test data: 51.81596284667457
# Perplexity of the 141 Absolute Discounting model on the test data: 35.58235638429544
# Perplexity of the 142 Absolute Discounting model on the test data: 40.9635433791774
# Perplexity of the 143 Absolute Discounting model on the test data: 79.51443251307282
# Perplexity of the 144 Absolute Discounting model on the test data: 34.68514006670664
# Perplexity of the 145 Absolute Discounting model on the test data: 43.798931329029344
# Perplexity of the 146 Absolute Discounting model on the test data: 46.38291302113708
# Perplexity of the 147 Absolute Discounting model on the test data: 94.05010685308571
# Perplexity of the 148 Absolute Discounting model on the test data: 37.29911618740506
# Perplexity of the 149 Absolute Discounting model on the test data: 43.73453744265963
# Perplexity of the 150 Absolute Discounting model on the test data: 65.86731388803305
# Perplexity of the 151 Absolute Discounting model on the test data: 23.55245236620555
# Perplexity of the 152 Absolute Discounting model on the test data: 19.279736082847062
# Perplexity of the 153 Absolute Discounting model on the test data: 42.276138023958424
# Perplexity of the 154 Absolute Discounting model on the test data: 59.8845794935774
# Perplexity of the 155 Absolute Discounting model on the test data: 47.03495227613861
# Perplexity of the 156 Absolute Discounting model on the test data: 39.84022314505822
# Perplexity of the 157 Absolute Discounting model on the test data: 43.284480680626714
# Perplexity of the 158 Absolute Discounting model on the test data: 46.39442854886058
# Perplexity of the 159 Absolute Discounting model on the test data: 61.171120468698
# Perplexity of the 160 Absolute Discounting model on the test data: 40.490244850023814
# Perplexity of the 161 Absolute Discounting model on the test data: 49.70875524686725
# Perplexity of the 162 Absolute Discounting model on the test data: 56.0600918563997
# Perplexity of the 163 Absolute Discounting model on the test data: 50.642670986560496
# Perplexity of the 164 Absolute Discounting model on the test data: 38.36226472883245
# Perplexity of the 165 Absolute Discounting model on the test data: 11.388229358943528
# Perplexity of the 166 Absolute Discounting model on the test data: 15.89760611788775
# Perplexity of the 167 Absolute Discounting model on the test data: 51.492307476054854
# Perplexity of the 168 Absolute Discounting model on the test data: 43.44836077567184
# Perplexity of the 169 Absolute Discounting model on the test data: 50.594432442505834
# Perplexity of the 170 Absolute Discounting model on the test data: 45.20431301589232
# Perplexity of the 171 Absolute Discounting model on the test data: 50.63893088249774
# Perplexity of the 172 Absolute Discounting model on the test data: 51.51203028109598
# Perplexity of the 173 Absolute Discounting model on the test data: 51.757738407490926
# Perplexity of the 174 Absolute Discounting model on the test data: 53.77575401936786
# Perplexity of the 175 Absolute Discounting model on the test data: 58.881465399691955
# Perplexity of the 176 Absolute Discounting model on the test data: 37.78381015479681
# Perplexity of the 177 Absolute Discounting model on the test data: 41.50920915872696
# Perplexity of the 178 Absolute Discounting model on the test data: 43.22212451310206
# Perplexity of the 179 Absolute Discounting model on the test data: 45.64753093837647
# Perplexity of the 180 Absolute Discounting model on the test data: 27.28559839147513
# Perplexity of the 181 Absolute Discounting model on the test data: 39.76110198165377
# Perplexity of the 182 Absolute Discounting model on the test data: 64.87749787703122
# Perplexity of the 183 Absolute Discounting model on the test data: 48.66639138297967
# Perplexity of the 184 Absolute Discounting model on the test data: 47.80657775837454
# Perplexity of the 185 Absolute Discounting model on the test data: 30.921478809483304
# Perplexity of the 186 Absolute Discounting model on the test data: 36.878054965545985
# Perplexity of the 187 Absolute Discounting model on the test data: 55.07157867107878
# Perplexity of the 188 Absolute Discounting model on the test data: 49.170226630294415
# Perplexity of the 189 Absolute Discounting model on the test data: 45.70255949649959
# Perplexity of the 190 Absolute Discounting model on the test data: 61.26582220229572
# Perplexity of the 191 Absolute Discounting model on the test data: 26.75639024637072
# Perplexity of the 192 Absolute Discounting model on the test data: 52.40965683230647
# Perplexity of the 193 Absolute Discounting model on the test data: 60.35103321072503
# Perplexity of the 194 Absolute Discounting model on the test data: 49.42439428897489
# Perplexity of the 195 Absolute Discounting model on the test data: 49.60553838946194
# Perplexity of the 196 Absolute Discounting model on the test data: 45.520751875641146
# Perplexity of the 197 Absolute Discounting model on the test data: 40.99603729216352
# Perplexity of the 198 Absolute Discounting model on the test data: 29.250429373392464
# Perplexity of the 199 Absolute Discounting model on the test data: 53.04808680647005
# Perplexity of the 200 Absolute Discounting model on the test data: 53.78688356786972
# Perplexity of the 201 Absolute Discounting model on the test data: 34.27440593422574
# Perplexity of the 202 Absolute Discounting model on the test data: 54.56308841612908
# Perplexity of the 203 Absolute Discounting model on the test data: 41.3196419407184
# Perplexity of the 204 Absolute Discounting model on the test data: 42.148021824739814
# Perplexity of the 205 Absolute Discounting model on the test data: 42.03845585226186
# Perplexity of the 206 Absolute Discounting model on the test data: 31.465273252033885
# Perplexity of the 207 Absolute Discounting model on the test data: 54.52436849740016
# Perplexity of the 208 Absolute Discounting model on the test data: 41.76539420382025
# Perplexity of the 209 Absolute Discounting model on the test data: 42.082371116208606
# Perplexity of the 210 Absolute Discounting model on the test data: 44.12919397926017
# Perplexity of the 211 Absolute Discounting model on the test data: 27.421309010002197
# Perplexity of the 212 Absolute Discounting model on the test data: 30.12849843640215
# Perplexity of the 213 Absolute Discounting model on the test data: 34.831989176705086
# Perplexity of the 214 Absolute Discounting model on the test data: 41.52879670998792
# Perplexity of the 215 Absolute Discounting model on the test data: 38.343410815394236
# Perplexity of the 216 Absolute Discounting model on the test data: 59.90233189024982
# Perplexity of the 217 Absolute Discounting model on the test data: 21.38115685904889
# Perplexity of the 218 Absolute Discounting model on the test data: 45.250274422529984
# Perplexity of the 219 Absolute Discounting model on the test data: 48.84402749875945
# Perplexity of the 220 Absolute Discounting model on the test data: 52.24304837002466
# Perplexity of the 221 Absolute Discounting model on the test data: 45.506033261445126
# Perplexity of the 222 Absolute Discounting model on the test data: 36.57460475519348
# Perplexity of the 223 Absolute Discounting model on the test data: 69.47960071207225
# Perplexity of the 224 Absolute Discounting model on the test data: 68.01709441816617
# Perplexity of the 225 Absolute Discounting model on the test data: 51.40653239774361
# Perplexity of the 226 Absolute Discounting model on the test data: 40.92562175414059
# Perplexity of the 227 Absolute Discounting model on the test data: 38.78079756624247
# Perplexity of the 228 Absolute Discounting model on the test data: 46.957927065006956
# Perplexity of the 229 Absolute Discounting model on the test data: 40.89437525378824
# Perplexity of the 230 Absolute Discounting model on the test data: 38.94031917413831
# Perplexity of the 231 Absolute Discounting model on the test data: 73.38800553571079
# Perplexity of the 232 Absolute Discounting model on the test data: 45.84171145345996
# Perplexity of the 233 Absolute Discounting model on the test data: 37.484440808392726
# Perplexity of the 234 Absolute Discounting model on the test data: 58.58930490900747
# Perplexity of the 235 Absolute Discounting model on the test data: 38.61204801154483
# Perplexity of the 236 Absolute Discounting model on the test data: 6.863959430250602
# Perplexity of the 237 Absolute Discounting model on the test data: 46.175626783070214
# Perplexity of the 238 Absolute Discounting model on the test data: 47.12184521067026
# Perplexity of the 239 Absolute Discounting model on the test data: 38.15925699213733
# Perplexity of the 240 Absolute Discounting model on the test data: 33.10232294037313
# Perplexity of the 241 Absolute Discounting model on the test data: 49.453824432029556
# Perplexity of the 242 Absolute Discounting model on the test data: 37.348424868767616
# Perplexity of the 243 Absolute Discounting model on the test data: 30.627756418660628
# Perplexity of the 244 Absolute Discounting model on the test data: 45.424962689175736
# Perplexity of the 245 Absolute Discounting model on the test data: 53.83981154803118
# Perplexity of the 246 Absolute Discounting model on the test data: 46.62317499306294
# Perplexity of the 247 Absolute Discounting model on the test data: 43.21645291437911
# Perplexity of the 248 Absolute Discounting model on the test data: 47.46248447860649
# Perplexity of the 249 Absolute Discounting model on the test data: 33.70731392602516
# Perplexity of the 250 Absolute Discounting model on the test data: 60.83371872546392
# Perplexity of the 251 Absolute Discounting model on the test data: 25.325658614796577
# Perplexity of the 252 Absolute Discounting model on the test data: 39.01647933158545
# Perplexity of the 253 Absolute Discounting model on the test data: 52.506424334599444
# Perplexity of the 254 Absolute Discounting model on the test data: 26.894287546047043
# Perplexity of the 255 Absolute Discounting model on the test data: 46.9179581743749
# Perplexity of the 256 Absolute Discounting model on the test data: 41.28294455976922
# Perplexity of the 257 Absolute Discounting model on the test data: 48.405762883722325
# Perplexity of the 258 Absolute Discounting model on the test data: 40.096532244013055
# Perplexity of the 259 Absolute Discounting model on the test data: 54.74166904739685
# Perplexity of the 260 Absolute Discounting model on the test data: 23.568245977342386
# Perplexity of the 261 Absolute Discounting model on the test data: 35.24742964456673
# Perplexity of the 262 Absolute Discounting model on the test data: 54.294514314291895
# Perplexity of the 263 Absolute Discounting model on the test data: 58.970490358702286
# Perplexity of the 264 Absolute Discounting model on the test data: 39.86489318583447
# Perplexity of the 265 Absolute Discounting model on the test data: 62.55519410196594
# Perplexity of the 266 Absolute Discounting model on the test data: 46.068281558391995
# Perplexity of the 267 Absolute Discounting model on the test data: 45.08460835411545
# Perplexity of the 268 Absolute Discounting model on the test data: 39.98053855413389
# Perplexity of the 269 Absolute Discounting model on the test data: 31.52666954072618
# Perplexity of the 270 Absolute Discounting model on the test data: 47.67906509983592
# Perplexity of the 271 Absolute Discounting model on the test data: 35.2311431769305
# Perplexity of the 272 Absolute Discounting model on the test data: 44.57841843120066
# Perplexity of the 273 Absolute Discounting model on the test data: 36.93347762083074
# Perplexity of the 274 Absolute Discounting model on the test data: 47.651186450025946
# Perplexity of the 275 Absolute Discounting model on the test data: 36.85333233962176
# Perplexity of the 276 Absolute Discounting model on the test data: 46.430240518194935
# Perplexity of the 277 Absolute Discounting model on the test data: 60.11897376419845
# Perplexity of the 278 Absolute Discounting model on the test data: 43.830876041149885
# Perplexity of the 279 Absolute Discounting model on the test data: 48.049110680449566
# Perplexity of the 280 Absolute Discounting model on the test data: 50.82471133191249
# Perplexity of the 281 Absolute Discounting model on the test data: 42.37263874328811
# Perplexity of the 282 Absolute Discounting model on the test data: 38.23285025756018
# Perplexity of the 283 Absolute Discounting model on the test data: 28.459305517463427
# Perplexity of the 284 Absolute Discounting model on the test data: 37.48285563355767
# Perplexity of the 285 Absolute Discounting model on the test data: 45.73446282232423
# Perplexity of the 286 Absolute Discounting model on the test data: 42.76446597282864
# Perplexity of the 287 Absolute Discounting model on the test data: 49.971551672382105
# Perplexity of the 288 Absolute Discounting model on the test data: 39.79494766888222
# Perplexity of the 289 Absolute Discounting model on the test data: 47.905666409961015
# Perplexity of the 290 Absolute Discounting model on the test data: 66.07512411518933
# Perplexity of the 291 Absolute Discounting model on the test data: 19.05321107574805
# Perplexity of the 292 Absolute Discounting model on the test data: 64.99129861800245
# Perplexity of the 293 Absolute Discounting model on the test data: 41.27632203792626
# Perplexity of the 294 Absolute Discounting model on the test data: 41.5341779302512
# Perplexity of the 295 Absolute Discounting model on the test data: 34.13353669846735
# Perplexity of the 296 Absolute Discounting model on the test data: 37.89014705512345
# Perplexity of the 297 Absolute Discounting model on the test data: 51.50954547735725
# Perplexity of the 298 Absolute Discounting model on the test data: 40.16572134652158
# Perplexity of the 299 Absolute Discounting model on the test data: 52.847676987164675
# Perplexity of the 300 Absolute Discounting model on the test data: 58.588458395876884
# Perplexity of the 301 Absolute Discounting model on the test data: 43.56579482115054
# Perplexity of the 302 Absolute Discounting model on the test data: 33.82306027576475
# Perplexity of the 303 Absolute Discounting model on the test data: 21.028338869740566
# Perplexity of the 304 Absolute Discounting model on the test data: 35.947242603146584
# Perplexity of the 305 Absolute Discounting model on the test data: 32.55842490353087
# Perplexity of the 306 Absolute Discounting model on the test data: 50.62563479269133
# Perplexity of the 307 Absolute Discounting model on the test data: 49.53400200084493
# Perplexity of the 308 Absolute Discounting model on the test data: 59.25455617854573
# Perplexity of the 309 Absolute Discounting model on the test data: 43.33162988123635
# Perplexity of the 310 Absolute Discounting model on the test data: 35.182425832573195
# Perplexity of the 311 Absolute Discounting model on the test data: 50.07633817382901
# Perplexity of the 312 Absolute Discounting model on the test data: 33.74633499885201
# Perplexity of the 313 Absolute Discounting model on the test data: 73.45182422414923
# Perplexity of the 314 Absolute Discounting model on the test data: 29.774408620583973
# Perplexity of the 315 Absolute Discounting model on the test data: 59.545870575579414
# Perplexity of the 316 Absolute Discounting model on the test data: 44.55382664586558
# Perplexity of the 317 Absolute Discounting model on the test data: 50.75519701903225
# Perplexity of the 318 Absolute Discounting model on the test data: 21.68535405223614
# Perplexity of the 319 Absolute Discounting model on the test data: 28.561648203059406
# Perplexity of the 320 Absolute Discounting model on the test data: 33.629083744313604
# Perplexity of the 321 Absolute Discounting model on the test data: 56.31934174008311
# Perplexity of the 322 Absolute Discounting model on the test data: 47.11704636206587
# Perplexity of the 323 Absolute Discounting model on the test data: 73.31841718508818
# Perplexity of the 324 Absolute Discounting model on the test data: 29.814461530156823
# Perplexity of the 325 Absolute Discounting model on the test data: 63.35667926278466
# Perplexity of the 326 Absolute Discounting model on the test data: 47.46998910340737
# Perplexity of the 327 Absolute Discounting model on the test data: 40.33141849678687
# Perplexity of the 328 Absolute Discounting model on the test data: 54.88510132365298
# Perplexity of the 329 Absolute Discounting model on the test data: 33.86459932639168
# Perplexity of the 330 Absolute Discounting model on the test data: 29.673344507740268
# Perplexity of the 331 Absolute Discounting model on the test data: 39.29452248092
# Perplexity of the 332 Absolute Discounting model on the test data: 41.917999782854345
# Perplexity of the 333 Absolute Discounting model on the test data: 42.87574212721003
# Perplexity of the 334 Absolute Discounting model on the test data: 67.24684709821769
# Perplexity of the 335 Absolute Discounting model on the test data: 70.11264196048764
# Perplexity of the 336 Absolute Discounting model on the test data: 49.90877340513854
# Perplexity of the 337 Absolute Discounting model on the test data: 22.869225021965857
# Perplexity of the 338 Absolute Discounting model on the test data: 43.82098695559857
# Perplexity of the 339 Absolute Discounting model on the test data: 39.23511889807225
# Perplexity of the 340 Absolute Discounting model on the test data: 60.219189166421494
# Perplexity of the 341 Absolute Discounting model on the test data: 54.11442953494014
# Perplexity of the 342 Absolute Discounting model on the test data: 56.739871195302065
# Perplexity of the 343 Absolute Discounting model on the test data: 41.355539047464
# Perplexity of the 344 Absolute Discounting model on the test data: 24.383028472389995
# Perplexity of the 345 Absolute Discounting model on the test data: 40.43064168556984
# Perplexity of the 346 Absolute Discounting model on the test data: 56.44679172288263
# Perplexity of the 347 Absolute Discounting model on the test data: 38.041166014908605
# Perplexity of the 348 Absolute Discounting model on the test data: 41.55934091870685
# Perplexity of the 349 Absolute Discounting model on the test data: 59.86030455234784
# Perplexity of the 350 Absolute Discounting model on the test data: 50.55857551554135
# Perplexity of the 351 Absolute Discounting model on the test data: 39.99301728370197
# Perplexity of the 352 Absolute Discounting model on the test data: 36.7784713408106
# Perplexity of the 353 Absolute Discounting model on the test data: 44.0889474439373
# Perplexity of the 354 Absolute Discounting model on the test data: 52.59373930912106
# Perplexity of the 355 Absolute Discounting model on the test data: 43.83839961614792
# Perplexity of the 356 Absolute Discounting model on the test data: 45.40656095540549
# Perplexity of the 357 Absolute Discounting model on the test data: 48.080133658363685
# Perplexity of the 358 Absolute Discounting model on the test data: 38.5973571745127
# Perplexity of the 359 Absolute Discounting model on the test data: 37.19614383802932
# Perplexity of the 360 Absolute Discounting model on the test data: 25.532498471116313
# Perplexity of the 361 Absolute Discounting model on the test data: 47.36761980711065
# Perplexity of the 362 Absolute Discounting model on the test data: 59.45718398368841
# Perplexity of the 363 Absolute Discounting model on the test data: 53.436088654307945
# Perplexity of the 364 Absolute Discounting model on the test data: 47.38531392304016
# Perplexity of the 365 Absolute Discounting model on the test data: 40.750724623386766
# Perplexity of the 366 Absolute Discounting model on the test data: 46.648129736316115
# Perplexity of the 367 Absolute Discounting model on the test data: 37.07698809400081
# Perplexity of the 368 Absolute Discounting model on the test data: 46.08683504647809
# Perplexity of the 369 Absolute Discounting model on the test data: 37.43356662346747
# Perplexity of the 370 Absolute Discounting model on the test data: 30.40039540231399
# Perplexity of the 371 Absolute Discounting model on the test data: 27.893202763675593
# Perplexity of the 372 Absolute Discounting model on the test data: 30.61872289288178
# Perplexity of the 373 Absolute Discounting model on the test data: 47.17786668285334
# Perplexity of the 374 Absolute Discounting model on the test data: 33.51127094415079
# Perplexity of the 375 Absolute Discounting model on the test data: 58.01881201437056
# Perplexity of the 376 Absolute Discounting model on the test data: 49.94403794820801
# Perplexity of the 377 Absolute Discounting model on the test data: 57.15767543652502
# Perplexity of the 378 Absolute Discounting model on the test data: 39.57282349591416
# Perplexity of the 379 Absolute Discounting model on the test data: 42.49248497177349
# Perplexity of the 380 Absolute Discounting model on the test data: 45.57084250367867
# Perplexity of the 381 Absolute Discounting model on the test data: 48.28774094191049
# Perplexity of the 382 Absolute Discounting model on the test data: 51.03593664190737
# Perplexity of the 383 Absolute Discounting model on the test data: 22.810144286665043
# Perplexity of the 384 Absolute Discounting model on the test data: 45.368579913139534
# Perplexity of the 385 Absolute Discounting model on the test data: 22.867581114355048
# Perplexity of the 386 Absolute Discounting model on the test data: 65.65717434005312
# Perplexity of the 387 Absolute Discounting model on the test data: 34.75828562386906
# Perplexity of the 388 Absolute Discounting model on the test data: 43.30613927976425
# Perplexity of the 389 Absolute Discounting model on the test data: 34.88514604211484
# Perplexity of the 390 Absolute Discounting model on the test data: 38.6448343396982
# Perplexity of the 391 Absolute Discounting model on the test data: 34.10984109297726
# Perplexity of the 392 Absolute Discounting model on the test data: 43.98929242670038
# Perplexity of the 393 Absolute Discounting model on the test data: 44.73668414469427
# Perplexity of the 394 Absolute Discounting model on the test data: 46.3691931978953
# Perplexity of the 395 Absolute Discounting model on the test data: 53.51158212636464
# Perplexity of the 396 Absolute Discounting model on the test data: 33.311875946023214
# Perplexity of the 397 Absolute Discounting model on the test data: 30.27007452159629
# Perplexity of the 398 Absolute Discounting model on the test data: 61.65433799732525
# Perplexity of the 399 Absolute Discounting model on the test data: 65.37878661974848
# Perplexity of the 400 Absolute Discounting model on the test data: 51.224891522126114
# Perplexity of the 401 Absolute Discounting model on the test data: 48.40238822138562
# Perplexity of the 402 Absolute Discounting model on the test data: 47.8539946691172
# Perplexity of the 403 Absolute Discounting model on the test data: 33.96684142872299
# Perplexity of the 404 Absolute Discounting model on the test data: 41.51553031361314
# Perplexity of the 405 Absolute Discounting model on the test data: 46.069004769053514
# Perplexity of the 406 Absolute Discounting model on the test data: 19.271920805238377
# Perplexity of the 407 Absolute Discounting model on the test data: 48.98551770774427
# Perplexity of the 408 Absolute Discounting model on the test data: 46.51766207944841
# Perplexity of the 409 Absolute Discounting model on the test data: 36.355895151467934
# Perplexity of the 410 Absolute Discounting model on the test data: 42.386278280655496
# Perplexity of the 411 Absolute Discounting model on the test data: 30.673400707133972
# Perplexity of the 412 Absolute Discounting model on the test data: 48.938291003913
# Perplexity of the 413 Absolute Discounting model on the test data: 34.572426364138835
# Perplexity of the 414 Absolute Discounting model on the test data: 57.40857233033863
# Perplexity of the 415 Absolute Discounting model on the test data: 58.15930508296961
# Perplexity of the 416 Absolute Discounting model on the test data: 22.962981531741697
# Perplexity of the 417 Absolute Discounting model on the test data: 51.54488663566355
# Perplexity of the 418 Absolute Discounting model on the test data: 52.01814933251414
# Perplexity of the 419 Absolute Discounting model on the test data: 92.46584813774885
# Perplexity of the 420 Absolute Discounting model on the test data: 38.07975386971409
# Perplexity of the 421 Absolute Discounting model on the test data: 41.36077584510005
# Perplexity of the 422 Absolute Discounting model on the test data: 35.03273863989619
# Perplexity of the 423 Absolute Discounting model on the test data: 62.56191487642432
# Perplexity of the 424 Absolute Discounting model on the test data: 44.85547163377087
# Perplexity of the 425 Absolute Discounting model on the test data: 48.63842269630997
# Perplexity of the 426 Absolute Discounting model on the test data: 50.78662866151967
# Perplexity of the 427 Absolute Discounting model on the test data: 38.63386399548982
# Perplexity of the 428 Absolute Discounting model on the test data: 38.27193501304579
# Perplexity of the 429 Absolute Discounting model on the test data: 24.86486671236834
# Perplexity of the 430 Absolute Discounting model on the test data: 44.64279019445492
# Perplexity of the 431 Absolute Discounting model on the test data: 45.361309585892045
# Perplexity of the 432 Absolute Discounting model on the test data: 55.20599361509295
# Perplexity of the 433 Absolute Discounting model on the test data: 36.40370827778978
# Perplexity of the 434 Absolute Discounting model on the test data: 39.61069025165424
# Perplexity of the 435 Absolute Discounting model on the test data: 45.328301249732135
# Perplexity of the 436 Absolute Discounting model on the test data: 39.96590120578694
# Perplexity of the 437 Absolute Discounting model on the test data: 55.58538815782314
# Perplexity of the 438 Absolute Discounting model on the test data: 48.37734678964051
# Perplexity of the 439 Absolute Discounting model on the test data: 38.16064947776443
# Perplexity of the 440 Absolute Discounting model on the test data: 32.79232185129604
# Perplexity of the 441 Absolute Discounting model on the test data: 52.65991204606787
# Perplexity of the 442 Absolute Discounting model on the test data: 50.26660025372177
# Perplexity of the 443 Absolute Discounting model on the test data: 44.798114138439665
# Perplexity of the 444 Absolute Discounting model on the test data: 50.08606902770592
# Perplexity of the 445 Absolute Discounting model on the test data: 41.16521263547319
# Perplexity of the 446 Absolute Discounting model on the test data: 38.985697254712285
# Perplexity of the 447 Absolute Discounting model on the test data: 36.12705662630427
# Perplexity of the 448 Absolute Discounting model on the test data: 31.59157260240209
# Perplexity of the 449 Absolute Discounting model on the test data: 43.6824038891981
# Perplexity of the 450 Absolute Discounting model on the test data: 57.34835489425651
# Perplexity of the 451 Absolute Discounting model on the test data: 37.34106701234245
# Perplexity of the 452 Absolute Discounting model on the test data: 40.66604207029773
# Perplexity of the 453 Absolute Discounting model on the test data: 44.09905114427173
# Perplexity of the 454 Absolute Discounting model on the test data: 26.175798309283675
# Perplexity of the 455 Absolute Discounting model on the test data: 51.914348640078764
# Perplexity of the 456 Absolute Discounting model on the test data: 48.25876163338695
# Perplexity of the 457 Absolute Discounting model on the test data: 37.815114370098236
# Perplexity of the 458 Absolute Discounting model on the test data: 39.23907978660886
# Perplexity of the 459 Absolute Discounting model on the test data: 46.916031656634395
# Perplexity of the 460 Absolute Discounting model on the test data: 52.706292908557145
# Perplexity of the 461 Absolute Discounting model on the test data: 25.816420852068056
# Perplexity of the 462 Absolute Discounting model on the test data: 52.163811794805746
# Perplexity of the 463 Absolute Discounting model on the test data: 67.96853412174372
# Perplexity of the 464 Absolute Discounting model on the test data: 47.736105169609715
# Perplexity of the 465 Absolute Discounting model on the test data: 36.62570749315594
# Perplexity of the 466 Absolute Discounting model on the test data: 52.923085675142964
# Perplexity of the 467 Absolute Discounting model on the test data: 35.80849194673719
# Perplexity of the 468 Absolute Discounting model on the test data: 46.29888030880653
# Perplexity of the 469 Absolute Discounting model on the test data: 56.99958972895744
# Perplexity of the 470 Absolute Discounting model on the test data: 58.952531422848224
# Perplexity of the 471 Absolute Discounting model on the test data: 49.538606914327765
# Perplexity of the 472 Absolute Discounting model on the test data: 40.28355702097746
# Perplexity of the 473 Absolute Discounting model on the test data: 37.29964915348307
# Perplexity of the 474 Absolute Discounting model on the test data: 59.15522233281879
# Perplexity of the 475 Absolute Discounting model on the test data: 38.600861505463925
# Perplexity of the 476 Absolute Discounting model on the test data: 53.75078426020379
# Perplexity of the 477 Absolute Discounting model on the test data: 54.7566108620787
# Perplexity of the 478 Absolute Discounting model on the test data: 73.25095723335059
# Perplexity of the 479 Absolute Discounting model on the test data: 24.548213560493934
# Perplexity of the 480 Absolute Discounting model on the test data: 24.386024779665224
# Perplexity of the 481 Absolute Discounting model on the test data: 38.66073293513185
# Perplexity of the 482 Absolute Discounting model on the test data: 43.156235694007506
# Perplexity of the 483 Absolute Discounting model on the test data: 42.46883350283346
# Perplexity of the 484 Absolute Discounting model on the test data: 63.54706112069547
# Perplexity of the 485 Absolute Discounting model on the test data: 40.153532806935615
# Perplexity of the 486 Absolute Discounting model on the test data: 45.510510378896
# Perplexity of the 487 Absolute Discounting model on the test data: 37.23854993529428
# Perplexity of the 488 Absolute Discounting model on the test data: 37.263953142904235
# Perplexity of the 489 Absolute Discounting model on the test data: 45.432932474271965
# Perplexity of the 490 Absolute Discounting model on the test data: 39.21008567611037
# Perplexity of the 491 Absolute Discounting model on the test data: 51.47066967829889
# Perplexity of the 492 Absolute Discounting model on the test data: 41.18748129138263
# Perplexity of the 493 Absolute Discounting model on the test data: 38.55280033396597
# Perplexity of the 494 Absolute Discounting model on the test data: 31.491038906353236
# Perplexity of the 495 Absolute Discounting model on the test data: 42.85129503325084
# Perplexity of the 496 Absolute Discounting model on the test data: 47.92154998281499
# Perplexity of the 497 Absolute Discounting model on the test data: 60.713566804634326
# Perplexity of the 498 Absolute Discounting model on the test data: 64.76302411393989
# Perplexity of the 499 Absolute Discounting model on the test data: 56.55412256585007
# Perplexity of the 500 Absolute Discounting model on the test data: 22.51392380727744
# Perplexity of the 501 Absolute Discounting model on the test data: 19.237397421359006
# Perplexity of the 502 Absolute Discounting model on the test data: 52.68752242102079
# Perplexity of the 503 Absolute Discounting model on the test data: 41.76237417922944
# Perplexity of the 504 Absolute Discounting model on the test data: 45.93427064129455
# Perplexity of the 505 Absolute Discounting model on the test data: 46.21854837268801
# Perplexity of the 506 Absolute Discounting model on the test data: 49.109860725458375
# Perplexity of the 507 Absolute Discounting model on the test data: 15.405233060232101
# Perplexity of the 508 Absolute Discounting model on the test data: 50.14640763500635
# Perplexity of the 509 Absolute Discounting model on the test data: 17.740114831921588
# Perplexity of the 510 Absolute Discounting model on the test data: 41.73155569518135
# Perplexity of the 511 Absolute Discounting model on the test data: 41.83660806323326
# Perplexity of the 512 Absolute Discounting model on the test data: 35.06285640474736
# Perplexity of the 513 Absolute Discounting model on the test data: 50.797723159843166
# Perplexity of the 514 Absolute Discounting model on the test data: 25.591552349067495
# Perplexity of the 515 Absolute Discounting model on the test data: 48.68283006553786
# Perplexity of the 516 Absolute Discounting model on the test data: 52.998048182685366
# Perplexity of the 517 Absolute Discounting model on the test data: 43.243029917061456
# Perplexity of the 518 Absolute Discounting model on the test data: 55.49711421781651
# Perplexity of the 519 Absolute Discounting model on the test data: 37.96147432098964
# Perplexity of the 520 Absolute Discounting model on the test data: 51.01307655459171
# Perplexity of the 521 Absolute Discounting model on the test data: 39.30629573765696
# Perplexity of the 522 Absolute Discounting model on the test data: 44.58231112310073
# Perplexity of the 523 Absolute Discounting model on the test data: 51.29962141889915
# Perplexity of the 524 Absolute Discounting model on the test data: 42.94817015673532
# Perplexity of the 525 Absolute Discounting model on the test data: 54.915044627275435
# Perplexity of the 526 Absolute Discounting model on the test data: 59.58208235752172
# Perplexity of the 527 Absolute Discounting model on the test data: 37.60537604893973
# Perplexity of the 528 Absolute Discounting model on the test data: 40.97571971895437
# Perplexity of the 529 Absolute Discounting model on the test data: 61.08651718189553
# Perplexity of the 530 Absolute Discounting model on the test data: 45.10820766884584
# Perplexity of the 531 Absolute Discounting model on the test data: 52.00555998954011
# Perplexity of the 532 Absolute Discounting model on the test data: 44.29735612329255
# Perplexity of the 533 Absolute Discounting model on the test data: 64.12485076917217
# Perplexity of the 534 Absolute Discounting model on the test data: 49.7118915075126
# Perplexity of the 535 Absolute Discounting model on the test data: 56.38444070589179
# Perplexity of the 536 Absolute Discounting model on the test data: 46.035827891643315
# Perplexity of the 537 Absolute Discounting model on the test data: 34.57140456824396
# Perplexity of the 538 Absolute Discounting model on the test data: 56.82017688354254
# Perplexity of the 539 Absolute Discounting model on the test data: 50.22312882141053
# Perplexity of the 540 Absolute Discounting model on the test data: 53.379947309144484
# Perplexity of the 541 Absolute Discounting model on the test data: 70.53657807034412
# Perplexity of the 542 Absolute Discounting model on the test data: 78.55999211352041
# Perplexity of the 543 Absolute Discounting model on the test data: 23.181239505403664
# Perplexity of the 544 Absolute Discounting model on the test data: 46.23558842021982
# Perplexity of the 545 Absolute Discounting model on the test data: 46.16237565615213
# Perplexity of the 546 Absolute Discounting model on the test data: 24.305483574041343
# Perplexity of the 547 Absolute Discounting model on the test data: 37.53576048025497
# Perplexity of the 548 Absolute Discounting model on the test data: 52.44778637442698
# Perplexity of the 549 Absolute Discounting model on the test data: 51.22922681609129
# Perplexity of the 550 Absolute Discounting model on the test data: 31.324478418364805
# Perplexity of the 551 Absolute Discounting model on the test data: 31.82642347262918
# Perplexity of the 552 Absolute Discounting model on the test data: 54.811280602497995
# Perplexity of the 553 Absolute Discounting model on the test data: 45.26779443404421
# Perplexity of the 554 Absolute Discounting model on the test data: 38.056037908619246
# Perplexity of the 555 Absolute Discounting model on the test data: 65.07775760626922
# Perplexity of the 556 Absolute Discounting model on the test data: 46.64369486780907
# Perplexity of the 557 Absolute Discounting model on the test data: 75.19302989065758
# Perplexity of the 558 Absolute Discounting model on the test data: 18.822903037205705
# Perplexity of the 559 Absolute Discounting model on the test data: 64.74233660613332
# Perplexity of the 560 Absolute Discounting model on the test data: 42.62020619381952
# Perplexity of the 561 Absolute Discounting model on the test data: 22.612899611895994
# Perplexity of the 562 Absolute Discounting model on the test data: 61.752267742755244
# Perplexity of the 563 Absolute Discounting model on the test data: 42.07875694358571
# ...
# Perplexity of the 1459 Absolute Discounting model on the test data: 42.31852969571493
# Perplexity of the 1460 Absolute Discounting model on the test data: 49.49777970184313
# Perplexity of the 1461 Absolute Discounting model on the test data: 42.11877858158971
# Perplexity of the 1462 Absolute Discounting model on the test data: 43.221113901181276
# Perplexity of the 1463 Absolute Discounting model on the test data: 35.99272165066113
# Perplexity of the 1464 Absolute Discounting model on the test data: 36.2419441732822
# Perplexity of the 1465 Absolute Discounting model on the test data: 47.56789301106101
# Perplexity of the 1466 Absolute Discounting model on the test data: 13.852864473321391
# Perplexity of the 1467 Absolute Discounting model on the test data: 44.62692230391315
# Perplexity of the 1468 Absolute Discounting model on the test data: 45.92979406791622
# Perplexity of the 1469 Absolute Discounting model on the test data: 37.84890836101844
# Perplexity of the 1470 Absolute Discounting model on the test data: 50.5608143220329
# Perplexity of the 1471 Absolute Discounting model on the test data: 45.96124497577133
# Perplexity of the 1472 Absolute Discounting model on the test data: 47.7446960945898
# Perplexity of the 1473 Absolute Discounting model on the test data: 42.19604400253566
# Perplexity of the 1474 Absolute Discounting model on the test data: 49.06175044160652
# Perplexity of the 1475 Absolute Discounting model on the test data: 53.61253891937424
# Perplexity of the 1476 Absolute Discounting model on the test data: 46.50013002880722
# Perplexity of the 1477 Absolute Discounting model on the test data: 43.04741346187319
# Perplexity of the 1478 Absolute Discounting model on the test data: 40.13855484777169
# Perplexity of the 1479 Absolute Discounting model on the test data: 42.527338687919055
# Perplexity of the 1480 Absolute Discounting model on the test data: 44.305577516950045
# Perplexity of the 1481 Absolute Discounting model on the test data: 41.93116824739214
# Perplexity of the 1482 Absolute Discounting model on the test data: 41.119667911194014
# Perplexity of the 1483 Absolute Discounting model on the test data: 64.37598318515512
# Perplexity of the 1484 Absolute Discounting model on the test data: 57.701832871575135
# Perplexity of the 1485 Absolute Discounting model on the test data: 39.12104434594965
# Perplexity of the 1486 Absolute Discounting model on the test data: 54.87728194624085
# Perplexity of the 1487 Absolute Discounting model on the test data: 47.461363441115644
# Perplexity of the 1488 Absolute Discounting model on the test data: 44.00494677957521
# Perplexity of the 1489 Absolute Discounting model on the test data: 52.79061277078952
# Perplexity of the 1490 Absolute Discounting model on the test data: 78.06990207918027
# Perplexity of the 1491 Absolute Discounting model on the test data: 38.403241830062896
# Perplexity of the 1492 Absolute Discounting model on the test data: 40.88210861698287
# Perplexity of the 1493 Absolute Discounting model on the test data: 62.80620317428004
# Perplexity of the 1494 Absolute Discounting model on the test data: 53.61578392360144
# Perplexity of the 1495 Absolute Discounting model on the test data: 39.66015146082521
# Perplexity of the 1496 Absolute Discounting model on the test data: 47.56966191953781
# Perplexity of the 1497 Absolute Discounting model on the test data: 52.09876265922159
# Perplexity of the 1498 Absolute Discounting model on the test data: 65.51752959051467
# Perplexity of the 1499 Absolute Discounting model on the test data: 28.7359258432969
# Perplexity of the 1500 Absolute Discounting model on the test data: 48.5399389911006
# Perplexity of the 1501 Absolute Discounting model on the test data: 32.5265197662098
# Perplexity of the 1502 Absolute Discounting model on the test data: 40.81032448298783
# Perplexity of the 1503 Absolute Discounting model on the test data: 52.90312458257099
# Perplexity of the 1504 Absolute Discounting model on the test data: 44.475478889352104
# Perplexity of the 1505 Absolute Discounting model on the test data: 50.18601120786651
# Perplexity of the 1506 Absolute Discounting model on the test data: 25.93604862993875
# Perplexity of the 1507 Absolute Discounting model on the test data: 54.88505767254346
# Perplexity of the 1508 Absolute Discounting model on the test data: 54.78940118016343
# Perplexity of the 1509 Absolute Discounting model on the test data: 40.217396455934605
# Perplexity of the 1510 Absolute Discounting model on the test data: 38.00049999772269
# Perplexity of the 1511 Absolute Discounting model on the test data: 41.21606631466918
# Perplexity of the 1512 Absolute Discounting model on the test data: 50.820412360318755
# Perplexity of the 1513 Absolute Discounting model on the test data: 39.105793474277704
# Perplexity of the 1514 Absolute Discounting model on the test data: 66.53310351219356
# Perplexity of the 1515 Absolute Discounting model on the test data: 56.44327069775019
# Perplexity of the 1516 Absolute Discounting model on the test data: 71.91194273218382
# Perplexity of the 1517 Absolute Discounting model on the test data: 54.96814793260611
# Perplexity of the 1518 Absolute Discounting model on the test data: 37.79434950429934
# Perplexity of the 1519 Absolute Discounting model on the test data: 33.07696994028106
# Perplexity of the 1520 Absolute Discounting model on the test data: 66.8362904224475
# Perplexity of the 1521 Absolute Discounting model on the test data: 51.15132174967633
# Perplexity of the 1522 Absolute Discounting model on the test data: 42.25089782507693
# Perplexity of the 1523 Absolute Discounting model on the test data: 32.109421466531856
# Perplexity of the 1524 Absolute Discounting model on the test data: 42.70154801980815
# Perplexity of the 1525 Absolute Discounting model on the test data: 37.35801367016125
# Perplexity of the 1526 Absolute Discounting model on the test data: 41.867484501389406
# Perplexity of the 1527 Absolute Discounting model on the test data: 52.275535486847104
# Perplexity of the 1528 Absolute Discounting model on the test data: 37.92698137513907
# Perplexity of the 1529 Absolute Discounting model on the test data: 42.51149236915459
# Perplexity of the 1530 Absolute Discounting model on the test data: 38.001268447675635
# Perplexity of the 1531 Absolute Discounting model on the test data: 43.09554521158341
# Perplexity of the 1532 Absolute Discounting model on the test data: 52.84702197670389
# Perplexity of the 1533 Absolute Discounting model on the test data: 37.431752701621996
# Perplexity of the 1534 Absolute Discounting model on the test data: 44.050090302844005
# Perplexity of the 1535 Absolute Discounting model on the test data: 46.31078024423629
# Perplexity of the 1536 Absolute Discounting model on the test data: 42.56678206155099
# Perplexity of the 1537 Absolute Discounting model on the test data: 61.120556202683204
# Perplexity of the 1538 Absolute Discounting model on the test data: 28.300624736802188
# Perplexity of the 1539 Absolute Discounting model on the test data: 27.472339771380103
# Perplexity of the 1540 Absolute Discounting model on the test data: 28.113051341803594
# Perplexity of the 1541 Absolute Discounting model on the test data: 50.77609890312273
# Perplexity of the 1542 Absolute Discounting model on the test data: 29.014254019204376
# Perplexity of the 1543 Absolute Discounting model on the test data: 27.40757350026785
# Perplexity of the 1544 Absolute Discounting model on the test data: 30.02979635715245
# Perplexity of the 1545 Absolute Discounting model on the test data: 28.890958188264793
# Perplexity of the 1546 Absolute Discounting model on the test data: 63.50328874417647
# Perplexity of the 1547 Absolute Discounting model on the test data: 57.99021927145487
# Perplexity of the 1548 Absolute Discounting model on the test data: 48.86187428906714
# Perplexity of the 1549 Absolute Discounting model on the test data: 54.781421460191666
# Perplexity of the 1550 Absolute Discounting model on the test data: 46.18199367942614
# Perplexity of the 1551 Absolute Discounting model on the test data: 38.265750214434
# Perplexity of the 1552 Absolute Discounting model on the test data: 41.22422497862735
# Perplexity of the 1553 Absolute Discounting model on the test data: 39.36135414473852
# Perplexity of the 1554 Absolute Discounting model on the test data: 41.50983676505798
# Perplexity of the 1555 Absolute Discounting model on the test data: 36.241310490106144
# Perplexity of the 1556 Absolute Discounting model on the test data: 43.5287175838466
# Perplexity of the 1557 Absolute Discounting model on the test data: 58.072942811125024
# Perplexity of the 1558 Absolute Discounting model on the test data: 45.66116403267375
# Perplexity of the 1559 Absolute Discounting model on the test data: 26.999543161611502
# Perplexity of the 1560 Absolute Discounting model on the test data: 46.23097910721059
# Perplexity of the 1561 Absolute Discounting model on the test data: 11.018318605834613
# Perplexity of the 1562 Absolute Discounting model on the test data: 44.33090007519129
# Perplexity of the 1563 Absolute Discounting model on the test data: 40.058685632196
# Perplexity of the 1564 Absolute Discounting model on the test data: 47.4012770709806
# Perplexity of the 1565 Absolute Discounting model on the test data: 69.70055502928156
# Perplexity of the 1566 Absolute Discounting model on the test data: 47.48905419200965
# Perplexity of the 1567 Absolute Discounting model on the test data: 67.4679192861594
# Perplexity of the 1568 Absolute Discounting model on the test data: 41.63976101939381
# Perplexity of the 1569 Absolute Discounting model on the test data: 56.53374696848883
# Perplexity of the 1570 Absolute Discounting model on the test data: 41.373475142709175
# Perplexity of the 1571 Absolute Discounting model on the test data: 43.49217900347759
# Perplexity of the 1572 Absolute Discounting model on the test data: 47.10790285426803
# Perplexity of the 1573 Absolute Discounting model on the test data: 39.92793572779882
# Perplexity of the 1574 Absolute Discounting model on the test data: 50.389733335214835
# Perplexity of the 1575 Absolute Discounting model on the test data: 43.41382478339661
# Perplexity of the 1576 Absolute Discounting model on the test data: 40.20891807884272
# Perplexity of the 1577 Absolute Discounting model on the test data: 43.068462088238434
# Perplexity of the 1578 Absolute Discounting model on the test data: 46.58323148328281
# Perplexity of the 1579 Absolute Discounting model on the test data: 44.57064606186762
# Perplexity of the 1580 Absolute Discounting model on the test data: 37.82443966693162
# Perplexity of the 1581 Absolute Discounting model on the test data: 21.31643110721426
# Perplexity of the 1582 Absolute Discounting model on the test data: 52.16206728217965
# Perplexity of the 1583 Absolute Discounting model on the test data: 42.46618677216495
# Perplexity of the 1584 Absolute Discounting model on the test data: 34.312549810410246
# Perplexity of the 1585 Absolute Discounting model on the test data: 74.91620882589119
# Perplexity of the 1586 Absolute Discounting model on the test data: 42.729530073092626
# Perplexity of the 1587 Absolute Discounting model on the test data: 44.00106262253117
# Perplexity of the 1588 Absolute Discounting model on the test data: 28.2840046360735
# Perplexity of the 1589 Absolute Discounting model on the test data: 33.89232344288623
# Perplexity of the 1590 Absolute Discounting model on the test data: 47.859474531949324
# Perplexity of the 1591 Absolute Discounting model on the test data: 34.981575768198596
# Perplexity of the 1592 Absolute Discounting model on the test data: 48.36400504234383
# Perplexity of the 1593 Absolute Discounting model on the test data: 44.599733960298884
# Perplexity of the 1594 Absolute Discounting model on the test data: 38.34289498621597
# Perplexity of the 1595 Absolute Discounting model on the test data: 54.49774104988799
# Perplexity of the 1596 Absolute Discounting model on the test data: 51.976370556598155
# Perplexity of the 1597 Absolute Discounting model on the test data: 43.220129376294395
# Perplexity of the 1598 Absolute Discounting model on the test data: 36.98809796189125
# Perplexity of the 1599 Absolute Discounting model on the test data: 63.793252414327256
# Perplexity of the 1600 Absolute Discounting model on the test data: 56.829333394494085
# Perplexity of the 1601 Absolute Discounting model on the test data: 29.305377128758305
# Perplexity of the 1602 Absolute Discounting model on the test data: 48.05729987699648
# Perplexity of the 1603 Absolute Discounting model on the test data: 38.43550208673837
# Perplexity of the 1604 Absolute Discounting model on the test data: 72.9936782182635
# Perplexity of the 1605 Absolute Discounting model on the test data: 29.6675103326924
# Perplexity of the 1606 Absolute Discounting model on the test data: 39.85554633351847
# Perplexity of the 1607 Absolute Discounting model on the test data: 43.314421785899306
# Perplexity of the 1608 Absolute Discounting model on the test data: 20.36104665664724
# Perplexity of the 1609 Absolute Discounting model on the test data: 42.96882033204013
# Perplexity of the 1610 Absolute Discounting model on the test data: 72.27949540238134
# Perplexity of the 1611 Absolute Discounting model on the test data: 53.70914630729574
# Perplexity of the 1612 Absolute Discounting model on the test data: 47.566053582077785
# Perplexity of the 1613 Absolute Discounting model on the test data: 36.197637038155065
# Perplexity of the 1614 Absolute Discounting model on the test data: 59.80789166682187
# Perplexity of the 1615 Absolute Discounting model on the test data: 52.930647354251576
# Perplexity of the 1616 Absolute Discounting model on the test data: 49.96416773377384
# Perplexity of the 1617 Absolute Discounting model on the test data: 40.52709056107212
# Perplexity of the 1618 Absolute Discounting model on the test data: 56.32608218504751
# Perplexity of the 1619 Absolute Discounting model on the test data: 54.65304762651046
# Perplexity of the 1620 Absolute Discounting model on the test data: 45.86990603023317
# Perplexity of the 1621 Absolute Discounting model on the test data: 37.65456228577253
# Perplexity of the 1622 Absolute Discounting model on the test data: 51.8994720684252
# Perplexity of the 1623 Absolute Discounting model on the test data: 51.509460170434785
# Perplexity of the 1624 Absolute Discounting model on the test data: 38.05030779522905
# Perplexity of the 1625 Absolute Discounting model on the test data: 21.18201731104157
# Perplexity of the 1626 Absolute Discounting model on the test data: 47.05058746888501
# Perplexity of the 1627 Absolute Discounting model on the test data: 39.1106449890408
# Perplexity of the 1628 Absolute Discounting model on the test data: 41.842886956547616
# Perplexity of the 1629 Absolute Discounting model on the test data: 46.8030426709484
# Perplexity of the 1630 Absolute Discounting model on the test data: 37.6005282669277
# Perplexity of the 1631 Absolute Discounting model on the test data: 33.12569966253253
# Perplexity of the 1632 Absolute Discounting model on the test data: 52.189215526166635
# Perplexity of the 1633 Absolute Discounting model on the test data: 39.806480405696284
# Perplexity of the 1634 Absolute Discounting model on the test data: 45.54813613407797
# Perplexity of the 1635 Absolute Discounting model on the test data: 38.47755972939676
# Perplexity of the 1636 Absolute Discounting model on the test data: 42.02974010391036
# Perplexity of the 1637 Absolute Discounting model on the test data: 39.95378359561726
# Perplexity of the 1638 Absolute Discounting model on the test data: 43.90526305504371
# Perplexity of the 1639 Absolute Discounting model on the test data: 62.76521002828554
# Perplexity of the 1640 Absolute Discounting model on the test data: 68.93541075245768
# Perplexity of the 1641 Absolute Discounting model on the test data: 54.39999624050477
# Perplexity of the 1642 Absolute Discounting model on the test data: 39.427717744612174
# Perplexity of the 1643 Absolute Discounting model on the test data: 54.22073726188795

# %%
# trigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(3)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 0.003746913207649293
# Perplexity of the 1 Absolute Discounting model on the test data: 10.788610858964786
# Perplexity of the 2 Absolute Discounting model on the test data: 10.841792401927307
# Perplexity of the 3 Absolute Discounting model on the test data: 8.564449376118656
# Perplexity of the 4 Absolute Discounting model on the test data: 8.821056346181145
# Perplexity of the 5 Absolute Discounting model on the test data: 14.625216958013151
# Perplexity of the 6 Absolute Discounting model on the test data: 14.682739458059043
# Perplexity of the 7 Absolute Discounting model on the test data: 10.207123256255471
# Perplexity of the 8 Absolute Discounting model on the test data: 6.59845570866539
# Perplexity of the 9 Absolute Discounting model on the test data: 7.398993420366893
# Perplexity of the 10 Absolute Discounting model on the test data: 10.727126312475507
# Perplexity of the 11 Absolute Discounting model on the test data: 11.902162561380841
# Perplexity of the 12 Absolute Discounting model on the test data: 13.969734919733222
# Perplexity of the 13 Absolute Discounting model on the test data: 9.021320676499954
# Perplexity of the 14 Absolute Discounting model on the test data: 9.491521158117608
# Perplexity of the 15 Absolute Discounting model on the test data: 20.283331904704184
# Perplexity of the 16 Absolute Discounting model on the test data: 9.836883419536575
# Perplexity of the 17 Absolute Discounting model on the test data: 15.550759391826082
# Perplexity of the 18 Absolute Discounting model on the test data: 7.371401764530275
# Perplexity of the 19 Absolute Discounting model on the test data: 14.103793228686843
# Perplexity of the 20 Absolute Discounting model on the test data: 12.156459987011734
# Perplexity of the 21 Absolute Discounting model on the test data: 11.60617776721774
# Perplexity of the 22 Absolute Discounting model on the test data: 7.786250028371623
# Perplexity of the 23 Absolute Discounting model on the test data: 10.023356304918577
# Perplexity of the 24 Absolute Discounting model on the test data: 12.858402900542117
# Perplexity of the 25 Absolute Discounting model on the test data: 11.290543427317987
# Perplexity of the 26 Absolute Discounting model on the test data: 6.834310961948448
# Perplexity of the 27 Absolute Discounting model on the test data: 10.557093172448052
# Perplexity of the 28 Absolute Discounting model on the test data: 11.101405786014215
# Perplexity of the 29 Absolute Discounting model on the test data: 9.68869657617986
# Perplexity of the 30 Absolute Discounting model on the test data: 12.582314958297037
# Perplexity of the 31 Absolute Discounting model on the test data: 13.750254394954693
# Perplexity of the 32 Absolute Discounting model on the test data: 20.78333110345229
# Perplexity of the 33 Absolute Discounting model on the test data: 13.778745721985075
# Perplexity of the 34 Absolute Discounting model on the test data: 6.792080280779907
# Perplexity of the 35 Absolute Discounting model on the test data: 13.586960570233359
# Perplexity of the 36 Absolute Discounting model on the test data: 8.430275852038283
# Perplexity of the 37 Absolute Discounting model on the test data: 6.479915892957642
# Perplexity of the 38 Absolute Discounting model on the test data: 11.241976399945212
# Perplexity of the 39 Absolute Discounting model on the test data: 16.39260019175857
# Perplexity of the 40 Absolute Discounting model on the test data: 10.547516908126227
# Perplexity of the 41 Absolute Discounting model on the test data: 14.097150061918573
# Perplexity of the 42 Absolute Discounting model on the test data: 11.19986807560999
# Perplexity of the 43 Absolute Discounting model on the test data: 16.76062390233069
# Perplexity of the 44 Absolute Discounting model on the test data: 18.042425785511647
# Perplexity of the 45 Absolute Discounting model on the test data: 14.343838977451666
# Perplexity of the 46 Absolute Discounting model on the test data: 10.529607531112037
# Perplexity of the 47 Absolute Discounting model on the test data: 13.838174193358174
# Perplexity of the 48 Absolute Discounting model on the test data: 10.5743443079971
# Perplexity of the 49 Absolute Discounting model on the test data: 13.680943064891709
# Perplexity of the 50 Absolute Discounting model on the test data: 9.432869895299142
# Perplexity of the 51 Absolute Discounting model on the test data: 13.879554259386339
# Perplexity of the 52 Absolute Discounting model on the test data: 6.8425558789406375
# Perplexity of the 53 Absolute Discounting model on the test data: 10.683652715194393
# Perplexity of the 54 Absolute Discounting model on the test data: 10.002511158870018
# Perplexity of the 55 Absolute Discounting model on the test data: 12.956546107505652
# Perplexity of the 56 Absolute Discounting model on the test data: 9.576962966670322
# Perplexity of the 57 Absolute Discounting model on the test data: 11.729398140943665
# Perplexity of the 58 Absolute Discounting model on the test data: 11.794847973472915
# Perplexity of the 59 Absolute Discounting model on the test data: 11.44911991238609
# Perplexity of the 60 Absolute Discounting model on the test data: 11.66490999097525
# Perplexity of the 61 Absolute Discounting model on the test data: 12.670812405796292
# Perplexity of the 62 Absolute Discounting model on the test data: 19.806216730126927
# Perplexity of the 63 Absolute Discounting model on the test data: 10.53468404590051
# Perplexity of the 64 Absolute Discounting model on the test data: 12.464833833207551
# Perplexity of the 65 Absolute Discounting model on the test data: 14.188951608163677
# Perplexity of the 66 Absolute Discounting model on the test data: 9.300121076754605
# Perplexity of the 67 Absolute Discounting model on the test data: 13.43837552673622
# Perplexity of the 68 Absolute Discounting model on the test data: 10.531785187401738
# Perplexity of the 69 Absolute Discounting model on the test data: 10.543600731978927
# Perplexity of the 70 Absolute Discounting model on the test data: 7.092810376841552
# Perplexity of the 71 Absolute Discounting model on the test data: 12.027642658571377
# Perplexity of the 72 Absolute Discounting model on the test data: 10.100430925877324
# Perplexity of the 73 Absolute Discounting model on the test data: 15.230625088991413
# Perplexity of the 74 Absolute Discounting model on the test data: 10.718932135758125
# Perplexity of the 75 Absolute Discounting model on the test data: 10.994008112246682
# Perplexity of the 76 Absolute Discounting model on the test data: 12.5947064231517
# Perplexity of the 77 Absolute Discounting model on the test data: 9.066342427214089
# Perplexity of the 78 Absolute Discounting model on the test data: 6.992260240172726
# Perplexity of the 79 Absolute Discounting model on the test data: 8.676505152392506
# Perplexity of the 80 Absolute Discounting model on the test data: 10.240855056896223
# Perplexity of the 81 Absolute Discounting model on the test data: 10.980777490997525
# Perplexity of the 82 Absolute Discounting model on the test data: 16.44502037559482
# Perplexity of the 83 Absolute Discounting model on the test data: 13.117884180931421
# Perplexity of the 84 Absolute Discounting model on the test data: 11.378008079310034
# Perplexity of the 85 Absolute Discounting model on the test data: 10.962545849378321
# Perplexity of the 86 Absolute Discounting model on the test data: 10.837277338151258
# Perplexity of the 87 Absolute Discounting model on the test data: 11.42413919059584
# Perplexity of the 88 Absolute Discounting model on the test data: 11.07357459874271
# Perplexity of the 89 Absolute Discounting model on the test data: 15.320482368676961
# Perplexity of the 90 Absolute Discounting model on the test data: 10.669438783753794
# Perplexity of the 91 Absolute Discounting model on the test data: 11.956660542312045
# Perplexity of the 92 Absolute Discounting model on the test data: 9.211323295956223
# Perplexity of the 93 Absolute Discounting model on the test data: 11.82862765569351
# Perplexity of the 94 Absolute Discounting model on the test data: 15.569052695531987
# Perplexity of the 95 Absolute Discounting model on the test data: 15.54457489021846
# Perplexity of the 96 Absolute Discounting model on the test data: 10.42687593484006
# Perplexity of the 97 Absolute Discounting model on the test data: 12.221724997747808
# Perplexity of the 98 Absolute Discounting model on the test data: 8.896932871111654
# Perplexity of the 99 Absolute Discounting model on the test data: 11.256198333308557
# Perplexity of the 100 Absolute Discounting model on the test data: 6.196858284180873
# Perplexity of the 101 Absolute Discounting model on the test data: 2.051059435101269
# Perplexity of the 102 Absolute Discounting model on the test data: 12.230619901134938
# Perplexity of the 103 Absolute Discounting model on the test data: 13.908064384289236
# Perplexity of the 104 Absolute Discounting model on the test data: 14.071401669553202
# Perplexity of the 105 Absolute Discounting model on the test data: 12.723730607617298
# Perplexity of the 106 Absolute Discounting model on the test data: 10.943442268820348
# Perplexity of the 107 Absolute Discounting model on the test data: 10.298819454782533
# Perplexity of the 108 Absolute Discounting model on the test data: 10.33124474388615
# Perplexity of the 109 Absolute Discounting model on the test data: 11.359244420612995
# Perplexity of the 110 Absolute Discounting model on the test data: 9.760011745348093
# Perplexity of the 111 Absolute Discounting model on the test data: 12.101517141472293
# Perplexity of the 112 Absolute Discounting model on the test data: 12.328018202181115
# Perplexity of the 113 Absolute Discounting model on the test data: 7.4980739692004565
# Perplexity of the 114 Absolute Discounting model on the test data: 7.439514090738403
# Perplexity of the 115 Absolute Discounting model on the test data: 16.91583655072789
# Perplexity of the 116 Absolute Discounting model on the test data: 10.817943167117473
# Perplexity of the 117 Absolute Discounting model on the test data: 8.27129443003263
# Perplexity of the 118 Absolute Discounting model on the test data: 12.411901476223072
# Perplexity of the 119 Absolute Discounting model on the test data: 10.551833882118178
# Perplexity of the 120 Absolute Discounting model on the test data: 9.12354447039059
# Perplexity of the 121 Absolute Discounting model on the test data: 11.772029849487508
# Perplexity of the 122 Absolute Discounting model on the test data: 9.595588234851602
# Perplexity of the 123 Absolute Discounting model on the test data: 10.25895734693881
# Perplexity of the 124 Absolute Discounting model on the test data: 15.907076871506169
# Perplexity of the 125 Absolute Discounting model on the test data: 14.713019738115687
# Perplexity of the 126 Absolute Discounting model on the test data: 9.61145136521643
# Perplexity of the 127 Absolute Discounting model on the test data: 11.259491365719954
# Perplexity of the 128 Absolute Discounting model on the test data: 11.005970935912998
# Perplexity of the 129 Absolute Discounting model on the test data: 11.882652945765695
# Perplexity of the 130 Absolute Discounting model on the test data: 11.851359679901917
# Perplexity of the 131 Absolute Discounting model on the test data: 11.535504304681435
# Perplexity of the 132 Absolute Discounting model on the test data: 8.349809184535994
# Perplexity of the 133 Absolute Discounting model on the test data: 12.491787213941235
# Perplexity of the 134 Absolute Discounting model on the test data: 9.270014182352519
# Perplexity of the 135 Absolute Discounting model on the test data: 12.434436942737202
# Perplexity of the 136 Absolute Discounting model on the test data: 9.57591880597783
# Perplexity of the 137 Absolute Discounting model on the test data: 13.017114776251614
# Perplexity of the 138 Absolute Discounting model on the test data: 11.120334566076842
# Perplexity of the 139 Absolute Discounting model on the test data: 13.78668732122281
# Perplexity of the 140 Absolute Discounting model on the test data: 14.26319810078048
# Perplexity of the 141 Absolute Discounting model on the test data: 7.9693280135545805
# Perplexity of the 142 Absolute Discounting model on the test data: 9.362915779339968
# Perplexity of the 143 Absolute Discounting model on the test data: 20.37568101776913
# Perplexity of the 144 Absolute Discounting model on the test data: 8.331863366432788
# Perplexity of the 145 Absolute Discounting model on the test data: 10.054113106995631
# Perplexity of the 146 Absolute Discounting model on the test data: 13.429692142385743
# Perplexity of the 147 Absolute Discounting model on the test data: 12.742894153079172
# Perplexity of the 148 Absolute Discounting model on the test data: 9.671060901225614
# Perplexity of the 149 Absolute Discounting model on the test data: 12.300622226952491
# Perplexity of the 150 Absolute Discounting model on the test data: 15.951039005856536
# Perplexity of the 151 Absolute Discounting model on the test data: 6.371321966781257
# Perplexity of the 152 Absolute Discounting model on the test data: 6.909444879235645
# Perplexity of the 153 Absolute Discounting model on the test data: 11.846555384187809
# Perplexity of the 154 Absolute Discounting model on the test data: 10.047134588487724
# Perplexity of the 155 Absolute Discounting model on the test data: 11.777158105488633
# Perplexity of the 156 Absolute Discounting model on the test data: 12.569783016330419
# Perplexity of the 157 Absolute Discounting model on the test data: 14.111720012119248
# Perplexity of the 158 Absolute Discounting model on the test data: 12.655879520639694
# Perplexity of the 159 Absolute Discounting model on the test data: 17.979819792910714
# Perplexity of the 160 Absolute Discounting model on the test data: 9.260196133914295
# Perplexity of the 161 Absolute Discounting model on the test data: 15.27795945224408
# Perplexity of the 162 Absolute Discounting model on the test data: 15.083274422587792
# Perplexity of the 163 Absolute Discounting model on the test data: 21.949621870293967
# Perplexity of the 164 Absolute Discounting model on the test data: 8.877125088227768
# Perplexity of the 165 Absolute Discounting model on the test data: 3.555404849077129
# Perplexity of the 166 Absolute Discounting model on the test data: 4.357309168192493
# Perplexity of the 167 Absolute Discounting model on the test data: 9.958957934576974
# Perplexity of the 168 Absolute Discounting model on the test data: 11.041523179248122
# Perplexity of the 169 Absolute Discounting model on the test data: 10.46738312950967
# Perplexity of the 170 Absolute Discounting model on the test data: 13.040580936232416
# Perplexity of the 171 Absolute Discounting model on the test data: 10.592015489876616
# Perplexity of the 172 Absolute Discounting model on the test data: 12.959263998121324
# Perplexity of the 173 Absolute Discounting model on the test data: 9.337629442880562
# Perplexity of the 174 Absolute Discounting model on the test data: 14.917972772032558
# Perplexity of the 175 Absolute Discounting model on the test data: 15.083160000445758
# Perplexity of the 176 Absolute Discounting model on the test data: 12.460094335492263
# Perplexity of the 177 Absolute Discounting model on the test data: 8.27744288632895
# Perplexity of the 178 Absolute Discounting model on the test data: 12.348620938792298
# Perplexity of the 179 Absolute Discounting model on the test data: 8.453628446345117
# Perplexity of the 180 Absolute Discounting model on the test data: 8.236977485509438
# Perplexity of the 181 Absolute Discounting model on the test data: 10.891672895787996
# Perplexity of the 182 Absolute Discounting model on the test data: 20.867755477227384
# Perplexity of the 183 Absolute Discounting model on the test data: 10.005210266111952
# Perplexity of the 184 Absolute Discounting model on the test data: 12.203852133902396
# Perplexity of the 185 Absolute Discounting model on the test data: 8.142524310189991
# Perplexity of the 186 Absolute Discounting model on the test data: 10.10060025719278
# Perplexity of the 187 Absolute Discounting model on the test data: 10.956066185344357
# Perplexity of the 188 Absolute Discounting model on the test data: 8.705406789608816
# Perplexity of the 189 Absolute Discounting model on the test data: 14.643989408796628
# Perplexity of the 190 Absolute Discounting model on the test data: 12.86755272739459
# Perplexity of the 191 Absolute Discounting model on the test data: 7.074360569662501
# Perplexity of the 192 Absolute Discounting model on the test data: 10.156608637155136
# Perplexity of the 193 Absolute Discounting model on the test data: 16.525735212817285
# Perplexity of the 194 Absolute Discounting model on the test data: 9.864209853079975
# Perplexity of the 195 Absolute Discounting model on the test data: 12.186451913168224
# Perplexity of the 196 Absolute Discounting model on the test data: 12.006793114953037
# Perplexity of the 197 Absolute Discounting model on the test data: 10.41857575039627
# Perplexity of the 198 Absolute Discounting model on the test data: 8.391512689400681
# Perplexity of the 199 Absolute Discounting model on the test data: 12.68895412861227
# Perplexity of the 200 Absolute Discounting model on the test data: 11.102910758738256
# Perplexity of the 201 Absolute Discounting model on the test data: 6.824923268820438
# Perplexity of the 202 Absolute Discounting model on the test data: 14.402797037532899
# Perplexity of the 203 Absolute Discounting model on the test data: 16.259758902785546
# Perplexity of the 204 Absolute Discounting model on the test data: 11.064340085967482
# Perplexity of the 205 Absolute Discounting model on the test data: 9.170281173094248
# Perplexity of the 206 Absolute Discounting model on the test data: 7.667080821632555
# Perplexity of the 207 Absolute Discounting model on the test data: 12.055008299326632
# Perplexity of the 208 Absolute Discounting model on the test data: 9.516401630591336
# Perplexity of the 209 Absolute Discounting model on the test data: 15.106697445045453
# Perplexity of the 210 Absolute Discounting model on the test data: 10.738232460558622
# Perplexity of the 211 Absolute Discounting model on the test data: 10.849207490412697
# Perplexity of the 212 Absolute Discounting model on the test data: 7.7214488707581665
# Perplexity of the 213 Absolute Discounting model on the test data: 10.685955339475443
# Perplexity of the 214 Absolute Discounting model on the test data: 12.330996787543748
# Perplexity of the 215 Absolute Discounting model on the test data: 10.067537583273875
# Perplexity of the 216 Absolute Discounting model on the test data: 13.293828870294899
# Perplexity of the 217 Absolute Discounting model on the test data: 5.997233192078411
# Perplexity of the 218 Absolute Discounting model on the test data: 13.113624011081816
# Perplexity of the 219 Absolute Discounting model on the test data: 10.483043989384154
# Perplexity of the 220 Absolute Discounting model on the test data: 12.306933389412277
# Perplexity of the 221 Absolute Discounting model on the test data: 11.880029263292998
# Perplexity of the 222 Absolute Discounting model on the test data: 4.972758028853411
# Perplexity of the 223 Absolute Discounting model on the test data: 13.419678661200662
# Perplexity of the 224 Absolute Discounting model on the test data: 14.20711846402149
# Perplexity of the 225 Absolute Discounting model on the test data: 10.968366567459729
# Perplexity of the 226 Absolute Discounting model on the test data: 10.614573185307124
# Perplexity of the 227 Absolute Discounting model on the test data: 10.704329914995052
# Perplexity of the 228 Absolute Discounting model on the test data: 12.547746252757344
# Perplexity of the 229 Absolute Discounting model on the test data: 9.31661900385546
# Perplexity of the 230 Absolute Discounting model on the test data: 7.753121936593854
# Perplexity of the 231 Absolute Discounting model on the test data: 16.80377741765639
# Perplexity of the 232 Absolute Discounting model on the test data: 12.672364172476355
# Perplexity of the 233 Absolute Discounting model on the test data: 8.561422764019046
# Perplexity of the 234 Absolute Discounting model on the test data: 11.757428357638243
# Perplexity of the 235 Absolute Discounting model on the test data: 10.247729874034905
# Perplexity of the 236 Absolute Discounting model on the test data: 3.070488282719745
# Perplexity of the 237 Absolute Discounting model on the test data: 12.449154839137986
# Perplexity of the 238 Absolute Discounting model on the test data: 15.041533326590308
# Perplexity of the 239 Absolute Discounting model on the test data: 12.456602206824332
# Perplexity of the 240 Absolute Discounting model on the test data: 7.8879466323595455
# Perplexity of the 241 Absolute Discounting model on the test data: 11.033275438073872
# Perplexity of the 242 Absolute Discounting model on the test data: 10.586024156622624
# Perplexity of the 243 Absolute Discounting model on the test data: 10.315868986147832
# Perplexity of the 244 Absolute Discounting model on the test data: 12.216603359031346
# Perplexity of the 245 Absolute Discounting model on the test data: 17.730372762859524
# Perplexity of the 246 Absolute Discounting model on the test data: 13.734800613695839
# Perplexity of the 247 Absolute Discounting model on the test data: 13.237012198512227
# Perplexity of the 248 Absolute Discounting model on the test data: 11.579356773462582
# Perplexity of the 249 Absolute Discounting model on the test data: 9.119528572943128
# Perplexity of the 250 Absolute Discounting model on the test data: 14.50342404349377
# Perplexity of the 251 Absolute Discounting model on the test data: 5.587270998901998
# Perplexity of the 252 Absolute Discounting model on the test data: 10.662334170401863
# Perplexity of the 253 Absolute Discounting model on the test data: 14.701745498889572
# Perplexity of the 254 Absolute Discounting model on the test data: 6.489390719907018
# Perplexity of the 255 Absolute Discounting model on the test data: 12.87822182035938
# Perplexity of the 256 Absolute Discounting model on the test data: 11.180919891173756
# Perplexity of the 257 Absolute Discounting model on the test data: 13.317326232016645
# Perplexity of the 258 Absolute Discounting model on the test data: 11.24367530626554
# Perplexity of the 259 Absolute Discounting model on the test data: 12.273310117911352
# Perplexity of the 260 Absolute Discounting model on the test data: 10.559083737122426
# Perplexity of the 261 Absolute Discounting model on the test data: 10.305352254195544
# Perplexity of the 262 Absolute Discounting model on the test data: 13.597412112989607
# Perplexity of the 263 Absolute Discounting model on the test data: 11.708531223001092
# Perplexity of the 264 Absolute Discounting model on the test data: 9.614757673143519
# Perplexity of the 265 Absolute Discounting model on the test data: 8.594728335797871
# Perplexity of the 266 Absolute Discounting model on the test data: 14.166555671035075
# Perplexity of the 267 Absolute Discounting model on the test data: 11.92537128545398
# Perplexity of the 268 Absolute Discounting model on the test data: 11.657574514490847
# Perplexity of the 269 Absolute Discounting model on the test data: 12.461621938800048
# Perplexity of the 270 Absolute Discounting model on the test data: 12.928880467021559
# Perplexity of the 271 Absolute Discounting model on the test data: 16.09030680259594
# Perplexity of the 272 Absolute Discounting model on the test data: 19.509538886577314
# Perplexity of the 273 Absolute Discounting model on the test data: 12.874692705315267
# Perplexity of the 274 Absolute Discounting model on the test data: 14.484493929954995
# Perplexity of the 275 Absolute Discounting model on the test data: 10.648261403009949
# Perplexity of the 276 Absolute Discounting model on the test data: 11.831732797584154
# Perplexity of the 277 Absolute Discounting model on the test data: 14.939751426047824
# Perplexity of the 278 Absolute Discounting model on the test data: 12.133747236464718
# Perplexity of the 279 Absolute Discounting model on the test data: 13.555563369817644
# Perplexity of the 280 Absolute Discounting model on the test data: 11.88364162806751
# Perplexity of the 281 Absolute Discounting model on the test data: 14.780123518165148
# Perplexity of the 282 Absolute Discounting model on the test data: 12.589958380525118
# Perplexity of the 283 Absolute Discounting model on the test data: 10.765764076123938
# Perplexity of the 284 Absolute Discounting model on the test data: 9.99930371509742
# Perplexity of the 285 Absolute Discounting model on the test data: 11.513683251140534
# Perplexity of the 286 Absolute Discounting model on the test data: 12.790711140535784
# Perplexity of the 287 Absolute Discounting model on the test data: 14.590049510627571
# Perplexity of the 288 Absolute Discounting model on the test data: 12.900135835891216
# Perplexity of the 289 Absolute Discounting model on the test data: 13.017151952764799
# Perplexity of the 290 Absolute Discounting model on the test data: 18.876943177016138
# Perplexity of the 291 Absolute Discounting model on the test data: 2.801653302946834
# Perplexity of the 292 Absolute Discounting model on the test data: 13.601490329683243
# Perplexity of the 293 Absolute Discounting model on the test data: 13.07557274055569
# Perplexity of the 294 Absolute Discounting model on the test data: 9.146843260672574
# Perplexity of the 295 Absolute Discounting model on the test data: 9.098717355891264
# Perplexity of the 296 Absolute Discounting model on the test data: 10.72445373731587
# Perplexity of the 297 Absolute Discounting model on the test data: 16.03171902314396
# Perplexity of the 298 Absolute Discounting model on the test data: 9.797149095304505
# Perplexity of the 299 Absolute Discounting model on the test data: 18.727696141813333
# Perplexity of the 300 Absolute Discounting model on the test data: 14.533144599804148
# Perplexity of the 301 Absolute Discounting model on the test data: 16.47186014215307
# Perplexity of the 302 Absolute Discounting model on the test data: 9.709458292666179
# Perplexity of the 303 Absolute Discounting model on the test data: 5.445429398698242
# Perplexity of the 304 Absolute Discounting model on the test data: 10.26441755761926
# Perplexity of the 305 Absolute Discounting model on the test data: 7.49174529987146
# Perplexity of the 306 Absolute Discounting model on the test data: 10.065839552064334
# Perplexity of the 307 Absolute Discounting model on the test data: 15.296524960854212
# Perplexity of the 308 Absolute Discounting model on the test data: 16.52544720310395
# Perplexity of the 309 Absolute Discounting model on the test data: 11.992233086454982
# Perplexity of the 310 Absolute Discounting model on the test data: 9.089499473017026
# Perplexity of the 311 Absolute Discounting model on the test data: 16.51747586926879
# Perplexity of the 312 Absolute Discounting model on the test data: 12.416927759997417
# Perplexity of the 313 Absolute Discounting model on the test data: 15.048467864016695
# Perplexity of the 314 Absolute Discounting model on the test data: 8.61437040684088
# Perplexity of the 315 Absolute Discounting model on the test data: 16.056958387954996
# Perplexity of the 316 Absolute Discounting model on the test data: 10.236910943838495
# Perplexity of the 317 Absolute Discounting model on the test data: 14.963277976240539
# Perplexity of the 318 Absolute Discounting model on the test data: 6.5118394669223605
# Perplexity of the 319 Absolute Discounting model on the test data: 7.500193532401193
# Perplexity of the 320 Absolute Discounting model on the test data: 8.95258293089107
# Perplexity of the 321 Absolute Discounting model on the test data: 13.956529500181492
# Perplexity of the 322 Absolute Discounting model on the test data: 10.60152761905124
# Perplexity of the 323 Absolute Discounting model on the test data: 16.76771956736068
# Perplexity of the 324 Absolute Discounting model on the test data: 10.561481062142962
# Perplexity of the 325 Absolute Discounting model on the test data: 11.076602103806454
# Perplexity of the 326 Absolute Discounting model on the test data: 14.58506282037549
# Perplexity of the 327 Absolute Discounting model on the test data: 8.575227803667996
# Perplexity of the 328 Absolute Discounting model on the test data: 14.046728452495165
# Perplexity of the 329 Absolute Discounting model on the test data: 14.900770448728245
# Perplexity of the 330 Absolute Discounting model on the test data: 5.7126801829939176
# Perplexity of the 331 Absolute Discounting model on the test data: 8.800748582206937
# Perplexity of the 332 Absolute Discounting model on the test data: 9.936475017553793
# Perplexity of the 333 Absolute Discounting model on the test data: 12.781368120833825
# Perplexity of the 334 Absolute Discounting model on the test data: 15.698400637405745
# Perplexity of the 335 Absolute Discounting model on the test data: 17.911040900031086
# Perplexity of the 336 Absolute Discounting model on the test data: 14.020026891115503
# Perplexity of the 337 Absolute Discounting model on the test data: 6.488508434978861
# Perplexity of the 338 Absolute Discounting model on the test data: 9.263138600900108
# Perplexity of the 339 Absolute Discounting model on the test data: 10.252724909519317
# Perplexity of the 340 Absolute Discounting model on the test data: 10.394254593647608
# Perplexity of the 341 Absolute Discounting model on the test data: 8.913346292122807
# Perplexity of the 342 Absolute Discounting model on the test data: 17.047646728194387
# Perplexity of the 343 Absolute Discounting model on the test data: 11.658771905970951
# Perplexity of the 344 Absolute Discounting model on the test data: 6.210686121006701
# Perplexity of the 345 Absolute Discounting model on the test data: 10.619228888543542
# Perplexity of the 346 Absolute Discounting model on the test data: 16.23176189528104
# Perplexity of the 347 Absolute Discounting model on the test data: 6.364368498057387
# Perplexity of the 348 Absolute Discounting model on the test data: 14.767333586080255
# Perplexity of the 349 Absolute Discounting model on the test data: 13.597934345307484
# Perplexity of the 350 Absolute Discounting model on the test data: 12.339538927977042
# Perplexity of the 351 Absolute Discounting model on the test data: 7.79582131315155
# Perplexity of the 352 Absolute Discounting model on the test data: 7.133158724776351
# Perplexity of the 353 Absolute Discounting model on the test data: 15.477136960170455
# Perplexity of the 354 Absolute Discounting model on the test data: 12.871657021336917
# Perplexity of the 355 Absolute Discounting model on the test data: 11.43048070016923
# Perplexity of the 356 Absolute Discounting model on the test data: 10.530985501733872
# Perplexity of the 357 Absolute Discounting model on the test data: 10.651829855284472
# Perplexity of the 358 Absolute Discounting model on the test data: 12.434220104676676
# Perplexity of the 359 Absolute Discounting model on the test data: 10.606811209117367
# Perplexity of the 360 Absolute Discounting model on the test data: 7.136032238218738
# Perplexity of the 361 Absolute Discounting model on the test data: 13.000784603840328
# Perplexity of the 362 Absolute Discounting model on the test data: 12.081534101590059
# Perplexity of the 363 Absolute Discounting model on the test data: 15.111178185229521
# Perplexity of the 364 Absolute Discounting model on the test data: 11.97605079269701
# Perplexity of the 365 Absolute Discounting model on the test data: 10.183817288465594
# Perplexity of the 366 Absolute Discounting model on the test data: 9.58114387632343
# Perplexity of the 367 Absolute Discounting model on the test data: 11.20247319313934
# Perplexity of the 368 Absolute Discounting model on the test data: 12.758381025680896
# Perplexity of the 369 Absolute Discounting model on the test data: 12.160466255179537
# Perplexity of the 370 Absolute Discounting model on the test data: 7.049793832599644
# Perplexity of the 371 Absolute Discounting model on the test data: 7.594682048397007
# Perplexity of the 372 Absolute Discounting model on the test data: 10.658285445886314
# Perplexity of the 373 Absolute Discounting model on the test data: 11.71576652137527
# Perplexity of the 374 Absolute Discounting model on the test data: 8.779393748077151
# Perplexity of the 375 Absolute Discounting model on the test data: 9.6300231014841
# Perplexity of the 376 Absolute Discounting model on the test data: 13.661690940615044
# Perplexity of the 377 Absolute Discounting model on the test data: 14.653675389246828
# Perplexity of the 378 Absolute Discounting model on the test data: 11.511344985456738
# Perplexity of the 379 Absolute Discounting model on the test data: 10.884310266500085
# Perplexity of the 380 Absolute Discounting model on the test data: 12.85386122203227
# Perplexity of the 381 Absolute Discounting model on the test data: 15.866675922353382
# Perplexity of the 382 Absolute Discounting model on the test data: 11.505166629219682
# Perplexity of the 383 Absolute Discounting model on the test data: 9.196711740950438
# Perplexity of the 384 Absolute Discounting model on the test data: 9.947457828416821
# Perplexity of the 385 Absolute Discounting model on the test data: 10.05078778481835
# Perplexity of the 386 Absolute Discounting model on the test data: 13.288264030992579
# Perplexity of the 387 Absolute Discounting model on the test data: 8.4874563725787
# Perplexity of the 388 Absolute Discounting model on the test data: 14.989411808048187
# Perplexity of the 389 Absolute Discounting model on the test data: 9.547507982891602
# Perplexity of the 390 Absolute Discounting model on the test data: 9.012844861793196
# Perplexity of the 391 Absolute Discounting model on the test data: 8.876721849603987
# Perplexity of the 392 Absolute Discounting model on the test data: 12.951629160062206
# Perplexity of the 393 Absolute Discounting model on the test data: 14.203043483702476
# Perplexity of the 394 Absolute Discounting model on the test data: 10.69058971051896
# Perplexity of the 395 Absolute Discounting model on the test data: 15.231771778451382
# Perplexity of the 396 Absolute Discounting model on the test data: 10.31998981332027
# Perplexity of the 397 Absolute Discounting model on the test data: 11.079032805035567
# Perplexity of the 398 Absolute Discounting model on the test data: 14.677389625201817
# Perplexity of the 399 Absolute Discounting model on the test data: 18.73933699534832
# Perplexity of the 400 Absolute Discounting model on the test data: 12.397278632944134
# Perplexity of the 401 Absolute Discounting model on the test data: 13.274418804368675
# Perplexity of the 402 Absolute Discounting model on the test data: 11.09914835410996
# Perplexity of the 403 Absolute Discounting model on the test data: 14.710470414189292
# Perplexity of the 404 Absolute Discounting model on the test data: 11.026039969742959
# Perplexity of the 405 Absolute Discounting model on the test data: 12.713001759983245
# Perplexity of the 406 Absolute Discounting model on the test data: 7.140509310726753
# Perplexity of the 407 Absolute Discounting model on the test data: 12.941910291122335
# Perplexity of the 408 Absolute Discounting model on the test data: 12.011567991394863
# Perplexity of the 409 Absolute Discounting model on the test data: 11.195819561578242
# Perplexity of the 410 Absolute Discounting model on the test data: 13.321028634094658
# Perplexity of the 411 Absolute Discounting model on the test data: 9.414749543080394
# Perplexity of the 412 Absolute Discounting model on the test data: 12.160445900645543
# Perplexity of the 413 Absolute Discounting model on the test data: 9.31485708355074
# Perplexity of the 414 Absolute Discounting model on the test data: 14.497982148089944
# Perplexity of the 415 Absolute Discounting model on the test data: 15.930238197082858
# Perplexity of the 416 Absolute Discounting model on the test data: 5.829241895869308
# Perplexity of the 417 Absolute Discounting model on the test data: 14.495100204645366
# Perplexity of the 418 Absolute Discounting model on the test data: 16.18075811725601
# Perplexity of the 419 Absolute Discounting model on the test data: 25.133196724559806
# Perplexity of the 420 Absolute Discounting model on the test data: 11.112625657088604
# Perplexity of the 421 Absolute Discounting model on the test data: 10.70593995883066
# Perplexity of the 422 Absolute Discounting model on the test data: 9.190994121488353
# Perplexity of the 423 Absolute Discounting model on the test data: 14.57771361618386
# Perplexity of the 424 Absolute Discounting model on the test data: 10.659153273124629
# Perplexity of the 425 Absolute Discounting model on the test data: 13.32095243290073
# Perplexity of the 426 Absolute Discounting model on the test data: 11.45125835736105
# Perplexity of the 427 Absolute Discounting model on the test data: 11.78865316725453
# Perplexity of the 428 Absolute Discounting model on the test data: 13.017335000827666
# Perplexity of the 429 Absolute Discounting model on the test data: 7.111029562489734
# Perplexity of the 430 Absolute Discounting model on the test data: 13.305545707203802
# Perplexity of the 431 Absolute Discounting model on the test data: 9.891611204467154
# Perplexity of the 432 Absolute Discounting model on the test data: 12.022791217780341
# Perplexity of the 433 Absolute Discounting model on the test data: 11.707829943375403
# Perplexity of the 434 Absolute Discounting model on the test data: 6.99399555263887
# Perplexity of the 435 Absolute Discounting model on the test data: 12.32427743881338
# Perplexity of the 436 Absolute Discounting model on the test data: 8.374007508911323
# Perplexity of the 437 Absolute Discounting model on the test data: 14.338228179908485
# Perplexity of the 438 Absolute Discounting model on the test data: 13.079656269440738
# Perplexity of the 439 Absolute Discounting model on the test data: 14.701136049388555
# Perplexity of the 440 Absolute Discounting model on the test data: 10.408414991555482
# Perplexity of the 441 Absolute Discounting model on the test data: 12.022477492900983
# Perplexity of the 442 Absolute Discounting model on the test data: 15.118945120070086
# Perplexity of the 443 Absolute Discounting model on the test data: 9.421965094536192
# Perplexity of the 444 Absolute Discounting model on the test data: 16.779504987091794
# Perplexity of the 445 Absolute Discounting model on the test data: 9.248858795148653
# Perplexity of the 446 Absolute Discounting model on the test data: 10.207223020061493
# Perplexity of the 447 Absolute Discounting model on the test data: 11.213119792862084
# Perplexity of the 448 Absolute Discounting model on the test data: 10.79439651096912
# Perplexity of the 449 Absolute Discounting model on the test data: 13.621883688957748
# Perplexity of the 450 Absolute Discounting model on the test data: 17.04556613645566
# Perplexity of the 451 Absolute Discounting model on the test data: 10.460009977284285
# Perplexity of the 452 Absolute Discounting model on the test data: 11.751944878291997
# Perplexity of the 453 Absolute Discounting model on the test data: 11.706158929921074
# Perplexity of the 454 Absolute Discounting model on the test data: 6.332162761946934
# Perplexity of the 455 Absolute Discounting model on the test data: 15.681069479573482
# Perplexity of the 456 Absolute Discounting model on the test data: 11.057741068764578
# Perplexity of the 457 Absolute Discounting model on the test data: 11.660581368590286
# Perplexity of the 458 Absolute Discounting model on the test data: 13.240482390229278
# Perplexity of the 459 Absolute Discounting model on the test data: 14.923838589009813
# Perplexity of the 460 Absolute Discounting model on the test data: 9.53468687507982
# Perplexity of the 461 Absolute Discounting model on the test data: 6.988819394400332
# Perplexity of the 462 Absolute Discounting model on the test data: 13.610069502757614
# Perplexity of the 463 Absolute Discounting model on the test data: 10.789842555797602
# Perplexity of the 464 Absolute Discounting model on the test data: 15.471954125814305
# Perplexity of the 465 Absolute Discounting model on the test data: 7.277494340473728
# Perplexity of the 466 Absolute Discounting model on the test data: 15.915908317824144
# Perplexity of the 467 Absolute Discounting model on the test data: 8.91863579531865
# Perplexity of the 468 Absolute Discounting model on the test data: 13.67385374129731
# Perplexity of the 469 Absolute Discounting model on the test data: 16.907423695118815
# Perplexity of the 470 Absolute Discounting model on the test data: 13.013239355374813
# Perplexity of the 471 Absolute Discounting model on the test data: 14.156715801375313
# Perplexity of the 472 Absolute Discounting model on the test data: 12.751773209647508
# Perplexity of the 473 Absolute Discounting model on the test data: 8.279793568482196
# Perplexity of the 474 Absolute Discounting model on the test data: 15.542056481051205
# Perplexity of the 475 Absolute Discounting model on the test data: 11.604427640483857
# Perplexity of the 476 Absolute Discounting model on the test data: 14.494652659862043
# Perplexity of the 477 Absolute Discounting model on the test data: 11.441653451086212
# Perplexity of the 478 Absolute Discounting model on the test data: 14.433110974531019
# Perplexity of the 479 Absolute Discounting model on the test data: 7.22481819695333
# Perplexity of the 480 Absolute Discounting model on the test data: 6.477999294498759
# Perplexity of the 481 Absolute Discounting model on the test data: 11.574834589381165
# Perplexity of the 482 Absolute Discounting model on the test data: 11.139483500079267
# Perplexity of the 483 Absolute Discounting model on the test data: 12.4423057196823
# Perplexity of the 484 Absolute Discounting model on the test data: 13.730983441285627
# Perplexity of the 485 Absolute Discounting model on the test data: 10.676794246043396
# Perplexity of the 486 Absolute Discounting model on the test data: 12.110585753392966
# Perplexity of the 487 Absolute Discounting model on the test data: 9.272388222876211
# Perplexity of the 488 Absolute Discounting model on the test data: 10.162206924405725
# Perplexity of the 489 Absolute Discounting model on the test data: 14.088068860537973
# Perplexity of the 490 Absolute Discounting model on the test data: 11.126517890311753
# Perplexity of the 491 Absolute Discounting model on the test data: 12.980331591250263
# Perplexity of the 492 Absolute Discounting model on the test data: 13.778596631764035
# Perplexity of the 493 Absolute Discounting model on the test data: 13.307767372344657
# Perplexity of the 494 Absolute Discounting model on the test data: 7.3719484243310385
# Perplexity of the 495 Absolute Discounting model on the test data: 11.551558406039115
# Perplexity of the 496 Absolute Discounting model on the test data: 14.907620964897621
# Perplexity of the 497 Absolute Discounting model on the test data: 14.47432179304542
# Perplexity of the 498 Absolute Discounting model on the test data: 13.802523612858682
# Perplexity of the 499 Absolute Discounting model on the test data: 16.520853426260697
# Perplexity of the 500 Absolute Discounting model on the test data: 6.16454604272914
# Perplexity of the 501 Absolute Discounting model on the test data: 4.449098980767349
# Perplexity of the 502 Absolute Discounting model on the test data: 12.751925418022271
# Perplexity of the 503 Absolute Discounting model on the test data: 12.674352378810624
# Perplexity of the 504 Absolute Discounting model on the test data: 16.28595180301281
# Perplexity of the 505 Absolute Discounting model on the test data: 12.13660560672864
# Perplexity of the 506 Absolute Discounting model on the test data: 12.108592520889646
# Perplexity of the 507 Absolute Discounting model on the test data: 5.675704258863502
# Perplexity of the 508 Absolute Discounting model on the test data: 11.909715379263059
# Perplexity of the 509 Absolute Discounting model on the test data: 5.157167363875388
# Perplexity of the 510 Absolute Discounting model on the test data: 11.48914102890778
# Perplexity of the 511 Absolute Discounting model on the test data: 10.724032471399038
# Perplexity of the 512 Absolute Discounting model on the test data: 8.003224055243937
# Perplexity of the 513 Absolute Discounting model on the test data: 10.702818795067596
# Perplexity of the 514 Absolute Discounting model on the test data: 3.4193203125718252
# Perplexity of the 515 Absolute Discounting model on the test data: 14.962387604583917
# Perplexity of the 516 Absolute Discounting model on the test data: 16.343657381083368
# Perplexity of the 517 Absolute Discounting model on the test data: 12.83843388059485
# Perplexity of the 518 Absolute Discounting model on the test data: 15.736602008370104
# Perplexity of the 519 Absolute Discounting model on the test data: 10.210012019301505
# Perplexity of the 520 Absolute Discounting model on the test data: 11.479824365308511
# Perplexity of the 521 Absolute Discounting model on the test data: 11.975653770908258
# Perplexity of the 522 Absolute Discounting model on the test data: 13.4723702768119
# Perplexity of the 523 Absolute Discounting model on the test data: 12.714138155462795
# Perplexity of the 524 Absolute Discounting model on the test data: 13.789769117442292
# Perplexity of the 525 Absolute Discounting model on the test data: 14.174204355431527
# Perplexity of the 526 Absolute Discounting model on the test data: 18.666141149264586
# Perplexity of the 527 Absolute Discounting model on the test data: 8.726434942718047
# Perplexity of the 528 Absolute Discounting model on the test data: 10.5822570083743
# Perplexity of the 529 Absolute Discounting model on the test data: 15.203009517523961
# Perplexity of the 530 Absolute Discounting model on the test data: 15.304493984623669
# Perplexity of the 531 Absolute Discounting model on the test data: 11.77146983133061
# Perplexity of the 532 Absolute Discounting model on the test data: 13.81024995287087
# Perplexity of the 533 Absolute Discounting model on the test data: 12.827422752703741
# Perplexity of the 534 Absolute Discounting model on the test data: 8.3255981252901
# Perplexity of the 535 Absolute Discounting model on the test data: 13.097370145706732
# Perplexity of the 536 Absolute Discounting model on the test data: 10.804133396800347
# Perplexity of the 537 Absolute Discounting model on the test data: 10.66480594032462
# Perplexity of the 538 Absolute Discounting model on the test data: 15.047646747169528
# Perplexity of the 539 Absolute Discounting model on the test data: 10.936907725031936
# Perplexity of the 540 Absolute Discounting model on the test data: 12.24819719578978
# Perplexity of the 541 Absolute Discounting model on the test data: 27.644232845509574
# Perplexity of the 542 Absolute Discounting model on the test data: 12.033889705872479
# Perplexity of the 543 Absolute Discounting model on the test data: 4.208029731300403
# Perplexity of the 544 Absolute Discounting model on the test data: 9.775969752615302
# Perplexity of the 545 Absolute Discounting model on the test data: 13.304745376938312
# Perplexity of the 546 Absolute Discounting model on the test data: 6.374398323809676
# Perplexity of the 547 Absolute Discounting model on the test data: 12.905786273512332
# Perplexity of the 548 Absolute Discounting model on the test data: 13.338584486453211
# Perplexity of the 549 Absolute Discounting model on the test data: 10.49846542839957
# Perplexity of the 550 Absolute Discounting model on the test data: 7.5167075156432155
# Perplexity of the 551 Absolute Discounting model on the test data: 9.724980575386972
# Perplexity of the 552 Absolute Discounting model on the test data: 11.566973454536997
# Perplexity of the 553 Absolute Discounting model on the test data: 15.201601705174081
# Perplexity of the 554 Absolute Discounting model on the test data: 11.610128905193267
# Perplexity of the 555 Absolute Discounting model on the test data: 12.506219557612086
# Perplexity of the 556 Absolute Discounting model on the test data: 13.36372489480276
# Perplexity of the 557 Absolute Discounting model on the test data: 15.57671223868626
# Perplexity of the 558 Absolute Discounting model on the test data: 4.611814495845948
# Perplexity of the 559 Absolute Discounting model on the test data: 20.718876380284527
# Perplexity of the 560 Absolute Discounting model on the test data: 14.069691364516151
# Perplexity of the 561 Absolute Discounting model on the test data: 6.924064900907774
# ...
# Perplexity of the 1460 Absolute Discounting model on the test data: 13.90138914749659
# Perplexity of the 1461 Absolute Discounting model on the test data: 10.62496864740694
# Perplexity of the 1462 Absolute Discounting model on the test data: 9.251755705862928
# Perplexity of the 1463 Absolute Discounting model on the test data: 9.83453809769382
# Perplexity of the 1464 Absolute Discounting model on the test data: 9.852665379911691
# Perplexity of the 1465 Absolute Discounting model on the test data: 10.17594890263248
# Perplexity of the 1466 Absolute Discounting model on the test data: 8.011890492665552
# Perplexity of the 1467 Absolute Discounting model on the test data: 12.113631732453607
# Perplexity of the 1468 Absolute Discounting model on the test data: 11.918764885604547
# Perplexity of the 1469 Absolute Discounting model on the test data: 10.5497854547499
# Perplexity of the 1470 Absolute Discounting model on the test data: 9.636696337332369
# Perplexity of the 1471 Absolute Discounting model on the test data: 10.221542910400483
# Perplexity of the 1472 Absolute Discounting model on the test data: 12.71470034214706
# Perplexity of the 1473 Absolute Discounting model on the test data: 9.521624751455157
# Perplexity of the 1474 Absolute Discounting model on the test data: 19.470777527835626
# Perplexity of the 1475 Absolute Discounting model on the test data: 14.219584273894293
# Perplexity of the 1476 Absolute Discounting model on the test data: 11.941558459180918
# Perplexity of the 1477 Absolute Discounting model on the test data: 14.795918651364374
# Perplexity of the 1478 Absolute Discounting model on the test data: 10.475420815006661
# Perplexity of the 1479 Absolute Discounting model on the test data: 9.956376884033299
# Perplexity of the 1480 Absolute Discounting model on the test data: 15.421947717837638
# Perplexity of the 1481 Absolute Discounting model on the test data: 9.669095749907605
# Perplexity of the 1482 Absolute Discounting model on the test data: 6.952665519479236
# Perplexity of the 1483 Absolute Discounting model on the test data: 11.613666660107315
# Perplexity of the 1484 Absolute Discounting model on the test data: 13.22819939825153
# Perplexity of the 1485 Absolute Discounting model on the test data: 8.034346351774897
# Perplexity of the 1486 Absolute Discounting model on the test data: 13.510777383754872
# Perplexity of the 1487 Absolute Discounting model on the test data: 12.100002280219268
# Perplexity of the 1488 Absolute Discounting model on the test data: 14.592273755540448
# Perplexity of the 1489 Absolute Discounting model on the test data: 12.945463636001923
# Perplexity of the 1490 Absolute Discounting model on the test data: 19.793294931225258
# Perplexity of the 1491 Absolute Discounting model on the test data: 8.016222488133273
# Perplexity of the 1492 Absolute Discounting model on the test data: 12.956453048504196
# Perplexity of the 1493 Absolute Discounting model on the test data: 14.828815408696334
# Perplexity of the 1494 Absolute Discounting model on the test data: 14.055357967348074
# Perplexity of the 1495 Absolute Discounting model on the test data: 10.152357822753203
# Perplexity of the 1496 Absolute Discounting model on the test data: 7.5036767862651645
# Perplexity of the 1497 Absolute Discounting model on the test data: 13.500066872343133
# Perplexity of the 1498 Absolute Discounting model on the test data: 21.963476511093667
# Perplexity of the 1499 Absolute Discounting model on the test data: 9.155398730942357
# Perplexity of the 1500 Absolute Discounting model on the test data: 11.418373406567396
# Perplexity of the 1501 Absolute Discounting model on the test data: 14.48497187028832
# Perplexity of the 1502 Absolute Discounting model on the test data: 12.138407840498592
# Perplexity of the 1503 Absolute Discounting model on the test data: 9.927397071112324
# Perplexity of the 1504 Absolute Discounting model on the test data: 13.451011347498705
# Perplexity of the 1505 Absolute Discounting model on the test data: 13.154244332275296
# Perplexity of the 1506 Absolute Discounting model on the test data: 8.224479662530747
# Perplexity of the 1507 Absolute Discounting model on the test data: 17.142484796672544
# Perplexity of the 1508 Absolute Discounting model on the test data: 14.435781593142071
# Perplexity of the 1509 Absolute Discounting model on the test data: 13.284803069988403
# Perplexity of the 1510 Absolute Discounting model on the test data: 8.733750156859818
# Perplexity of the 1511 Absolute Discounting model on the test data: 10.695406124611994
# Perplexity of the 1512 Absolute Discounting model on the test data: 10.52295610700525
# Perplexity of the 1513 Absolute Discounting model on the test data: 8.046441624650495
# Perplexity of the 1514 Absolute Discounting model on the test data: 16.86516923829723
# Perplexity of the 1515 Absolute Discounting model on the test data: 15.28705290915011
# Perplexity of the 1516 Absolute Discounting model on the test data: 14.769014256361627
# Perplexity of the 1517 Absolute Discounting model on the test data: 12.766832677407832
# Perplexity of the 1518 Absolute Discounting model on the test data: 12.321429085098153
# Perplexity of the 1519 Absolute Discounting model on the test data: 11.686504562861044
# Perplexity of the 1520 Absolute Discounting model on the test data: 12.102103179188738
# Perplexity of the 1521 Absolute Discounting model on the test data: 15.221343619938649
# Perplexity of the 1522 Absolute Discounting model on the test data: 12.037038169775501
# Perplexity of the 1523 Absolute Discounting model on the test data: 9.228410590084412
# Perplexity of the 1524 Absolute Discounting model on the test data: 11.462264460823043
# Perplexity of the 1525 Absolute Discounting model on the test data: 9.700893510449532
# Perplexity of the 1526 Absolute Discounting model on the test data: 12.12009111900437
# Perplexity of the 1527 Absolute Discounting model on the test data: 10.101965998988668
# Perplexity of the 1528 Absolute Discounting model on the test data: 11.272448276854286
# Perplexity of the 1529 Absolute Discounting model on the test data: 10.216781611410376
# Perplexity of the 1530 Absolute Discounting model on the test data: 10.608699859902488
# Perplexity of the 1531 Absolute Discounting model on the test data: 16.896304608379914
# Perplexity of the 1532 Absolute Discounting model on the test data: 17.54360607104252
# Perplexity of the 1533 Absolute Discounting model on the test data: 10.754130047052449
# Perplexity of the 1534 Absolute Discounting model on the test data: 14.225867914424859
# Perplexity of the 1535 Absolute Discounting model on the test data: 11.890351925424124
# Perplexity of the 1536 Absolute Discounting model on the test data: 12.126487390353901
# Perplexity of the 1537 Absolute Discounting model on the test data: 15.290917786164933
# Perplexity of the 1538 Absolute Discounting model on the test data: 7.471408154525753
# Perplexity of the 1539 Absolute Discounting model on the test data: 6.472900646688737
# Perplexity of the 1540 Absolute Discounting model on the test data: 6.092466373113936
# Perplexity of the 1541 Absolute Discounting model on the test data: 14.853793856210121
# Perplexity of the 1542 Absolute Discounting model on the test data: 8.303333465245979
# Perplexity of the 1543 Absolute Discounting model on the test data: 5.094842386055661
# Perplexity of the 1544 Absolute Discounting model on the test data: 10.773154612861697
# Perplexity of the 1545 Absolute Discounting model on the test data: 6.644116962610389
# Perplexity of the 1546 Absolute Discounting model on the test data: 18.613248816848326
# Perplexity of the 1547 Absolute Discounting model on the test data: 12.509101677423246
# Perplexity of the 1548 Absolute Discounting model on the test data: 10.685011306919309
# Perplexity of the 1549 Absolute Discounting model on the test data: 14.185177345587814
# Perplexity of the 1550 Absolute Discounting model on the test data: 12.156442305041695
# Perplexity of the 1551 Absolute Discounting model on the test data: 10.345801823246516
# Perplexity of the 1552 Absolute Discounting model on the test data: 11.689673908381511
# Perplexity of the 1553 Absolute Discounting model on the test data: 11.345024232697144
# Perplexity of the 1554 Absolute Discounting model on the test data: 12.336942333253662
# Perplexity of the 1555 Absolute Discounting model on the test data: 10.652304718669088
# Perplexity of the 1556 Absolute Discounting model on the test data: 11.316110770809711
# Perplexity of the 1557 Absolute Discounting model on the test data: 13.094921498392763
# Perplexity of the 1558 Absolute Discounting model on the test data: 11.51832587701094
# Perplexity of the 1559 Absolute Discounting model on the test data: 8.528597565179275
# Perplexity of the 1560 Absolute Discounting model on the test data: 9.69978186121424
# Perplexity of the 1561 Absolute Discounting model on the test data: 6.961253233513317
# Perplexity of the 1562 Absolute Discounting model on the test data: 10.20818457601403
# Perplexity of the 1563 Absolute Discounting model on the test data: 11.167900339462596
# Perplexity of the 1564 Absolute Discounting model on the test data: 12.191313739209013
# Perplexity of the 1565 Absolute Discounting model on the test data: 18.00101653553364
# Perplexity of the 1566 Absolute Discounting model on the test data: 11.864078735340163
# Perplexity of the 1567 Absolute Discounting model on the test data: 12.209770400805379
# Perplexity of the 1568 Absolute Discounting model on the test data: 13.43171089055887
# Perplexity of the 1569 Absolute Discounting model on the test data: 14.63134756705741
# Perplexity of the 1570 Absolute Discounting model on the test data: 12.840956347984116
# Perplexity of the 1571 Absolute Discounting model on the test data: 11.266425458294837
# Perplexity of the 1572 Absolute Discounting model on the test data: 11.395843699171083
# Perplexity of the 1573 Absolute Discounting model on the test data: 10.791222490084781
# Perplexity of the 1574 Absolute Discounting model on the test data: 16.73944705785596
# Perplexity of the 1575 Absolute Discounting model on the test data: 9.299392885039802
# Perplexity of the 1576 Absolute Discounting model on the test data: 15.510806944778665
# Perplexity of the 1577 Absolute Discounting model on the test data: 11.189444036662476
# Perplexity of the 1578 Absolute Discounting model on the test data: 10.818364253188637
# Perplexity of the 1579 Absolute Discounting model on the test data: 11.282606942820607
# Perplexity of the 1580 Absolute Discounting model on the test data: 9.381291679625582
# Perplexity of the 1581 Absolute Discounting model on the test data: 6.559253160444254
# Perplexity of the 1582 Absolute Discounting model on the test data: 10.578432270248337
# Perplexity of the 1583 Absolute Discounting model on the test data: 13.028617086981786
# Perplexity of the 1584 Absolute Discounting model on the test data: 8.4001265631951
# Perplexity of the 1585 Absolute Discounting model on the test data: 16.08931740603121
# Perplexity of the 1586 Absolute Discounting model on the test data: 8.069873367740508
# Perplexity of the 1587 Absolute Discounting model on the test data: 11.616149254642107
# Perplexity of the 1588 Absolute Discounting model on the test data: 7.8430424060831605
# Perplexity of the 1589 Absolute Discounting model on the test data: 9.046387793285529
# Perplexity of the 1590 Absolute Discounting model on the test data: 11.00323482676203
# Perplexity of the 1591 Absolute Discounting model on the test data: 9.416421572831215
# Perplexity of the 1592 Absolute Discounting model on the test data: 12.975476323557825
# Perplexity of the 1593 Absolute Discounting model on the test data: 12.715650533344276
# Perplexity of the 1594 Absolute Discounting model on the test data: 16.076155029125847
# Perplexity of the 1595 Absolute Discounting model on the test data: 18.246868259788965
# Perplexity of the 1596 Absolute Discounting model on the test data: 12.783049064265683
# Perplexity of the 1597 Absolute Discounting model on the test data: 15.432599525527278
# Perplexity of the 1598 Absolute Discounting model on the test data: 11.10202962729624
# Perplexity of the 1599 Absolute Discounting model on the test data: 12.026145819783645
# Perplexity of the 1600 Absolute Discounting model on the test data: 14.30071273793765
# Perplexity of the 1601 Absolute Discounting model on the test data: 10.175311898439102
# Perplexity of the 1602 Absolute Discounting model on the test data: 14.166590778188697
# Perplexity of the 1603 Absolute Discounting model on the test data: 8.811547670413269
# Perplexity of the 1604 Absolute Discounting model on the test data: 13.381665792366457
# Perplexity of the 1605 Absolute Discounting model on the test data: 8.042016323048168
# Perplexity of the 1606 Absolute Discounting model on the test data: 9.784893250431933
# Perplexity of the 1607 Absolute Discounting model on the test data: 10.842156804744889
# Perplexity of the 1608 Absolute Discounting model on the test data: 5.419493594917316
# Perplexity of the 1609 Absolute Discounting model on the test data: 13.948351541834478
# Perplexity of the 1610 Absolute Discounting model on the test data: 11.688212625700107
# Perplexity of the 1611 Absolute Discounting model on the test data: 10.962893856429313
# Perplexity of the 1612 Absolute Discounting model on the test data: 12.824148944989963
# Perplexity of the 1613 Absolute Discounting model on the test data: 6.678757095434539
# Perplexity of the 1614 Absolute Discounting model on the test data: 13.313209161282618
# Perplexity of the 1615 Absolute Discounting model on the test data: 13.411238221331878
# Perplexity of the 1616 Absolute Discounting model on the test data: 11.935646902760169
# Perplexity of the 1617 Absolute Discounting model on the test data: 11.53320179013626
# Perplexity of the 1618 Absolute Discounting model on the test data: 16.503445906557598
# Perplexity of the 1619 Absolute Discounting model on the test data: 13.365243041004215
# Perplexity of the 1620 Absolute Discounting model on the test data: 9.081251782253618
# Perplexity of the 1621 Absolute Discounting model on the test data: 8.784585534440653
# Perplexity of the 1622 Absolute Discounting model on the test data: 9.614436246030701
# Perplexity of the 1623 Absolute Discounting model on the test data: 15.541060850330625
# Perplexity of the 1624 Absolute Discounting model on the test data: 12.296326846638786
# Perplexity of the 1625 Absolute Discounting model on the test data: 5.730572199972897
# Perplexity of the 1626 Absolute Discounting model on the test data: 12.922363389942063
# Perplexity of the 1627 Absolute Discounting model on the test data: 9.110171321069405
# Perplexity of the 1628 Absolute Discounting model on the test data: 7.6994768456833445
# Perplexity of the 1629 Absolute Discounting model on the test data: 13.135175330569048
# Perplexity of the 1630 Absolute Discounting model on the test data: 11.359702306590178
# Perplexity of the 1631 Absolute Discounting model on the test data: 11.005937323982652
# Perplexity of the 1632 Absolute Discounting model on the test data: 14.47718370439868
# Perplexity of the 1633 Absolute Discounting model on the test data: 11.847530457011551
# Perplexity of the 1634 Absolute Discounting model on the test data: 11.926616129052569
# Perplexity of the 1635 Absolute Discounting model on the test data: 12.955564161855275
# Perplexity of the 1636 Absolute Discounting model on the test data: 14.096200346601378
# Perplexity of the 1637 Absolute Discounting model on the test data: 12.651799359778508
# Perplexity of the 1638 Absolute Discounting model on the test data: 12.121617755650083
# Perplexity of the 1639 Absolute Discounting model on the test data: 11.076402817014639
# Perplexity of the 1640 Absolute Discounting model on the test data: 15.070119037202133
# Perplexity of the 1641 Absolute Discounting model on the test data: 9.25405407739229
# Perplexity of the 1642 Absolute Discounting model on the test data: 10.257218139149469
# Perplexity of the 1643 Absolute Discounting model on the test data: 14.70010982730348

# %%
labels = list(range(0, 8))
test_class_tokens = {}
for i in labels:
    test_label = test[test['label'] == i]
    test_tokens = []
    for j, content in enumerate(test_label['content']):
        for token in content:
            test_tokens.append(token)
    test_class_tokens[i] = test_tokens

# %%
best_pg = backoff_model.p_bg
backoff_model = BackoffSmoothing(1, best_pg)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with unigram: {backoff_model.perplexity(test_tokens)}")

backoff_model = BackoffSmoothing(2, best_pg)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with bigram: {backoff_model.perplexity(test_tokens)}")

backoff_model = BackoffSmoothing(3, best_pg)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with trigram: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the class 0 BackoffSmoothing model on the test data with unigram: 1542.5819205583166
# Perplexity of the class 1 BackoffSmoothing model on the test data with unigram: 1532.2697543357367
# Perplexity of the class 2 BackoffSmoothing model on the test data with unigram: 1469.7123696075662
# Perplexity of the class 3 BackoffSmoothing model on the test data with unigram: 1407.3628970836887
# Perplexity of the class 4 BackoffSmoothing model on the test data with unigram: 1793.8588562807918
# Perplexity of the class 5 BackoffSmoothing model on the test data with unigram: 1661.5376001806842
# Perplexity of the class 6 BackoffSmoothing model on the test data with unigram: 1580.6194972850167
# Perplexity of the class 7 BackoffSmoothing model on the test data with unigram: 1497.4705622934903
# Perplexity of the class 0 BackoffSmoothing model on the test data with bigram: 56.68193475239538
# Perplexity of the class 1 BackoffSmoothing model on the test data with bigram: 53.874553318633176
# Perplexity of the class 2 BackoffSmoothing model on the test data with bigram: 60.324306242518226
# Perplexity of the class 3 BackoffSmoothing model on the test data with bigram: 59.58632181463544
# Perplexity of the class 4 BackoffSmoothing model on the test data with bigram: 60.61372645806485
# Perplexity of the class 5 BackoffSmoothing model on the test data with bigram: 55.33387665698232
# Perplexity of the class 6 BackoffSmoothing model on the test data with bigram: 57.39370692760074
# Perplexity of the class 7 BackoffSmoothing model on the test data with bigram: 58.68400285678047
# Perplexity of the class 0 BackoffSmoothing model on the test data with trigram: 11.034032875459765
# Perplexity of the class 1 BackoffSmoothing model on the test data with trigram: 10.139654813454252
# Perplexity of the class 2 BackoffSmoothing model on the test data with trigram: 11.411705680566504
# Perplexity of the class 3 BackoffSmoothing model on the test data with trigram: 11.471002630227003
# Perplexity of the class 4 BackoffSmoothing model on the test data with trigram: 11.728914885508779
# Perplexity of the class 5 BackoffSmoothing model on the test data with trigram: 11.171899843967626
# Perplexity of the class 6 BackoffSmoothing model on the test data with trigram: 11.439216843149813
# Perplexity of the class 7 BackoffSmoothing model on the test data with trigram: 11.282148970377174

# %%
best_pg = absolute_discounting_model.p_bg
best_discount = 0.75
absolute_discounting_model = AbsoluteDiscounting(1,best_discount, best_discount)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with unigram: {absolute_discounting_model.perplexity(test_tokens)}")

absolute_discounting_model = AbsoluteDiscounting(2,best_discount, best_discount)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with bigram: {absolute_discounting_model.perplexity(test_tokens)}")

absolute_discounting_model = AbsoluteDiscounting(3,best_discount, best_discount)  # Change the number to the desired n-gram
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with trigram: {absolute_discounting_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the class 0 absolute discounting model on the test data with unigram: 1.755121906086166
# Perplexity of the class 1 absolute discounting model on the test data with unigram: 1.7564037981632385
# Perplexity of the class 2 absolute discounting model on the test data with unigram: 1.7553718548325226
# Perplexity of the class 3 absolute discounting model on the test data with unigram: 1.7549754984189967
# Perplexity of the class 4 absolute discounting model on the test data with unigram: 1.7562084619202152
# Perplexity of the class 5 absolute discounting model on the test data with unigram: 1.7553690335834364
# Perplexity of the class 6 absolute discounting model on the test data with unigram: 1.7564953461090733
# Perplexity of the class 7 absolute discounting model on the test data with unigram: 1.7550817001051089
# Perplexity of the class 0 absolute discounting model on the test data with bigram: 136.3252781740603
# Perplexity of the class 1 absolute discounting model on the test data with bigram: 114.83113443287944
# Perplexity of the class 2 absolute discounting model on the test data with bigram: 134.2743099406956
# Perplexity of the class 3 absolute discounting model on the test data with bigram: 121.98488695025968
# Perplexity of the class 4 absolute discounting model on the test data with bigram: 199.7092583676591
# Perplexity of the class 5 absolute discounting model on the test data with bigram: 184.1588035002287
# Perplexity of the class 6 absolute discounting model on the test data with bigram: 145.93233233723916
# Perplexity of the class 7 absolute discounting model on the test data with bigram: 134.52483059132325
# Perplexity of the class 0 absolute discounting model on the test data with trigram: 442.61781338744896
# Perplexity of the class 1 absolute discounting model on the test data with trigram: 293.3547551079023
# Perplexity of the class 2 absolute discounting model on the test data with trigram: 545.074920324531
# Perplexity of the class 3 absolute discounting model on the test data with trigram: 489.0069077310159
# Perplexity of the class 4 absolute discounting model on the test data with trigram: 541.8870621119095
# Perplexity of the class 5 absolute discounting model on the test data with trigram: 409.03850743624406
# Perplexity of the class 6 absolute discounting model on the test data with trigram: 487.5671724630174
# Perplexity of the class 7 absolute discounting model on the test data with trigram: 516.1145412943035
