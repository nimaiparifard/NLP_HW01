# %%
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %%
# Load the data
train = pd.read_csv("train.csv")
val = pd.read_csv("val.csv")
test = pd.read_csv("test.csv")

# %%
from hazm import Normalizer, word_tokenize
# Create a normalizer object
normalizer = Normalizer()

def remove_u200c(text):
    return text.replace('\u200c', '')

def preprocess_text(text):
    # Normalize the text
    text = normalizer.normalize(text)
    text = normalizer.remove_specials_chars(text)

    # Tokenize the text
    words = word_tokenize(text)
    words = [remove_u200c(word) for word in words]
    return words

# %%
train['content'] = train['content'].apply(preprocess_text)
val['content'] = val['content'].apply(preprocess_text)
test['content'] = test['content'].apply(preprocess_text)

# %%
print(f"Shape of the train data: {train.shape}")
print(f"Shape of the validation data: {val.shape}")
print(f"Shape of the test data: {test.shape}")
# Out:
# Shape of the train data: (13314, 2)
# Shape of the validation data: (1480, 2)
# Shape of the test data: (1644, 2)

# %%
class NgramLanguageModel:
    def __init__(self, n):
        self.number_of_minus_n_grams = None
        self.n = n
        self.counts = {}
        self.counts_minus_one_grams = {}
        self.vocab = set()


    def update_counts(self, tokens):
        n = self.n
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i + n])
            self.counts[ngram] = self.counts.get(ngram, 0) + 1
            for token in ngram:
                self.vocab.add(token)

        n = self.n - 1
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i + n])
            self.counts_minus_one_grams[ngram] = self.counts_minus_one_grams.get(ngram, 0) + 1
        self.number_of_minus_n_grams = sum(self.counts_minus_one_grams.values())
        self.number_of_n_grams = sum(self.counts.values())

    def probability(self, token, context):
        context = tuple(context)
        ngram = context + (token,)
        if self.n == 1:
            if ngram in self.counts:
                return self.counts[ngram] / self.number_of_n_grams
        if context in self.counts_minus_one_grams:
            context_count = self.counts_minus_one_grams[context]
            if ngram in self.counts:
                return self.counts[ngram] / context_count
        return 0

    def perplexity(self, test_data):
        log_prob_sum = 0
        for i in range(len(test_data) - self.n + 1):
            context = tuple(test_data[i:i + self.n - 1])
            token = test_data[i + self.n - 1]
            prob = self.probability(token, context)
            log_prob_sum += np.log(prob)
        return np.exp(-log_prob_sum / len(test_data))

class BackoffSmoothing(NgramLanguageModel):
    def __init__(self, n, p_bg=0.001):
        super().__init__(n)
        self.p_bg = p_bg


    def probability(self, token, context):
        p = super().probability(token, context)
        if p == 0:
            p = self.p_bg
        return p


class AbsoluteDiscounting(NgramLanguageModel):
    def __init__(self, n, discount=0.5, p_bg=0.000001):
        super().__init__(n)
        self.discount = discount
        self.p_bg = p_bg
        self.applied_discounting = 1

    def probability(self, token, context):
        context = tuple(context)
        ngram = context + (token,)
        if self.n == 1:
            if ngram in self.counts:
                return self.counts[ngram] / self.number_of_n_grams
        if context in self.counts_minus_one_grams:
            context_count = self.counts_minus_one_grams[context]
            ngram_count = self.counts.get(ngram, 0)
            if context_count > 0:
                self.applied_discounting += 1
            interpolation = self.discount * context_count / self.number_of_minus_n_grams
            return max(ngram_count - self.discount, 0) / context_count + interpolation * self.p_bg
        return  self.p_bg

# %%
# make all validation token in one list for tuning hyperparameters
validation_tokens = []
for i, content in enumerate(val['content']):
    for token in content:
        validation_tokens.append(token)

# %%
# unigram
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(1, 0.1)  # Change the number to the desired n-gram
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 1361.474788040928
# Perplexity of the 1 BackoffSmoothing model on the test data: 2024.8146238209442
# Perplexity of the 2 BackoffSmoothing model on the test data: 1891.3562055503637
# Perplexity of the 3 BackoffSmoothing model on the test data: 1563.4277211881613
# Perplexity of the 4 BackoffSmoothing model on the test data: 2128.5230368981092
# Perplexity of the 5 BackoffSmoothing model on the test data: 1826.7812172408296
# Perplexity of the 6 BackoffSmoothing model on the test data: 1140.8369810893387
# Perplexity of the 7 BackoffSmoothing model on the test data: 1183.3245657119264
# Perplexity of the 8 BackoffSmoothing model on the test data: 1693.4523805271658
# Perplexity of the 9 BackoffSmoothing model on the test data: 2383.3324362662056
# Perplexity of the 10 BackoffSmoothing model on the test data: 2087.9888769771005
# Perplexity of the 11 BackoffSmoothing model on the test data: 1808.0667075637584
# Perplexity of the 12 BackoffSmoothing model on the test data: 929.8622987162407
# Perplexity of the 13 BackoffSmoothing model on the test data: 4747.969404839887
# Perplexity of the 14 BackoffSmoothing model on the test data: 2727.3617945148694
# Perplexity of the 15 BackoffSmoothing model on the test data: 974.5402697318374
# Perplexity of the 16 BackoffSmoothing model on the test data: 2362.3951826775756
# Perplexity of the 17 BackoffSmoothing model on the test data: 2006.7555803002033
# Perplexity of the 18 BackoffSmoothing model on the test data: 1272.581101070281
# Perplexity of the 19 BackoffSmoothing model on the test data: 1349.8542140932097
# Perplexity of the 20 BackoffSmoothing model on the test data: 1434.2859873380717
# Perplexity of the 21 BackoffSmoothing model on the test data: 2193.500832219811
# Perplexity of the 22 BackoffSmoothing model on the test data: 4148.410407211391
# Perplexity of the 23 BackoffSmoothing model on the test data: 2100.3050527007777
# Perplexity of the 24 BackoffSmoothing model on the test data: 1574.0435125317556
# Perplexity of the 25 BackoffSmoothing model on the test data: 2684.831702734809
# Perplexity of the 26 BackoffSmoothing model on the test data: 1249.197218905032
# Perplexity of the 27 BackoffSmoothing model on the test data: 923.849879119296
# Perplexity of the 28 BackoffSmoothing model on the test data: 2039.3070042242196
# Perplexity of the 29 BackoffSmoothing model on the test data: 1235.625334115066
# Perplexity of the 30 BackoffSmoothing model on the test data: 1750.5810342286647
# Perplexity of the 31 BackoffSmoothing model on the test data: 1195.8801323189493
# Perplexity of the 32 BackoffSmoothing model on the test data: 2682.0534164632927
# Perplexity of the 33 BackoffSmoothing model on the test data: 3431.5997521591275
# Perplexity of the 34 BackoffSmoothing model on the test data: 2144.299811774836
# Perplexity of the 35 BackoffSmoothing model on the test data: 2744.199311739726
# Perplexity of the 36 BackoffSmoothing model on the test data: 1173.1349675699191
# Perplexity of the 37 BackoffSmoothing model on the test data: 1801.7109790981556
# Perplexity of the 38 BackoffSmoothing model on the test data: 2086.9863189677335
# Perplexity of the 39 BackoffSmoothing model on the test data: 1156.1982052530343
# Perplexity of the 40 BackoffSmoothing model on the test data: 1233.5176023530719
# Perplexity of the 41 BackoffSmoothing model on the test data: 1541.7340901340865
# Perplexity of the 42 BackoffSmoothing model on the test data: 1415.8621865648686
# Perplexity of the 43 BackoffSmoothing model on the test data: 921.0312763465096
# Perplexity of the 44 BackoffSmoothing model on the test data: 1983.0450026224512
# Perplexity of the 45 BackoffSmoothing model on the test data: 1155.451176248193
# Perplexity of the 46 BackoffSmoothing model on the test data: 1357.6989858124737
# Perplexity of the 47 BackoffSmoothing model on the test data: 1717.2415667751231
# Perplexity of the 48 BackoffSmoothing model on the test data: 1388.9806986375136
# Perplexity of the 49 BackoffSmoothing model on the test data: 1879.8411998562838
# Perplexity of the 50 BackoffSmoothing model on the test data: 1076.225544590805
# Perplexity of the 51 BackoffSmoothing model on the test data: 2216.6954189317626
# Perplexity of the 52 BackoffSmoothing model on the test data: 1530.877111594994
# Perplexity of the 53 BackoffSmoothing model on the test data: 1230.0400890992487
# Perplexity of the 54 BackoffSmoothing model on the test data: 1278.712814906038
# Perplexity of the 55 BackoffSmoothing model on the test data: 2147.975955487665
# Perplexity of the 56 BackoffSmoothing model on the test data: 1917.158352831063
# Perplexity of the 57 BackoffSmoothing model on the test data: 1527.4500299261738
# Perplexity of the 58 BackoffSmoothing model on the test data: 1360.644417894329
# Perplexity of the 59 BackoffSmoothing model on the test data: 1709.0232857790138
# Perplexity of the 60 BackoffSmoothing model on the test data: 1921.7636932729808
# Perplexity of the 61 BackoffSmoothing model on the test data: 909.848972890407
# Perplexity of the 62 BackoffSmoothing model on the test data: 1335.1267083129203
# Perplexity of the 63 BackoffSmoothing model on the test data: 1151.3332455579866
# Perplexity of the 64 BackoffSmoothing model on the test data: 1628.3915987303917
# Perplexity of the 65 BackoffSmoothing model on the test data: 890.3285003457404
# Perplexity of the 66 BackoffSmoothing model on the test data: 2173.060277896934
# Perplexity of the 67 BackoffSmoothing model on the test data: 1570.3390096454743
# Perplexity of the 68 BackoffSmoothing model on the test data: 1070.9619823699295
# Perplexity of the 69 BackoffSmoothing model on the test data: 1702.5879424038906
# Perplexity of the 70 BackoffSmoothing model on the test data: 2242.0916633453685
# Perplexity of the 71 BackoffSmoothing model on the test data: 1732.799481053348
# Perplexity of the 72 BackoffSmoothing model on the test data: 2767.5958051943485
# Perplexity of the 73 BackoffSmoothing model on the test data: 1648.8271493288291
# Perplexity of the 74 BackoffSmoothing model on the test data: 1841.2066557395408
# Perplexity of the 75 BackoffSmoothing model on the test data: 977.1927153246253
# Perplexity of the 76 BackoffSmoothing model on the test data: 1729.3778282996693
# Perplexity of the 77 BackoffSmoothing model on the test data: 1460.0370602641174
# Perplexity of the 78 BackoffSmoothing model on the test data: 1114.2721154092212
# Perplexity of the 79 BackoffSmoothing model on the test data: 1356.125666925878
# Perplexity of the 80 BackoffSmoothing model on the test data: 1229.0956384703559
# Perplexity of the 81 BackoffSmoothing model on the test data: 1274.2613486538905
# Perplexity of the 82 BackoffSmoothing model on the test data: 1095.4742290518714
# Perplexity of the 83 BackoffSmoothing model on the test data: 953.9228696563116
# Perplexity of the 84 BackoffSmoothing model on the test data: 1058.7774403807496
# Perplexity of the 85 BackoffSmoothing model on the test data: 1606.6501692887375
# Perplexity of the 86 BackoffSmoothing model on the test data: 1458.8732516668272
# Perplexity of the 87 BackoffSmoothing model on the test data: 1204.4002999537322
# Perplexity of the 88 BackoffSmoothing model on the test data: 2039.1503060955565
# Perplexity of the 89 BackoffSmoothing model on the test data: 1491.1547540166132
# Perplexity of the 90 BackoffSmoothing model on the test data: 1914.321637048869
# Perplexity of the 91 BackoffSmoothing model on the test data: 2084.5588953420292
# Perplexity of the 92 BackoffSmoothing model on the test data: 1927.5869215943164
# Perplexity of the 93 BackoffSmoothing model on the test data: 2028.2166117808129
# Perplexity of the 94 BackoffSmoothing model on the test data: 1308.3822590298043
# Perplexity of the 95 BackoffSmoothing model on the test data: 1155.9247621199931
# Perplexity of the 96 BackoffSmoothing model on the test data: 3470.8508768500583
# Perplexity of the 97 BackoffSmoothing model on the test data: 945.2206453933743
# Perplexity of the 98 BackoffSmoothing model on the test data: 1602.6100050908456
# Perplexity of the 99 BackoffSmoothing model on the test data: 1742.0615619676773
# Perplexity of the 100 BackoffSmoothing model on the test data: 1065.1889201110073
# Perplexity of the 101 BackoffSmoothing model on the test data: 2168.900948073323
# Perplexity of the 102 BackoffSmoothing model on the test data: 1971.7954668568418
# Perplexity of the 103 BackoffSmoothing model on the test data: 1175.0625003656764
# Perplexity of the 104 BackoffSmoothing model on the test data: 2049.0790315483514
# Perplexity of the 105 BackoffSmoothing model on the test data: 1637.4591772121746
# Perplexity of the 106 BackoffSmoothing model on the test data: 2130.998514045114
# Perplexity of the 107 BackoffSmoothing model on the test data: 2248.775454316349
# Perplexity of the 108 BackoffSmoothing model on the test data: 1128.8262178797859
# Perplexity of the 109 BackoffSmoothing model on the test data: 1299.7461522117615
# Perplexity of the 110 BackoffSmoothing model on the test data: 1447.6935523138138
# Perplexity of the 111 BackoffSmoothing model on the test data: 1210.0303927747323
# Perplexity of the 112 BackoffSmoothing model on the test data: 1147.724973232739
# Perplexity of the 113 BackoffSmoothing model on the test data: 1355.8127844409855
# Perplexity of the 114 BackoffSmoothing model on the test data: 1698.9428446736201
# Perplexity of the 115 BackoffSmoothing model on the test data: 1894.1081603643634
# Perplexity of the 116 BackoffSmoothing model on the test data: 1350.5199047963447
# Perplexity of the 117 BackoffSmoothing model on the test data: 1631.94878225657
# Perplexity of the 118 BackoffSmoothing model on the test data: 1375.3030062835314
# Perplexity of the 119 BackoffSmoothing model on the test data: 1304.6327325113166
# Perplexity of the 120 BackoffSmoothing model on the test data: 1192.1769004845032
# Perplexity of the 121 BackoffSmoothing model on the test data: 1688.8177537162003
# Perplexity of the 122 BackoffSmoothing model on the test data: 1291.5247197629917
# Perplexity of the 123 BackoffSmoothing model on the test data: 2061.0477378342657
# Perplexity of the 124 BackoffSmoothing model on the test data: 1275.5890335929114
# Perplexity of the 125 BackoffSmoothing model on the test data: 1194.8532640106394
# Perplexity of the 126 BackoffSmoothing model on the test data: 1412.5947271951081
# Perplexity of the 127 BackoffSmoothing model on the test data: 1782.2224722239835
# Perplexity of the 128 BackoffSmoothing model on the test data: 1568.722454103725
# Perplexity of the 129 BackoffSmoothing model on the test data: 1331.035116889958
# Perplexity of the 130 BackoffSmoothing model on the test data: 2075.062066485852
# Perplexity of the 131 BackoffSmoothing model on the test data: 1452.4759386886528
# Perplexity of the 132 BackoffSmoothing model on the test data: 1839.4685419608822
# Perplexity of the 133 BackoffSmoothing model on the test data: 1340.7946829835723
# Perplexity of the 134 BackoffSmoothing model on the test data: 1662.0981263483734
# Perplexity of the 135 BackoffSmoothing model on the test data: 1892.9792807961985
# Perplexity of the 136 BackoffSmoothing model on the test data: 1379.7395074738754
# Perplexity of the 137 BackoffSmoothing model on the test data: 1175.113919391492
# Perplexity of the 138 BackoffSmoothing model on the test data: 2596.3945149252854
# Perplexity of the 139 BackoffSmoothing model on the test data: 1646.3221223991243
# Perplexity of the 140 BackoffSmoothing model on the test data: 1512.9605703921025
# Perplexity of the 141 BackoffSmoothing model on the test data: 1918.5226795183191
# Perplexity of the 142 BackoffSmoothing model on the test data: 1441.7221204481673
# Perplexity of the 143 BackoffSmoothing model on the test data: 2339.434626449448
# Perplexity of the 144 BackoffSmoothing model on the test data: 1019.8447328255269
# Perplexity of the 145 BackoffSmoothing model on the test data: 1665.4084603970596
# Perplexity of the 146 BackoffSmoothing model on the test data: 1705.5286485803392
# Perplexity of the 147 BackoffSmoothing model on the test data: 982.7892880561349
# Perplexity of the 148 BackoffSmoothing model on the test data: 1210.8354124221503
# Perplexity of the 149 BackoffSmoothing model on the test data: 1245.8698706226628
# Perplexity of the 150 BackoffSmoothing model on the test data: 1306.6244668097954
# Perplexity of the 151 BackoffSmoothing model on the test data: 2579.127200659472
# Perplexity of the 152 BackoffSmoothing model on the test data: 1507.7602667478102
# Perplexity of the 153 BackoffSmoothing model on the test data: 1870.1119995134086
# Perplexity of the 154 BackoffSmoothing model on the test data: 1311.435994406063
# Perplexity of the 155 BackoffSmoothing model on the test data: 1788.188713639178
# Perplexity of the 156 BackoffSmoothing model on the test data: 2031.5734580917103
# Perplexity of the 157 BackoffSmoothing model on the test data: 2761.996385195182
# Perplexity of the 158 BackoffSmoothing model on the test data: 1647.948598848493
# Perplexity of the 159 BackoffSmoothing model on the test data: 1569.453819575946
# Perplexity of the 160 BackoffSmoothing model on the test data: 1710.5037329712072
# Perplexity of the 161 BackoffSmoothing model on the test data: 2004.0179878405597
# Perplexity of the 162 BackoffSmoothing model on the test data: 1635.8620100701787
# Perplexity of the 163 BackoffSmoothing model on the test data: 1310.1141838833826
# Perplexity of the 164 BackoffSmoothing model on the test data: 1223.679975577709
# Perplexity of the 165 BackoffSmoothing model on the test data: 1650.3843211059848
# Perplexity of the 166 BackoffSmoothing model on the test data: 2451.9056590383434
# Perplexity of the 167 BackoffSmoothing model on the test data: 2083.2776978893125
# Perplexity of the 168 BackoffSmoothing model on the test data: 2111.0365708456616
# Perplexity of the 169 BackoffSmoothing model on the test data: 1695.7755757261282
# Perplexity of the 170 BackoffSmoothing model on the test data: 1317.512544198265
# Perplexity of the 171 BackoffSmoothing model on the test data: 1359.082185215574
# Perplexity of the 172 BackoffSmoothing model on the test data: 1545.7960728825162
# Perplexity of the 173 BackoffSmoothing model on the test data: 2445.567909951836
# Perplexity of the 174 BackoffSmoothing model on the test data: 1204.5459434296008
# Perplexity of the 175 BackoffSmoothing model on the test data: 1682.0569132303274
# Perplexity of the 176 BackoffSmoothing model on the test data: 1871.8999995853023
# Perplexity of the 177 BackoffSmoothing model on the test data: 2702.685929481309
# Perplexity of the 178 BackoffSmoothing model on the test data: 1448.605364593051
# Perplexity of the 179 BackoffSmoothing model on the test data: 1594.4156334986985
# Perplexity of the 180 BackoffSmoothing model on the test data: 1780.566541795681
# Perplexity of the 181 BackoffSmoothing model on the test data: 1436.1903577259027
# Perplexity of the 182 BackoffSmoothing model on the test data: 1245.5898679166935
# Perplexity of the 183 BackoffSmoothing model on the test data: 1409.9276532438207
# Perplexity of the 184 BackoffSmoothing model on the test data: 1591.2181819189323
# Perplexity of the 185 BackoffSmoothing model on the test data: 1549.4411331316649
# Perplexity of the 186 BackoffSmoothing model on the test data: 1297.0513668395893
# Perplexity of the 187 BackoffSmoothing model on the test data: 1243.8144469309152
# Perplexity of the 188 BackoffSmoothing model on the test data: 2733.572666668301
# Perplexity of the 189 BackoffSmoothing model on the test data: 905.1264156214338
# Perplexity of the 190 BackoffSmoothing model on the test data: 1735.6836742081723
# Perplexity of the 191 BackoffSmoothing model on the test data: 2299.584380738559
# Perplexity of the 192 BackoffSmoothing model on the test data: 1133.611813982857
# Perplexity of the 193 BackoffSmoothing model on the test data: 1393.8024026904127
# Perplexity of the 194 BackoffSmoothing model on the test data: 2083.0202401889414
# Perplexity of the 195 BackoffSmoothing model on the test data: 1740.094617617095
# Perplexity of the 196 BackoffSmoothing model on the test data: 1047.1374652715592
# Perplexity of the 197 BackoffSmoothing model on the test data: 1920.1104421284006
# Perplexity of the 198 BackoffSmoothing model on the test data: 1043.3932083078846
# Perplexity of the 199 BackoffSmoothing model on the test data: 1923.811734706462
# Perplexity of the 200 BackoffSmoothing model on the test data: 1529.8439205710085
# Perplexity of the 201 BackoffSmoothing model on the test data: 1280.986121152215
# Perplexity of the 202 BackoffSmoothing model on the test data: 1678.6610204719482
# Perplexity of the 203 BackoffSmoothing model on the test data: 1999.4523772728826
# Perplexity of the 204 BackoffSmoothing model on the test data: 1274.441648928688
# Perplexity of the 205 BackoffSmoothing model on the test data: 2442.2248763556754
# Perplexity of the 206 BackoffSmoothing model on the test data: 1901.960885550253
# Perplexity of the 207 BackoffSmoothing model on the test data: 2370.704182410661
# Perplexity of the 208 BackoffSmoothing model on the test data: 1098.8161180242248
# Perplexity of the 209 BackoffSmoothing model on the test data: 1338.6375832842077
# Perplexity of the 210 BackoffSmoothing model on the test data: 1182.517232482584
# Perplexity of the 211 BackoffSmoothing model on the test data: 1215.0952228460392
# Perplexity of the 212 BackoffSmoothing model on the test data: 1385.7898969451705
# Perplexity of the 213 BackoffSmoothing model on the test data: 1611.3426240099145
# Perplexity of the 214 BackoffSmoothing model on the test data: 1571.795767026935
# Perplexity of the 215 BackoffSmoothing model on the test data: 1289.7612942214596
# Perplexity of the 216 BackoffSmoothing model on the test data: 1898.7960808380753
# Perplexity of the 217 BackoffSmoothing model on the test data: 1247.605951091549
# Perplexity of the 218 BackoffSmoothing model on the test data: 1448.9709463892818
# Perplexity of the 219 BackoffSmoothing model on the test data: 921.9979660922478
# Perplexity of the 220 BackoffSmoothing model on the test data: 2048.106216526373
# Perplexity of the 221 BackoffSmoothing model on the test data: 1369.843137814318
# Perplexity of the 222 BackoffSmoothing model on the test data: 1214.5262869182038
# Perplexity of the 223 BackoffSmoothing model on the test data: 1251.632352512677
# Perplexity of the 224 BackoffSmoothing model on the test data: 1015.2663741229925
# Perplexity of the 225 BackoffSmoothing model on the test data: 1641.5407139719255
# Perplexity of the 226 BackoffSmoothing model on the test data: 1103.8639705874252
# Perplexity of the 227 BackoffSmoothing model on the test data: 1547.3235325980436
# Perplexity of the 228 BackoffSmoothing model on the test data: 1273.516478232416
# Perplexity of the 229 BackoffSmoothing model on the test data: 1357.6551203262911
# Perplexity of the 230 BackoffSmoothing model on the test data: 1972.0866115469987
# Perplexity of the 231 BackoffSmoothing model on the test data: 1328.2723746382567
# Perplexity of the 232 BackoffSmoothing model on the test data: 1029.6441691858288
# Perplexity of the 233 BackoffSmoothing model on the test data: 1441.0914398969921
# Perplexity of the 234 BackoffSmoothing model on the test data: 1285.0691830487795
# Perplexity of the 235 BackoffSmoothing model on the test data: 1876.264268151823
# Perplexity of the 236 BackoffSmoothing model on the test data: 1919.152351653244
# Perplexity of the 237 BackoffSmoothing model on the test data: 1840.4110109850508
# Perplexity of the 238 BackoffSmoothing model on the test data: 1758.3888784928506
# Perplexity of the 239 BackoffSmoothing model on the test data: 1540.07030081525
# Perplexity of the 240 BackoffSmoothing model on the test data: 1253.805539805982
# Perplexity of the 241 BackoffSmoothing model on the test data: 1540.4064442909175
# Perplexity of the 242 BackoffSmoothing model on the test data: 1421.4590710256882
# Perplexity of the 243 BackoffSmoothing model on the test data: 1432.2458731450586
# Perplexity of the 244 BackoffSmoothing model on the test data: 1659.141140882302
# Perplexity of the 245 BackoffSmoothing model on the test data: 1152.2563513700077
# Perplexity of the 246 BackoffSmoothing model on the test data: 1309.3879907460419
# Perplexity of the 247 BackoffSmoothing model on the test data: 1412.6282315363833
# Perplexity of the 248 BackoffSmoothing model on the test data: 1586.4857109396742
# Perplexity of the 249 BackoffSmoothing model on the test data: 1399.52580687622
# Perplexity of the 250 BackoffSmoothing model on the test data: 1290.3701211100663
# Perplexity of the 251 BackoffSmoothing model on the test data: 1629.7120661984484
# Perplexity of the 252 BackoffSmoothing model on the test data: 1129.0626175209836
# Perplexity of the 253 BackoffSmoothing model on the test data: 2712.217860430595
# Perplexity of the 254 BackoffSmoothing model on the test data: 2347.418763722684
# Perplexity of the 255 BackoffSmoothing model on the test data: 2291.434619572689
# Perplexity of the 256 BackoffSmoothing model on the test data: 1581.4919437381502
# Perplexity of the 257 BackoffSmoothing model on the test data: 2198.961161082296
# Perplexity of the 258 BackoffSmoothing model on the test data: 1782.6924260395392
# Perplexity of the 259 BackoffSmoothing model on the test data: 1931.1631394981248
# Perplexity of the 260 BackoffSmoothing model on the test data: 1421.804825297082
# Perplexity of the 261 BackoffSmoothing model on the test data: 1468.3721827349104
# Perplexity of the 262 BackoffSmoothing model on the test data: 1227.697016018871
# Perplexity of the 263 BackoffSmoothing model on the test data: 1660.042853558376
# Perplexity of the 264 BackoffSmoothing model on the test data: 880.4541364991616
# Perplexity of the 265 BackoffSmoothing model on the test data: 1074.1145003680767
# Perplexity of the 266 BackoffSmoothing model on the test data: 1824.45483422649
# Perplexity of the 267 BackoffSmoothing model on the test data: 2346.3910570671983
# Perplexity of the 268 BackoffSmoothing model on the test data: 1731.9545220767095
# Perplexity of the 269 BackoffSmoothing model on the test data: 939.5458253573753
# Perplexity of the 270 BackoffSmoothing model on the test data: 1316.9917355037805
# Perplexity of the 271 BackoffSmoothing model on the test data: 1331.1353295255558
# Perplexity of the 272 BackoffSmoothing model on the test data: 1974.058326885706
# Perplexity of the 273 BackoffSmoothing model on the test data: 1514.4866456473721
# Perplexity of the 274 BackoffSmoothing model on the test data: 2341.211103211707
# Perplexity of the 275 BackoffSmoothing model on the test data: 1518.401390308075
# Perplexity of the 276 BackoffSmoothing model on the test data: 1981.5673046363977
# Perplexity of the 277 BackoffSmoothing model on the test data: 1250.970235612842
# Perplexity of the 278 BackoffSmoothing model on the test data: 1437.0188261129224
# Perplexity of the 279 BackoffSmoothing model on the test data: 1907.6956937400798
# Perplexity of the 280 BackoffSmoothing model on the test data: 1022.8115235970607
# Perplexity of the 281 BackoffSmoothing model on the test data: 1497.5916204588318
# Perplexity of the 282 BackoffSmoothing model on the test data: 1406.8182139807452
# Perplexity of the 283 BackoffSmoothing model on the test data: 1735.7863412200961
# Perplexity of the 284 BackoffSmoothing model on the test data: 1093.5536425532623
# Perplexity of the 285 BackoffSmoothing model on the test data: 1441.9733208752336
# Perplexity of the 286 BackoffSmoothing model on the test data: 1306.89265213203
# Perplexity of the 287 BackoffSmoothing model on the test data: 1248.1605827229846
# Perplexity of the 288 BackoffSmoothing model on the test data: 1887.470207961987
# Perplexity of the 289 BackoffSmoothing model on the test data: 1413.9094906933938
# Perplexity of the 290 BackoffSmoothing model on the test data: 3410.267207408128
# Perplexity of the 291 BackoffSmoothing model on the test data: 1481.120376195486
# Perplexity of the 292 BackoffSmoothing model on the test data: 1924.6261639242134
# Perplexity of the 293 BackoffSmoothing model on the test data: 1754.4990988903326
# Perplexity of the 294 BackoffSmoothing model on the test data: 1321.7677802049868
# Perplexity of the 295 BackoffSmoothing model on the test data: 2106.9240872537925
# Perplexity of the 296 BackoffSmoothing model on the test data: 989.4719201237186
# Perplexity of the 297 BackoffSmoothing model on the test data: 1513.833044692822
# Perplexity of the 298 BackoffSmoothing model on the test data: 2706.3965027662875
# Perplexity of the 299 BackoffSmoothing model on the test data: 925.7339291100037
# Perplexity of the 300 BackoffSmoothing model on the test data: 1391.2915879662467
# Perplexity of the 301 BackoffSmoothing model on the test data: 2309.3029199310627
# Perplexity of the 302 BackoffSmoothing model on the test data: 1151.4939991055585
# Perplexity of the 303 BackoffSmoothing model on the test data: 1741.216004609565
# Perplexity of the 304 BackoffSmoothing model on the test data: 1658.8867169985779
# Perplexity of the 305 BackoffSmoothing model on the test data: 2434.525231400964
# Perplexity of the 306 BackoffSmoothing model on the test data: 1653.3471196592207
# Perplexity of the 307 BackoffSmoothing model on the test data: 1115.570418819212
# Perplexity of the 308 BackoffSmoothing model on the test data: 1979.2581322259932
# Perplexity of the 309 BackoffSmoothing model on the test data: 1198.4595788073168
# Perplexity of the 310 BackoffSmoothing model on the test data: 1422.3377382465255
# Perplexity of the 311 BackoffSmoothing model on the test data: 1092.4991135076423
# Perplexity of the 312 BackoffSmoothing model on the test data: 1714.3787172502603
# Perplexity of the 313 BackoffSmoothing model on the test data: 1843.16569101843
# Perplexity of the 314 BackoffSmoothing model on the test data: 1243.8284526644861
# Perplexity of the 315 BackoffSmoothing model on the test data: 1470.4335536237675
# Perplexity of the 316 BackoffSmoothing model on the test data: 1972.477744827292
# Perplexity of the 317 BackoffSmoothing model on the test data: 1255.5661119222045
# Perplexity of the 318 BackoffSmoothing model on the test data: 1725.1464521891012
# Perplexity of the 319 BackoffSmoothing model on the test data: 2427.747258055643
# Perplexity of the 320 BackoffSmoothing model on the test data: 1962.0411328737973
# Perplexity of the 321 BackoffSmoothing model on the test data: 1239.8563232109743
# Perplexity of the 322 BackoffSmoothing model on the test data: 1394.7673158879456
# Perplexity of the 323 BackoffSmoothing model on the test data: 1218.10393045021
# Perplexity of the 324 BackoffSmoothing model on the test data: 1952.504259780555
# Perplexity of the 325 BackoffSmoothing model on the test data: 1079.9531812291748
# Perplexity of the 326 BackoffSmoothing model on the test data: 2160.7155591887076
# Perplexity of the 327 BackoffSmoothing model on the test data: 1106.3723861462115
# Perplexity of the 328 BackoffSmoothing model on the test data: 1442.5207123204418
# Perplexity of the 329 BackoffSmoothing model on the test data: 1817.2448919200053
# Perplexity of the 330 BackoffSmoothing model on the test data: 1366.4007733059834
# Perplexity of the 331 BackoffSmoothing model on the test data: 3247.9146772006893
# Perplexity of the 332 BackoffSmoothing model on the test data: 1866.8068071463317
# Perplexity of the 333 BackoffSmoothing model on the test data: 1269.6900645614694
# Perplexity of the 334 BackoffSmoothing model on the test data: 986.7145081469846
# Perplexity of the 335 BackoffSmoothing model on the test data: 1843.910811773294
# Perplexity of the 336 BackoffSmoothing model on the test data: 1417.4751566489406
# Perplexity of the 337 BackoffSmoothing model on the test data: 4586.600600911241
# Perplexity of the 338 BackoffSmoothing model on the test data: 1422.9337921282256
# Perplexity of the 339 BackoffSmoothing model on the test data: 1065.2519320388008
# Perplexity of the 340 BackoffSmoothing model on the test data: 2196.1310628239958
# Perplexity of the 341 BackoffSmoothing model on the test data: 1396.0037611284893
# Perplexity of the 342 BackoffSmoothing model on the test data: 1419.4402014288435
# Perplexity of the 343 BackoffSmoothing model on the test data: 937.8524290048035
# Perplexity of the 344 BackoffSmoothing model on the test data: 1382.9938390135178
# Perplexity of the 345 BackoffSmoothing model on the test data: 1907.8446298704962
# Perplexity of the 346 BackoffSmoothing model on the test data: 1908.478096399203
# Perplexity of the 347 BackoffSmoothing model on the test data: 2140.110259558132
# Perplexity of the 348 BackoffSmoothing model on the test data: 1280.903844293766
# Perplexity of the 349 BackoffSmoothing model on the test data: 1241.692409135189
# Perplexity of the 350 BackoffSmoothing model on the test data: 1800.5794791151297
# Perplexity of the 351 BackoffSmoothing model on the test data: 1980.8330400044213
# Perplexity of the 352 BackoffSmoothing model on the test data: 1169.5898096523165
# Perplexity of the 353 BackoffSmoothing model on the test data: 1272.4321626231565
# Perplexity of the 354 BackoffSmoothing model on the test data: 1215.1687401205338
# Perplexity of the 355 BackoffSmoothing model on the test data: 1372.0971443983885
# Perplexity of the 356 BackoffSmoothing model on the test data: 1201.7183208229942
# Perplexity of the 357 BackoffSmoothing model on the test data: 1171.4088405957975
# Perplexity of the 358 BackoffSmoothing model on the test data: 1492.9707221366439
# Perplexity of the 359 BackoffSmoothing model on the test data: 1356.6403922901357
# Perplexity of the 360 BackoffSmoothing model on the test data: 1642.0244712680585
# Perplexity of the 361 BackoffSmoothing model on the test data: 1136.7256978139428
# Perplexity of the 362 BackoffSmoothing model on the test data: 1539.6967602881252
# Perplexity of the 363 BackoffSmoothing model on the test data: 1530.2115300618498
# Perplexity of the 364 BackoffSmoothing model on the test data: 1341.3917239196933
# Perplexity of the 365 BackoffSmoothing model on the test data: 2022.2511751164136
# Perplexity of the 366 BackoffSmoothing model on the test data: 1798.090122443846
# Perplexity of the 367 BackoffSmoothing model on the test data: 1868.379386302834
# Perplexity of the 368 BackoffSmoothing model on the test data: 882.9975748902513
# Perplexity of the 369 BackoffSmoothing model on the test data: 1718.716875096321
# Perplexity of the 370 BackoffSmoothing model on the test data: 1179.1464767667321
# Perplexity of the 371 BackoffSmoothing model on the test data: 1582.5393250026937
# Perplexity of the 372 BackoffSmoothing model on the test data: 1408.9400478675057
# Perplexity of the 373 BackoffSmoothing model on the test data: 1992.7868026913316
# Perplexity of the 374 BackoffSmoothing model on the test data: 1486.2915840079895
# Perplexity of the 375 BackoffSmoothing model on the test data: 2707.1033481923077
# Perplexity of the 376 BackoffSmoothing model on the test data: 1687.489932881656
# Perplexity of the 377 BackoffSmoothing model on the test data: 2254.389533875714
# Perplexity of the 378 BackoffSmoothing model on the test data: 1850.667814834129
# Perplexity of the 379 BackoffSmoothing model on the test data: 1283.9161305087387
# Perplexity of the 380 BackoffSmoothing model on the test data: 1178.2433357441087
# Perplexity of the 381 BackoffSmoothing model on the test data: 1508.9542780073307
# Perplexity of the 382 BackoffSmoothing model on the test data: 1419.3954416122028
# Perplexity of the 383 BackoffSmoothing model on the test data: 1286.5618239903245
# Perplexity of the 384 BackoffSmoothing model on the test data: 1241.4792222142003
# Perplexity of the 385 BackoffSmoothing model on the test data: 1441.1012309724222
# Perplexity of the 386 BackoffSmoothing model on the test data: 1119.5205528089134
# Perplexity of the 387 BackoffSmoothing model on the test data: 1905.3199668539214
# Perplexity of the 388 BackoffSmoothing model on the test data: 1698.642474734159
# Perplexity of the 389 BackoffSmoothing model on the test data: 1620.5733610135978
# Perplexity of the 390 BackoffSmoothing model on the test data: 1455.8216485598957
# Perplexity of the 391 BackoffSmoothing model on the test data: 1594.1202072342487
# Perplexity of the 392 BackoffSmoothing model on the test data: 1477.7465177536403
# Perplexity of the 393 BackoffSmoothing model on the test data: 1029.1912978333144
# Perplexity of the 394 BackoffSmoothing model on the test data: 1287.483779213271
# Perplexity of the 395 BackoffSmoothing model on the test data: 1859.9824169743413
# Perplexity of the 396 BackoffSmoothing model on the test data: 1097.2124758326113
# Perplexity of the 397 BackoffSmoothing model on the test data: 976.8245373879872
# Perplexity of the 398 BackoffSmoothing model on the test data: 1636.5254633198251
# Perplexity of the 399 BackoffSmoothing model on the test data: 1857.0632445352594
# Perplexity of the 400 BackoffSmoothing model on the test data: 1085.3336222960402
# Perplexity of the 401 BackoffSmoothing model on the test data: 1541.359390007439
# Perplexity of the 402 BackoffSmoothing model on the test data: 2145.992778026473
# Perplexity of the 403 BackoffSmoothing model on the test data: 1137.9615800393829
# Perplexity of the 404 BackoffSmoothing model on the test data: 1189.1127831584486
# Perplexity of the 405 BackoffSmoothing model on the test data: 1156.2850687029745
# Perplexity of the 406 BackoffSmoothing model on the test data: 1862.8188412423372
# Perplexity of the 407 BackoffSmoothing model on the test data: 1648.3582251059522
# Perplexity of the 408 BackoffSmoothing model on the test data: 1214.8426414237142
# Perplexity of the 409 BackoffSmoothing model on the test data: 1204.4003268309484
# Perplexity of the 410 BackoffSmoothing model on the test data: 1524.0033026870658
# Perplexity of the 411 BackoffSmoothing model on the test data: 2033.626956390418
# Perplexity of the 412 BackoffSmoothing model on the test data: 2377.925526890737
# Perplexity of the 413 BackoffSmoothing model on the test data: 1409.3130128890086
# Perplexity of the 414 BackoffSmoothing model on the test data: 2207.8981359117874
# Perplexity of the 415 BackoffSmoothing model on the test data: 1155.4997517960242
# Perplexity of the 416 BackoffSmoothing model on the test data: 1895.446515031307
# Perplexity of the 417 BackoffSmoothing model on the test data: 1399.9622573347813
# Perplexity of the 418 BackoffSmoothing model on the test data: 1403.175769700068
# Perplexity of the 419 BackoffSmoothing model on the test data: 1509.873931893444
# Perplexity of the 420 BackoffSmoothing model on the test data: 1710.1294630972484
# Perplexity of the 421 BackoffSmoothing model on the test data: 1304.6895066294794
# Perplexity of the 422 BackoffSmoothing model on the test data: 1956.3335157139052
# Perplexity of the 423 BackoffSmoothing model on the test data: 1154.08927333014
# Perplexity of the 424 BackoffSmoothing model on the test data: 1324.7927964809749
# Perplexity of the 425 BackoffSmoothing model on the test data: 1675.5025031022976
# Perplexity of the 426 BackoffSmoothing model on the test data: 1780.985199510814
# Perplexity of the 427 BackoffSmoothing model on the test data: 1699.0675609910354
# Perplexity of the 428 BackoffSmoothing model on the test data: 932.747351443593
# Perplexity of the 429 BackoffSmoothing model on the test data: 1445.8369771678313
# Perplexity of the 430 BackoffSmoothing model on the test data: 1704.6295796129339
# Perplexity of the 431 BackoffSmoothing model on the test data: 1641.0152036026516
# Perplexity of the 432 BackoffSmoothing model on the test data: 1497.597534062841
# Perplexity of the 433 BackoffSmoothing model on the test data: 1073.5743384641846
# Perplexity of the 434 BackoffSmoothing model on the test data: 1201.3467988194752
# Perplexity of the 435 BackoffSmoothing model on the test data: 2006.82428884769
# Perplexity of the 436 BackoffSmoothing model on the test data: 1471.011833163448
# Perplexity of the 437 BackoffSmoothing model on the test data: 2688.4575959541826
# Perplexity of the 438 BackoffSmoothing model on the test data: 1999.7192500462359
# Perplexity of the 439 BackoffSmoothing model on the test data: 2883.9014047660226
# Perplexity of the 440 BackoffSmoothing model on the test data: 946.0794377593279
# Perplexity of the 441 BackoffSmoothing model on the test data: 1541.0782237944616
# Perplexity of the 442 BackoffSmoothing model on the test data: 1212.7259181693105
# Perplexity of the 443 BackoffSmoothing model on the test data: 1599.2764626042574
# Perplexity of the 444 BackoffSmoothing model on the test data: 913.2783012299351
# Perplexity of the 445 BackoffSmoothing model on the test data: 1276.0006334220068
# Perplexity of the 446 BackoffSmoothing model on the test data: 3515.4001788228484
# Perplexity of the 447 BackoffSmoothing model on the test data: 1193.449090746468
# Perplexity of the 448 BackoffSmoothing model on the test data: 1276.9968642634867
# Perplexity of the 449 BackoffSmoothing model on the test data: 1686.5560502927465
# Perplexity of the 450 BackoffSmoothing model on the test data: 950.4840724453888
# Perplexity of the 451 BackoffSmoothing model on the test data: 1049.6643861944356
# Perplexity of the 452 BackoffSmoothing model on the test data: 2260.103540406283
# Perplexity of the 453 BackoffSmoothing model on the test data: 1171.8889200531987
# Perplexity of the 454 BackoffSmoothing model on the test data: 1227.4592653853654
# Perplexity of the 455 BackoffSmoothing model on the test data: 1249.0346257510143
# Perplexity of the 456 BackoffSmoothing model on the test data: 1755.4461741018781
# Perplexity of the 457 BackoffSmoothing model on the test data: 1250.969036864618
# Perplexity of the 458 BackoffSmoothing model on the test data: 1350.100049697312
# Perplexity of the 459 BackoffSmoothing model on the test data: 1956.1367868572613
# Perplexity of the 460 BackoffSmoothing model on the test data: 1869.2496132370857
# Perplexity of the 461 BackoffSmoothing model on the test data: 2654.262427096377
# Perplexity of the 462 BackoffSmoothing model on the test data: 1193.0047409458775
# Perplexity of the 463 BackoffSmoothing model on the test data: 1242.6464305894003
# Perplexity of the 464 BackoffSmoothing model on the test data: 1774.630000850601
# Perplexity of the 465 BackoffSmoothing model on the test data: 2269.8558041200595
# Perplexity of the 466 BackoffSmoothing model on the test data: 2651.1799360743976
# Perplexity of the 467 BackoffSmoothing model on the test data: 1528.3613918361314
# Perplexity of the 468 BackoffSmoothing model on the test data: 1712.2027962632321
# Perplexity of the 469 BackoffSmoothing model on the test data: 983.0270943551812
# Perplexity of the 470 BackoffSmoothing model on the test data: 1886.3131317357615
# Perplexity of the 471 BackoffSmoothing model on the test data: 1476.4321975509026
# Perplexity of the 472 BackoffSmoothing model on the test data: 1872.528875596916
# Perplexity of the 473 BackoffSmoothing model on the test data: 1309.5899363012836
# Perplexity of the 474 BackoffSmoothing model on the test data: 1042.1854274348918
# Perplexity of the 475 BackoffSmoothing model on the test data: 1244.9638326435038
# Perplexity of the 476 BackoffSmoothing model on the test data: 1334.3702024201498
# Perplexity of the 477 BackoffSmoothing model on the test data: 1178.7454713586376
# Perplexity of the 478 BackoffSmoothing model on the test data: 1473.597582969278
# Perplexity of the 479 BackoffSmoothing model on the test data: 2253.208600538161
# Perplexity of the 480 BackoffSmoothing model on the test data: 2414.184744054523
# Perplexity of the 481 BackoffSmoothing model on the test data: 1647.3261050308934
# Perplexity of the 482 BackoffSmoothing model on the test data: 1179.117805455555
# Perplexity of the 483 BackoffSmoothing model on the test data: 1139.679812216399
# Perplexity of the 484 BackoffSmoothing model on the test data: 1429.7515847638292
# Perplexity of the 485 BackoffSmoothing model on the test data: 1537.3148855155887
# Perplexity of the 486 BackoffSmoothing model on the test data: 1018.2051237849086
# Perplexity of the 487 BackoffSmoothing model on the test data: 2730.5004238085426
# Perplexity of the 488 BackoffSmoothing model on the test data: 1929.8740305010353
# Perplexity of the 489 BackoffSmoothing model on the test data: 1185.0843442679688
# Perplexity of the 490 BackoffSmoothing model on the test data: 1499.8561932058562
# Perplexity of the 491 BackoffSmoothing model on the test data: 1245.788762206517
# Perplexity of the 492 BackoffSmoothing model on the test data: 1028.0522045916066
# Perplexity of the 493 BackoffSmoothing model on the test data: 1681.0349072666475
# Perplexity of the 494 BackoffSmoothing model on the test data: 1623.3770747116134
# Perplexity of the 495 BackoffSmoothing model on the test data: 1706.7238452534114
# Perplexity of the 496 BackoffSmoothing model on the test data: 1456.0308276165892
# Perplexity of the 497 BackoffSmoothing model on the test data: 1482.102297851834
# Perplexity of the 498 BackoffSmoothing model on the test data: 988.8913644742483
# Perplexity of the 499 BackoffSmoothing model on the test data: 891.2308360745106
# Perplexity of the 500 BackoffSmoothing model on the test data: 2379.709929554781
# Perplexity of the 501 BackoffSmoothing model on the test data: 1194.5716844858646
# Perplexity of the 502 BackoffSmoothing model on the test data: 1749.3874139123845
# Perplexity of the 503 BackoffSmoothing model on the test data: 1272.3289597731307
# Perplexity of the 504 BackoffSmoothing model on the test data: 1291.7658344375507
# Perplexity of the 505 BackoffSmoothing model on the test data: 1331.8877907617177
# Perplexity of the 506 BackoffSmoothing model on the test data: 1382.4310204652277
# Perplexity of the 507 BackoffSmoothing model on the test data: 1655.1847558389052
# Perplexity of the 508 BackoffSmoothing model on the test data: 1117.59716628789
# Perplexity of the 509 BackoffSmoothing model on the test data: 1855.7603520510345
# Perplexity of the 510 BackoffSmoothing model on the test data: 1436.798602077729
# Perplexity of the 511 BackoffSmoothing model on the test data: 1582.819313404702
# Perplexity of the 512 BackoffSmoothing model on the test data: 1661.9874837356049
# Perplexity of the 513 BackoffSmoothing model on the test data: 1278.2652193797048
# Perplexity of the 514 BackoffSmoothing model on the test data: 2214.264965242936
# Perplexity of the 515 BackoffSmoothing model on the test data: 995.8816182312235
# Perplexity of the 516 BackoffSmoothing model on the test data: 1151.5608972728191
# Perplexity of the 517 BackoffSmoothing model on the test data: 1450.3327068645378
# Perplexity of the 518 BackoffSmoothing model on the test data: 1212.4407667327494
# Perplexity of the 519 BackoffSmoothing model on the test data: 1994.2610330846705
# Perplexity of the 520 BackoffSmoothing model on the test data: 1358.7847906910683
# Perplexity of the 521 BackoffSmoothing model on the test data: 1636.5724239446884
# Perplexity of the 522 BackoffSmoothing model on the test data: 2063.810704232683
# Perplexity of the 523 BackoffSmoothing model on the test data: 1665.3163146935406
# Perplexity of the 524 BackoffSmoothing model on the test data: 1138.86396869555
# Perplexity of the 525 BackoffSmoothing model on the test data: 1642.1607351409652
# Perplexity of the 526 BackoffSmoothing model on the test data: 2954.5023799085166
# Perplexity of the 527 BackoffSmoothing model on the test data: 1588.179647309534
# Perplexity of the 528 BackoffSmoothing model on the test data: 1594.8204731548985
# Perplexity of the 529 BackoffSmoothing model on the test data: 1903.9240314033464
# Perplexity of the 530 BackoffSmoothing model on the test data: 1443.5467567252438
# Perplexity of the 531 BackoffSmoothing model on the test data: 1027.9935862207035
# Perplexity of the 532 BackoffSmoothing model on the test data: 1162.2912981589038
# Perplexity of the 533 BackoffSmoothing model on the test data: 1847.0601002826581
# Perplexity of the 534 BackoffSmoothing model on the test data: 1529.4685999364774
# Perplexity of the 535 BackoffSmoothing model on the test data: 939.5146690418203
# Perplexity of the 536 BackoffSmoothing model on the test data: 1605.3095333271053
# Perplexity of the 537 BackoffSmoothing model on the test data: 2027.2528923037894
# Perplexity of the 538 BackoffSmoothing model on the test data: 1551.8329228158054
# Perplexity of the 539 BackoffSmoothing model on the test data: 2376.239013484817
# Perplexity of the 540 BackoffSmoothing model on the test data: 1261.7591719939664
# Perplexity of the 541 BackoffSmoothing model on the test data: 1733.6862807146829
# Perplexity of the 542 BackoffSmoothing model on the test data: 947.1202974596614
# Perplexity of the 543 BackoffSmoothing model on the test data: 1226.0877617358883
# Perplexity of the 544 BackoffSmoothing model on the test data: 1638.5295915365866
# Perplexity of the 545 BackoffSmoothing model on the test data: 1476.5337867416486
# Perplexity of the 546 BackoffSmoothing model on the test data: 1704.0047250196892
# Perplexity of the 547 BackoffSmoothing model on the test data: 1779.4627004166189
# Perplexity of the 548 BackoffSmoothing model on the test data: 1824.8432565921623
# Perplexity of the 549 BackoffSmoothing model on the test data: 1453.29721289569
# Perplexity of the 550 BackoffSmoothing model on the test data: 1122.6208371229607
# Perplexity of the 551 BackoffSmoothing model on the test data: 2236.2394937630074
# Perplexity of the 552 BackoffSmoothing model on the test data: 1636.1515440385735
# Perplexity of the 553 BackoffSmoothing model on the test data: 728.1399491330968
# Perplexity of the 554 BackoffSmoothing model on the test data: 1332.1340770151119
# Perplexity of the 555 BackoffSmoothing model on the test data: 1159.867051490787
# Perplexity of the 556 BackoffSmoothing model on the test data: 1153.8414010703698
# Perplexity of the 557 BackoffSmoothing model on the test data: 1598.5990313420787
# Perplexity of the 558 BackoffSmoothing model on the test data: 1029.8249449131888
# Perplexity of the 559 BackoffSmoothing model on the test data: 1155.2182826416754
# Perplexity of the 560 BackoffSmoothing model on the test data: 1327.7638848637273
# Perplexity of the 561 BackoffSmoothing model on the test data: 2400.273313268538
# Perplexity of the 562 BackoffSmoothing model on the test data: 1668.393451520576
# Perplexity of the 563 BackoffSmoothing model on the test data: 1279.9838225542367
# Perplexity of the 564 BackoffSmoothing model on the test data: 1534.7334399306076
# Perplexity of the 565 BackoffSmoothing model on the test data: 1793.2098628928006
# Perplexity of the 566 BackoffSmoothing model on the test data: 962.7802647469883
# Perplexity of the 567 BackoffSmoothing model on the test data: 1629.4305911679364
# Perplexity of the 568 BackoffSmoothing model on the test data: 1621.3793820821488
# Perplexity of the 569 BackoffSmoothing model on the test data: 1104.111844132921
# Perplexity of the 570 BackoffSmoothing model on the test data: 1667.952112736842
# Perplexity of the 571 BackoffSmoothing model on the test data: 1082.5545439636824
# Perplexity of the 572 BackoffSmoothing model on the test data: 1334.5566407159151
# Perplexity of the 573 BackoffSmoothing model on the test data: 997.4913849176959
# Perplexity of the 574 BackoffSmoothing model on the test data: 1527.341405883857
# Perplexity of the 575 BackoffSmoothing model on the test data: 1268.4785307596937
# Perplexity of the 576 BackoffSmoothing model on the test data: 1466.8028106517913
# Perplexity of the 577 BackoffSmoothing model on the test data: 1617.584458262778
# Perplexity of the 578 BackoffSmoothing model on the test data: 1994.1285407517903
# Perplexity of the 579 BackoffSmoothing model on the test data: 1108.2502050446135
# Perplexity of the 580 BackoffSmoothing model on the test data: 1938.6749192034292
# Perplexity of the 581 BackoffSmoothing model on the test data: 1183.205100459378
# Perplexity of the 582 BackoffSmoothing model on the test data: 1447.5484628162496
# Perplexity of the 583 BackoffSmoothing model on the test data: 1427.1156968739592
# Perplexity of the 584 BackoffSmoothing model on the test data: 913.7597072001536
# Perplexity of the 585 BackoffSmoothing model on the test data: 2672.0359584078833
# Perplexity of the 586 BackoffSmoothing model on the test data: 4702.59964973758
# Perplexity of the 587 BackoffSmoothing model on the test data: 1975.856865923106
# Perplexity of the 588 BackoffSmoothing model on the test data: 1944.9547372143988
# ...
# Perplexity of the 1451 BackoffSmoothing model on the test data: 1454.7001607015427
# Perplexity of the 1452 BackoffSmoothing model on the test data: 866.5922195422326
# Perplexity of the 1453 BackoffSmoothing model on the test data: 1643.9836246332786
# Perplexity of the 1454 BackoffSmoothing model on the test data: 2829.9845953239983
# Perplexity of the 1455 BackoffSmoothing model on the test data: 1297.0293338719696
# Perplexity of the 1456 BackoffSmoothing model on the test data: 2508.0112105094017
# Perplexity of the 1457 BackoffSmoothing model on the test data: 7187.1089590558095
# Perplexity of the 1458 BackoffSmoothing model on the test data: 771.0756775842971
# Perplexity of the 1459 BackoffSmoothing model on the test data: 2033.0128193527023
# Perplexity of the 1460 BackoffSmoothing model on the test data: 1017.3536449202774
# Perplexity of the 1461 BackoffSmoothing model on the test data: 1496.4424956524074
# Perplexity of the 1462 BackoffSmoothing model on the test data: 1244.5709039577466
# Perplexity of the 1463 BackoffSmoothing model on the test data: 1056.2925183119619
# Perplexity of the 1464 BackoffSmoothing model on the test data: 1611.2163378705006
# Perplexity of the 1465 BackoffSmoothing model on the test data: 1489.53869760523
# Perplexity of the 1466 BackoffSmoothing model on the test data: 10389.868905277457
# Perplexity of the 1467 BackoffSmoothing model on the test data: 2300.997177361714
# Perplexity of the 1468 BackoffSmoothing model on the test data: 1953.1176690020243
# Perplexity of the 1469 BackoffSmoothing model on the test data: 1923.2184059674962
# Perplexity of the 1470 BackoffSmoothing model on the test data: 1722.8329935639458
# Perplexity of the 1471 BackoffSmoothing model on the test data: 1178.0374637985308
# Perplexity of the 1472 BackoffSmoothing model on the test data: 1418.713714336818
# Perplexity of the 1473 BackoffSmoothing model on the test data: 1340.1151161336159
# Perplexity of the 1474 BackoffSmoothing model on the test data: 1485.9058347993246
# Perplexity of the 1475 BackoffSmoothing model on the test data: 999.7329081029169
# Perplexity of the 1476 BackoffSmoothing model on the test data: 1022.193964690989
# Perplexity of the 1477 BackoffSmoothing model on the test data: 1400.9106660239063
# Perplexity of the 1478 BackoffSmoothing model on the test data: 1422.7761449074667
# Perplexity of the 1479 BackoffSmoothing model on the test data: 1582.9369280329847
# Perplexity of the 1480 BackoffSmoothing model on the test data: 2139.499053796001
# Perplexity of the 1481 BackoffSmoothing model on the test data: 1297.6405610657698
# Perplexity of the 1482 BackoffSmoothing model on the test data: 1516.2015499347867
# Perplexity of the 1483 BackoffSmoothing model on the test data: 1197.3682382557306
# Perplexity of the 1484 BackoffSmoothing model on the test data: 1188.6442850389597
# Perplexity of the 1485 BackoffSmoothing model on the test data: 1233.2542430227302
# Perplexity of the 1486 BackoffSmoothing model on the test data: 1812.7731857563497
# Perplexity of the 1487 BackoffSmoothing model on the test data: 1366.7102490624607
# Perplexity of the 1488 BackoffSmoothing model on the test data: 1858.4658943097772
# Perplexity of the 1489 BackoffSmoothing model on the test data: 1234.465626885802
# Perplexity of the 1490 BackoffSmoothing model on the test data: 1492.5084634335058
# Perplexity of the 1491 BackoffSmoothing model on the test data: 1309.198779481533
# Perplexity of the 1492 BackoffSmoothing model on the test data: 1620.2336695250303
# Perplexity of the 1493 BackoffSmoothing model on the test data: 1198.5142955186836
# Perplexity of the 1494 BackoffSmoothing model on the test data: 1671.02188190717
# Perplexity of the 1495 BackoffSmoothing model on the test data: 1091.0143596107482
# Perplexity of the 1496 BackoffSmoothing model on the test data: 1463.4896999273092
# Perplexity of the 1497 BackoffSmoothing model on the test data: 1947.8821729767596
# Perplexity of the 1498 BackoffSmoothing model on the test data: 1271.7372004414879
# Perplexity of the 1499 BackoffSmoothing model on the test data: 1672.2160587243343
# Perplexity of the 1500 BackoffSmoothing model on the test data: 1397.72954294788
# Perplexity of the 1501 BackoffSmoothing model on the test data: 945.3459046602057
# Perplexity of the 1502 BackoffSmoothing model on the test data: 1356.6886544153624
# Perplexity of the 1503 BackoffSmoothing model on the test data: 1989.3090517372782
# Perplexity of the 1504 BackoffSmoothing model on the test data: 1155.4848876592107
# Perplexity of the 1505 BackoffSmoothing model on the test data: 1852.6280821036162
# Perplexity of the 1506 BackoffSmoothing model on the test data: 2359.628220011928
# Perplexity of the 1507 BackoffSmoothing model on the test data: 965.3777187107368
# Perplexity of the 1508 BackoffSmoothing model on the test data: 1193.40228908016
# Perplexity of the 1509 BackoffSmoothing model on the test data: 1707.6937503762372
# Perplexity of the 1510 BackoffSmoothing model on the test data: 1785.5139549905662
# Perplexity of the 1511 BackoffSmoothing model on the test data: 1652.068520971711
# Perplexity of the 1512 BackoffSmoothing model on the test data: 1722.9112910000265
# Perplexity of the 1513 BackoffSmoothing model on the test data: 1228.3085756580429
# Perplexity of the 1514 BackoffSmoothing model on the test data: 1275.748976963949
# Perplexity of the 1515 BackoffSmoothing model on the test data: 948.3306985387062
# Perplexity of the 1516 BackoffSmoothing model on the test data: 1416.4765224810978
# Perplexity of the 1517 BackoffSmoothing model on the test data: 2061.8224286788245
# Perplexity of the 1518 BackoffSmoothing model on the test data: 1625.1468188425079
# Perplexity of the 1519 BackoffSmoothing model on the test data: 1614.9997907366933
# Perplexity of the 1520 BackoffSmoothing model on the test data: 2148.546142367946
# Perplexity of the 1521 BackoffSmoothing model on the test data: 958.4895121823719
# Perplexity of the 1522 BackoffSmoothing model on the test data: 2268.0481063677526
# Perplexity of the 1523 BackoffSmoothing model on the test data: 1874.0249961381837
# Perplexity of the 1524 BackoffSmoothing model on the test data: 1609.150949553251
# Perplexity of the 1525 BackoffSmoothing model on the test data: 1380.0965951059775
# Perplexity of the 1526 BackoffSmoothing model on the test data: 2598.821489521324
# Perplexity of the 1527 BackoffSmoothing model on the test data: 1945.4868096106936
# Perplexity of the 1528 BackoffSmoothing model on the test data: 1951.387402694689
# Perplexity of the 1529 BackoffSmoothing model on the test data: 850.3808576883791
# Perplexity of the 1530 BackoffSmoothing model on the test data: 1631.8180076326196
# Perplexity of the 1531 BackoffSmoothing model on the test data: 1276.292398238901
# Perplexity of the 1532 BackoffSmoothing model on the test data: 1946.8478253877597
# Perplexity of the 1533 BackoffSmoothing model on the test data: 1899.033963054058
# Perplexity of the 1534 BackoffSmoothing model on the test data: 1170.9662168023413
# Perplexity of the 1535 BackoffSmoothing model on the test data: 1745.2989140583534
# Perplexity of the 1536 BackoffSmoothing model on the test data: 1728.719100036864
# Perplexity of the 1537 BackoffSmoothing model on the test data: 1680.9722567591932
# Perplexity of the 1538 BackoffSmoothing model on the test data: 1503.165453268132
# Perplexity of the 1539 BackoffSmoothing model on the test data: 1288.9143297421324
# Perplexity of the 1540 BackoffSmoothing model on the test data: 1330.0277690576731
# Perplexity of the 1541 BackoffSmoothing model on the test data: 1546.8200976968128
# Perplexity of the 1542 BackoffSmoothing model on the test data: 1944.98553627162
# Perplexity of the 1543 BackoffSmoothing model on the test data: 1297.6160863463597
# Perplexity of the 1544 BackoffSmoothing model on the test data: 1010.8590756233809
# Perplexity of the 1545 BackoffSmoothing model on the test data: 1755.9981739574011
# Perplexity of the 1546 BackoffSmoothing model on the test data: 1205.6995180126792
# Perplexity of the 1547 BackoffSmoothing model on the test data: 1227.9255362278943
# Perplexity of the 1548 BackoffSmoothing model on the test data: 1844.9490754229907
# Perplexity of the 1549 BackoffSmoothing model on the test data: 1021.7815552797215
# Perplexity of the 1550 BackoffSmoothing model on the test data: 3099.1449391162023
# Perplexity of the 1551 BackoffSmoothing model on the test data: 1496.761635140418
# Perplexity of the 1552 BackoffSmoothing model on the test data: 1999.3953312773313
# Perplexity of the 1553 BackoffSmoothing model on the test data: 1927.6859682392799
# Perplexity of the 1554 BackoffSmoothing model on the test data: 1766.3055887407052
# Perplexity of the 1555 BackoffSmoothing model on the test data: 1504.5871738555268
# Perplexity of the 1556 BackoffSmoothing model on the test data: 1981.3661893856483
# Perplexity of the 1557 BackoffSmoothing model on the test data: 984.2668096150951
# Perplexity of the 1558 BackoffSmoothing model on the test data: 1795.6266785565272
# Perplexity of the 1559 BackoffSmoothing model on the test data: 1223.6756833821516
# Perplexity of the 1560 BackoffSmoothing model on the test data: 1410.3122514529784
# Perplexity of the 1561 BackoffSmoothing model on the test data: 3024.810144304694
# Perplexity of the 1562 BackoffSmoothing model on the test data: 1192.9266071981513
# Perplexity of the 1563 BackoffSmoothing model on the test data: 1818.4329356310368
# Perplexity of the 1564 BackoffSmoothing model on the test data: 1228.0991043640533
# Perplexity of the 1565 BackoffSmoothing model on the test data: 898.1988524590287
# Perplexity of the 1566 BackoffSmoothing model on the test data: 1646.3717049735526
# Perplexity of the 1567 BackoffSmoothing model on the test data: 1351.6384768004648
# Perplexity of the 1568 BackoffSmoothing model on the test data: 1652.8187299156086
# Perplexity of the 1569 BackoffSmoothing model on the test data: 1040.6219510911033
# Perplexity of the 1570 BackoffSmoothing model on the test data: 1099.1230323613722
# Perplexity of the 1571 BackoffSmoothing model on the test data: 1755.7266998251043
# Perplexity of the 1572 BackoffSmoothing model on the test data: 1714.3770708303448
# Perplexity of the 1573 BackoffSmoothing model on the test data: 1481.2638809372374
# Perplexity of the 1574 BackoffSmoothing model on the test data: 1336.3455050190958
# Perplexity of the 1575 BackoffSmoothing model on the test data: 1535.768227861535
# Perplexity of the 1576 BackoffSmoothing model on the test data: 1177.4022207089756
# Perplexity of the 1577 BackoffSmoothing model on the test data: 1575.8054006573773
# Perplexity of the 1578 BackoffSmoothing model on the test data: 2021.9624865201642
# Perplexity of the 1579 BackoffSmoothing model on the test data: 1870.563347016704
# Perplexity of the 1580 BackoffSmoothing model on the test data: 1054.2897945089037
# Perplexity of the 1581 BackoffSmoothing model on the test data: 1827.1689056884773
# Perplexity of the 1582 BackoffSmoothing model on the test data: 1762.4486379342836
# Perplexity of the 1583 BackoffSmoothing model on the test data: 1147.9610434310425
# Perplexity of the 1584 BackoffSmoothing model on the test data: 1311.635594881408
# Perplexity of the 1585 BackoffSmoothing model on the test data: 1887.824546178024
# Perplexity of the 1586 BackoffSmoothing model on the test data: 1781.6225283696474
# Perplexity of the 1587 BackoffSmoothing model on the test data: 1197.1747201457372
# Perplexity of the 1588 BackoffSmoothing model on the test data: 1512.7643939606037
# Perplexity of the 1589 BackoffSmoothing model on the test data: 2102.7432053626785
# Perplexity of the 1590 BackoffSmoothing model on the test data: 1047.616736589923
# Perplexity of the 1591 BackoffSmoothing model on the test data: 1713.0340253467193
# Perplexity of the 1592 BackoffSmoothing model on the test data: 1288.725051940232
# Perplexity of the 1593 BackoffSmoothing model on the test data: 1832.1765759342925
# Perplexity of the 1594 BackoffSmoothing model on the test data: 1227.0745972553282
# Perplexity of the 1595 BackoffSmoothing model on the test data: 1390.011648229509
# Perplexity of the 1596 BackoffSmoothing model on the test data: 1359.7590902576155
# Perplexity of the 1597 BackoffSmoothing model on the test data: 1194.6400386301527
# Perplexity of the 1598 BackoffSmoothing model on the test data: 1557.0072027269873
# Perplexity of the 1599 BackoffSmoothing model on the test data: 1576.9711745259076
# Perplexity of the 1600 BackoffSmoothing model on the test data: 2046.4397155888223
# Perplexity of the 1601 BackoffSmoothing model on the test data: 2783.46444636405
# Perplexity of the 1602 BackoffSmoothing model on the test data: 935.3971081638233
# Perplexity of the 1603 BackoffSmoothing model on the test data: 1836.7724025084767
# Perplexity of the 1604 BackoffSmoothing model on the test data: 1750.506675966933
# Perplexity of the 1605 BackoffSmoothing model on the test data: 1104.6288792372638
# Perplexity of the 1606 BackoffSmoothing model on the test data: 1460.7220756199968
# Perplexity of the 1607 BackoffSmoothing model on the test data: 2864.1922571312625
# Perplexity of the 1608 BackoffSmoothing model on the test data: 1281.2698220017653
# Perplexity of the 1609 BackoffSmoothing model on the test data: 1112.493184632054
# Perplexity of the 1610 BackoffSmoothing model on the test data: 1538.7059353495576
# Perplexity of the 1611 BackoffSmoothing model on the test data: 1105.0812380878183
# Perplexity of the 1612 BackoffSmoothing model on the test data: 2027.758307543031
# Perplexity of the 1613 BackoffSmoothing model on the test data: 1204.347315046001
# Perplexity of the 1614 BackoffSmoothing model on the test data: 1962.896162008442
# Perplexity of the 1615 BackoffSmoothing model on the test data: 1436.22486883292
# Perplexity of the 1616 BackoffSmoothing model on the test data: 1398.506745636824
# Perplexity of the 1617 BackoffSmoothing model on the test data: 1439.9509226229814
# Perplexity of the 1618 BackoffSmoothing model on the test data: 1278.709362120298
# Perplexity of the 1619 BackoffSmoothing model on the test data: 1144.3167982199477
# Perplexity of the 1620 BackoffSmoothing model on the test data: 1566.784180955471
# Perplexity of the 1621 BackoffSmoothing model on the test data: 1717.64357462351
# Perplexity of the 1622 BackoffSmoothing model on the test data: 1512.2910482051695
# Perplexity of the 1623 BackoffSmoothing model on the test data: 895.0324522781603
# Perplexity of the 1624 BackoffSmoothing model on the test data: 1887.0175275055176
# Perplexity of the 1625 BackoffSmoothing model on the test data: 1264.698534492408
# Perplexity of the 1626 BackoffSmoothing model on the test data: 1540.2110632538474
# Perplexity of the 1627 BackoffSmoothing model on the test data: 2197.3746819716034
# Perplexity of the 1628 BackoffSmoothing model on the test data: 2849.0321857390836
# Perplexity of the 1629 BackoffSmoothing model on the test data: 1183.2517846829032
# Perplexity of the 1630 BackoffSmoothing model on the test data: 1659.9751493782182
# Perplexity of the 1631 BackoffSmoothing model on the test data: 1436.9893079336957
# Perplexity of the 1632 BackoffSmoothing model on the test data: 1600.4338754825815
# Perplexity of the 1633 BackoffSmoothing model on the test data: 1663.0915097055988
# Perplexity of the 1634 BackoffSmoothing model on the test data: 1694.9900764398278
# Perplexity of the 1635 BackoffSmoothing model on the test data: 1854.4708642450257
# Perplexity of the 1636 BackoffSmoothing model on the test data: 1287.8518812738266
# Perplexity of the 1637 BackoffSmoothing model on the test data: 1293.0578552115064
# Perplexity of the 1638 BackoffSmoothing model on the test data: 1292.6318791819253
# Perplexity of the 1639 BackoffSmoothing model on the test data: 1779.7132979314833
# Perplexity of the 1640 BackoffSmoothing model on the test data: 1235.4793437936235
# Perplexity of the 1641 BackoffSmoothing model on the test data: 2387.7384355379763
# Perplexity of the 1642 BackoffSmoothing model on the test data: 3639.6150622199966
# Perplexity of the 1643 BackoffSmoothing model on the test data: 1066.552102827491

# %%
# bigrams
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(2, 0.1)
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 70.52274693495694
# Perplexity of the 1 BackoffSmoothing model on the test data: 61.055592205520504
# Perplexity of the 2 BackoffSmoothing model on the test data: 59.59813567479229
# Perplexity of the 3 BackoffSmoothing model on the test data: 64.88075571991914
# Perplexity of the 4 BackoffSmoothing model on the test data: 41.28288484089346
# Perplexity of the 5 BackoffSmoothing model on the test data: 43.12513998746346
# Perplexity of the 6 BackoffSmoothing model on the test data: 64.19933289817801
# Perplexity of the 7 BackoffSmoothing model on the test data: 74.61355024708156
# Perplexity of the 8 BackoffSmoothing model on the test data: 79.03624798683738
# Perplexity of the 9 BackoffSmoothing model on the test data: 60.865325616596714
# Perplexity of the 10 BackoffSmoothing model on the test data: 57.74036207957768
# Perplexity of the 11 BackoffSmoothing model on the test data: 56.7466879229338
# Perplexity of the 12 BackoffSmoothing model on the test data: 65.982127394933
# Perplexity of the 13 BackoffSmoothing model on the test data: 45.378312462939284
# Perplexity of the 14 BackoffSmoothing model on the test data: 52.57284279406926
# Perplexity of the 15 BackoffSmoothing model on the test data: 54.16246561777209
# Perplexity of the 16 BackoffSmoothing model on the test data: 61.6816323969256
# Perplexity of the 17 BackoffSmoothing model on the test data: 60.24523413164318
# Perplexity of the 18 BackoffSmoothing model on the test data: 68.99875643044199
# Perplexity of the 19 BackoffSmoothing model on the test data: 52.938751073065426
# Perplexity of the 20 BackoffSmoothing model on the test data: 62.23581415695812
# Perplexity of the 21 BackoffSmoothing model on the test data: 41.27472852361659
# Perplexity of the 22 BackoffSmoothing model on the test data: 39.98850198012501
# Perplexity of the 23 BackoffSmoothing model on the test data: 55.56037345648058
# Perplexity of the 24 BackoffSmoothing model on the test data: 64.04735276496663
# Perplexity of the 25 BackoffSmoothing model on the test data: 48.87357345470111
# Perplexity of the 26 BackoffSmoothing model on the test data: 68.41023423907518
# Perplexity of the 27 BackoffSmoothing model on the test data: 76.58784121010481
# Perplexity of the 28 BackoffSmoothing model on the test data: 55.331582796348016
# Perplexity of the 29 BackoffSmoothing model on the test data: 49.07032768726235
# Perplexity of the 30 BackoffSmoothing model on the test data: 56.35721663204666
# Perplexity of the 31 BackoffSmoothing model on the test data: 48.746339517541486
# Perplexity of the 32 BackoffSmoothing model on the test data: 45.85595764316994
# Perplexity of the 33 BackoffSmoothing model on the test data: 23.05385844206947
# Perplexity of the 34 BackoffSmoothing model on the test data: 51.03493676048779
# Perplexity of the 35 BackoffSmoothing model on the test data: 48.4093812637933
# Perplexity of the 36 BackoffSmoothing model on the test data: 46.84656219782226
# Perplexity of the 37 BackoffSmoothing model on the test data: 49.123329844285394
# Perplexity of the 38 BackoffSmoothing model on the test data: 51.449820567586336
# Perplexity of the 39 BackoffSmoothing model on the test data: 37.893714370772074
# Perplexity of the 40 BackoffSmoothing model on the test data: 54.95628332422352
# Perplexity of the 41 BackoffSmoothing model on the test data: 62.177082464549706
# Perplexity of the 42 BackoffSmoothing model on the test data: 55.10803076066187
# Perplexity of the 43 BackoffSmoothing model on the test data: 62.112525406866396
# Perplexity of the 44 BackoffSmoothing model on the test data: 42.37499830024776
# Perplexity of the 45 BackoffSmoothing model on the test data: 58.828481279986285
# Perplexity of the 46 BackoffSmoothing model on the test data: 59.6387388041543
# Perplexity of the 47 BackoffSmoothing model on the test data: 55.70813257053745
# Perplexity of the 48 BackoffSmoothing model on the test data: 56.77900303106171
# Perplexity of the 49 BackoffSmoothing model on the test data: 61.55108576732381
# Perplexity of the 50 BackoffSmoothing model on the test data: 40.74270654576979
# Perplexity of the 51 BackoffSmoothing model on the test data: 38.217969601129255
# Perplexity of the 52 BackoffSmoothing model on the test data: 58.41691268240758
# Perplexity of the 53 BackoffSmoothing model on the test data: 63.92060105080996
# Perplexity of the 54 BackoffSmoothing model on the test data: 62.60926799081722
# Perplexity of the 55 BackoffSmoothing model on the test data: 54.01777766700359
# Perplexity of the 56 BackoffSmoothing model on the test data: 55.738106397493056
# Perplexity of the 57 BackoffSmoothing model on the test data: 38.167932765962256
# Perplexity of the 58 BackoffSmoothing model on the test data: 58.583829021107825
# Perplexity of the 59 BackoffSmoothing model on the test data: 53.193484758266855
# Perplexity of the 60 BackoffSmoothing model on the test data: 69.73888973244907
# Perplexity of the 61 BackoffSmoothing model on the test data: 56.2064005375033
# Perplexity of the 62 BackoffSmoothing model on the test data: 44.348688046306215
# Perplexity of the 63 BackoffSmoothing model on the test data: 61.99654783235571
# Perplexity of the 64 BackoffSmoothing model on the test data: 66.85154550946943
# Perplexity of the 65 BackoffSmoothing model on the test data: 45.735405833891335
# Perplexity of the 66 BackoffSmoothing model on the test data: 70.06102944955023
# Perplexity of the 67 BackoffSmoothing model on the test data: 45.261843979401625
# Perplexity of the 68 BackoffSmoothing model on the test data: 50.70442879757795
# Perplexity of the 69 BackoffSmoothing model on the test data: 62.97230226370714
# Perplexity of the 70 BackoffSmoothing model on the test data: 39.73800526940595
# Perplexity of the 71 BackoffSmoothing model on the test data: 45.45742952517958
# Perplexity of the 72 BackoffSmoothing model on the test data: 66.88590771742119
# Perplexity of the 73 BackoffSmoothing model on the test data: 63.10057120822506
# Perplexity of the 74 BackoffSmoothing model on the test data: 58.12548499342362
# Perplexity of the 75 BackoffSmoothing model on the test data: 55.19891845380634
# Perplexity of the 76 BackoffSmoothing model on the test data: 49.79954288805388
# Perplexity of the 77 BackoffSmoothing model on the test data: 63.74225580147682
# Perplexity of the 78 BackoffSmoothing model on the test data: 52.38751918661929
# Perplexity of the 79 BackoffSmoothing model on the test data: 30.39485354744812
# Perplexity of the 80 BackoffSmoothing model on the test data: 55.327870956810735
# Perplexity of the 81 BackoffSmoothing model on the test data: 47.10333151877109
# Perplexity of the 82 BackoffSmoothing model on the test data: 48.137561068409745
# Perplexity of the 83 BackoffSmoothing model on the test data: 49.30589227447195
# Perplexity of the 84 BackoffSmoothing model on the test data: 46.035219573720084
# Perplexity of the 85 BackoffSmoothing model on the test data: 42.76152247955512
# Perplexity of the 86 BackoffSmoothing model on the test data: 45.50213565420979
# Perplexity of the 87 BackoffSmoothing model on the test data: 54.330770384158555
# Perplexity of the 88 BackoffSmoothing model on the test data: 47.4497178786899
# Perplexity of the 89 BackoffSmoothing model on the test data: 57.60582247788431
# Perplexity of the 90 BackoffSmoothing model on the test data: 44.13423990297615
# Perplexity of the 91 BackoffSmoothing model on the test data: 58.131818960570456
# Perplexity of the 92 BackoffSmoothing model on the test data: 63.63837623090927
# Perplexity of the 93 BackoffSmoothing model on the test data: 60.27763260063739
# Perplexity of the 94 BackoffSmoothing model on the test data: 57.54584221952709
# Perplexity of the 95 BackoffSmoothing model on the test data: 27.46525039748279
# Perplexity of the 96 BackoffSmoothing model on the test data: 79.00723149284649
# Perplexity of the 97 BackoffSmoothing model on the test data: 59.69403884540635
# Perplexity of the 98 BackoffSmoothing model on the test data: 55.09519804249624
# Perplexity of the 99 BackoffSmoothing model on the test data: 66.88345285933572
# Perplexity of the 100 BackoffSmoothing model on the test data: 61.868692346686
# Perplexity of the 101 BackoffSmoothing model on the test data: 33.65605788432406
# Perplexity of the 102 BackoffSmoothing model on the test data: 61.40471884902977
# Perplexity of the 103 BackoffSmoothing model on the test data: 60.25561322514457
# Perplexity of the 104 BackoffSmoothing model on the test data: 45.76370446067026
# Perplexity of the 105 BackoffSmoothing model on the test data: 57.517218260879446
# Perplexity of the 106 BackoffSmoothing model on the test data: 47.41028628789784
# Perplexity of the 107 BackoffSmoothing model on the test data: 57.29573903996988
# Perplexity of the 108 BackoffSmoothing model on the test data: 47.668696651962144
# Perplexity of the 109 BackoffSmoothing model on the test data: 60.08518655425641
# Perplexity of the 110 BackoffSmoothing model on the test data: 53.85576923873248
# Perplexity of the 111 BackoffSmoothing model on the test data: 42.12820394773191
# Perplexity of the 112 BackoffSmoothing model on the test data: 49.02097843364017
# Perplexity of the 113 BackoffSmoothing model on the test data: 60.70146045959396
# Perplexity of the 114 BackoffSmoothing model on the test data: 55.62851867166145
# Perplexity of the 115 BackoffSmoothing model on the test data: 49.47337430214358
# Perplexity of the 116 BackoffSmoothing model on the test data: 45.18051419004946
# Perplexity of the 117 BackoffSmoothing model on the test data: 43.80812034408343
# Perplexity of the 118 BackoffSmoothing model on the test data: 53.44429012805402
# Perplexity of the 119 BackoffSmoothing model on the test data: 49.881454231033324
# Perplexity of the 120 BackoffSmoothing model on the test data: 61.0884469571007
# Perplexity of the 121 BackoffSmoothing model on the test data: 64.2827839694145
# Perplexity of the 122 BackoffSmoothing model on the test data: 67.72573111986557
# Perplexity of the 123 BackoffSmoothing model on the test data: 49.69251976521479
# Perplexity of the 124 BackoffSmoothing model on the test data: 37.65219201866667
# Perplexity of the 125 BackoffSmoothing model on the test data: 56.51175937272086
# Perplexity of the 126 BackoffSmoothing model on the test data: 54.32337912967622
# Perplexity of the 127 BackoffSmoothing model on the test data: 59.24951355203165
# Perplexity of the 128 BackoffSmoothing model on the test data: 44.27747708017624
# Perplexity of the 129 BackoffSmoothing model on the test data: 51.25668484355752
# Perplexity of the 130 BackoffSmoothing model on the test data: 63.87583551891538
# Perplexity of the 131 BackoffSmoothing model on the test data: 44.65707344530174
# Perplexity of the 132 BackoffSmoothing model on the test data: 60.3551060117842
# Perplexity of the 133 BackoffSmoothing model on the test data: 46.289144039408384
# Perplexity of the 134 BackoffSmoothing model on the test data: 51.99897129444888
# Perplexity of the 135 BackoffSmoothing model on the test data: 63.2954647600028
# Perplexity of the 136 BackoffSmoothing model on the test data: 59.47867639662767
# Perplexity of the 137 BackoffSmoothing model on the test data: 48.189164420375455
# Perplexity of the 138 BackoffSmoothing model on the test data: 55.38184553653349
# Perplexity of the 139 BackoffSmoothing model on the test data: 33.21733182592932
# Perplexity of the 140 BackoffSmoothing model on the test data: 49.95129134738644
# Perplexity of the 141 BackoffSmoothing model on the test data: 68.48709178735372
# Perplexity of the 142 BackoffSmoothing model on the test data: 57.52984271488219
# Perplexity of the 143 BackoffSmoothing model on the test data: 53.684622932026464
# Perplexity of the 144 BackoffSmoothing model on the test data: 58.4643626330834
# Perplexity of the 145 BackoffSmoothing model on the test data: 65.4860153765129
# Perplexity of the 146 BackoffSmoothing model on the test data: 48.00391517729031
# Perplexity of the 147 BackoffSmoothing model on the test data: 67.54851075454613
# Perplexity of the 148 BackoffSmoothing model on the test data: 66.38326644896037
# Perplexity of the 149 BackoffSmoothing model on the test data: 47.58332507131775
# Perplexity of the 150 BackoffSmoothing model on the test data: 70.04627662212702
# Perplexity of the 151 BackoffSmoothing model on the test data: 55.16315366955036
# Perplexity of the 152 BackoffSmoothing model on the test data: 43.91055090549017
# Perplexity of the 153 BackoffSmoothing model on the test data: 57.670321297508494
# Perplexity of the 154 BackoffSmoothing model on the test data: 85.81856501870638
# Perplexity of the 155 BackoffSmoothing model on the test data: 54.18328398476848
# Perplexity of the 156 BackoffSmoothing model on the test data: 49.998789813227965
# Perplexity of the 157 BackoffSmoothing model on the test data: 35.06974107210609
# Perplexity of the 158 BackoffSmoothing model on the test data: 33.83414368286195
# Perplexity of the 159 BackoffSmoothing model on the test data: 63.12795226590211
# Perplexity of the 160 BackoffSmoothing model on the test data: 69.39046872178275
# Perplexity of the 161 BackoffSmoothing model on the test data: 50.59692672725986
# Perplexity of the 162 BackoffSmoothing model on the test data: 59.83810975785557
# Perplexity of the 163 BackoffSmoothing model on the test data: 25.485004946544688
# Perplexity of the 164 BackoffSmoothing model on the test data: 67.91398895807473
# Perplexity of the 165 BackoffSmoothing model on the test data: 60.9055699703657
# Perplexity of the 166 BackoffSmoothing model on the test data: 53.229171907538245
# Perplexity of the 167 BackoffSmoothing model on the test data: 65.01699044678237
# Perplexity of the 168 BackoffSmoothing model on the test data: 49.037702497970855
# Perplexity of the 169 BackoffSmoothing model on the test data: 68.8050395196235
# Perplexity of the 170 BackoffSmoothing model on the test data: 51.07760328806089
# Perplexity of the 171 BackoffSmoothing model on the test data: 70.83917551142143
# Perplexity of the 172 BackoffSmoothing model on the test data: 58.00447481592903
# Perplexity of the 173 BackoffSmoothing model on the test data: 67.28781210966106
# Perplexity of the 174 BackoffSmoothing model on the test data: 51.948203610054726
# Perplexity of the 175 BackoffSmoothing model on the test data: 55.05132508103544
# Perplexity of the 176 BackoffSmoothing model on the test data: 57.2161291329459
# Perplexity of the 177 BackoffSmoothing model on the test data: 65.3571602803366
# Perplexity of the 178 BackoffSmoothing model on the test data: 57.08079966132786
# Perplexity of the 179 BackoffSmoothing model on the test data: 81.44140008172577
# Perplexity of the 180 BackoffSmoothing model on the test data: 46.99615195477189
# Perplexity of the 181 BackoffSmoothing model on the test data: 47.26971897989974
# Perplexity of the 182 BackoffSmoothing model on the test data: 42.27297686631287
# Perplexity of the 183 BackoffSmoothing model on the test data: 81.55450541094164
# Perplexity of the 184 BackoffSmoothing model on the test data: 59.93415186330711
# Perplexity of the 185 BackoffSmoothing model on the test data: 50.75028215188612
# Perplexity of the 186 BackoffSmoothing model on the test data: 56.11273294669337
# Perplexity of the 187 BackoffSmoothing model on the test data: 76.44386763547115
# Perplexity of the 188 BackoffSmoothing model on the test data: 56.46366527202791
# Perplexity of the 189 BackoffSmoothing model on the test data: 65.8701683066977
# Perplexity of the 190 BackoffSmoothing model on the test data: 59.26417565562926
# Perplexity of the 191 BackoffSmoothing model on the test data: 65.15757827737322
# Perplexity of the 192 BackoffSmoothing model on the test data: 53.26937174459796
# Perplexity of the 193 BackoffSmoothing model on the test data: 56.03053452259989
# Perplexity of the 194 BackoffSmoothing model on the test data: 63.237726885799695
# Perplexity of the 195 BackoffSmoothing model on the test data: 55.67872452267452
# Perplexity of the 196 BackoffSmoothing model on the test data: 54.572193165378444
# Perplexity of the 197 BackoffSmoothing model on the test data: 53.27459024261636
# Perplexity of the 198 BackoffSmoothing model on the test data: 43.26459888665018
# Perplexity of the 199 BackoffSmoothing model on the test data: 58.342140134123106
# Perplexity of the 200 BackoffSmoothing model on the test data: 54.98745734365097
# Perplexity of the 201 BackoffSmoothing model on the test data: 70.97065060404995
# Perplexity of the 202 BackoffSmoothing model on the test data: 58.556432129516594
# Perplexity of the 203 BackoffSmoothing model on the test data: 41.94106061682624
# Perplexity of the 204 BackoffSmoothing model on the test data: 68.52842869831552
# Perplexity of the 205 BackoffSmoothing model on the test data: 58.88603533103929
# Perplexity of the 206 BackoffSmoothing model on the test data: 51.001593316564175
# Perplexity of the 207 BackoffSmoothing model on the test data: 55.531377623670146
# Perplexity of the 208 BackoffSmoothing model on the test data: 52.04585197432982
# Perplexity of the 209 BackoffSmoothing model on the test data: 51.57075486395278
# Perplexity of the 210 BackoffSmoothing model on the test data: 62.02365768256046
# Perplexity of the 211 BackoffSmoothing model on the test data: 42.07084723693372
# Perplexity of the 212 BackoffSmoothing model on the test data: 58.358742333671465
# Perplexity of the 213 BackoffSmoothing model on the test data: 50.76808995248779
# Perplexity of the 214 BackoffSmoothing model on the test data: 52.600279982088196
# Perplexity of the 215 BackoffSmoothing model on the test data: 53.00302676732878
# Perplexity of the 216 BackoffSmoothing model on the test data: 73.62235727057578
# Perplexity of the 217 BackoffSmoothing model on the test data: 45.48239841604742
# Perplexity of the 218 BackoffSmoothing model on the test data: 45.342564667065155
# Perplexity of the 219 BackoffSmoothing model on the test data: 56.72879899438592
# Perplexity of the 220 BackoffSmoothing model on the test data: 59.64586376142783
# Perplexity of the 221 BackoffSmoothing model on the test data: 53.40745458230306
# Perplexity of the 222 BackoffSmoothing model on the test data: 41.1121438730932
# Perplexity of the 223 BackoffSmoothing model on the test data: 90.61614859921902
# Perplexity of the 224 BackoffSmoothing model on the test data: 72.63637191770485
# Perplexity of the 225 BackoffSmoothing model on the test data: 70.14200640056343
# Perplexity of the 226 BackoffSmoothing model on the test data: 58.297778209675705
# Perplexity of the 227 BackoffSmoothing model on the test data: 51.72643690368801
# Perplexity of the 228 BackoffSmoothing model on the test data: 51.11776371557754
# Perplexity of the 229 BackoffSmoothing model on the test data: 64.53532892974899
# Perplexity of the 230 BackoffSmoothing model on the test data: 55.144133198479494
# Perplexity of the 231 BackoffSmoothing model on the test data: 58.83486157428767
# Perplexity of the 232 BackoffSmoothing model on the test data: 44.870005833982916
# Perplexity of the 233 BackoffSmoothing model on the test data: 68.74536617535787
# Perplexity of the 234 BackoffSmoothing model on the test data: 74.28539461487237
# Perplexity of the 235 BackoffSmoothing model on the test data: 61.47595926745359
# Perplexity of the 236 BackoffSmoothing model on the test data: 57.99355531467188
# Perplexity of the 237 BackoffSmoothing model on the test data: 57.20856841460631
# Perplexity of the 238 BackoffSmoothing model on the test data: 53.962337938491665
# Perplexity of the 239 BackoffSmoothing model on the test data: 53.193497315831664
# Perplexity of the 240 BackoffSmoothing model on the test data: 61.18641102758249
# Perplexity of the 241 BackoffSmoothing model on the test data: 60.93349244075325
# Perplexity of the 242 BackoffSmoothing model on the test data: 45.818123346795296
# Perplexity of the 243 BackoffSmoothing model on the test data: 37.26333618661764
# Perplexity of the 244 BackoffSmoothing model on the test data: 48.897760754352014
# Perplexity of the 245 BackoffSmoothing model on the test data: 70.13408881625782
# Perplexity of the 246 BackoffSmoothing model on the test data: 70.43545782551868
# Perplexity of the 247 BackoffSmoothing model on the test data: 56.81681508532721
# Perplexity of the 248 BackoffSmoothing model on the test data: 48.79207066762211
# Perplexity of the 249 BackoffSmoothing model on the test data: 49.46410574944768
# Perplexity of the 250 BackoffSmoothing model on the test data: 66.35064755354482
# Perplexity of the 251 BackoffSmoothing model on the test data: 68.50261287493225
# Perplexity of the 252 BackoffSmoothing model on the test data: 57.3491961501488
# Perplexity of the 253 BackoffSmoothing model on the test data: 41.907036410660226
# Perplexity of the 254 BackoffSmoothing model on the test data: 62.92617746571032
# Perplexity of the 255 BackoffSmoothing model on the test data: 63.72886638491988
# Perplexity of the 256 BackoffSmoothing model on the test data: 53.45317522398997
# Perplexity of the 257 BackoffSmoothing model on the test data: 56.42063627767718
# Perplexity of the 258 BackoffSmoothing model on the test data: 51.38636621606166
# Perplexity of the 259 BackoffSmoothing model on the test data: 70.42413182435344
# Perplexity of the 260 BackoffSmoothing model on the test data: 34.391739328253685
# Perplexity of the 261 BackoffSmoothing model on the test data: 50.00885868323478
# Perplexity of the 262 BackoffSmoothing model on the test data: 64.04814748684728
# Perplexity of the 263 BackoffSmoothing model on the test data: 69.53619565124147
# Perplexity of the 264 BackoffSmoothing model on the test data: 61.95530545127247
# Perplexity of the 265 BackoffSmoothing model on the test data: 71.73266749204606
# Perplexity of the 266 BackoffSmoothing model on the test data: 52.881717287772794
# Perplexity of the 267 BackoffSmoothing model on the test data: 39.50619893334771
# Perplexity of the 268 BackoffSmoothing model on the test data: 22.096000476099814
# Perplexity of the 269 BackoffSmoothing model on the test data: 49.937831834346426
# Perplexity of the 270 BackoffSmoothing model on the test data: 59.83232677389135
# Perplexity of the 271 BackoffSmoothing model on the test data: 42.666839545831486
# Perplexity of the 272 BackoffSmoothing model on the test data: 39.729134507294624
# Perplexity of the 273 BackoffSmoothing model on the test data: 46.22603666681609
# Perplexity of the 274 BackoffSmoothing model on the test data: 50.45406263830343
# Perplexity of the 275 BackoffSmoothing model on the test data: 41.21920938221174
# Perplexity of the 276 BackoffSmoothing model on the test data: 53.5169018094682
# Perplexity of the 277 BackoffSmoothing model on the test data: 61.42088974895102
# Perplexity of the 278 BackoffSmoothing model on the test data: 47.173517173381164
# Perplexity of the 279 BackoffSmoothing model on the test data: 49.60564411790652
# Perplexity of the 280 BackoffSmoothing model on the test data: 65.07757326469931
# Perplexity of the 281 BackoffSmoothing model on the test data: 43.29612865051027
# Perplexity of the 282 BackoffSmoothing model on the test data: 48.813541894874575
# Perplexity of the 283 BackoffSmoothing model on the test data: 36.07910560473774
# Perplexity of the 284 BackoffSmoothing model on the test data: 53.6905118550163
# Perplexity of the 285 BackoffSmoothing model on the test data: 63.247251607214906
# Perplexity of the 286 BackoffSmoothing model on the test data: 56.81411990990018
# Perplexity of the 287 BackoffSmoothing model on the test data: 48.29525329479627
# Perplexity of the 288 BackoffSmoothing model on the test data: 43.6123104484856
# Perplexity of the 289 BackoffSmoothing model on the test data: 65.36697042767364
# Perplexity of the 290 BackoffSmoothing model on the test data: 44.22491329759694
# Perplexity of the 291 BackoffSmoothing model on the test data: 41.478629525904374
# Perplexity of the 292 BackoffSmoothing model on the test data: 70.86862481380776
# Perplexity of the 293 BackoffSmoothing model on the test data: 49.29734437500007
# Perplexity of the 294 BackoffSmoothing model on the test data: 37.594713378955085
# Perplexity of the 295 BackoffSmoothing model on the test data: 56.53684891486287
# Perplexity of the 296 BackoffSmoothing model on the test data: 42.48343982064528
# Perplexity of the 297 BackoffSmoothing model on the test data: 45.07052760389081
# Perplexity of the 298 BackoffSmoothing model on the test data: 55.46898176893608
# Perplexity of the 299 BackoffSmoothing model on the test data: 44.26505623999913
# Perplexity of the 300 BackoffSmoothing model on the test data: 59.78862084247398
# Perplexity of the 301 BackoffSmoothing model on the test data: 38.46627747046577
# Perplexity of the 302 BackoffSmoothing model on the test data: 34.90603794326751
# Perplexity of the 303 BackoffSmoothing model on the test data: 62.46946057878409
# Perplexity of the 304 BackoffSmoothing model on the test data: 49.33688892240096
# Perplexity of the 305 BackoffSmoothing model on the test data: 54.728992655423355
# Perplexity of the 306 BackoffSmoothing model on the test data: 66.62240472693452
# Perplexity of the 307 BackoffSmoothing model on the test data: 52.93968867584568
# Perplexity of the 308 BackoffSmoothing model on the test data: 47.566322457438496
# Perplexity of the 309 BackoffSmoothing model on the test data: 63.2448089391905
# Perplexity of the 310 BackoffSmoothing model on the test data: 53.33081036831841
# Perplexity of the 311 BackoffSmoothing model on the test data: 42.85424826472714
# Perplexity of the 312 BackoffSmoothing model on the test data: 47.336830106055
# Perplexity of the 313 BackoffSmoothing model on the test data: 69.8928288569086
# Perplexity of the 314 BackoffSmoothing model on the test data: 33.45357976076053
# Perplexity of the 315 BackoffSmoothing model on the test data: 58.14989456000169
# Perplexity of the 316 BackoffSmoothing model on the test data: 49.55831303769108
# Perplexity of the 317 BackoffSmoothing model on the test data: 43.209287598920426
# Perplexity of the 318 BackoffSmoothing model on the test data: 47.96859448295824
# Perplexity of the 319 BackoffSmoothing model on the test data: 53.77684095029954
# Perplexity of the 320 BackoffSmoothing model on the test data: 59.16558602287194
# Perplexity of the 321 BackoffSmoothing model on the test data: 57.00303556784928
# Perplexity of the 322 BackoffSmoothing model on the test data: 66.27862766420192
# Perplexity of the 323 BackoffSmoothing model on the test data: 63.32680089721005
# Perplexity of the 324 BackoffSmoothing model on the test data: 41.333917987540914
# Perplexity of the 325 BackoffSmoothing model on the test data: 56.15782199136327
# Perplexity of the 326 BackoffSmoothing model on the test data: 40.91646670133813
# Perplexity of the 327 BackoffSmoothing model on the test data: 70.13229912431184
# Perplexity of the 328 BackoffSmoothing model on the test data: 61.097290325003144
# Perplexity of the 329 BackoffSmoothing model on the test data: 38.45726988603588
# Perplexity of the 330 BackoffSmoothing model on the test data: 80.86812694514248
# Perplexity of the 331 BackoffSmoothing model on the test data: 59.738203483213475
# Perplexity of the 332 BackoffSmoothing model on the test data: 59.743571532553965
# Perplexity of the 333 BackoffSmoothing model on the test data: 51.516860651249026
# Perplexity of the 334 BackoffSmoothing model on the test data: 67.4396222157262
# Perplexity of the 335 BackoffSmoothing model on the test data: 61.01839005378044
# Perplexity of the 336 BackoffSmoothing model on the test data: 52.37275998175722
# Perplexity of the 337 BackoffSmoothing model on the test data: 46.05947952864077
# Perplexity of the 338 BackoffSmoothing model on the test data: 48.40726095665072
# Perplexity of the 339 BackoffSmoothing model on the test data: 58.12825792085257
# Perplexity of the 340 BackoffSmoothing model on the test data: 74.4640131158975
# Perplexity of the 341 BackoffSmoothing model on the test data: 89.22749057503114
# Perplexity of the 342 BackoffSmoothing model on the test data: 72.26803776682209
# Perplexity of the 343 BackoffSmoothing model on the test data: 56.434644907356116
# Perplexity of the 344 BackoffSmoothing model on the test data: 61.61948072882777
# Perplexity of the 345 BackoffSmoothing model on the test data: 62.12210778740363
# Perplexity of the 346 BackoffSmoothing model on the test data: 50.329882137886365
# Perplexity of the 347 BackoffSmoothing model on the test data: 68.61538869900252
# Perplexity of the 348 BackoffSmoothing model on the test data: 39.54685441621674
# Perplexity of the 349 BackoffSmoothing model on the test data: 70.61573532337484
# Perplexity of the 350 BackoffSmoothing model on the test data: 63.16243938951669
# Perplexity of the 351 BackoffSmoothing model on the test data: 74.54965929007402
# Perplexity of the 352 BackoffSmoothing model on the test data: 75.78449852614695
# Perplexity of the 353 BackoffSmoothing model on the test data: 43.86055120290349
# Perplexity of the 354 BackoffSmoothing model on the test data: 59.281326749090766
# Perplexity of the 355 BackoffSmoothing model on the test data: 47.90912179885643
# Perplexity of the 356 BackoffSmoothing model on the test data: 69.24763047282822
# Perplexity of the 357 BackoffSmoothing model on the test data: 55.54370375646947
# Perplexity of the 358 BackoffSmoothing model on the test data: 34.84741005794847
# Perplexity of the 359 BackoffSmoothing model on the test data: 42.80783418285223
# Perplexity of the 360 BackoffSmoothing model on the test data: 61.386982831017875
# Perplexity of the 361 BackoffSmoothing model on the test data: 50.71041482938987
# Perplexity of the 362 BackoffSmoothing model on the test data: 60.73028499594681
# Perplexity of the 363 BackoffSmoothing model on the test data: 51.583231407297376
# Perplexity of the 364 BackoffSmoothing model on the test data: 56.28244675384077
# Perplexity of the 365 BackoffSmoothing model on the test data: 65.04724322775985
# Perplexity of the 366 BackoffSmoothing model on the test data: 80.3062801631773
# Perplexity of the 367 BackoffSmoothing model on the test data: 55.372958250222844
# Perplexity of the 368 BackoffSmoothing model on the test data: 59.133075950483715
# Perplexity of the 369 BackoffSmoothing model on the test data: 45.29240605774638
# Perplexity of the 370 BackoffSmoothing model on the test data: 66.90157798344393
# Perplexity of the 371 BackoffSmoothing model on the test data: 60.056127453973794
# Perplexity of the 372 BackoffSmoothing model on the test data: 44.85113892993214
# Perplexity of the 373 BackoffSmoothing model on the test data: 63.00590505216208
# Perplexity of the 374 BackoffSmoothing model on the test data: 63.20606847626394
# Perplexity of the 375 BackoffSmoothing model on the test data: 50.513408268912116
# Perplexity of the 376 BackoffSmoothing model on the test data: 61.29694487033684
# Perplexity of the 377 BackoffSmoothing model on the test data: 54.09907870552255
# Perplexity of the 378 BackoffSmoothing model on the test data: 56.40275870044831
# Perplexity of the 379 BackoffSmoothing model on the test data: 53.969985353427646
# Perplexity of the 380 BackoffSmoothing model on the test data: 54.403059789021015
# Perplexity of the 381 BackoffSmoothing model on the test data: 53.21491362168571
# Perplexity of the 382 BackoffSmoothing model on the test data: 64.71654605031665
# Perplexity of the 383 BackoffSmoothing model on the test data: 34.423472951269375
# Perplexity of the 384 BackoffSmoothing model on the test data: 68.40318498224337
# Perplexity of the 385 BackoffSmoothing model on the test data: 31.670526566112517
# Perplexity of the 386 BackoffSmoothing model on the test data: 68.01847691620407
# Perplexity of the 387 BackoffSmoothing model on the test data: 58.02425380123156
# Perplexity of the 388 BackoffSmoothing model on the test data: 53.15270361992765
# Perplexity of the 389 BackoffSmoothing model on the test data: 53.08558060428087
# Perplexity of the 390 BackoffSmoothing model on the test data: 64.6237853413138
# Perplexity of the 391 BackoffSmoothing model on the test data: 49.38572561005713
# Perplexity of the 392 BackoffSmoothing model on the test data: 46.82632976549472
# Perplexity of the 393 BackoffSmoothing model on the test data: 43.052065391917886
# Perplexity of the 394 BackoffSmoothing model on the test data: 63.04883174284214
# Perplexity of the 395 BackoffSmoothing model on the test data: 55.81982380632202
# Perplexity of the 396 BackoffSmoothing model on the test data: 45.50013373678366
# Perplexity of the 397 BackoffSmoothing model on the test data: 48.26441503980717
# Perplexity of the 398 BackoffSmoothing model on the test data: 58.44398017152695
# Perplexity of the 399 BackoffSmoothing model on the test data: 47.388325982316786
# Perplexity of the 400 BackoffSmoothing model on the test data: 65.43602246275525
# Perplexity of the 401 BackoffSmoothing model on the test data: 54.39149752916228
# Perplexity of the 402 BackoffSmoothing model on the test data: 60.64991447743084
# Perplexity of the 403 BackoffSmoothing model on the test data: 40.10107833794921
# Perplexity of the 404 BackoffSmoothing model on the test data: 60.85703524897459
# Perplexity of the 405 BackoffSmoothing model on the test data: 59.185217815457456
# Perplexity of the 406 BackoffSmoothing model on the test data: 48.07400849987546
# Perplexity of the 407 BackoffSmoothing model on the test data: 67.06382806203281
# Perplexity of the 408 BackoffSmoothing model on the test data: 55.66998628306784
# Perplexity of the 409 BackoffSmoothing model on the test data: 44.64052041293986
# Perplexity of the 410 BackoffSmoothing model on the test data: 52.887441526473054
# Perplexity of the 411 BackoffSmoothing model on the test data: 61.94746936964293
# Perplexity of the 412 BackoffSmoothing model on the test data: 63.70221097706619
# Perplexity of the 413 BackoffSmoothing model on the test data: 54.416787406895054
# Perplexity of the 414 BackoffSmoothing model on the test data: 76.99339054741664
# Perplexity of the 415 BackoffSmoothing model on the test data: 78.81629731695963
# Perplexity of the 416 BackoffSmoothing model on the test data: 54.78228676249239
# Perplexity of the 417 BackoffSmoothing model on the test data: 57.16158643738812
# Perplexity of the 418 BackoffSmoothing model on the test data: 57.12917630326278
# Perplexity of the 419 BackoffSmoothing model on the test data: 72.84781011242035
# Perplexity of the 420 BackoffSmoothing model on the test data: 65.52628478547278
# Perplexity of the 421 BackoffSmoothing model on the test data: 55.36870928052194
# Perplexity of the 422 BackoffSmoothing model on the test data: 46.05444850404224
# Perplexity of the 423 BackoffSmoothing model on the test data: 63.553665059158
# Perplexity of the 424 BackoffSmoothing model on the test data: 61.91700624563252
# Perplexity of the 425 BackoffSmoothing model on the test data: 61.90385477232177
# Perplexity of the 426 BackoffSmoothing model on the test data: 66.39218800680851
# Perplexity of the 427 BackoffSmoothing model on the test data: 54.65981323377259
# Perplexity of the 428 BackoffSmoothing model on the test data: 54.99721565902955
# Perplexity of the 429 BackoffSmoothing model on the test data: 55.872973599658145
# Perplexity of the 430 BackoffSmoothing model on the test data: 49.45434431707307
# Perplexity of the 431 BackoffSmoothing model on the test data: 67.8237629182403
# Perplexity of the 432 BackoffSmoothing model on the test data: 69.89678476533767
# Perplexity of the 433 BackoffSmoothing model on the test data: 38.799893309047434
# Perplexity of the 434 BackoffSmoothing model on the test data: 82.65284296759411
# Perplexity of the 435 BackoffSmoothing model on the test data: 58.63764882597735
# Perplexity of the 436 BackoffSmoothing model on the test data: 73.86369593771828
# Perplexity of the 437 BackoffSmoothing model on the test data: 67.17050545299715
# Perplexity of the 438 BackoffSmoothing model on the test data: 53.494007663265826
# Perplexity of the 439 BackoffSmoothing model on the test data: 45.90184002312507
# Perplexity of the 440 BackoffSmoothing model on the test data: 55.49276395260521
# Perplexity of the 441 BackoffSmoothing model on the test data: 51.722389711157994
# Perplexity of the 442 BackoffSmoothing model on the test data: 60.00092945935609
# Perplexity of the 443 BackoffSmoothing model on the test data: 51.74581646688709
# Perplexity of the 444 BackoffSmoothing model on the test data: 57.32691440837649
# Perplexity of the 445 BackoffSmoothing model on the test data: 72.12017973427152
# Perplexity of the 446 BackoffSmoothing model on the test data: 57.03644890127893
# Perplexity of the 447 BackoffSmoothing model on the test data: 42.955938721135496
# Perplexity of the 448 BackoffSmoothing model on the test data: 48.61638856358168
# Perplexity of the 449 BackoffSmoothing model on the test data: 50.117060271164746
# Perplexity of the 450 BackoffSmoothing model on the test data: 57.08554705854472
# Perplexity of the 451 BackoffSmoothing model on the test data: 50.23108808684416
# Perplexity of the 452 BackoffSmoothing model on the test data: 56.544172412465294
# Perplexity of the 453 BackoffSmoothing model on the test data: 51.71415576977652
# Perplexity of the 454 BackoffSmoothing model on the test data: 67.16614632036077
# Perplexity of the 455 BackoffSmoothing model on the test data: 67.2568947677485
# Perplexity of the 456 BackoffSmoothing model on the test data: 72.75369439866888
# Perplexity of the 457 BackoffSmoothing model on the test data: 51.4503414103419
# Perplexity of the 458 BackoffSmoothing model on the test data: 57.96161014283382
# Perplexity of the 459 BackoffSmoothing model on the test data: 49.43293400202715
# Perplexity of the 460 BackoffSmoothing model on the test data: 60.38612117899199
# Perplexity of the 461 BackoffSmoothing model on the test data: 63.324522608835416
# Perplexity of the 462 BackoffSmoothing model on the test data: 41.0038244073053
# Perplexity of the 463 BackoffSmoothing model on the test data: 64.64707042284482
# Perplexity of the 464 BackoffSmoothing model on the test data: 36.334026527486834
# Perplexity of the 465 BackoffSmoothing model on the test data: 57.696049603987255
# Perplexity of the 466 BackoffSmoothing model on the test data: 61.27414766891421
# Perplexity of the 467 BackoffSmoothing model on the test data: 55.31964507314481
# Perplexity of the 468 BackoffSmoothing model on the test data: 65.42591355953472
# Perplexity of the 469 BackoffSmoothing model on the test data: 39.04985834524638
# Perplexity of the 470 BackoffSmoothing model on the test data: 59.25258805640896
# Perplexity of the 471 BackoffSmoothing model on the test data: 54.45625089464716
# Perplexity of the 472 BackoffSmoothing model on the test data: 39.79703694277855
# Perplexity of the 473 BackoffSmoothing model on the test data: 60.69694148447476
# Perplexity of the 474 BackoffSmoothing model on the test data: 63.95506857698835
# Perplexity of the 475 BackoffSmoothing model on the test data: 49.30037422749731
# Perplexity of the 476 BackoffSmoothing model on the test data: 68.32369849309575
# Perplexity of the 477 BackoffSmoothing model on the test data: 65.62673048015019
# Perplexity of the 478 BackoffSmoothing model on the test data: 68.78042763731547
# Perplexity of the 479 BackoffSmoothing model on the test data: 42.01226775997234
# Perplexity of the 480 BackoffSmoothing model on the test data: 57.07231815010121
# Perplexity of the 481 BackoffSmoothing model on the test data: 41.105821579312334
# Perplexity of the 482 BackoffSmoothing model on the test data: 58.91393215698759
# Perplexity of the 483 BackoffSmoothing model on the test data: 53.01489312648911
# Perplexity of the 484 BackoffSmoothing model on the test data: 68.48515536115409
# Perplexity of the 485 BackoffSmoothing model on the test data: 56.866155764392644
# Perplexity of the 486 BackoffSmoothing model on the test data: 58.28546255744025
# Perplexity of the 487 BackoffSmoothing model on the test data: 57.10608860193559
# Perplexity of the 488 BackoffSmoothing model on the test data: 47.955542552123774
# Perplexity of the 489 BackoffSmoothing model on the test data: 50.28407143748529
# Perplexity of the 490 BackoffSmoothing model on the test data: 45.82862854781554
# Perplexity of the 491 BackoffSmoothing model on the test data: 53.93472935886061
# Perplexity of the 492 BackoffSmoothing model on the test data: 48.568308032380514
# Perplexity of the 493 BackoffSmoothing model on the test data: 49.42322950805288
# Perplexity of the 494 BackoffSmoothing model on the test data: 60.025955904955055
# Perplexity of the 495 BackoffSmoothing model on the test data: 51.44688728501817
# Perplexity of the 496 BackoffSmoothing model on the test data: 54.01431117701374
# Perplexity of the 497 BackoffSmoothing model on the test data: 53.312390937093774
# Perplexity of the 498 BackoffSmoothing model on the test data: 73.39048748126103
# Perplexity of the 499 BackoffSmoothing model on the test data: 60.90801165081978
# Perplexity of the 500 BackoffSmoothing model on the test data: 72.39232616269317
# Perplexity of the 501 BackoffSmoothing model on the test data: 64.05808139336717
# Perplexity of the 502 BackoffSmoothing model on the test data: 64.35951974391493
# Perplexity of the 503 BackoffSmoothing model on the test data: 49.95028407356926
# Perplexity of the 504 BackoffSmoothing model on the test data: 40.046988984074154
# Perplexity of the 505 BackoffSmoothing model on the test data: 59.857387209694025
# Perplexity of the 506 BackoffSmoothing model on the test data: 60.589678519872585
# Perplexity of the 507 BackoffSmoothing model on the test data: 50.245431914287536
# Perplexity of the 508 BackoffSmoothing model on the test data: 66.68087830051967
# Perplexity of the 509 BackoffSmoothing model on the test data: 55.04618053245709
# Perplexity of the 510 BackoffSmoothing model on the test data: 51.8441420587259
# Perplexity of the 511 BackoffSmoothing model on the test data: 49.84992492629368
# Perplexity of the 512 BackoffSmoothing model on the test data: 70.93318500174645
# Perplexity of the 513 BackoffSmoothing model on the test data: 73.48115169347449
# Perplexity of the 514 BackoffSmoothing model on the test data: 51.85594330719301
# Perplexity of the 515 BackoffSmoothing model on the test data: 53.003039587091635
# Perplexity of the 516 BackoffSmoothing model on the test data: 49.000704078134596
# Perplexity of the 517 BackoffSmoothing model on the test data: 47.41109803372936
# Perplexity of the 518 BackoffSmoothing model on the test data: 58.11127581584686
# Perplexity of the 519 BackoffSmoothing model on the test data: 49.84363686356111
# Perplexity of the 520 BackoffSmoothing model on the test data: 75.1270458199897
# Perplexity of the 521 BackoffSmoothing model on the test data: 53.03632104225492
# Perplexity of the 522 BackoffSmoothing model on the test data: 49.24728514439783
# Perplexity of the 523 BackoffSmoothing model on the test data: 60.3040005223622
# Perplexity of the 524 BackoffSmoothing model on the test data: 49.20304645954624
# Perplexity of the 525 BackoffSmoothing model on the test data: 78.68518838469505
# Perplexity of the 526 BackoffSmoothing model on the test data: 51.76708957738594
# Perplexity of the 527 BackoffSmoothing model on the test data: 67.91126221699042
# Perplexity of the 528 BackoffSmoothing model on the test data: 49.365341750376956
# Perplexity of the 529 BackoffSmoothing model on the test data: 65.43144990703308
# Perplexity of the 530 BackoffSmoothing model on the test data: 53.7946569093687
# Perplexity of the 531 BackoffSmoothing model on the test data: 57.51587260255565
# Perplexity of the 532 BackoffSmoothing model on the test data: 55.27572544255738
# Perplexity of the 533 BackoffSmoothing model on the test data: 77.20630640458904
# Perplexity of the 534 BackoffSmoothing model on the test data: 41.376386703852816
# Perplexity of the 535 BackoffSmoothing model on the test data: 77.39406981910638
# Perplexity of the 536 BackoffSmoothing model on the test data: 75.07922657591388
# Perplexity of the 537 BackoffSmoothing model on the test data: 49.8895113831022
# Perplexity of the 538 BackoffSmoothing model on the test data: 54.62300566918825
# Perplexity of the 539 BackoffSmoothing model on the test data: 40.51505350580844
# Perplexity of the 540 BackoffSmoothing model on the test data: 63.54624293339864
# Perplexity of the 541 BackoffSmoothing model on the test data: 47.0829634716526
# Perplexity of the 542 BackoffSmoothing model on the test data: 75.70756332054377
# Perplexity of the 543 BackoffSmoothing model on the test data: 86.8604059351027
# Perplexity of the 544 BackoffSmoothing model on the test data: 58.691461349320534
# Perplexity of the 545 BackoffSmoothing model on the test data: 41.56343354323928
# Perplexity of the 546 BackoffSmoothing model on the test data: 61.85936445556576
# Perplexity of the 547 BackoffSmoothing model on the test data: 34.529861211943995
# Perplexity of the 548 BackoffSmoothing model on the test data: 60.10602481930391
# Perplexity of the 549 BackoffSmoothing model on the test data: 55.02617604307093
# Perplexity of the 550 BackoffSmoothing model on the test data: 56.83404654743167
# Perplexity of the 551 BackoffSmoothing model on the test data: 59.018192879134304
# Perplexity of the 552 BackoffSmoothing model on the test data: 41.99901277140415
# Perplexity of the 553 BackoffSmoothing model on the test data: 48.82549808005486
# Perplexity of the 554 BackoffSmoothing model on the test data: 45.1881864392321
# Perplexity of the 555 BackoffSmoothing model on the test data: 61.5641321953826
# Perplexity of the 556 BackoffSmoothing model on the test data: 59.78364371078772
# Perplexity of the 557 BackoffSmoothing model on the test data: 65.46492829178786
# Perplexity of the 558 BackoffSmoothing model on the test data: 56.80937510181843
# Perplexity of the 559 BackoffSmoothing model on the test data: 76.88689914186638
# Perplexity of the 560 BackoffSmoothing model on the test data: 53.074868476600514
# Perplexity of the 561 BackoffSmoothing model on the test data: 59.92395710688361
# Perplexity of the 562 BackoffSmoothing model on the test data: 56.164029512473995
# Perplexity of the 563 BackoffSmoothing model on the test data: 46.28581419481823
# Perplexity of the 564 BackoffSmoothing model on the test data: 47.9523357400627
# Perplexity of the 565 BackoffSmoothing model on the test data: 52.719201327679365
# Perplexity of the 566 BackoffSmoothing model on the test data: 47.295772541095836
# Perplexity of the 567 BackoffSmoothing model on the test data: 62.48672423471885
# Perplexity of the 568 BackoffSmoothing model on the test data: 84.40063709509243
# Perplexity of the 569 BackoffSmoothing model on the test data: 46.03896357781543
# Perplexity of the 570 BackoffSmoothing model on the test data: 56.31245442008301
# Perplexity of the 571 BackoffSmoothing model on the test data: 65.25686138627648
# Perplexity of the 572 BackoffSmoothing model on the test data: 37.298747263102754
# Perplexity of the 573 BackoffSmoothing model on the test data: 34.70135059872984
# Perplexity of the 574 BackoffSmoothing model on the test data: 54.46142693971305
# Perplexity of the 575 BackoffSmoothing model on the test data: 59.07569206550043
# Perplexity of the 576 BackoffSmoothing model on the test data: 50.43865414754865
# Perplexity of the 577 BackoffSmoothing model on the test data: 49.399619752882366
# Perplexity of the 578 BackoffSmoothing model on the test data: 46.773863736484834
# Perplexity of the 579 BackoffSmoothing model on the test data: 45.697806577225265
# Perplexity of the 580 BackoffSmoothing model on the test data: 49.23089605920681
# Perplexity of the 581 BackoffSmoothing model on the test data: 76.25213679006032
# Perplexity of the 582 BackoffSmoothing model on the test data: 44.257685692376505
# Perplexity of the 583 BackoffSmoothing model on the test data: 66.63215246969327
# Perplexity of the 584 BackoffSmoothing model on the test data: 54.465214425449695
# Perplexity of the 585 BackoffSmoothing model on the test data: 44.59565949549201
# Perplexity of the 586 BackoffSmoothing model on the test data: 53.234488213991995
# Perplexity of the 587 BackoffSmoothing model on the test data: 49.90953771566246
# Perplexity of the 588 BackoffSmoothing model on the test data: 47.43825484658541
# Perplexity of the 589 BackoffSmoothing model on the test data: 59.18098293041149
# Perplexity of the 590 BackoffSmoothing model on the test data: 49.183515911491796
# Perplexity of the 591 BackoffSmoothing model on the test data: 64.66477711470749
# ...
# Perplexity of the 1450 BackoffSmoothing model on the test data: 72.24345967732148
# Perplexity of the 1451 BackoffSmoothing model on the test data: 70.8574176905979
# Perplexity of the 1452 BackoffSmoothing model on the test data: 61.05962507030186
# Perplexity of the 1453 BackoffSmoothing model on the test data: 62.766979759037106
# Perplexity of the 1454 BackoffSmoothing model on the test data: 37.70862656837252
# Perplexity of the 1455 BackoffSmoothing model on the test data: 47.240304582631815
# Perplexity of the 1456 BackoffSmoothing model on the test data: 60.84748556879617
# Perplexity of the 1457 BackoffSmoothing model on the test data: 39.7226123147593
# Perplexity of the 1458 BackoffSmoothing model on the test data: 65.78076239146668
# Perplexity of the 1459 BackoffSmoothing model on the test data: 57.40522526017728
# Perplexity of the 1460 BackoffSmoothing model on the test data: 52.97698496917912
# Perplexity of the 1461 BackoffSmoothing model on the test data: 62.99566638118038
# Perplexity of the 1462 BackoffSmoothing model on the test data: 65.29375444055557
# Perplexity of the 1463 BackoffSmoothing model on the test data: 52.78762263929871
# Perplexity of the 1464 BackoffSmoothing model on the test data: 51.19259638476524
# Perplexity of the 1465 BackoffSmoothing model on the test data: 73.82378759833587
# Perplexity of the 1466 BackoffSmoothing model on the test data: 15.992011403158989
# Perplexity of the 1467 BackoffSmoothing model on the test data: 52.587019969127745
# Perplexity of the 1468 BackoffSmoothing model on the test data: 49.92859742431807
# Perplexity of the 1469 BackoffSmoothing model on the test data: 55.904257817862835
# Perplexity of the 1470 BackoffSmoothing model on the test data: 73.32652491960134
# Perplexity of the 1471 BackoffSmoothing model on the test data: 72.98942556212776
# Perplexity of the 1472 BackoffSmoothing model on the test data: 42.61684374061062
# Perplexity of the 1473 BackoffSmoothing model on the test data: 58.790866011249356
# Perplexity of the 1474 BackoffSmoothing model on the test data: 35.44337935536029
# Perplexity of the 1475 BackoffSmoothing model on the test data: 53.710293053866465
# Perplexity of the 1476 BackoffSmoothing model on the test data: 46.52162602920262
# Perplexity of the 1477 BackoffSmoothing model on the test data: 56.03949471494624
# Perplexity of the 1478 BackoffSmoothing model on the test data: 56.258634522374386
# Perplexity of the 1479 BackoffSmoothing model on the test data: 59.38071062642179
# Perplexity of the 1480 BackoffSmoothing model on the test data: 50.21018037383487
# Perplexity of the 1481 BackoffSmoothing model on the test data: 66.06350630900695
# Perplexity of the 1482 BackoffSmoothing model on the test data: 72.516431886915
# Perplexity of the 1483 BackoffSmoothing model on the test data: 84.1722090594826
# Perplexity of the 1484 BackoffSmoothing model on the test data: 46.198396666129085
# Perplexity of the 1485 BackoffSmoothing model on the test data: 62.987650641169544
# Perplexity of the 1486 BackoffSmoothing model on the test data: 55.94895389445681
# Perplexity of the 1487 BackoffSmoothing model on the test data: 69.24140740197453
# Perplexity of the 1488 BackoffSmoothing model on the test data: 48.83911908436073
# Perplexity of the 1489 BackoffSmoothing model on the test data: 61.39640468647907
# Perplexity of the 1490 BackoffSmoothing model on the test data: 80.39349071876654
# Perplexity of the 1491 BackoffSmoothing model on the test data: 74.18456292604358
# Perplexity of the 1492 BackoffSmoothing model on the test data: 52.99863948324692
# Perplexity of the 1493 BackoffSmoothing model on the test data: 44.907415627197814
# Perplexity of the 1494 BackoffSmoothing model on the test data: 43.051141167599745
# Perplexity of the 1495 BackoffSmoothing model on the test data: 56.97923426997757
# Perplexity of the 1496 BackoffSmoothing model on the test data: 94.06828724342488
# Perplexity of the 1497 BackoffSmoothing model on the test data: 58.705706477642664
# Perplexity of the 1498 BackoffSmoothing model on the test data: 51.00040621047141
# Perplexity of the 1499 BackoffSmoothing model on the test data: 48.23555220918505
# Perplexity of the 1500 BackoffSmoothing model on the test data: 72.79176473513525
# Perplexity of the 1501 BackoffSmoothing model on the test data: 34.75024464599941
# Perplexity of the 1502 BackoffSmoothing model on the test data: 51.508655455412786
# Perplexity of the 1503 BackoffSmoothing model on the test data: 52.426853951689715
# Perplexity of the 1504 BackoffSmoothing model on the test data: 43.86373832172213
# Perplexity of the 1505 BackoffSmoothing model on the test data: 53.31401326779261
# Perplexity of the 1506 BackoffSmoothing model on the test data: 56.73903704151654
# Perplexity of the 1507 BackoffSmoothing model on the test data: 54.21432725152012
# Perplexity of the 1508 BackoffSmoothing model on the test data: 70.77499894234725
# Perplexity of the 1509 BackoffSmoothing model on the test data: 38.22345904752303
# Perplexity of the 1510 BackoffSmoothing model on the test data: 67.79259636326235
# Perplexity of the 1511 BackoffSmoothing model on the test data: 55.288514183581775
# Perplexity of the 1512 BackoffSmoothing model on the test data: 66.10930849308582
# Perplexity of the 1513 BackoffSmoothing model on the test data: 65.5924488498866
# Perplexity of the 1514 BackoffSmoothing model on the test data: 55.715237815205555
# Perplexity of the 1515 BackoffSmoothing model on the test data: 57.31166165368268
# Perplexity of the 1516 BackoffSmoothing model on the test data: 98.89109929138414
# Perplexity of the 1517 BackoffSmoothing model on the test data: 56.04931158669627
# Perplexity of the 1518 BackoffSmoothing model on the test data: 53.16146530053218
# Perplexity of the 1519 BackoffSmoothing model on the test data: 41.44081213096592
# Perplexity of the 1520 BackoffSmoothing model on the test data: 83.96259560627398
# Perplexity of the 1521 BackoffSmoothing model on the test data: 58.44824505928694
# Perplexity of the 1522 BackoffSmoothing model on the test data: 52.71978300396872
# Perplexity of the 1523 BackoffSmoothing model on the test data: 37.74132533862581
# Perplexity of the 1524 BackoffSmoothing model on the test data: 53.020484741455235
# Perplexity of the 1525 BackoffSmoothing model on the test data: 45.330006174005135
# Perplexity of the 1526 BackoffSmoothing model on the test data: 39.202159327537295
# Perplexity of the 1527 BackoffSmoothing model on the test data: 88.39700352077602
# Perplexity of the 1528 BackoffSmoothing model on the test data: 49.046203885729184
# Perplexity of the 1529 BackoffSmoothing model on the test data: 65.27478166809145
# Perplexity of the 1530 BackoffSmoothing model on the test data: 50.324839202561954
# Perplexity of the 1531 BackoffSmoothing model on the test data: 23.503471233253965
# Perplexity of the 1532 BackoffSmoothing model on the test data: 50.786967808730154
# Perplexity of the 1533 BackoffSmoothing model on the test data: 55.145930674494025
# Perplexity of the 1534 BackoffSmoothing model on the test data: 44.23891574321058
# Perplexity of the 1535 BackoffSmoothing model on the test data: 40.255805728154975
# Perplexity of the 1536 BackoffSmoothing model on the test data: 40.724083214433186
# Perplexity of the 1537 BackoffSmoothing model on the test data: 54.27123336799208
# Perplexity of the 1538 BackoffSmoothing model on the test data: 53.41080019687884
# Perplexity of the 1539 BackoffSmoothing model on the test data: 62.07783276924681
# Perplexity of the 1540 BackoffSmoothing model on the test data: 73.74785082185066
# Perplexity of the 1541 BackoffSmoothing model on the test data: 54.84611676695012
# Perplexity of the 1542 BackoffSmoothing model on the test data: 53.92588636407307
# Perplexity of the 1543 BackoffSmoothing model on the test data: 53.03252885070095
# Perplexity of the 1544 BackoffSmoothing model on the test data: 30.67701510717888
# Perplexity of the 1545 BackoffSmoothing model on the test data: 62.884123840079276
# Perplexity of the 1546 BackoffSmoothing model on the test data: 41.421721256787336
# Perplexity of the 1547 BackoffSmoothing model on the test data: 68.8603481969264
# Perplexity of the 1548 BackoffSmoothing model on the test data: 79.13115005378636
# Perplexity of the 1549 BackoffSmoothing model on the test data: 61.27205089014853
# Perplexity of the 1550 BackoffSmoothing model on the test data: 46.149941382234054
# Perplexity of the 1551 BackoffSmoothing model on the test data: 64.90472439422909
# Perplexity of the 1552 BackoffSmoothing model on the test data: 51.97709869186223
# Perplexity of the 1553 BackoffSmoothing model on the test data: 46.64936817760684
# Perplexity of the 1554 BackoffSmoothing model on the test data: 54.4380176683505
# Perplexity of the 1555 BackoffSmoothing model on the test data: 43.56621744278659
# Perplexity of the 1556 BackoffSmoothing model on the test data: 43.28132577910004
# Perplexity of the 1557 BackoffSmoothing model on the test data: 74.9705890814802
# Perplexity of the 1558 BackoffSmoothing model on the test data: 59.42781881619739
# Perplexity of the 1559 BackoffSmoothing model on the test data: 47.16769152788032
# Perplexity of the 1560 BackoffSmoothing model on the test data: 59.810721257340795
# Perplexity of the 1561 BackoffSmoothing model on the test data: 38.21510727825048
# Perplexity of the 1562 BackoffSmoothing model on the test data: 51.11493196748528
# Perplexity of the 1563 BackoffSmoothing model on the test data: 55.2569364177612
# Perplexity of the 1564 BackoffSmoothing model on the test data: 58.985497350109014
# Perplexity of the 1565 BackoffSmoothing model on the test data: 69.6124875248409
# Perplexity of the 1566 BackoffSmoothing model on the test data: 56.556558253309504
# Perplexity of the 1567 BackoffSmoothing model on the test data: 82.27279020086182
# Perplexity of the 1568 BackoffSmoothing model on the test data: 45.352220174957395
# Perplexity of the 1569 BackoffSmoothing model on the test data: 64.6634512914176
# Perplexity of the 1570 BackoffSmoothing model on the test data: 48.33720365431305
# Perplexity of the 1571 BackoffSmoothing model on the test data: 39.819816561998
# Perplexity of the 1572 BackoffSmoothing model on the test data: 66.56180882851086
# Perplexity of the 1573 BackoffSmoothing model on the test data: 46.010391516426175
# Perplexity of the 1574 BackoffSmoothing model on the test data: 50.46539674394218
# Perplexity of the 1575 BackoffSmoothing model on the test data: 57.07756509747615
# Perplexity of the 1576 BackoffSmoothing model on the test data: 37.340454950893175
# Perplexity of the 1577 BackoffSmoothing model on the test data: 57.05839971139376
# Perplexity of the 1578 BackoffSmoothing model on the test data: 62.44316688394032
# Perplexity of the 1579 BackoffSmoothing model on the test data: 56.43427155904335
# Perplexity of the 1580 BackoffSmoothing model on the test data: 60.7826365449246
# Perplexity of the 1581 BackoffSmoothing model on the test data: 56.523034833881155
# Perplexity of the 1582 BackoffSmoothing model on the test data: 59.45260897357241
# Perplexity of the 1583 BackoffSmoothing model on the test data: 44.48367607193249
# Perplexity of the 1584 BackoffSmoothing model on the test data: 60.831132461903515
# Perplexity of the 1585 BackoffSmoothing model on the test data: 57.477501998297285
# Perplexity of the 1586 BackoffSmoothing model on the test data: 69.7241399705039
# Perplexity of the 1587 BackoffSmoothing model on the test data: 60.30026441983232
# Perplexity of the 1588 BackoffSmoothing model on the test data: 39.49453311476938
# Perplexity of the 1589 BackoffSmoothing model on the test data: 51.73748693213132
# Perplexity of the 1590 BackoffSmoothing model on the test data: 56.65559695232909
# Perplexity of the 1591 BackoffSmoothing model on the test data: 61.09617361729683
# Perplexity of the 1592 BackoffSmoothing model on the test data: 62.32519006448351
# Perplexity of the 1593 BackoffSmoothing model on the test data: 49.08827705780471
# Perplexity of the 1594 BackoffSmoothing model on the test data: 41.34695076679746
# Perplexity of the 1595 BackoffSmoothing model on the test data: 54.60057406103147
# Perplexity of the 1596 BackoffSmoothing model on the test data: 79.43344848560437
# Perplexity of the 1597 BackoffSmoothing model on the test data: 51.81187032433253
# Perplexity of the 1598 BackoffSmoothing model on the test data: 54.95079225646594
# Perplexity of the 1599 BackoffSmoothing model on the test data: 72.37693689181518
# Perplexity of the 1600 BackoffSmoothing model on the test data: 78.34178299770059
# Perplexity of the 1601 BackoffSmoothing model on the test data: 39.28703427442751
# Perplexity of the 1602 BackoffSmoothing model on the test data: 48.030289074191344
# Perplexity of the 1603 BackoffSmoothing model on the test data: 67.08364972852523
# Perplexity of the 1604 BackoffSmoothing model on the test data: 64.5626282359088
# Perplexity of the 1605 BackoffSmoothing model on the test data: 54.4227377266731
# Perplexity of the 1606 BackoffSmoothing model on the test data: 48.12443819369667
# Perplexity of the 1607 BackoffSmoothing model on the test data: 53.42894790787076
# Perplexity of the 1608 BackoffSmoothing model on the test data: 58.45011930867128
# Perplexity of the 1609 BackoffSmoothing model on the test data: 54.963023978738605
# Perplexity of the 1610 BackoffSmoothing model on the test data: 74.53706350506947
# Perplexity of the 1611 BackoffSmoothing model on the test data: 76.22341702248352
# Perplexity of the 1612 BackoffSmoothing model on the test data: 62.3964367849353
# Perplexity of the 1613 BackoffSmoothing model on the test data: 73.02660287265397
# Perplexity of the 1614 BackoffSmoothing model on the test data: 69.17479950964187
# Perplexity of the 1615 BackoffSmoothing model on the test data: 44.64863696295919
# Perplexity of the 1616 BackoffSmoothing model on the test data: 36.712310762228455
# Perplexity of the 1617 BackoffSmoothing model on the test data: 60.042591801213376
# Perplexity of the 1618 BackoffSmoothing model on the test data: 58.45989501886009
# Perplexity of the 1619 BackoffSmoothing model on the test data: 51.20719769300728
# Perplexity of the 1620 BackoffSmoothing model on the test data: 64.4702431144634
# Perplexity of the 1621 BackoffSmoothing model on the test data: 68.72591786649802
# Perplexity of the 1622 BackoffSmoothing model on the test data: 44.237507774249956
# Perplexity of the 1623 BackoffSmoothing model on the test data: 61.118500006636104
# Perplexity of the 1624 BackoffSmoothing model on the test data: 53.85212511938602
# Perplexity of the 1625 BackoffSmoothing model on the test data: 55.49681051716332
# Perplexity of the 1626 BackoffSmoothing model on the test data: 54.92905800522387
# Perplexity of the 1627 BackoffSmoothing model on the test data: 59.16802786768685
# Perplexity of the 1628 BackoffSmoothing model on the test data: 43.94221838412237
# Perplexity of the 1629 BackoffSmoothing model on the test data: 56.141104723992
# Perplexity of the 1630 BackoffSmoothing model on the test data: 42.9834578884768
# Perplexity of the 1631 BackoffSmoothing model on the test data: 46.545220206917314
# Perplexity of the 1632 BackoffSmoothing model on the test data: 55.00547145827366
# Perplexity of the 1633 BackoffSmoothing model on the test data: 62.0005292237633
# Perplexity of the 1634 BackoffSmoothing model on the test data: 55.97499210535065
# Perplexity of the 1635 BackoffSmoothing model on the test data: 49.80043260603905
# Perplexity of the 1636 BackoffSmoothing model on the test data: 50.989681158745704
# Perplexity of the 1637 BackoffSmoothing model on the test data: 39.52420223976061
# Perplexity of the 1638 BackoffSmoothing model on the test data: 61.20852671430907
# Perplexity of the 1639 BackoffSmoothing model on the test data: 85.57248393963096
# Perplexity of the 1640 BackoffSmoothing model on the test data: 68.27408186582947
# Perplexity of the 1641 BackoffSmoothing model on the test data: 76.74241371768042
# Perplexity of the 1642 BackoffSmoothing model on the test data: 30.548339525233217
# Perplexity of the 1643 BackoffSmoothing model on the test data: 65.21304679393566

# %%
# trigrams
# Train the model with BackoffSmoothing
backoff_model = BackoffSmoothing(3, 0.1)
for tokens in train['content']:
    backoff_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
perplexity_dict = {}
for p_bg in background_prob:
    backoff_model.p_bg = p_bg
    perplexity_dict[p_bg] = backoff_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg = min(perplexity_dict, key=perplexity_dict.get)
backoff_model.p_bg = best_p_bg
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} BackoffSmoothing model on the test data: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the 0 BackoffSmoothing model on the test data: 10.880632421725235
# Perplexity of the 1 BackoffSmoothing model on the test data: 10.006412596405259
# Perplexity of the 2 BackoffSmoothing model on the test data: 11.21840991612558
# Perplexity of the 3 BackoffSmoothing model on the test data: 10.476501005077056
# Perplexity of the 4 BackoffSmoothing model on the test data: 10.601222209853903
# Perplexity of the 5 BackoffSmoothing model on the test data: 10.200645017261365
# Perplexity of the 6 BackoffSmoothing model on the test data: 11.502393347782105
# Perplexity of the 7 BackoffSmoothing model on the test data: 11.304426592886166
# Perplexity of the 8 BackoffSmoothing model on the test data: 9.942346051600575
# Perplexity of the 9 BackoffSmoothing model on the test data: 11.411867085472283
# Perplexity of the 10 BackoffSmoothing model on the test data: 11.632169855998821
# Perplexity of the 11 BackoffSmoothing model on the test data: 7.273376412911166
# Perplexity of the 12 BackoffSmoothing model on the test data: 11.565581775835636
# Perplexity of the 13 BackoffSmoothing model on the test data: 7.86264857972286
# Perplexity of the 14 BackoffSmoothing model on the test data: 10.263010077013728
# Perplexity of the 15 BackoffSmoothing model on the test data: 14.015757562486836
# Perplexity of the 16 BackoffSmoothing model on the test data: 10.317028566791027
# Perplexity of the 17 BackoffSmoothing model on the test data: 12.640975235720134
# Perplexity of the 18 BackoffSmoothing model on the test data: 12.941883343626861
# Perplexity of the 19 BackoffSmoothing model on the test data: 10.88151847988458
# Perplexity of the 20 BackoffSmoothing model on the test data: 10.711057889675262
# Perplexity of the 21 BackoffSmoothing model on the test data: 9.159162670507257
# Perplexity of the 22 BackoffSmoothing model on the test data: 9.688718650064168
# Perplexity of the 23 BackoffSmoothing model on the test data: 8.856490503090873
# Perplexity of the 24 BackoffSmoothing model on the test data: 9.285532478995119
# Perplexity of the 25 BackoffSmoothing model on the test data: 10.538307473959918
# Perplexity of the 26 BackoffSmoothing model on the test data: 12.79648398126388
# Perplexity of the 27 BackoffSmoothing model on the test data: 12.108586732543246
# Perplexity of the 28 BackoffSmoothing model on the test data: 10.435179602079561
# Perplexity of the 29 BackoffSmoothing model on the test data: 10.055842372579255
# Perplexity of the 30 BackoffSmoothing model on the test data: 9.637639144887622
# Perplexity of the 31 BackoffSmoothing model on the test data: 10.20185922343042
# Perplexity of the 32 BackoffSmoothing model on the test data: 10.94264950129984
# Perplexity of the 33 BackoffSmoothing model on the test data: 10.082448574992206
# Perplexity of the 34 BackoffSmoothing model on the test data: 11.2270316364675
# Perplexity of the 35 BackoffSmoothing model on the test data: 12.466079114515267
# Perplexity of the 36 BackoffSmoothing model on the test data: 9.219852792011789
# Perplexity of the 37 BackoffSmoothing model on the test data: 11.111189961738186
# Perplexity of the 38 BackoffSmoothing model on the test data: 10.581185785790057
# Perplexity of the 39 BackoffSmoothing model on the test data: 9.778680767747716
# Perplexity of the 40 BackoffSmoothing model on the test data: 11.983939185422093
# Perplexity of the 41 BackoffSmoothing model on the test data: 10.729151576328169
# Perplexity of the 42 BackoffSmoothing model on the test data: 9.136841112333016
# Perplexity of the 43 BackoffSmoothing model on the test data: 11.546728340772002
# Perplexity of the 44 BackoffSmoothing model on the test data: 8.926610290831277
# Perplexity of the 45 BackoffSmoothing model on the test data: 10.61579319307758
# Perplexity of the 46 BackoffSmoothing model on the test data: 9.743475755771136
# Perplexity of the 47 BackoffSmoothing model on the test data: 12.462960131897741
# Perplexity of the 48 BackoffSmoothing model on the test data: 11.622513431551113
# Perplexity of the 49 BackoffSmoothing model on the test data: 12.388424595456216
# Perplexity of the 50 BackoffSmoothing model on the test data: 8.813589138208684
# Perplexity of the 51 BackoffSmoothing model on the test data: 11.685170859314104
# Perplexity of the 52 BackoffSmoothing model on the test data: 11.296309761898275
# Perplexity of the 53 BackoffSmoothing model on the test data: 10.917463025579721
# Perplexity of the 54 BackoffSmoothing model on the test data: 11.57144387264005
# Perplexity of the 55 BackoffSmoothing model on the test data: 11.712129148040004
# Perplexity of the 56 BackoffSmoothing model on the test data: 10.578715401670506
# Perplexity of the 57 BackoffSmoothing model on the test data: 8.62470467550069
# Perplexity of the 58 BackoffSmoothing model on the test data: 9.915759610642871
# Perplexity of the 59 BackoffSmoothing model on the test data: 10.000317155854992
# Perplexity of the 60 BackoffSmoothing model on the test data: 11.113984098933994
# Perplexity of the 61 BackoffSmoothing model on the test data: 12.466173108537005
# Perplexity of the 62 BackoffSmoothing model on the test data: 11.486723274806437
# Perplexity of the 63 BackoffSmoothing model on the test data: 12.404746311579085
# Perplexity of the 64 BackoffSmoothing model on the test data: 11.199384181265023
# Perplexity of the 65 BackoffSmoothing model on the test data: 11.593089409262957
# Perplexity of the 66 BackoffSmoothing model on the test data: 11.501272671231717
# Perplexity of the 67 BackoffSmoothing model on the test data: 11.043077107675119
# Perplexity of the 68 BackoffSmoothing model on the test data: 10.762124116973803
# Perplexity of the 69 BackoffSmoothing model on the test data: 11.412850968619612
# Perplexity of the 70 BackoffSmoothing model on the test data: 7.869570580020796
# Perplexity of the 71 BackoffSmoothing model on the test data: 10.894012376818566
# Perplexity of the 72 BackoffSmoothing model on the test data: 10.115780863620905
# Perplexity of the 73 BackoffSmoothing model on the test data: 11.558055625362762
# Perplexity of the 74 BackoffSmoothing model on the test data: 8.72561002144144
# Perplexity of the 75 BackoffSmoothing model on the test data: 10.25896823450332
# Perplexity of the 76 BackoffSmoothing model on the test data: 11.086330606872556
# Perplexity of the 77 BackoffSmoothing model on the test data: 11.281241046221533
# Perplexity of the 78 BackoffSmoothing model on the test data: 11.819160624411579
# Perplexity of the 79 BackoffSmoothing model on the test data: 9.970090430252457
# Perplexity of the 80 BackoffSmoothing model on the test data: 10.263354437319094
# Perplexity of the 81 BackoffSmoothing model on the test data: 11.378335844867067
# Perplexity of the 82 BackoffSmoothing model on the test data: 11.97243769285521
# Perplexity of the 83 BackoffSmoothing model on the test data: 11.11912555434036
# Perplexity of the 84 BackoffSmoothing model on the test data: 8.86951314899027
# Perplexity of the 85 BackoffSmoothing model on the test data: 10.283186009659426
# Perplexity of the 86 BackoffSmoothing model on the test data: 10.15389026825872
# Perplexity of the 87 BackoffSmoothing model on the test data: 10.641080498576393
# Perplexity of the 88 BackoffSmoothing model on the test data: 10.993464709035763
# Perplexity of the 89 BackoffSmoothing model on the test data: 12.42214836442715
# Perplexity of the 90 BackoffSmoothing model on the test data: 9.489782526400946
# Perplexity of the 91 BackoffSmoothing model on the test data: 11.27021234557844
# Perplexity of the 92 BackoffSmoothing model on the test data: 10.536758374438838
# Perplexity of the 93 BackoffSmoothing model on the test data: 11.505210053080125
# Perplexity of the 94 BackoffSmoothing model on the test data: 10.374752188311165
# Perplexity of the 95 BackoffSmoothing model on the test data: 8.365242315924267
# Perplexity of the 96 BackoffSmoothing model on the test data: 9.2347785681611
# Perplexity of the 97 BackoffSmoothing model on the test data: 12.375191685815917
# Perplexity of the 98 BackoffSmoothing model on the test data: 10.448700025863467
# Perplexity of the 99 BackoffSmoothing model on the test data: 11.32155624603683
# Perplexity of the 100 BackoffSmoothing model on the test data: 10.137457765477
# Perplexity of the 101 BackoffSmoothing model on the test data: 4.854683076705596
# Perplexity of the 102 BackoffSmoothing model on the test data: 11.437378559844735
# Perplexity of the 103 BackoffSmoothing model on the test data: 11.000790449039275
# Perplexity of the 104 BackoffSmoothing model on the test data: 11.111824853114953
# Perplexity of the 105 BackoffSmoothing model on the test data: 10.54303151178341
# Perplexity of the 106 BackoffSmoothing model on the test data: 9.119415707604022
# Perplexity of the 107 BackoffSmoothing model on the test data: 10.244249383589548
# Perplexity of the 108 BackoffSmoothing model on the test data: 10.613187146154411
# Perplexity of the 109 BackoffSmoothing model on the test data: 10.661015139699199
# Perplexity of the 110 BackoffSmoothing model on the test data: 9.820461513437266
# Perplexity of the 111 BackoffSmoothing model on the test data: 9.90951703039599
# Perplexity of the 112 BackoffSmoothing model on the test data: 12.045760524155318
# Perplexity of the 113 BackoffSmoothing model on the test data: 11.37975859293089
# Perplexity of the 114 BackoffSmoothing model on the test data: 7.260936015501747
# Perplexity of the 115 BackoffSmoothing model on the test data: 11.984832919915881
# Perplexity of the 116 BackoffSmoothing model on the test data: 10.428060473082333
# Perplexity of the 117 BackoffSmoothing model on the test data: 11.402282195997406
# Perplexity of the 118 BackoffSmoothing model on the test data: 11.270174212299116
# Perplexity of the 119 BackoffSmoothing model on the test data: 10.98943158794945
# Perplexity of the 120 BackoffSmoothing model on the test data: 11.289397672166642
# Perplexity of the 121 BackoffSmoothing model on the test data: 11.151560950554744
# Perplexity of the 122 BackoffSmoothing model on the test data: 12.070684500527308
# Perplexity of the 123 BackoffSmoothing model on the test data: 10.326158473379975
# Perplexity of the 124 BackoffSmoothing model on the test data: 11.564855336568085
# Perplexity of the 125 BackoffSmoothing model on the test data: 12.211996520061827
# Perplexity of the 126 BackoffSmoothing model on the test data: 11.573897599818519
# Perplexity of the 127 BackoffSmoothing model on the test data: 9.87171961159891
# Perplexity of the 128 BackoffSmoothing model on the test data: 10.580151582648881
# Perplexity of the 129 BackoffSmoothing model on the test data: 11.753134999995613
# Perplexity of the 130 BackoffSmoothing model on the test data: 11.654851851437845
# Perplexity of the 131 BackoffSmoothing model on the test data: 9.645020937238222
# Perplexity of the 132 BackoffSmoothing model on the test data: 10.160278500522915
# Perplexity of the 133 BackoffSmoothing model on the test data: 11.211465214358645
# Perplexity of the 134 BackoffSmoothing model on the test data: 10.280995829669761
# Perplexity of the 135 BackoffSmoothing model on the test data: 12.852474202688024
# Perplexity of the 136 BackoffSmoothing model on the test data: 10.382209049675918
# Perplexity of the 137 BackoffSmoothing model on the test data: 11.19802676125862
# Perplexity of the 138 BackoffSmoothing model on the test data: 9.68218314340972
# Perplexity of the 139 BackoffSmoothing model on the test data: 9.253404510022152
# Perplexity of the 140 BackoffSmoothing model on the test data: 11.589642275866984
# Perplexity of the 141 BackoffSmoothing model on the test data: 12.05520738321233
# Perplexity of the 142 BackoffSmoothing model on the test data: 9.398850313455961
# Perplexity of the 143 BackoffSmoothing model on the test data: 10.279097190766294
# Perplexity of the 144 BackoffSmoothing model on the test data: 10.962230381595488
# Perplexity of the 145 BackoffSmoothing model on the test data: 11.653583265634403
# Perplexity of the 146 BackoffSmoothing model on the test data: 11.47151301727804
# Perplexity of the 147 BackoffSmoothing model on the test data: 13.154834788437356
# Perplexity of the 148 BackoffSmoothing model on the test data: 10.787534141756309
# Perplexity of the 149 BackoffSmoothing model on the test data: 11.136640418989968
# Perplexity of the 150 BackoffSmoothing model on the test data: 12.993139427795295
# Perplexity of the 151 BackoffSmoothing model on the test data: 10.12795503484421
# Perplexity of the 152 BackoffSmoothing model on the test data: 11.106189582860978
# Perplexity of the 153 BackoffSmoothing model on the test data: 10.707607623381888
# Perplexity of the 154 BackoffSmoothing model on the test data: 10.041268844015372
# Perplexity of the 155 BackoffSmoothing model on the test data: 11.155889276521648
# Perplexity of the 156 BackoffSmoothing model on the test data: 11.951164650359777
# Perplexity of the 157 BackoffSmoothing model on the test data: 10.29197613208675
# Perplexity of the 158 BackoffSmoothing model on the test data: 8.83252640407486
# Perplexity of the 159 BackoffSmoothing model on the test data: 10.496790250829937
# Perplexity of the 160 BackoffSmoothing model on the test data: 11.950953754242706
# Perplexity of the 161 BackoffSmoothing model on the test data: 12.165106589997237
# Perplexity of the 162 BackoffSmoothing model on the test data: 11.278115538012317
# Perplexity of the 163 BackoffSmoothing model on the test data: 9.82174514905391
# Perplexity of the 164 BackoffSmoothing model on the test data: 12.192775652065489
# Perplexity of the 165 BackoffSmoothing model on the test data: 11.694295040545176
# Perplexity of the 166 BackoffSmoothing model on the test data: 10.298944110732059
# Perplexity of the 167 BackoffSmoothing model on the test data: 8.751978263151372
# Perplexity of the 168 BackoffSmoothing model on the test data: 10.717932788654544
# Perplexity of the 169 BackoffSmoothing model on the test data: 10.85664786256092
# Perplexity of the 170 BackoffSmoothing model on the test data: 11.161729791388462
# Perplexity of the 171 BackoffSmoothing model on the test data: 10.183007444730679
# Perplexity of the 172 BackoffSmoothing model on the test data: 11.231267085429689
# Perplexity of the 173 BackoffSmoothing model on the test data: 9.373778141247296
# Perplexity of the 174 BackoffSmoothing model on the test data: 10.429007764654168
# Perplexity of the 175 BackoffSmoothing model on the test data: 11.260680756048732
# Perplexity of the 176 BackoffSmoothing model on the test data: 12.086219034469607
# Perplexity of the 177 BackoffSmoothing model on the test data: 9.444206419019372
# Perplexity of the 178 BackoffSmoothing model on the test data: 10.427857427813038
# Perplexity of the 179 BackoffSmoothing model on the test data: 11.566590945922943
# Perplexity of the 180 BackoffSmoothing model on the test data: 10.595683915969369
# Perplexity of the 181 BackoffSmoothing model on the test data: 10.841943156810583
# Perplexity of the 182 BackoffSmoothing model on the test data: 11.37752600047352
# Perplexity of the 183 BackoffSmoothing model on the test data: 11.046398818829527
# Perplexity of the 184 BackoffSmoothing model on the test data: 11.914695607709517
# Perplexity of the 185 BackoffSmoothing model on the test data: 9.250390522942308
# Perplexity of the 186 BackoffSmoothing model on the test data: 12.726367903556657
# Perplexity of the 187 BackoffSmoothing model on the test data: 12.09399900241658
# Perplexity of the 188 BackoffSmoothing model on the test data: 8.819414479151407
# Perplexity of the 189 BackoffSmoothing model on the test data: 14.649712105741832
# Perplexity of the 190 BackoffSmoothing model on the test data: 10.342674389841815
# Perplexity of the 191 BackoffSmoothing model on the test data: 12.040907490585456
# Perplexity of the 192 BackoffSmoothing model on the test data: 9.071850743923997
# Perplexity of the 193 BackoffSmoothing model on the test data: 9.869178342777818
# Perplexity of the 194 BackoffSmoothing model on the test data: 10.262989768329247
# Perplexity of the 195 BackoffSmoothing model on the test data: 10.463840939058892
# Perplexity of the 196 BackoffSmoothing model on the test data: 10.744682761069404
# Perplexity of the 197 BackoffSmoothing model on the test data: 10.072620740167466
# Perplexity of the 198 BackoffSmoothing model on the test data: 9.140976414769087
# Perplexity of the 199 BackoffSmoothing model on the test data: 12.783872616955332
# Perplexity of the 200 BackoffSmoothing model on the test data: 10.430898427797292
# Perplexity of the 201 BackoffSmoothing model on the test data: 12.109873620029779
# Perplexity of the 202 BackoffSmoothing model on the test data: 10.646562080027804
# Perplexity of the 203 BackoffSmoothing model on the test data: 11.641712846045532
# Perplexity of the 204 BackoffSmoothing model on the test data: 12.782596256226245
# Perplexity of the 205 BackoffSmoothing model on the test data: 10.121822189720817
# Perplexity of the 206 BackoffSmoothing model on the test data: 8.003251551020261
# Perplexity of the 207 BackoffSmoothing model on the test data: 10.009034017343554
# Perplexity of the 208 BackoffSmoothing model on the test data: 8.593935198320267
# Perplexity of the 209 BackoffSmoothing model on the test data: 12.263916105322151
# Perplexity of the 210 BackoffSmoothing model on the test data: 12.16509348359251
# Perplexity of the 211 BackoffSmoothing model on the test data: 9.177163022111236
# Perplexity of the 212 BackoffSmoothing model on the test data: 11.962769425207382
# Perplexity of the 213 BackoffSmoothing model on the test data: 10.97121088028495
# Perplexity of the 214 BackoffSmoothing model on the test data: 13.024283127337418
# Perplexity of the 215 BackoffSmoothing model on the test data: 12.503179830929
# Perplexity of the 216 BackoffSmoothing model on the test data: 11.568120583892057
# Perplexity of the 217 BackoffSmoothing model on the test data: 10.403826037570882
# Perplexity of the 218 BackoffSmoothing model on the test data: 11.761535368052023
# Perplexity of the 219 BackoffSmoothing model on the test data: 10.759289117743025
# Perplexity of the 220 BackoffSmoothing model on the test data: 11.086157147505062
# Perplexity of the 221 BackoffSmoothing model on the test data: 11.675325446000304
# Perplexity of the 222 BackoffSmoothing model on the test data: 5.501148622009393
# Perplexity of the 223 BackoffSmoothing model on the test data: 11.888362082867548
# Perplexity of the 224 BackoffSmoothing model on the test data: 10.995402315642567
# Perplexity of the 225 BackoffSmoothing model on the test data: 10.53224430102587
# Perplexity of the 226 BackoffSmoothing model on the test data: 12.476809482359272
# Perplexity of the 227 BackoffSmoothing model on the test data: 11.55172415836929
# Perplexity of the 228 BackoffSmoothing model on the test data: 11.284744239516089
# Perplexity of the 229 BackoffSmoothing model on the test data: 11.494218523498612
# Perplexity of the 230 BackoffSmoothing model on the test data: 7.490732387169876
# Perplexity of the 231 BackoffSmoothing model on the test data: 11.273710685737875
# Perplexity of the 232 BackoffSmoothing model on the test data: 13.4515040489353
# Perplexity of the 233 BackoffSmoothing model on the test data: 11.139186731159215
# Perplexity of the 234 BackoffSmoothing model on the test data: 10.6847171197241
# Perplexity of the 235 BackoffSmoothing model on the test data: 10.63511130072446
# Perplexity of the 236 BackoffSmoothing model on the test data: 11.66879726270781
# Perplexity of the 237 BackoffSmoothing model on the test data: 12.133212107862885
# Perplexity of the 238 BackoffSmoothing model on the test data: 10.331729227842109
# Perplexity of the 239 BackoffSmoothing model on the test data: 12.463013350891224
# Perplexity of the 240 BackoffSmoothing model on the test data: 12.419423600414953
# Perplexity of the 241 BackoffSmoothing model on the test data: 10.754931981254721
# Perplexity of the 242 BackoffSmoothing model on the test data: 8.32340302503928
# Perplexity of the 243 BackoffSmoothing model on the test data: 9.267772370764298
# Perplexity of the 244 BackoffSmoothing model on the test data: 10.129728376389147
# Perplexity of the 245 BackoffSmoothing model on the test data: 13.321132007269423
# Perplexity of the 246 BackoffSmoothing model on the test data: 12.355850023315915
# Perplexity of the 247 BackoffSmoothing model on the test data: 11.385309530126396
# Perplexity of the 248 BackoffSmoothing model on the test data: 10.42766071104064
# Perplexity of the 249 BackoffSmoothing model on the test data: 11.441893093983687
# Perplexity of the 250 BackoffSmoothing model on the test data: 12.078541598989814
# Perplexity of the 251 BackoffSmoothing model on the test data: 11.666666187541578
# Perplexity of the 252 BackoffSmoothing model on the test data: 13.095154524635161
# Perplexity of the 253 BackoffSmoothing model on the test data: 11.042327343377242
# Perplexity of the 254 BackoffSmoothing model on the test data: 11.22023193002362
# Perplexity of the 255 BackoffSmoothing model on the test data: 11.920497118722587
# Perplexity of the 256 BackoffSmoothing model on the test data: 10.88050366612894
# Perplexity of the 257 BackoffSmoothing model on the test data: 11.235996526630945
# Perplexity of the 258 BackoffSmoothing model on the test data: 10.152878472431574
# Perplexity of the 259 BackoffSmoothing model on the test data: 10.089216800636198
# Perplexity of the 260 BackoffSmoothing model on the test data: 10.22201962365652
# Perplexity of the 261 BackoffSmoothing model on the test data: 11.363110849168526
# Perplexity of the 262 BackoffSmoothing model on the test data: 11.500463301413465
# Perplexity of the 263 BackoffSmoothing model on the test data: 10.46689635893486
# Perplexity of the 264 BackoffSmoothing model on the test data: 9.320969620539781
# Perplexity of the 265 BackoffSmoothing model on the test data: 9.975371686288202
# Perplexity of the 266 BackoffSmoothing model on the test data: 10.653314855029684
# Perplexity of the 267 BackoffSmoothing model on the test data: 8.874359299334648
# Perplexity of the 268 BackoffSmoothing model on the test data: 9.310153042030784
# Perplexity of the 269 BackoffSmoothing model on the test data: 12.786666188167978
# Perplexity of the 270 BackoffSmoothing model on the test data: 10.150126049602322
# Perplexity of the 271 BackoffSmoothing model on the test data: 10.59604976905415
# Perplexity of the 272 BackoffSmoothing model on the test data: 10.899354325707646
# Perplexity of the 273 BackoffSmoothing model on the test data: 11.31291338241498
# Perplexity of the 274 BackoffSmoothing model on the test data: 10.282479851933186
# Perplexity of the 275 BackoffSmoothing model on the test data: 9.695203342830125
# Perplexity of the 276 BackoffSmoothing model on the test data: 10.8278899127114
# Perplexity of the 277 BackoffSmoothing model on the test data: 9.24978299038213
# Perplexity of the 278 BackoffSmoothing model on the test data: 9.96913175177741
# Perplexity of the 279 BackoffSmoothing model on the test data: 10.5935844889247
# Perplexity of the 280 BackoffSmoothing model on the test data: 10.20890747182231
# Perplexity of the 281 BackoffSmoothing model on the test data: 10.21535500842001
# Perplexity of the 282 BackoffSmoothing model on the test data: 10.844953075116651
# Perplexity of the 283 BackoffSmoothing model on the test data: 8.014731026434845
# Perplexity of the 284 BackoffSmoothing model on the test data: 10.149041351930537
# Perplexity of the 285 BackoffSmoothing model on the test data: 10.74756061975053
# Perplexity of the 286 BackoffSmoothing model on the test data: 12.652058601807571
# Perplexity of the 287 BackoffSmoothing model on the test data: 11.269421128939321
# Perplexity of the 288 BackoffSmoothing model on the test data: 11.099308914639836
# Perplexity of the 289 BackoffSmoothing model on the test data: 12.55183425522431
# Perplexity of the 290 BackoffSmoothing model on the test data: 9.940971274197487
# Perplexity of the 291 BackoffSmoothing model on the test data: 4.6493739439899935
# Perplexity of the 292 BackoffSmoothing model on the test data: 11.311745735934396
# Perplexity of the 293 BackoffSmoothing model on the test data: 12.289944512765912
# Perplexity of the 294 BackoffSmoothing model on the test data: 6.452729171382151
# Perplexity of the 295 BackoffSmoothing model on the test data: 11.570835938550356
# Perplexity of the 296 BackoffSmoothing model on the test data: 9.850230578924366
# Perplexity of the 297 BackoffSmoothing model on the test data: 11.060185616098906
# Perplexity of the 298 BackoffSmoothing model on the test data: 9.618496178085582
# Perplexity of the 299 BackoffSmoothing model on the test data: 10.355038564086211
# Perplexity of the 300 BackoffSmoothing model on the test data: 10.159830052175105
# Perplexity of the 301 BackoffSmoothing model on the test data: 11.57414711494381
# Perplexity of the 302 BackoffSmoothing model on the test data: 7.343099500162338
# Perplexity of the 303 BackoffSmoothing model on the test data: 11.075126488055732
# Perplexity of the 304 BackoffSmoothing model on the test data: 10.242529799916012
# Perplexity of the 305 BackoffSmoothing model on the test data: 8.435710321014922
# Perplexity of the 306 BackoffSmoothing model on the test data: 9.26157075854554
# Perplexity of the 307 BackoffSmoothing model on the test data: 11.320868771515839
# Perplexity of the 308 BackoffSmoothing model on the test data: 10.247412101547235
# Perplexity of the 309 BackoffSmoothing model on the test data: 11.350128841427088
# Perplexity of the 310 BackoffSmoothing model on the test data: 9.312224973868181
# Perplexity of the 311 BackoffSmoothing model on the test data: 11.03939313638306
# Perplexity of the 312 BackoffSmoothing model on the test data: 11.829989645219277
# Perplexity of the 313 BackoffSmoothing model on the test data: 11.043275524121487
# Perplexity of the 314 BackoffSmoothing model on the test data: 7.722850539998848
# Perplexity of the 315 BackoffSmoothing model on the test data: 10.482459517894219
# Perplexity of the 316 BackoffSmoothing model on the test data: 9.86394721443124
# Perplexity of the 317 BackoffSmoothing model on the test data: 10.810426529655205
# Perplexity of the 318 BackoffSmoothing model on the test data: 11.841320009697696
# Perplexity of the 319 BackoffSmoothing model on the test data: 10.180796449017619
# Perplexity of the 320 BackoffSmoothing model on the test data: 11.704739284078698
# Perplexity of the 321 BackoffSmoothing model on the test data: 11.307805488318277
# Perplexity of the 322 BackoffSmoothing model on the test data: 10.728163668771058
# Perplexity of the 323 BackoffSmoothing model on the test data: 8.967982283376458
# Perplexity of the 324 BackoffSmoothing model on the test data: 10.744825222763946
# Perplexity of the 325 BackoffSmoothing model on the test data: 9.921185656838613
# Perplexity of the 326 BackoffSmoothing model on the test data: 10.586414499932781
# Perplexity of the 327 BackoffSmoothing model on the test data: 12.132199732192804
# Perplexity of the 328 BackoffSmoothing model on the test data: 10.617240079867306
# Perplexity of the 329 BackoffSmoothing model on the test data: 9.181949613358487
# Perplexity of the 330 BackoffSmoothing model on the test data: 12.33883240874407
# Perplexity of the 331 BackoffSmoothing model on the test data: 10.339771887108327
# Perplexity of the 332 BackoffSmoothing model on the test data: 11.048411787783234
# Perplexity of the 333 BackoffSmoothing model on the test data: 10.913630259143297
# Perplexity of the 334 BackoffSmoothing model on the test data: 13.52237115877262
# Perplexity of the 335 BackoffSmoothing model on the test data: 12.233405949546805
# Perplexity of the 336 BackoffSmoothing model on the test data: 11.788299409815657
# Perplexity of the 337 BackoffSmoothing model on the test data: 8.681973714557795
# Perplexity of the 338 BackoffSmoothing model on the test data: 9.284523426068871
# Perplexity of the 339 BackoffSmoothing model on the test data: 11.477806497823227
# Perplexity of the 340 BackoffSmoothing model on the test data: 9.008825325946761
# Perplexity of the 341 BackoffSmoothing model on the test data: 10.602143001402819
# Perplexity of the 342 BackoffSmoothing model on the test data: 10.930389619656088
# Perplexity of the 343 BackoffSmoothing model on the test data: 12.07972378529776
# Perplexity of the 344 BackoffSmoothing model on the test data: 12.286556205313781
# Perplexity of the 345 BackoffSmoothing model on the test data: 12.13448923958391
# Perplexity of the 346 BackoffSmoothing model on the test data: 11.269812534486135
# Perplexity of the 347 BackoffSmoothing model on the test data: 9.647036330210797
# Perplexity of the 348 BackoffSmoothing model on the test data: 10.611792812349673
# Perplexity of the 349 BackoffSmoothing model on the test data: 10.581074456277339
# Perplexity of the 350 BackoffSmoothing model on the test data: 12.539637857548108
# Perplexity of the 351 BackoffSmoothing model on the test data: 11.178405245911375
# Perplexity of the 352 BackoffSmoothing model on the test data: 11.468989675479396
# Perplexity of the 353 BackoffSmoothing model on the test data: 12.013660633962097
# Perplexity of the 354 BackoffSmoothing model on the test data: 10.90054179492264
# Perplexity of the 355 BackoffSmoothing model on the test data: 8.784714091711939
# Perplexity of the 356 BackoffSmoothing model on the test data: 10.44407718950008
# Perplexity of the 357 BackoffSmoothing model on the test data: 11.11295162234414
# Perplexity of the 358 BackoffSmoothing model on the test data: 8.989938606450423
# Perplexity of the 359 BackoffSmoothing model on the test data: 8.622670009890104
# Perplexity of the 360 BackoffSmoothing model on the test data: 12.883257858467847
# Perplexity of the 361 BackoffSmoothing model on the test data: 10.515081936414013
# Perplexity of the 362 BackoffSmoothing model on the test data: 10.158935589537894
# Perplexity of the 363 BackoffSmoothing model on the test data: 11.113941659216332
# Perplexity of the 364 BackoffSmoothing model on the test data: 11.599204734856299
# Perplexity of the 365 BackoffSmoothing model on the test data: 11.495923452900252
# Perplexity of the 366 BackoffSmoothing model on the test data: 12.883959323603229
# Perplexity of the 367 BackoffSmoothing model on the test data: 11.056602579849736
# Perplexity of the 368 BackoffSmoothing model on the test data: 12.919103228403696
# Perplexity of the 369 BackoffSmoothing model on the test data: 12.515914302583807
# Perplexity of the 370 BackoffSmoothing model on the test data: 13.304869829054898
# Perplexity of the 371 BackoffSmoothing model on the test data: 11.616947513456672
# Perplexity of the 372 BackoffSmoothing model on the test data: 10.988586241444038
# Perplexity of the 373 BackoffSmoothing model on the test data: 13.039913695834036
# Perplexity of the 374 BackoffSmoothing model on the test data: 11.920453215685534
# Perplexity of the 375 BackoffSmoothing model on the test data: 10.009237946032188
# Perplexity of the 376 BackoffSmoothing model on the test data: 11.908698006740243
# Perplexity of the 377 BackoffSmoothing model on the test data: 11.362756525304025
# Perplexity of the 378 BackoffSmoothing model on the test data: 11.241537865151814
# Perplexity of the 379 BackoffSmoothing model on the test data: 11.199654541259813
# Perplexity of the 380 BackoffSmoothing model on the test data: 11.78207374436856
# Perplexity of the 381 BackoffSmoothing model on the test data: 10.031594280694007
# Perplexity of the 382 BackoffSmoothing model on the test data: 11.587261401650144
# Perplexity of the 383 BackoffSmoothing model on the test data: 9.34009472844436
# Perplexity of the 384 BackoffSmoothing model on the test data: 12.2126349993621
# Perplexity of the 385 BackoffSmoothing model on the test data: 8.844140560390793
# Perplexity of the 386 BackoffSmoothing model on the test data: 11.444775832604732
# Perplexity of the 387 BackoffSmoothing model on the test data: 11.454517990505572
# Perplexity of the 388 BackoffSmoothing model on the test data: 12.094166940344724
# Perplexity of the 389 BackoffSmoothing model on the test data: 9.555689533003518
# Perplexity of the 390 BackoffSmoothing model on the test data: 12.051914136535913
# Perplexity of the 391 BackoffSmoothing model on the test data: 9.862938848845973
# Perplexity of the 392 BackoffSmoothing model on the test data: 10.905025471372085
# Perplexity of the 393 BackoffSmoothing model on the test data: 10.124648683424763
# Perplexity of the 394 BackoffSmoothing model on the test data: 11.506916790383867
# Perplexity of the 395 BackoffSmoothing model on the test data: 12.870139689366447
# Perplexity of the 396 BackoffSmoothing model on the test data: 10.227202829291127
# Perplexity of the 397 BackoffSmoothing model on the test data: 11.36464454202017
# Perplexity of the 398 BackoffSmoothing model on the test data: 11.010571976563039
# Perplexity of the 399 BackoffSmoothing model on the test data: 12.583740963290456
# Perplexity of the 400 BackoffSmoothing model on the test data: 10.943601914528418
# Perplexity of the 401 BackoffSmoothing model on the test data: 11.19076237466718
# Perplexity of the 402 BackoffSmoothing model on the test data: 11.255924155922633
# Perplexity of the 403 BackoffSmoothing model on the test data: 13.314861269604735
# Perplexity of the 404 BackoffSmoothing model on the test data: 11.617598872136202
# Perplexity of the 405 BackoffSmoothing model on the test data: 11.278124755055332
# Perplexity of the 406 BackoffSmoothing model on the test data: 11.886692502697061
# Perplexity of the 407 BackoffSmoothing model on the test data: 11.63583373332253
# Perplexity of the 408 BackoffSmoothing model on the test data: 10.097099228718283
# Perplexity of the 409 BackoffSmoothing model on the test data: 12.282879056715903
# Perplexity of the 410 BackoffSmoothing model on the test data: 12.917760252821127
# Perplexity of the 411 BackoffSmoothing model on the test data: 12.17059220613689
# Perplexity of the 412 BackoffSmoothing model on the test data: 10.646779364882216
# Perplexity of the 413 BackoffSmoothing model on the test data: 11.221430575550066
# Perplexity of the 414 BackoffSmoothing model on the test data: 10.842885811826411
# Perplexity of the 415 BackoffSmoothing model on the test data: 12.500316699537882
# Perplexity of the 416 BackoffSmoothing model on the test data: 9.861989137693005
# Perplexity of the 417 BackoffSmoothing model on the test data: 12.027848444055328
# Perplexity of the 418 BackoffSmoothing model on the test data: 11.48676654073762
# Perplexity of the 419 BackoffSmoothing model on the test data: 13.988210689799512
# Perplexity of the 420 BackoffSmoothing model on the test data: 11.311114057253903
# Perplexity of the 421 BackoffSmoothing model on the test data: 10.86994638774193
# Perplexity of the 422 BackoffSmoothing model on the test data: 10.868653633018779
# Perplexity of the 423 BackoffSmoothing model on the test data: 10.88087427522598
# Perplexity of the 424 BackoffSmoothing model on the test data: 11.493846097280358
# Perplexity of the 425 BackoffSmoothing model on the test data: 12.531724812151442
# Perplexity of the 426 BackoffSmoothing model on the test data: 9.612016889752292
# Perplexity of the 427 BackoffSmoothing model on the test data: 10.785823025892519
# Perplexity of the 428 BackoffSmoothing model on the test data: 12.157604623531471
# Perplexity of the 429 BackoffSmoothing model on the test data: 12.709892420340536
# Perplexity of the 430 BackoffSmoothing model on the test data: 11.960130682807856
# Perplexity of the 431 BackoffSmoothing model on the test data: 10.971517021234618
# Perplexity of the 432 BackoffSmoothing model on the test data: 11.343124468401076
# Perplexity of the 433 BackoffSmoothing model on the test data: 9.696839991230789
# Perplexity of the 434 BackoffSmoothing model on the test data: 11.055680475677152
# Perplexity of the 435 BackoffSmoothing model on the test data: 12.401243058067775
# Perplexity of the 436 BackoffSmoothing model on the test data: 11.878806769730222
# Perplexity of the 437 BackoffSmoothing model on the test data: 9.844341838858199
# Perplexity of the 438 BackoffSmoothing model on the test data: 9.710648013552042
# Perplexity of the 439 BackoffSmoothing model on the test data: 10.456443436801202
# Perplexity of the 440 BackoffSmoothing model on the test data: 11.960167429086265
# Perplexity of the 441 BackoffSmoothing model on the test data: 9.32863906137125
# Perplexity of the 442 BackoffSmoothing model on the test data: 12.19625453697388
# Perplexity of the 443 BackoffSmoothing model on the test data: 9.496457347946247
# Perplexity of the 444 BackoffSmoothing model on the test data: 12.340055343818346
# Perplexity of the 445 BackoffSmoothing model on the test data: 12.586007532374843
# Perplexity of the 446 BackoffSmoothing model on the test data: 9.376910063908984
# Perplexity of the 447 BackoffSmoothing model on the test data: 9.934862435061257
# Perplexity of the 448 BackoffSmoothing model on the test data: 11.137778640725928
# Perplexity of the 449 BackoffSmoothing model on the test data: 10.3699405665925
# Perplexity of the 450 BackoffSmoothing model on the test data: 12.325183356150436
# Perplexity of the 451 BackoffSmoothing model on the test data: 12.062081447358999
# Perplexity of the 452 BackoffSmoothing model on the test data: 11.697150825312022
# Perplexity of the 453 BackoffSmoothing model on the test data: 11.2978318138189
# Perplexity of the 454 BackoffSmoothing model on the test data: 13.116925773531799
# Perplexity of the 455 BackoffSmoothing model on the test data: 12.224479770724509
# Perplexity of the 456 BackoffSmoothing model on the test data: 12.151893753095116
# Perplexity of the 457 BackoffSmoothing model on the test data: 12.015273941523324
# Perplexity of the 458 BackoffSmoothing model on the test data: 10.92897336629356
# Perplexity of the 459 BackoffSmoothing model on the test data: 11.075988092304812
# Perplexity of the 460 BackoffSmoothing model on the test data: 10.227171973392489
# Perplexity of the 461 BackoffSmoothing model on the test data: 11.30204773599176
# Perplexity of the 462 BackoffSmoothing model on the test data: 9.812376399751786
# Perplexity of the 463 BackoffSmoothing model on the test data: 10.499073525825196
# Perplexity of the 464 BackoffSmoothing model on the test data: 9.562843746069037
# Perplexity of the 465 BackoffSmoothing model on the test data: 9.502066007962314
# Perplexity of the 466 BackoffSmoothing model on the test data: 9.27573740528501
# Perplexity of the 467 BackoffSmoothing model on the test data: 9.188813944994852
# Perplexity of the 468 BackoffSmoothing model on the test data: 12.971105158190356
# Perplexity of the 469 BackoffSmoothing model on the test data: 11.184256245279826
# Perplexity of the 470 BackoffSmoothing model on the test data: 10.932762290822048
# Perplexity of the 471 BackoffSmoothing model on the test data: 11.38514300742669
# Perplexity of the 472 BackoffSmoothing model on the test data: 10.709205898224301
# Perplexity of the 473 BackoffSmoothing model on the test data: 10.907262579768663
# Perplexity of the 474 BackoffSmoothing model on the test data: 12.723267105503727
# Perplexity of the 475 BackoffSmoothing model on the test data: 12.032208834910262
# Perplexity of the 476 BackoffSmoothing model on the test data: 12.03600546329731
# Perplexity of the 477 BackoffSmoothing model on the test data: 10.696603208184207
# Perplexity of the 478 BackoffSmoothing model on the test data: 11.818875354043197
# Perplexity of the 479 BackoffSmoothing model on the test data: 9.557091856132308
# Perplexity of the 480 BackoffSmoothing model on the test data: 11.429707685882423
# Perplexity of the 481 BackoffSmoothing model on the test data: 10.286942589862695
# Perplexity of the 482 BackoffSmoothing model on the test data: 10.886131880537171
# Perplexity of the 483 BackoffSmoothing model on the test data: 11.760482004204743
# Perplexity of the 484 BackoffSmoothing model on the test data: 11.801068937919126
# Perplexity of the 485 BackoffSmoothing model on the test data: 10.795301848821339
# Perplexity of the 486 BackoffSmoothing model on the test data: 10.154428069051153
# Perplexity of the 487 BackoffSmoothing model on the test data: 8.692402845814973
# Perplexity of the 488 BackoffSmoothing model on the test data: 10.814204784957152
# Perplexity of the 489 BackoffSmoothing model on the test data: 10.017128841726702
# Perplexity of the 490 BackoffSmoothing model on the test data: 11.119799410062637
# Perplexity of the 491 BackoffSmoothing model on the test data: 10.868756159555518
# Perplexity of the 492 BackoffSmoothing model on the test data: 12.00216824832055
# Perplexity of the 493 BackoffSmoothing model on the test data: 10.675902191763761
# Perplexity of the 494 BackoffSmoothing model on the test data: 10.554232919729651
# Perplexity of the 495 BackoffSmoothing model on the test data: 10.909734044147388
# Perplexity of the 496 BackoffSmoothing model on the test data: 11.532767822492858
# Perplexity of the 497 BackoffSmoothing model on the test data: 10.70244549538937
# Perplexity of the 498 BackoffSmoothing model on the test data: 14.371837530660743
# Perplexity of the 499 BackoffSmoothing model on the test data: 13.217768075591888
# Perplexity of the 500 BackoffSmoothing model on the test data: 11.72338937084161
# Perplexity of the 501 BackoffSmoothing model on the test data: 11.230000850303519
# Perplexity of the 502 BackoffSmoothing model on the test data: 10.95322860344071
# Perplexity of the 503 BackoffSmoothing model on the test data: 9.818785482105561
# Perplexity of the 504 BackoffSmoothing model on the test data: 9.425111946726542
# Perplexity of the 505 BackoffSmoothing model on the test data: 12.354644383397378
# Perplexity of the 506 BackoffSmoothing model on the test data: 11.067508292314391
# Perplexity of the 507 BackoffSmoothing model on the test data: 12.886703375185329
# Perplexity of the 508 BackoffSmoothing model on the test data: 12.122086136029903
# Perplexity of the 509 BackoffSmoothing model on the test data: 11.467065097719532
# Perplexity of the 510 BackoffSmoothing model on the test data: 11.476996522874654
# Perplexity of the 511 BackoffSmoothing model on the test data: 11.100578510905583
# Perplexity of the 512 BackoffSmoothing model on the test data: 11.422713964116575
# Perplexity of the 513 BackoffSmoothing model on the test data: 10.526423299700763
# Perplexity of the 514 BackoffSmoothing model on the test data: 5.416857288275406
# Perplexity of the 515 BackoffSmoothing model on the test data: 10.808300946682683
# Perplexity of the 516 BackoffSmoothing model on the test data: 10.658403010617468
# Perplexity of the 517 BackoffSmoothing model on the test data: 11.503227437538843
# Perplexity of the 518 BackoffSmoothing model on the test data: 10.953830469559524
# Perplexity of the 519 BackoffSmoothing model on the test data: 8.807534697256399
# Perplexity of the 520 BackoffSmoothing model on the test data: 12.06271809970941
# Perplexity of the 521 BackoffSmoothing model on the test data: 10.169546226192772
# Perplexity of the 522 BackoffSmoothing model on the test data: 10.490772758764287
# Perplexity of the 523 BackoffSmoothing model on the test data: 11.301592755004664
# Perplexity of the 524 BackoffSmoothing model on the test data: 12.65023409504237
# Perplexity of the 525 BackoffSmoothing model on the test data: 11.749695502864064
# Perplexity of the 526 BackoffSmoothing model on the test data: 10.468125686720407
# Perplexity of the 527 BackoffSmoothing model on the test data: 11.188873056840338
# Perplexity of the 528 BackoffSmoothing model on the test data: 10.472059858258422
# Perplexity of the 529 BackoffSmoothing model on the test data: 11.973963609037583
# Perplexity of the 530 BackoffSmoothing model on the test data: 10.991289778970359
# Perplexity of the 531 BackoffSmoothing model on the test data: 11.895790053878343
# Perplexity of the 532 BackoffSmoothing model on the test data: 10.729629571777554
# Perplexity of the 533 BackoffSmoothing model on the test data: 11.345064376610937
# Perplexity of the 534 BackoffSmoothing model on the test data: 9.243491603244301
# Perplexity of the 535 BackoffSmoothing model on the test data: 12.063757160605702
# Perplexity of the 536 BackoffSmoothing model on the test data: 12.70158390354109
# Perplexity of the 537 BackoffSmoothing model on the test data: 10.52138557745795
# Perplexity of the 538 BackoffSmoothing model on the test data: 11.598823467808252
# Perplexity of the 539 BackoffSmoothing model on the test data: 10.889106768114699
# Perplexity of the 540 BackoffSmoothing model on the test data: 11.615448508316172
# Perplexity of the 541 BackoffSmoothing model on the test data: 11.493990086815437
# Perplexity of the 542 BackoffSmoothing model on the test data: 11.25794938471489
# Perplexity of the 543 BackoffSmoothing model on the test data: 12.77186968609009
# Perplexity of the 544 BackoffSmoothing model on the test data: 11.05117117370661
# Perplexity of the 545 BackoffSmoothing model on the test data: 9.3003586823206
# Perplexity of the 546 BackoffSmoothing model on the test data: 11.556653867979515
# Perplexity of the 547 BackoffSmoothing model on the test data: 7.974950891864015
# Perplexity of the 548 BackoffSmoothing model on the test data: 10.428968127179113
# Perplexity of the 549 BackoffSmoothing model on the test data: 9.82189921004794
# Perplexity of the 550 BackoffSmoothing model on the test data: 10.897206012297667
# Perplexity of the 551 BackoffSmoothing model on the test data: 12.728893827607347
# Perplexity of the 552 BackoffSmoothing model on the test data: 9.89838817417558
# Perplexity of the 553 BackoffSmoothing model on the test data: 12.939028899568973
# Perplexity of the 554 BackoffSmoothing model on the test data: 10.548608256558262
# Perplexity of the 555 BackoffSmoothing model on the test data: 9.42155091521416
# Perplexity of the 556 BackoffSmoothing model on the test data: 11.627785394701462
# Perplexity of the 557 BackoffSmoothing model on the test data: 11.345879711703345
# Perplexity of the 558 BackoffSmoothing model on the test data: 11.963882858595122
# Perplexity of the 559 BackoffSmoothing model on the test data: 12.05907758755812
# Perplexity of the 560 BackoffSmoothing model on the test data: 11.069526189841046
# Perplexity of the 561 BackoffSmoothing model on the test data: 11.45300565874978
# Perplexity of the 562 BackoffSmoothing model on the test data: 13.075912717162902
# Perplexity of the 563 BackoffSmoothing model on the test data: 10.620988709197452
# Perplexity of the 564 BackoffSmoothing model on the test data: 10.621616640988604
# Perplexity of the 565 BackoffSmoothing model on the test data: 10.273716065747223
# Perplexity of the 566 BackoffSmoothing model on the test data: 13.958756218934429
# Perplexity of the 567 BackoffSmoothing model on the test data: 9.256585839629897
# Perplexity of the 568 BackoffSmoothing model on the test data: 11.903937480401181
# Perplexity of the 569 BackoffSmoothing model on the test data: 10.874975891103087
# Perplexity of the 570 BackoffSmoothing model on the test data: 10.41284462060288
# Perplexity of the 571 BackoffSmoothing model on the test data: 12.336656113691294
# Perplexity of the 572 BackoffSmoothing model on the test data: 10.395038147276553
# Perplexity of the 573 BackoffSmoothing model on the test data: 9.697422586984237
# Perplexity of the 574 BackoffSmoothing model on the test data: 11.827814772602865
# Perplexity of the 575 BackoffSmoothing model on the test data: 11.464915346583851
# Perplexity of the 576 BackoffSmoothing model on the test data: 9.149216677928129
# Perplexity of the 577 BackoffSmoothing model on the test data: 8.55504603894997
# Perplexity of the 578 BackoffSmoothing model on the test data: 11.480518210463847
# Perplexity of the 579 BackoffSmoothing model on the test data: 12.07989983140752
# Perplexity of the 580 BackoffSmoothing model on the test data: 10.916889644841659
# Perplexity of the 581 BackoffSmoothing model on the test data: 10.031736798266783
# Perplexity of the 582 BackoffSmoothing model on the test data: 11.024264679666063
# Perplexity of the 583 BackoffSmoothing model on the test data: 10.786151032557669
# Perplexity of the 584 BackoffSmoothing model on the test data: 12.427548445712302
# Perplexity of the 585 BackoffSmoothing model on the test data: 11.43449763099892
# Perplexity of the 586 BackoffSmoothing model on the test data: 9.43477904107366
# Perplexity of the 587 BackoffSmoothing model on the test data: 11.374460244198096
# Perplexity of the 588 BackoffSmoothing model on the test data: 9.284994870573152
# ...
# Perplexity of the 1451 BackoffSmoothing model on the test data: 11.686453438094631
# Perplexity of the 1452 BackoffSmoothing model on the test data: 12.417566564722913
# Perplexity of the 1453 BackoffSmoothing model on the test data: 12.947584723233767
# Perplexity of the 1454 BackoffSmoothing model on the test data: 11.237301356358397
# Perplexity of the 1455 BackoffSmoothing model on the test data: 11.368455164955959
# Perplexity of the 1456 BackoffSmoothing model on the test data: 10.596107406202576
# Perplexity of the 1457 BackoffSmoothing model on the test data: 8.42662224869863
# Perplexity of the 1458 BackoffSmoothing model on the test data: 11.368288639953207
# Perplexity of the 1459 BackoffSmoothing model on the test data: 9.820251749902333
# Perplexity of the 1460 BackoffSmoothing model on the test data: 11.615969407490857
# Perplexity of the 1461 BackoffSmoothing model on the test data: 12.30668262190637
# Perplexity of the 1462 BackoffSmoothing model on the test data: 8.671243295650813
# Perplexity of the 1463 BackoffSmoothing model on the test data: 12.085230106572155
# Perplexity of the 1464 BackoffSmoothing model on the test data: 11.72789435074938
# Perplexity of the 1465 BackoffSmoothing model on the test data: 10.849884775385668
# Perplexity of the 1466 BackoffSmoothing model on the test data: 8.05696632747464
# Perplexity of the 1467 BackoffSmoothing model on the test data: 9.953551932621496
# Perplexity of the 1468 BackoffSmoothing model on the test data: 12.586374100549856
# Perplexity of the 1469 BackoffSmoothing model on the test data: 11.928419765225597
# Perplexity of the 1470 BackoffSmoothing model on the test data: 10.53481997138544
# Perplexity of the 1471 BackoffSmoothing model on the test data: 11.183284083079899
# Perplexity of the 1472 BackoffSmoothing model on the test data: 10.190786909104686
# Perplexity of the 1473 BackoffSmoothing model on the test data: 11.27190259377578
# Perplexity of the 1474 BackoffSmoothing model on the test data: 11.81038144664931
# Perplexity of the 1475 BackoffSmoothing model on the test data: 11.048788274354916
# Perplexity of the 1476 BackoffSmoothing model on the test data: 9.550741489992772
# Perplexity of the 1477 BackoffSmoothing model on the test data: 11.445697339172739
# Perplexity of the 1478 BackoffSmoothing model on the test data: 10.125850415333186
# Perplexity of the 1479 BackoffSmoothing model on the test data: 10.069687575259575
# Perplexity of the 1480 BackoffSmoothing model on the test data: 12.163657720601874
# Perplexity of the 1481 BackoffSmoothing model on the test data: 11.479993229968347
# Perplexity of the 1482 BackoffSmoothing model on the test data: 10.507981186761265
# Perplexity of the 1483 BackoffSmoothing model on the test data: 12.21154650938679
# Perplexity of the 1484 BackoffSmoothing model on the test data: 9.94168534706122
# Perplexity of the 1485 BackoffSmoothing model on the test data: 10.695568819248916
# Perplexity of the 1486 BackoffSmoothing model on the test data: 11.85650589853411
# Perplexity of the 1487 BackoffSmoothing model on the test data: 12.377836354790224
# Perplexity of the 1488 BackoffSmoothing model on the test data: 11.626335201674843
# Perplexity of the 1489 BackoffSmoothing model on the test data: 10.197481205518487
# Perplexity of the 1490 BackoffSmoothing model on the test data: 13.536370652859267
# Perplexity of the 1491 BackoffSmoothing model on the test data: 12.398154711577087
# Perplexity of the 1492 BackoffSmoothing model on the test data: 10.461066931180996
# Perplexity of the 1493 BackoffSmoothing model on the test data: 9.864214892307782
# Perplexity of the 1494 BackoffSmoothing model on the test data: 8.98460074317669
# Perplexity of the 1495 BackoffSmoothing model on the test data: 9.878022458001716
# Perplexity of the 1496 BackoffSmoothing model on the test data: 9.722032628349373
# Perplexity of the 1497 BackoffSmoothing model on the test data: 13.530139109807378
# Perplexity of the 1498 BackoffSmoothing model on the test data: 13.632360108284772
# Perplexity of the 1499 BackoffSmoothing model on the test data: 11.15757983666599
# Perplexity of the 1500 BackoffSmoothing model on the test data: 11.42042615463161
# Perplexity of the 1501 BackoffSmoothing model on the test data: 8.967616975386226
# Perplexity of the 1502 BackoffSmoothing model on the test data: 11.64741046532392
# Perplexity of the 1503 BackoffSmoothing model on the test data: 9.234295402412755
# Perplexity of the 1504 BackoffSmoothing model on the test data: 10.359642496493812
# Perplexity of the 1505 BackoffSmoothing model on the test data: 10.288620411001768
# Perplexity of the 1506 BackoffSmoothing model on the test data: 11.544253022931501
# Perplexity of the 1507 BackoffSmoothing model on the test data: 13.662886229172797
# Perplexity of the 1508 BackoffSmoothing model on the test data: 12.250048490552853
# Perplexity of the 1509 BackoffSmoothing model on the test data: 10.241881517487178
# Perplexity of the 1510 BackoffSmoothing model on the test data: 11.884347411223548
# Perplexity of the 1511 BackoffSmoothing model on the test data: 11.328780462322793
# Perplexity of the 1512 BackoffSmoothing model on the test data: 11.791039702220251
# Perplexity of the 1513 BackoffSmoothing model on the test data: 10.611984400667442
# Perplexity of the 1514 BackoffSmoothing model on the test data: 11.138951239594219
# Perplexity of the 1515 BackoffSmoothing model on the test data: 11.375114251538962
# Perplexity of the 1516 BackoffSmoothing model on the test data: 11.066295789437811
# Perplexity of the 1517 BackoffSmoothing model on the test data: 9.016118206163757
# Perplexity of the 1518 BackoffSmoothing model on the test data: 9.80992821080795
# Perplexity of the 1519 BackoffSmoothing model on the test data: 11.736870296458191
# Perplexity of the 1520 BackoffSmoothing model on the test data: 8.634813565822068
# Perplexity of the 1521 BackoffSmoothing model on the test data: 13.997794891662934
# Perplexity of the 1522 BackoffSmoothing model on the test data: 12.275030474638422
# Perplexity of the 1523 BackoffSmoothing model on the test data: 8.022903337295766
# Perplexity of the 1524 BackoffSmoothing model on the test data: 10.793807417095953
# Perplexity of the 1525 BackoffSmoothing model on the test data: 8.445698747912916
# Perplexity of the 1526 BackoffSmoothing model on the test data: 9.711979864684881
# Perplexity of the 1527 BackoffSmoothing model on the test data: 11.724351885118633
# Perplexity of the 1528 BackoffSmoothing model on the test data: 9.276339704281773
# Perplexity of the 1529 BackoffSmoothing model on the test data: 12.00914090636755
# Perplexity of the 1530 BackoffSmoothing model on the test data: 10.079216725404475
# Perplexity of the 1531 BackoffSmoothing model on the test data: 8.446318796281794
# Perplexity of the 1532 BackoffSmoothing model on the test data: 12.397871087135696
# Perplexity of the 1533 BackoffSmoothing model on the test data: 12.239363634107447
# Perplexity of the 1534 BackoffSmoothing model on the test data: 11.063013853549151
# Perplexity of the 1535 BackoffSmoothing model on the test data: 10.175370987700004
# Perplexity of the 1536 BackoffSmoothing model on the test data: 9.787625999153533
# Perplexity of the 1537 BackoffSmoothing model on the test data: 10.669831359831567
# Perplexity of the 1538 BackoffSmoothing model on the test data: 10.865004283547403
# Perplexity of the 1539 BackoffSmoothing model on the test data: 12.162080424227886
# Perplexity of the 1540 BackoffSmoothing model on the test data: 12.365077786715723
# Perplexity of the 1541 BackoffSmoothing model on the test data: 12.152700290842013
# Perplexity of the 1542 BackoffSmoothing model on the test data: 11.235227857266262
# Perplexity of the 1543 BackoffSmoothing model on the test data: 8.204214491619599
# Perplexity of the 1544 BackoffSmoothing model on the test data: 8.088526774211076
# Perplexity of the 1545 BackoffSmoothing model on the test data: 10.844894888985092
# Perplexity of the 1546 BackoffSmoothing model on the test data: 12.289458888201343
# Perplexity of the 1547 BackoffSmoothing model on the test data: 11.159489519724165
# Perplexity of the 1548 BackoffSmoothing model on the test data: 12.58075439933124
# Perplexity of the 1549 BackoffSmoothing model on the test data: 11.901373493403565
# Perplexity of the 1550 BackoffSmoothing model on the test data: 9.793760127829493
# Perplexity of the 1551 BackoffSmoothing model on the test data: 10.87209509047361
# Perplexity of the 1552 BackoffSmoothing model on the test data: 10.297528777591168
# Perplexity of the 1553 BackoffSmoothing model on the test data: 10.447966346601113
# Perplexity of the 1554 BackoffSmoothing model on the test data: 12.455573280786567
# Perplexity of the 1555 BackoffSmoothing model on the test data: 8.80846541895668
# Perplexity of the 1556 BackoffSmoothing model on the test data: 8.917673274559903
# Perplexity of the 1557 BackoffSmoothing model on the test data: 12.708572293773168
# Perplexity of the 1558 BackoffSmoothing model on the test data: 11.79939076577891
# Perplexity of the 1559 BackoffSmoothing model on the test data: 9.631894140272056
# Perplexity of the 1560 BackoffSmoothing model on the test data: 8.959527334142036
# Perplexity of the 1561 BackoffSmoothing model on the test data: 10.084990794555075
# Perplexity of the 1562 BackoffSmoothing model on the test data: 9.57523603762788
# Perplexity of the 1563 BackoffSmoothing model on the test data: 11.017691433127332
# Perplexity of the 1564 BackoffSmoothing model on the test data: 10.65160603451855
# Perplexity of the 1565 BackoffSmoothing model on the test data: 15.076477620454238
# Perplexity of the 1566 BackoffSmoothing model on the test data: 11.917893679559928
# Perplexity of the 1567 BackoffSmoothing model on the test data: 12.421918863248102
# Perplexity of the 1568 BackoffSmoothing model on the test data: 12.944359681012168
# Perplexity of the 1569 BackoffSmoothing model on the test data: 12.526383184796673
# Perplexity of the 1570 BackoffSmoothing model on the test data: 11.561120201444057
# Perplexity of the 1571 BackoffSmoothing model on the test data: 9.703816757653112
# Perplexity of the 1572 BackoffSmoothing model on the test data: 10.379397013494135
# Perplexity of the 1573 BackoffSmoothing model on the test data: 7.6058228424897205
# Perplexity of the 1574 BackoffSmoothing model on the test data: 11.653220682405674
# Perplexity of the 1575 BackoffSmoothing model on the test data: 9.78104005245321
# Perplexity of the 1576 BackoffSmoothing model on the test data: 13.102678794070924
# Perplexity of the 1577 BackoffSmoothing model on the test data: 11.48863991363087
# Perplexity of the 1578 BackoffSmoothing model on the test data: 10.056972312374905
# Perplexity of the 1579 BackoffSmoothing model on the test data: 12.076384824075133
# Perplexity of the 1580 BackoffSmoothing model on the test data: 11.975502197802776
# Perplexity of the 1581 BackoffSmoothing model on the test data: 11.565382984178473
# Perplexity of the 1582 BackoffSmoothing model on the test data: 10.01218175111278
# Perplexity of the 1583 BackoffSmoothing model on the test data: 11.32688867193181
# Perplexity of the 1584 BackoffSmoothing model on the test data: 11.697236939961565
# Perplexity of the 1585 BackoffSmoothing model on the test data: 10.925475549686997
# Perplexity of the 1586 BackoffSmoothing model on the test data: 9.75200208598232
# Perplexity of the 1587 BackoffSmoothing model on the test data: 11.782256494043448
# Perplexity of the 1588 BackoffSmoothing model on the test data: 9.374305594941896
# Perplexity of the 1589 BackoffSmoothing model on the test data: 9.841461215655196
# Perplexity of the 1590 BackoffSmoothing model on the test data: 10.595633414041224
# Perplexity of the 1591 BackoffSmoothing model on the test data: 12.044867277441881
# Perplexity of the 1592 BackoffSmoothing model on the test data: 11.768915046961144
# Perplexity of the 1593 BackoffSmoothing model on the test data: 9.12972324702095
# Perplexity of the 1594 BackoffSmoothing model on the test data: 10.476956374199784
# Perplexity of the 1595 BackoffSmoothing model on the test data: 10.720231066063304
# Perplexity of the 1596 BackoffSmoothing model on the test data: 12.269229746709042
# Perplexity of the 1597 BackoffSmoothing model on the test data: 10.754294666798247
# Perplexity of the 1598 BackoffSmoothing model on the test data: 12.274113006463551
# Perplexity of the 1599 BackoffSmoothing model on the test data: 13.511982631144832
# Perplexity of the 1600 BackoffSmoothing model on the test data: 12.374324809548549
# Perplexity of the 1601 BackoffSmoothing model on the test data: 9.546917231711133
# Perplexity of the 1602 BackoffSmoothing model on the test data: 11.803905898120616
# Perplexity of the 1603 BackoffSmoothing model on the test data: 11.651896580721262
# Perplexity of the 1604 BackoffSmoothing model on the test data: 10.989066886894596
# Perplexity of the 1605 BackoffSmoothing model on the test data: 12.003113319598526
# Perplexity of the 1606 BackoffSmoothing model on the test data: 7.9816503880536285
# Perplexity of the 1607 BackoffSmoothing model on the test data: 9.898880574018284
# Perplexity of the 1608 BackoffSmoothing model on the test data: 12.089900824502099
# Perplexity of the 1609 BackoffSmoothing model on the test data: 12.572056666119229
# Perplexity of the 1610 BackoffSmoothing model on the test data: 10.956357906206955
# Perplexity of the 1611 BackoffSmoothing model on the test data: 10.63024527991455
# Perplexity of the 1612 BackoffSmoothing model on the test data: 11.89200250023125
# Perplexity of the 1613 BackoffSmoothing model on the test data: 10.968999827783726
# Perplexity of the 1614 BackoffSmoothing model on the test data: 10.96546357665195
# Perplexity of the 1615 BackoffSmoothing model on the test data: 9.117527256628815
# Perplexity of the 1616 BackoffSmoothing model on the test data: 7.682348906418684
# Perplexity of the 1617 BackoffSmoothing model on the test data: 13.152537209460975
# Perplexity of the 1618 BackoffSmoothing model on the test data: 13.739066309360847
# Perplexity of the 1619 BackoffSmoothing model on the test data: 10.32471615860737
# Perplexity of the 1620 BackoffSmoothing model on the test data: 9.981414384356697
# Perplexity of the 1621 BackoffSmoothing model on the test data: 11.231045807682841
# Perplexity of the 1622 BackoffSmoothing model on the test data: 9.527049673352415
# Perplexity of the 1623 BackoffSmoothing model on the test data: 12.725339904332008
# Perplexity of the 1624 BackoffSmoothing model on the test data: 11.64016558411867
# Perplexity of the 1625 BackoffSmoothing model on the test data: 11.32751743475167
# Perplexity of the 1626 BackoffSmoothing model on the test data: 12.421405264539487
# Perplexity of the 1627 BackoffSmoothing model on the test data: 9.105096805234012
# Perplexity of the 1628 BackoffSmoothing model on the test data: 7.588061746762389
# Perplexity of the 1629 BackoffSmoothing model on the test data: 13.2738422433352
# Perplexity of the 1630 BackoffSmoothing model on the test data: 9.419725935627453
# Perplexity of the 1631 BackoffSmoothing model on the test data: 11.137598513887669
# Perplexity of the 1632 BackoffSmoothing model on the test data: 11.364816797565963
# Perplexity of the 1633 BackoffSmoothing model on the test data: 11.875808312764068
# Perplexity of the 1634 BackoffSmoothing model on the test data: 10.972342086937111
# Perplexity of the 1635 BackoffSmoothing model on the test data: 12.65959752623195
# Perplexity of the 1636 BackoffSmoothing model on the test data: 13.178533313276569
# Perplexity of the 1637 BackoffSmoothing model on the test data: 10.088178857108911
# Perplexity of the 1638 BackoffSmoothing model on the test data: 11.42651121125716
# Perplexity of the 1639 BackoffSmoothing model on the test data: 10.651299373900118
# Perplexity of the 1640 BackoffSmoothing model on the test data: 11.15957121663397
# Perplexity of the 1641 BackoffSmoothing model on the test data: 9.297161636991007
# Perplexity of the 1642 BackoffSmoothing model on the test data: 8.703163204149591
# Perplexity of the 1643 BackoffSmoothing model on the test data: 12.579258447396484

# %%
# unigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(1)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1, 0.3, 0.5, 0.7]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 1359.2671923496907
# Perplexity of the 1 Absolute Discounting model on the test data: 2019.8896803896578
# Perplexity of the 2 Absolute Discounting model on the test data: 1894.681655035519
# Perplexity of the 3 Absolute Discounting model on the test data: 1564.5747019000942
# Perplexity of the 4 Absolute Discounting model on the test data: 2199.2778027887275
# Perplexity of the 5 Absolute Discounting model on the test data: 1847.4877816438327
# Perplexity of the 6 Absolute Discounting model on the test data: 1144.3833184895336
# Perplexity of the 7 Absolute Discounting model on the test data: 1181.4442306690078
# Perplexity of the 8 Absolute Discounting model on the test data: 1690.4982172693926
# Perplexity of the 9 Absolute Discounting model on the test data: 2400.1103218888547
# Perplexity of the 10 Absolute Discounting model on the test data: 2093.8585734870117
# Perplexity of the 11 Absolute Discounting model on the test data: 1809.7898486540885
# Perplexity of the 12 Absolute Discounting model on the test data: 936.1593025835582
# Perplexity of the 13 Absolute Discounting model on the test data: 4750.157743279035
# Perplexity of the 14 Absolute Discounting model on the test data: 2738.442842989125
# Perplexity of the 15 Absolute Discounting model on the test data: 989.382571839937
# Perplexity of the 16 Absolute Discounting model on the test data: 2362.9497207806717
# Perplexity of the 17 Absolute Discounting model on the test data: 2004.9230397533156
# Perplexity of the 18 Absolute Discounting model on the test data: 1275.4940929578977
# Perplexity of the 19 Absolute Discounting model on the test data: 1363.77577202463
# Perplexity of the 20 Absolute Discounting model on the test data: 1432.994854665256
# Perplexity of the 21 Absolute Discounting model on the test data: 2208.833074052299
# Perplexity of the 22 Absolute Discounting model on the test data: 4157.920644972573
# Perplexity of the 23 Absolute Discounting model on the test data: 2107.567404443713
# Perplexity of the 24 Absolute Discounting model on the test data: 1570.2149767406831
# Perplexity of the 25 Absolute Discounting model on the test data: 2681.34682200217
# Perplexity of the 26 Absolute Discounting model on the test data: 1249.431748399343
# Perplexity of the 27 Absolute Discounting model on the test data: 921.6028050710602
# Perplexity of the 28 Absolute Discounting model on the test data: 2034.3468110703839
# Perplexity of the 29 Absolute Discounting model on the test data: 1232.6199306567946
# Perplexity of the 30 Absolute Discounting model on the test data: 1754.279435952961
# Perplexity of the 31 Absolute Discounting model on the test data: 1194.8518647024166
# Perplexity of the 32 Absolute Discounting model on the test data: 2723.1042161149194
# Perplexity of the 33 Absolute Discounting model on the test data: 3503.729030272506
# Perplexity of the 34 Absolute Discounting model on the test data: 2154.111882143389
# Perplexity of the 35 Absolute Discounting model on the test data: 2746.993577407261
# Perplexity of the 36 Absolute Discounting model on the test data: 1170.281559023493
# Perplexity of the 37 Absolute Discounting model on the test data: 1851.4172394468758
# Perplexity of the 38 Absolute Discounting model on the test data: 2089.0426807191616
# Perplexity of the 39 Absolute Discounting model on the test data: 1160.0321500166085
# Perplexity of the 40 Absolute Discounting model on the test data: 1232.4513130810114
# Perplexity of the 41 Absolute Discounting model on the test data: 1541.198574991594
# Perplexity of the 42 Absolute Discounting model on the test data: 1426.4800362033031
# Perplexity of the 43 Absolute Discounting model on the test data: 920.2785095365338
# Perplexity of the 44 Absolute Discounting model on the test data: 1983.7794445248246
# Perplexity of the 45 Absolute Discounting model on the test data: 1156.7060207321788
# Perplexity of the 46 Absolute Discounting model on the test data: 1367.0339886017991
# Perplexity of the 47 Absolute Discounting model on the test data: 1717.0902315178373
# Perplexity of the 48 Absolute Discounting model on the test data: 1390.3492973466412
# Perplexity of the 49 Absolute Discounting model on the test data: 1877.6841494765665
# Perplexity of the 50 Absolute Discounting model on the test data: 1073.6078482031687
# Perplexity of the 51 Absolute Discounting model on the test data: 2224.728086076039
# Perplexity of the 52 Absolute Discounting model on the test data: 1532.1609989052004
# Perplexity of the 53 Absolute Discounting model on the test data: 1231.8212653117553
# Perplexity of the 54 Absolute Discounting model on the test data: 1276.3562567863953
# Perplexity of the 55 Absolute Discounting model on the test data: 2151.7438371004255
# Perplexity of the 56 Absolute Discounting model on the test data: 1944.60932622728
# Perplexity of the 57 Absolute Discounting model on the test data: 1523.7348231595927
# Perplexity of the 58 Absolute Discounting model on the test data: 1357.3349313322497
# Perplexity of the 59 Absolute Discounting model on the test data: 1704.8664395639673
# Perplexity of the 60 Absolute Discounting model on the test data: 1927.4961324252124
# Perplexity of the 61 Absolute Discounting model on the test data: 913.2591712616296
# Perplexity of the 62 Absolute Discounting model on the test data: 1340.010643957664
# Perplexity of the 63 Absolute Discounting model on the test data: 1149.6362019501653
# Perplexity of the 64 Absolute Discounting model on the test data: 1628.1271580850155
# Perplexity of the 65 Absolute Discounting model on the test data: 891.9680925407454
# Perplexity of the 66 Absolute Discounting model on the test data: 2169.642396190835
# Perplexity of the 67 Absolute Discounting model on the test data: 1570.5428788489921
# Perplexity of the 68 Absolute Discounting model on the test data: 1068.357088510423
# Perplexity of the 69 Absolute Discounting model on the test data: 1700.1465669725762
# Perplexity of the 70 Absolute Discounting model on the test data: 2236.638238384963
# Perplexity of the 71 Absolute Discounting model on the test data: 1737.0223119940913
# Perplexity of the 72 Absolute Discounting model on the test data: 2779.4004557649005
# Perplexity of the 73 Absolute Discounting model on the test data: 1644.8167177846817
# Perplexity of the 74 Absolute Discounting model on the test data: 1836.7283007740425
# Perplexity of the 75 Absolute Discounting model on the test data: 981.6465616645243
# Perplexity of the 76 Absolute Discounting model on the test data: 1734.840909702108
# Perplexity of the 77 Absolute Discounting model on the test data: 1462.735123662775
# Perplexity of the 78 Absolute Discounting model on the test data: 1112.4612810259753
# Perplexity of the 79 Absolute Discounting model on the test data: 1352.827171292378
# Perplexity of the 80 Absolute Discounting model on the test data: 1229.891409273622
# Perplexity of the 81 Absolute Discounting model on the test data: 1271.984736737081
# Perplexity of the 82 Absolute Discounting model on the test data: 1111.7718266677086
# Perplexity of the 83 Absolute Discounting model on the test data: 954.5702457010402
# Perplexity of the 84 Absolute Discounting model on the test data: 1059.3676918801837
# Perplexity of the 85 Absolute Discounting model on the test data: 1604.311378497294
# Perplexity of the 86 Absolute Discounting model on the test data: 1457.9016148455962
# Perplexity of the 87 Absolute Discounting model on the test data: 1215.7477819683834
# Perplexity of the 88 Absolute Discounting model on the test data: 2054.5320411787034
# Perplexity of the 89 Absolute Discounting model on the test data: 1497.0975220690416
# Perplexity of the 90 Absolute Discounting model on the test data: 1909.6654449901898
# Perplexity of the 91 Absolute Discounting model on the test data: 2097.34499851198
# Perplexity of the 92 Absolute Discounting model on the test data: 1925.2607089794515
# Perplexity of the 93 Absolute Discounting model on the test data: 2031.4088367394384
# Perplexity of the 94 Absolute Discounting model on the test data: 1314.3328711494878
# Perplexity of the 95 Absolute Discounting model on the test data: 1184.7930094519672
# Perplexity of the 96 Absolute Discounting model on the test data: 3486.755143256736
# Perplexity of the 97 Absolute Discounting model on the test data: 943.8154521436294
# Perplexity of the 98 Absolute Discounting model on the test data: 1603.0672556753145
# Perplexity of the 99 Absolute Discounting model on the test data: 1743.6665893862812
# Perplexity of the 100 Absolute Discounting model on the test data: 1062.5980680332589
# Perplexity of the 101 Absolute Discounting model on the test data: 2179.153950493748
# Perplexity of the 102 Absolute Discounting model on the test data: 1978.6347191923614
# Perplexity of the 103 Absolute Discounting model on the test data: 1172.204403493771
# Perplexity of the 104 Absolute Discounting model on the test data: 2056.2307666551083
# Perplexity of the 105 Absolute Discounting model on the test data: 1633.4763959126283
# Perplexity of the 106 Absolute Discounting model on the test data: 2125.8153002287286
# Perplexity of the 107 Absolute Discounting model on the test data: 2253.9028228753928
# Perplexity of the 108 Absolute Discounting model on the test data: 1126.0805812168533
# Perplexity of the 109 Absolute Discounting model on the test data: 1312.8270628152954
# Perplexity of the 110 Absolute Discounting model on the test data: 1447.704656469454
# Perplexity of the 111 Absolute Discounting model on the test data: 1209.420018288154
# Perplexity of the 112 Absolute Discounting model on the test data: 1144.9333692501607
# Perplexity of the 113 Absolute Discounting model on the test data: 1355.3309226835909
# Perplexity of the 114 Absolute Discounting model on the test data: 1697.7532802360638
# Perplexity of the 115 Absolute Discounting model on the test data: 1902.6585998534888
# Perplexity of the 116 Absolute Discounting model on the test data: 1347.2350440215855
# Perplexity of the 117 Absolute Discounting model on the test data: 1638.2442554076722
# Perplexity of the 118 Absolute Discounting model on the test data: 1377.8828316243987
# Perplexity of the 119 Absolute Discounting model on the test data: 1304.3838094123148
# Perplexity of the 120 Absolute Discounting model on the test data: 1191.8069730668096
# Perplexity of the 121 Absolute Discounting model on the test data: 1690.7708949684154
# Perplexity of the 122 Absolute Discounting model on the test data: 1289.9880655161326
# Perplexity of the 123 Absolute Discounting model on the test data: 2059.6483160817497
# Perplexity of the 124 Absolute Discounting model on the test data: 1275.2093528588507
# Perplexity of the 125 Absolute Discounting model on the test data: 1193.2527458694697
# Perplexity of the 126 Absolute Discounting model on the test data: 1414.1615900583581
# Perplexity of the 127 Absolute Discounting model on the test data: 1777.887584104159
# Perplexity of the 128 Absolute Discounting model on the test data: 1568.4012782248997
# Perplexity of the 129 Absolute Discounting model on the test data: 1337.981732991507
# Perplexity of the 130 Absolute Discounting model on the test data: 2070.014906526797
# Perplexity of the 131 Absolute Discounting model on the test data: 1448.943090916227
# Perplexity of the 132 Absolute Discounting model on the test data: 1834.9944145981942
# Perplexity of the 133 Absolute Discounting model on the test data: 1346.8745077912934
# Perplexity of the 134 Absolute Discounting model on the test data: 1667.6352512265603
# Perplexity of the 135 Absolute Discounting model on the test data: 1894.5923952894343
# Perplexity of the 136 Absolute Discounting model on the test data: 1376.3835760496943
# Perplexity of the 137 Absolute Discounting model on the test data: 1172.255697453433
# Perplexity of the 138 Absolute Discounting model on the test data: 2613.5846813504586
# Perplexity of the 139 Absolute Discounting model on the test data: 1664.1040706133867
# Perplexity of the 140 Absolute Discounting model on the test data: 1513.4236721175873
# Perplexity of the 141 Absolute Discounting model on the test data: 1914.699749964081
# Perplexity of the 142 Absolute Discounting model on the test data: 1442.8899777553167
# Perplexity of the 143 Absolute Discounting model on the test data: 2359.2792232357724
# Perplexity of the 144 Absolute Discounting model on the test data: 1018.327329917869
# Perplexity of the 145 Absolute Discounting model on the test data: 1661.3576982379166
# Perplexity of the 146 Absolute Discounting model on the test data: 1723.7435648818516
# Perplexity of the 147 Absolute Discounting model on the test data: 980.3988560671529
# Perplexity of the 148 Absolute Discounting model on the test data: 1210.0502727276719
# Perplexity of the 149 Absolute Discounting model on the test data: 1256.0920471064237
# Perplexity of the 150 Absolute Discounting model on the test data: 1314.12810531758
# Perplexity of the 151 Absolute Discounting model on the test data: 2589.374761926963
# Perplexity of the 152 Absolute Discounting model on the test data: 1561.4294913675944
# Perplexity of the 153 Absolute Discounting model on the test data: 1865.5633382683593
# Perplexity of the 154 Absolute Discounting model on the test data: 1308.2461971721725
# Perplexity of the 155 Absolute Discounting model on the test data: 1807.5873150026534
# Perplexity of the 156 Absolute Discounting model on the test data: 2042.3864553288304
# Perplexity of the 157 Absolute Discounting model on the test data: 2755.2783993635585
# Perplexity of the 158 Absolute Discounting model on the test data: 1647.934037555455
# Perplexity of the 159 Absolute Discounting model on the test data: 1588.6861706771
# Perplexity of the 160 Absolute Discounting model on the test data: 1714.7464716276063
# Perplexity of the 161 Absolute Discounting model on the test data: 2015.2509161142411
# Perplexity of the 162 Absolute Discounting model on the test data: 1631.883113549871
# Perplexity of the 163 Absolute Discounting model on the test data: 1343.8209888120898
# Perplexity of the 164 Absolute Discounting model on the test data: 1222.283401236492
# Perplexity of the 165 Absolute Discounting model on the test data: 1663.694518668135
# Perplexity of the 166 Absolute Discounting model on the test data: 2464.5123597946404
# Perplexity of the 167 Absolute Discounting model on the test data: 2110.0755389494466
# Perplexity of the 168 Absolute Discounting model on the test data: 2105.901910333789
# Perplexity of the 169 Absolute Discounting model on the test data: 1700.1567492424133
# Perplexity of the 170 Absolute Discounting model on the test data: 1317.327285375546
# Perplexity of the 171 Absolute Discounting model on the test data: 1357.8410907666878
# Perplexity of the 172 Absolute Discounting model on the test data: 1545.0652302386145
# Perplexity of the 173 Absolute Discounting model on the test data: 2462.022337322809
# Perplexity of the 174 Absolute Discounting model on the test data: 1206.9333469663327
# Perplexity of the 175 Absolute Discounting model on the test data: 1687.712803009264
# Perplexity of the 176 Absolute Discounting model on the test data: 1871.966800318952
# Perplexity of the 177 Absolute Discounting model on the test data: 2709.272372916294
# Perplexity of the 178 Absolute Discounting model on the test data: 1451.5562709810456
# Perplexity of the 179 Absolute Discounting model on the test data: 1592.468374016561
# Perplexity of the 180 Absolute Discounting model on the test data: 1829.347968165664
# Perplexity of the 181 Absolute Discounting model on the test data: 1436.169836607303
# Perplexity of the 182 Absolute Discounting model on the test data: 1260.7823897643325
# Perplexity of the 183 Absolute Discounting model on the test data: 1406.4982953891551
# Perplexity of the 184 Absolute Discounting model on the test data: 1600.6911197946374
# Perplexity of the 185 Absolute Discounting model on the test data: 1545.672437547883
# Perplexity of the 186 Absolute Discounting model on the test data: 1295.1199021759553
# Perplexity of the 187 Absolute Discounting model on the test data: 1243.8102692089383
# Perplexity of the 188 Absolute Discounting model on the test data: 2726.923815662273
# Perplexity of the 189 Absolute Discounting model on the test data: 902.9248825316104
# Perplexity of the 190 Absolute Discounting model on the test data: 1731.4619821038668
# Perplexity of the 191 Absolute Discounting model on the test data: 2308.2620565796915
# Perplexity of the 192 Absolute Discounting model on the test data: 1130.8545373456743
# Perplexity of the 193 Absolute Discounting model on the test data: 1390.412266177729
# Perplexity of the 194 Absolute Discounting model on the test data: 2079.8978991627664
# Perplexity of the 195 Absolute Discounting model on the test data: 1738.8050934266487
# Perplexity of the 196 Absolute Discounting model on the test data: 1054.3161117105938
# Perplexity of the 197 Absolute Discounting model on the test data: 1932.901877202745
# Perplexity of the 198 Absolute Discounting model on the test data: 1040.8553697981051
# Perplexity of the 199 Absolute Discounting model on the test data: 1938.0206228190837
# Perplexity of the 200 Absolute Discounting model on the test data: 1541.42258191912
# Perplexity of the 201 Absolute Discounting model on the test data: 1279.026819951145
# Perplexity of the 202 Absolute Discounting model on the test data: 1682.4746374951974
# Perplexity of the 203 Absolute Discounting model on the test data: 2035.5479953907388
# Perplexity of the 204 Absolute Discounting model on the test data: 1278.2431877084593
# Perplexity of the 205 Absolute Discounting model on the test data: 2448.228759827058
# Perplexity of the 206 Absolute Discounting model on the test data: 1897.3347584669802
# Perplexity of the 207 Absolute Discounting model on the test data: 2381.6491182157374
# Perplexity of the 208 Absolute Discounting model on the test data: 1102.311329996064
# Perplexity of the 209 Absolute Discounting model on the test data: 1338.2054827563434
# Perplexity of the 210 Absolute Discounting model on the test data: 1184.1322949485132
# Perplexity of the 211 Absolute Discounting model on the test data: 1212.1397546437954
# Perplexity of the 212 Absolute Discounting model on the test data: 1385.6799640158206
# Perplexity of the 213 Absolute Discounting model on the test data: 1610.8025978372868
# Perplexity of the 214 Absolute Discounting model on the test data: 1571.5180527305538
# Perplexity of the 215 Absolute Discounting model on the test data: 1288.6130200386406
# Perplexity of the 216 Absolute Discounting model on the test data: 1894.177651488708
# Perplexity of the 217 Absolute Discounting model on the test data: 1250.6218894988012
# Perplexity of the 218 Absolute Discounting model on the test data: 1450.2166296135936
# Perplexity of the 219 Absolute Discounting model on the test data: 925.5976890268065
# Perplexity of the 220 Absolute Discounting model on the test data: 2045.539556699405
# Perplexity of the 221 Absolute Discounting model on the test data: 1366.5112772656432
# Perplexity of the 222 Absolute Discounting model on the test data: 1238.2302119435785
# Perplexity of the 223 Absolute Discounting model on the test data: 1260.027547895549
# Perplexity of the 224 Absolute Discounting model on the test data: 1015.7107775875934
# Perplexity of the 225 Absolute Discounting model on the test data: 1640.2602035494685
# Perplexity of the 226 Absolute Discounting model on the test data: 1102.6049975802794
# Perplexity of the 227 Absolute Discounting model on the test data: 1544.7602552214598
# Perplexity of the 228 Absolute Discounting model on the test data: 1297.340807815368
# Perplexity of the 229 Absolute Discounting model on the test data: 1356.0910259154987
# Perplexity of the 230 Absolute Discounting model on the test data: 1973.3896469856995
# Perplexity of the 231 Absolute Discounting model on the test data: 1335.4833394767809
# Perplexity of the 232 Absolute Discounting model on the test data: 1030.4681839093164
# Perplexity of the 233 Absolute Discounting model on the test data: 1441.5629410160595
# Perplexity of the 234 Absolute Discounting model on the test data: 1287.370962727848
# Perplexity of the 235 Absolute Discounting model on the test data: 1871.700642783809
# Perplexity of the 236 Absolute Discounting model on the test data: 1943.2729384202166
# Perplexity of the 237 Absolute Discounting model on the test data: 1844.573189032047
# Perplexity of the 238 Absolute Discounting model on the test data: 1768.4053499808674
# Perplexity of the 239 Absolute Discounting model on the test data: 1537.4887835150378
# Perplexity of the 240 Absolute Discounting model on the test data: 1251.7119398255793
# Perplexity of the 241 Absolute Discounting model on the test data: 1540.7077582103
# Perplexity of the 242 Absolute Discounting model on the test data: 1418.001665378596
# Perplexity of the 243 Absolute Discounting model on the test data: 1432.6252112545021
# Perplexity of the 244 Absolute Discounting model on the test data: 1658.9949258382123
# Perplexity of the 245 Absolute Discounting model on the test data: 1158.820054673384
# Perplexity of the 246 Absolute Discounting model on the test data: 1306.2031748581244
# Perplexity of the 247 Absolute Discounting model on the test data: 1409.1923050827143
# Perplexity of the 248 Absolute Discounting model on the test data: 1597.4967888424292
# Perplexity of the 249 Absolute Discounting model on the test data: 1400.230578832414
# Perplexity of the 250 Absolute Discounting model on the test data: 1291.5589880650296
# Perplexity of the 251 Absolute Discounting model on the test data: 1631.7509495552242
# Perplexity of the 252 Absolute Discounting model on the test data: 1132.996600325397
# Perplexity of the 253 Absolute Discounting model on the test data: 2705.6209505807865
# Perplexity of the 254 Absolute Discounting model on the test data: 2361.6201685554124
# Perplexity of the 255 Absolute Discounting model on the test data: 2302.9080704389708
# Perplexity of the 256 Absolute Discounting model on the test data: 1586.145141668109
# Perplexity of the 257 Absolute Discounting model on the test data: 2222.4458991033885
# Perplexity of the 258 Absolute Discounting model on the test data: 1780.1924739970925
# Perplexity of the 259 Absolute Discounting model on the test data: 1931.210265442226
# Perplexity of the 260 Absolute Discounting model on the test data: 1425.801763649043
# Perplexity of the 261 Absolute Discounting model on the test data: 1466.8409462869354
# Perplexity of the 262 Absolute Discounting model on the test data: 1224.7108965571088
# Perplexity of the 263 Absolute Discounting model on the test data: 1656.0051421298342
# Perplexity of the 264 Absolute Discounting model on the test data: 880.2861464076066
# Perplexity of the 265 Absolute Discounting model on the test data: 1071.501938659563
# Perplexity of the 266 Absolute Discounting model on the test data: 1820.017224607413
# Perplexity of the 267 Absolute Discounting model on the test data: 2369.8490979360563
# Perplexity of the 268 Absolute Discounting model on the test data: 1873.137984512528
# Perplexity of the 269 Absolute Discounting model on the test data: 940.1417442178632
# Perplexity of the 270 Absolute Discounting model on the test data: 1317.7590756350282
# Perplexity of the 271 Absolute Discounting model on the test data: 1332.1243443445446
# Perplexity of the 272 Absolute Discounting model on the test data: 2000.8381692517341
# Perplexity of the 273 Absolute Discounting model on the test data: 1519.8222393542148
# Perplexity of the 274 Absolute Discounting model on the test data: 2338.590802037798
# Perplexity of the 275 Absolute Discounting model on the test data: 1517.8465814321921
# Perplexity of the 276 Absolute Discounting model on the test data: 1992.9999650995742
# Perplexity of the 277 Absolute Discounting model on the test data: 1247.927508850541
# Perplexity of the 278 Absolute Discounting model on the test data: 1436.9943886430694
# Perplexity of the 279 Absolute Discounting model on the test data: 1918.6511436281583
# Perplexity of the 280 Absolute Discounting model on the test data: 1027.174130525788
# Perplexity of the 281 Absolute Discounting model on the test data: 1493.9490381072553
# Perplexity of the 282 Absolute Discounting model on the test data: 1410.6666097670852
# Perplexity of the 283 Absolute Discounting model on the test data: 1731.5643993994859
# Perplexity of the 284 Absolute Discounting model on the test data: 1092.1264166670612
# Perplexity of the 285 Absolute Discounting model on the test data: 1440.3055133571381
# Perplexity of the 286 Absolute Discounting model on the test data: 1310.675730180067
# Perplexity of the 287 Absolute Discounting model on the test data: 1264.4757227351736
# Perplexity of the 288 Absolute Discounting model on the test data: 1917.576218812013
# Perplexity of the 289 Absolute Discounting model on the test data: 1429.1466522682958
# Perplexity of the 290 Absolute Discounting model on the test data: 3408.5117778473887
# Perplexity of the 291 Absolute Discounting model on the test data: 1478.2292769349012
# Perplexity of the 292 Absolute Discounting model on the test data: 1934.4639746554049
# Perplexity of the 293 Absolute Discounting model on the test data: 1772.742652580549
# Perplexity of the 294 Absolute Discounting model on the test data: 1318.5528530357442
# Perplexity of the 295 Absolute Discounting model on the test data: 2111.5864095293664
# Perplexity of the 296 Absolute Discounting model on the test data: 987.983964921823
# Perplexity of the 297 Absolute Discounting model on the test data: 1526.674355167617
# Perplexity of the 298 Absolute Discounting model on the test data: 2711.5201507820607
# Perplexity of the 299 Absolute Discounting model on the test data: 923.4822724992515
# Perplexity of the 300 Absolute Discounting model on the test data: 1393.999079548106
# Perplexity of the 301 Absolute Discounting model on the test data: 2330.0149951660305
# Perplexity of the 302 Absolute Discounting model on the test data: 1154.2249992180143
# Perplexity of the 303 Absolute Discounting model on the test data: 1751.4993847887222
# Perplexity of the 304 Absolute Discounting model on the test data: 1671.3270589297465
# Perplexity of the 305 Absolute Discounting model on the test data: 2428.603751525429
# Perplexity of the 306 Absolute Discounting model on the test data: 1671.4088808688432
# Perplexity of the 307 Absolute Discounting model on the test data: 1121.3562285818005
# Perplexity of the 308 Absolute Discounting model on the test data: 1974.4439955527184
# Perplexity of the 309 Absolute Discounting model on the test data: 1197.5247010010596
# Perplexity of the 310 Absolute Discounting model on the test data: 1438.0185952032616
# Perplexity of the 311 Absolute Discounting model on the test data: 1095.5563762908132
# Perplexity of the 312 Absolute Discounting model on the test data: 1728.9512408768633
# Perplexity of the 313 Absolute Discounting model on the test data: 1841.9063190930306
# Perplexity of the 314 Absolute Discounting model on the test data: 1244.0128891525235
# Perplexity of the 315 Absolute Discounting model on the test data: 1473.8506444169634
# Perplexity of the 316 Absolute Discounting model on the test data: 1967.680100046151
# Perplexity of the 317 Absolute Discounting model on the test data: 1267.1059236244275
# Perplexity of the 318 Absolute Discounting model on the test data: 1731.1727127503343
# Perplexity of the 319 Absolute Discounting model on the test data: 2435.500224443745
# Perplexity of the 320 Absolute Discounting model on the test data: 1960.864378673245
# Perplexity of the 321 Absolute Discounting model on the test data: 1252.349623180169
# Perplexity of the 322 Absolute Discounting model on the test data: 1398.9277747403137
# Perplexity of the 323 Absolute Discounting model on the test data: 1224.0187454924067
# Perplexity of the 324 Absolute Discounting model on the test data: 1949.2439751907455
# Perplexity of the 325 Absolute Discounting model on the test data: 1083.7224546251473
# Perplexity of the 326 Absolute Discounting model on the test data: 2170.61647314372
# Perplexity of the 327 Absolute Discounting model on the test data: 1109.5863051739009
# Perplexity of the 328 Absolute Discounting model on the test data: 1447.3711654106671
# Perplexity of the 329 Absolute Discounting model on the test data: 1815.841232636345
# Perplexity of the 330 Absolute Discounting model on the test data: 1366.439882376593
# Perplexity of the 331 Absolute Discounting model on the test data: 3261.047133362152
# Perplexity of the 332 Absolute Discounting model on the test data: 1868.4975994428676
# Perplexity of the 333 Absolute Discounting model on the test data: 1275.7577988574128
# Perplexity of the 334 Absolute Discounting model on the test data: 985.8798313981619
# Perplexity of the 335 Absolute Discounting model on the test data: 1850.9497684665478
# Perplexity of the 336 Absolute Discounting model on the test data: 1416.1100866879513
# Perplexity of the 337 Absolute Discounting model on the test data: 4623.883675893741
# Perplexity of the 338 Absolute Discounting model on the test data: 1427.0635258148968
# Perplexity of the 339 Absolute Discounting model on the test data: 1064.1382093684108
# Perplexity of the 340 Absolute Discounting model on the test data: 2201.234577509791
# Perplexity of the 341 Absolute Discounting model on the test data: 1392.6082702659942
# Perplexity of the 342 Absolute Discounting model on the test data: 1415.987706265156
# Perplexity of the 343 Absolute Discounting model on the test data: 937.7274517469574
# Perplexity of the 344 Absolute Discounting model on the test data: 1381.9772609635113
# Perplexity of the 345 Absolute Discounting model on the test data: 1915.1677850142385
# Perplexity of the 346 Absolute Discounting model on the test data: 1918.133010223864
# Perplexity of the 347 Absolute Discounting model on the test data: 2151.9807628854496
# Perplexity of the 348 Absolute Discounting model on the test data: 1290.3643435090808
# Perplexity of the 349 Absolute Discounting model on the test data: 1244.1087766127614
# Perplexity of the 350 Absolute Discounting model on the test data: 1815.0399605248958
# Perplexity of the 351 Absolute Discounting model on the test data: 1977.1902683222118
# Perplexity of the 352 Absolute Discounting model on the test data: 1170.696994174799
# Perplexity of the 353 Absolute Discounting model on the test data: 1269.3372341554673
# Perplexity of the 354 Absolute Discounting model on the test data: 1220.276434041397
# Perplexity of the 355 Absolute Discounting model on the test data: 1371.5876358340508
# Perplexity of the 356 Absolute Discounting model on the test data: 1204.257156228475
# Perplexity of the 357 Absolute Discounting model on the test data: 1169.8635925229855
# Perplexity of the 358 Absolute Discounting model on the test data: 1494.079978375091
# Perplexity of the 359 Absolute Discounting model on the test data: 1353.340644693481
# Perplexity of the 360 Absolute Discounting model on the test data: 1643.49576145882
# Perplexity of the 361 Absolute Discounting model on the test data: 1135.5908853715428
# Perplexity of the 362 Absolute Discounting model on the test data: 1540.406406311055
# Perplexity of the 363 Absolute Discounting model on the test data: 1531.182086139772
# Perplexity of the 364 Absolute Discounting model on the test data: 1341.1868067942837
# Perplexity of the 365 Absolute Discounting model on the test data: 2022.3463692707544
# Perplexity of the 366 Absolute Discounting model on the test data: 1802.8767144847982
# Perplexity of the 367 Absolute Discounting model on the test data: 1880.6962591563351
# Perplexity of the 368 Absolute Discounting model on the test data: 882.6388107048849
# Perplexity of the 369 Absolute Discounting model on the test data: 1714.536451227048
# Perplexity of the 370 Absolute Discounting model on the test data: 1178.5686274749467
# Perplexity of the 371 Absolute Discounting model on the test data: 1606.5885840459123
# Perplexity of the 372 Absolute Discounting model on the test data: 1405.5130921589714
# Perplexity of the 373 Absolute Discounting model on the test data: 1998.4970373856684
# Perplexity of the 374 Absolute Discounting model on the test data: 1485.1842250165057
# Perplexity of the 375 Absolute Discounting model on the test data: 2778.1763882097143
# Perplexity of the 376 Absolute Discounting model on the test data: 1700.1061473047355
# Perplexity of the 377 Absolute Discounting model on the test data: 2248.9061968848728
# Perplexity of the 378 Absolute Discounting model on the test data: 1848.407594616153
# Perplexity of the 379 Absolute Discounting model on the test data: 1287.807783314809
# Perplexity of the 380 Absolute Discounting model on the test data: 1177.008323787383
# Perplexity of the 381 Absolute Discounting model on the test data: 1505.2840583377579
# Perplexity of the 382 Absolute Discounting model on the test data: 1418.893833506462
# Perplexity of the 383 Absolute Discounting model on the test data: 1287.2790616427026
# Perplexity of the 384 Absolute Discounting model on the test data: 1239.5747274201683
# Perplexity of the 385 Absolute Discounting model on the test data: 1437.5960498275488
# Perplexity of the 386 Absolute Discounting model on the test data: 1125.4370926023153
# Perplexity of the 387 Absolute Discounting model on the test data: 1908.39927506727
# Perplexity of the 388 Absolute Discounting model on the test data: 1700.3533497541232
# Perplexity of the 389 Absolute Discounting model on the test data: 1616.631650974898
# Perplexity of the 390 Absolute Discounting model on the test data: 1464.0828654680743
# Perplexity of the 391 Absolute Discounting model on the test data: 1595.0188687267087
# Perplexity of the 392 Absolute Discounting model on the test data: 1480.2147291562712
# Perplexity of the 393 Absolute Discounting model on the test data: 1029.1005983459165
# Perplexity of the 394 Absolute Discounting model on the test data: 1284.3522407964972
# Perplexity of the 395 Absolute Discounting model on the test data: 1859.96598214801
# Perplexity of the 396 Absolute Discounting model on the test data: 1098.4814173417053
# Perplexity of the 397 Absolute Discounting model on the test data: 974.448613423232
# Perplexity of the 398 Absolute Discounting model on the test data: 1647.843817077672
# Perplexity of the 399 Absolute Discounting model on the test data: 1852.5463216920225
# Perplexity of the 400 Absolute Discounting model on the test data: 1088.9830394428539
# Perplexity of the 401 Absolute Discounting model on the test data: 1543.0871274520628
# Perplexity of the 402 Absolute Discounting model on the test data: 2166.362178514205
# Perplexity of the 403 Absolute Discounting model on the test data: 1140.7663519845566
# Perplexity of the 404 Absolute Discounting model on the test data: 1186.2205118751442
# Perplexity of the 405 Absolute Discounting model on the test data: 1155.6153231368237
# Perplexity of the 406 Absolute Discounting model on the test data: 1862.9198878703173
# Perplexity of the 407 Absolute Discounting model on the test data: 1646.3119071024103
# Perplexity of the 408 Absolute Discounting model on the test data: 1213.4888489028872
# Perplexity of the 409 Absolute Discounting model on the test data: 1208.149992625339
# Perplexity of the 410 Absolute Discounting model on the test data: 1524.8720033924453
# Perplexity of the 411 Absolute Discounting model on the test data: 2049.8136797743605
# Perplexity of the 412 Absolute Discounting model on the test data: 2372.141714108093
# Perplexity of the 413 Absolute Discounting model on the test data: 1406.9903275081083
# Perplexity of the 414 Absolute Discounting model on the test data: 2202.527879645619
# Perplexity of the 415 Absolute Discounting model on the test data: 1152.689237270147
# Perplexity of the 416 Absolute Discounting model on the test data: 1930.438238898032
# Perplexity of the 417 Absolute Discounting model on the test data: 1403.3508784866376
# Perplexity of the 418 Absolute Discounting model on the test data: 1399.7628344078134
# Perplexity of the 419 Absolute Discounting model on the test data: 1506.2014753557162
# Perplexity of the 420 Absolute Discounting model on the test data: 1717.8111121335862
# Perplexity of the 421 Absolute Discounting model on the test data: 1302.9960346256007
# Perplexity of the 422 Absolute Discounting model on the test data: 1977.368621256485
# Perplexity of the 423 Absolute Discounting model on the test data: 1153.7167433859424
# Perplexity of the 424 Absolute Discounting model on the test data: 1321.5705115843296
# Perplexity of the 425 Absolute Discounting model on the test data: 1683.515372024955
# Perplexity of the 426 Absolute Discounting model on the test data: 1776.6533208013557
# Perplexity of the 427 Absolute Discounting model on the test data: 1699.4163471480178
# Perplexity of the 428 Absolute Discounting model on the test data: 935.3654911839438
# Perplexity of the 429 Absolute Discounting model on the test data: 1446.7657264247064
# Perplexity of the 430 Absolute Discounting model on the test data: 1711.2036365928964
# Perplexity of the 431 Absolute Discounting model on the test data: 1637.0237730032466
# Perplexity of the 432 Absolute Discounting model on the test data: 1499.477047293724
# Perplexity of the 433 Absolute Discounting model on the test data: 1079.4962156593897
# Perplexity of the 434 Absolute Discounting model on the test data: 1199.9012220517031
# Perplexity of the 435 Absolute Discounting model on the test data: 2001.943103191059
# Perplexity of the 436 Absolute Discounting model on the test data: 1469.8311770556936
# Perplexity of the 437 Absolute Discounting model on the test data: 2681.9184780410237
# Perplexity of the 438 Absolute Discounting model on the test data: 1994.8553459292552
# Perplexity of the 439 Absolute Discounting model on the test data: 2881.7642447595185
# Perplexity of the 440 Absolute Discounting model on the test data: 943.778294900299
# Perplexity of the 441 Absolute Discounting model on the test data: 1537.3298692606334
# Perplexity of the 442 Absolute Discounting model on the test data: 1209.7762128114202
# Perplexity of the 443 Absolute Discounting model on the test data: 1595.3865528729461
# Perplexity of the 444 Absolute Discounting model on the test data: 911.0569403618105
# Perplexity of the 445 Absolute Discounting model on the test data: 1275.1990305079546
# Perplexity of the 446 Absolute Discounting model on the test data: 3543.315425144193
# Perplexity of the 447 Absolute Discounting model on the test data: 1206.7895662273481
# Perplexity of the 448 Absolute Discounting model on the test data: 1273.8908331017042
# Perplexity of the 449 Absolute Discounting model on the test data: 1686.8377143433627
# Perplexity of the 450 Absolute Discounting model on the test data: 951.8209118047305
# Perplexity of the 451 Absolute Discounting model on the test data: 1047.1112943395026
# Perplexity of the 452 Absolute Discounting model on the test data: 2272.3537858009827
# Perplexity of the 453 Absolute Discounting model on the test data: 1171.7241377422808
# Perplexity of the 454 Absolute Discounting model on the test data: 1227.1124931545073
# Perplexity of the 455 Absolute Discounting model on the test data: 1291.88845940493
# Perplexity of the 456 Absolute Discounting model on the test data: 1755.054615482304
# Perplexity of the 457 Absolute Discounting model on the test data: 1250.7779331218103
# Perplexity of the 458 Absolute Discounting model on the test data: 1355.1092524156147
# Perplexity of the 459 Absolute Discounting model on the test data: 1964.3991719793617
# Perplexity of the 460 Absolute Discounting model on the test data: 1871.8404391885142
# Perplexity of the 461 Absolute Discounting model on the test data: 2657.16339158539
# Perplexity of the 462 Absolute Discounting model on the test data: 1226.8387319278318
# Perplexity of the 463 Absolute Discounting model on the test data: 1239.6239497638746
# Perplexity of the 464 Absolute Discounting model on the test data: 1774.7339342346759
# Perplexity of the 465 Absolute Discounting model on the test data: 2264.334848620745
# Perplexity of the 466 Absolute Discounting model on the test data: 2644.731488370741
# Perplexity of the 467 Absolute Discounting model on the test data: 1524.6439683699014
# Perplexity of the 468 Absolute Discounting model on the test data: 1708.038216545524
# Perplexity of the 469 Absolute Discounting model on the test data: 983.067758847328
# Perplexity of the 470 Absolute Discounting model on the test data: 1881.7250645822455
# Perplexity of the 471 Absolute Discounting model on the test data: 1486.7036235465862
# Perplexity of the 472 Absolute Discounting model on the test data: 1905.8815967607002
# Perplexity of the 473 Absolute Discounting model on the test data: 1308.8936221427452
# Perplexity of the 474 Absolute Discounting model on the test data: 1039.650526602669
# Perplexity of the 475 Absolute Discounting model on the test data: 1243.7500138775072
# Perplexity of the 476 Absolute Discounting model on the test data: 1331.1246224613744
# Perplexity of the 477 Absolute Discounting model on the test data: 1178.091333434129
# Perplexity of the 478 Absolute Discounting model on the test data: 1497.8874006774333
# Perplexity of the 479 Absolute Discounting model on the test data: 2259.096511376189
# Perplexity of the 480 Absolute Discounting model on the test data: 2413.2692611169705
# Perplexity of the 481 Absolute Discounting model on the test data: 1648.3069010425163
# Perplexity of the 482 Absolute Discounting model on the test data: 1181.5197475920195
# Perplexity of the 483 Absolute Discounting model on the test data: 1142.4837376685618
# Perplexity of the 484 Absolute Discounting model on the test data: 1429.8983204796752
# Perplexity of the 485 Absolute Discounting model on the test data: 1537.9760494332518
# Perplexity of the 486 Absolute Discounting model on the test data: 1015.7285500891802
# Perplexity of the 487 Absolute Discounting model on the test data: 2732.9312085256365
# Perplexity of the 488 Absolute Discounting model on the test data: 1940.9568453864713
# Perplexity of the 489 Absolute Discounting model on the test data: 1190.723250858139
# Perplexity of the 490 Absolute Discounting model on the test data: 1524.8689738071948
# Perplexity of the 491 Absolute Discounting model on the test data: 1247.1202968860218
# Perplexity of the 492 Absolute Discounting model on the test data: 1031.9211377952847
# Perplexity of the 493 Absolute Discounting model on the test data: 1743.1641421008862
# Perplexity of the 494 Absolute Discounting model on the test data: 1626.633068841315
# Perplexity of the 495 Absolute Discounting model on the test data: 1706.2934371690667
# Perplexity of the 496 Absolute Discounting model on the test data: 1455.902512064399
# Perplexity of the 497 Absolute Discounting model on the test data: 1484.0674738902283
# Perplexity of the 498 Absolute Discounting model on the test data: 988.535946816319
# Perplexity of the 499 Absolute Discounting model on the test data: 896.519113435641
# Perplexity of the 500 Absolute Discounting model on the test data: 2379.5700263271656
# Perplexity of the 501 Absolute Discounting model on the test data: 1196.148316166233
# Perplexity of the 502 Absolute Discounting model on the test data: 1754.3276750175664
# Perplexity of the 503 Absolute Discounting model on the test data: 1273.442117336712
# Perplexity of the 504 Absolute Discounting model on the test data: 1288.623880805731
# Perplexity of the 505 Absolute Discounting model on the test data: 1333.878770535126
# Perplexity of the 506 Absolute Discounting model on the test data: 1380.167067547092
# Perplexity of the 507 Absolute Discounting model on the test data: 1658.9580917424018
# Perplexity of the 508 Absolute Discounting model on the test data: 1114.8788419740588
# Perplexity of the 509 Absolute Discounting model on the test data: 1857.7151063619951
# Perplexity of the 510 Absolute Discounting model on the test data: 1441.9287739643935
# Perplexity of the 511 Absolute Discounting model on the test data: 1582.122710223098
# Perplexity of the 512 Absolute Discounting model on the test data: 1659.9576987668252
# Perplexity of the 513 Absolute Discounting model on the test data: 1275.1561032060247
# Perplexity of the 514 Absolute Discounting model on the test data: 2214.0698288307517
# Perplexity of the 515 Absolute Discounting model on the test data: 993.4593418527672
# Perplexity of the 516 Absolute Discounting model on the test data: 1148.7599631971675
# Perplexity of the 517 Absolute Discounting model on the test data: 1446.805072060925
# Perplexity of the 518 Absolute Discounting model on the test data: 1209.4917549468316
# Perplexity of the 519 Absolute Discounting model on the test data: 1992.1706871043602
# Perplexity of the 520 Absolute Discounting model on the test data: 1361.9485591645987
# Perplexity of the 521 Absolute Discounting model on the test data: 1632.5917994893402
# Perplexity of the 522 Absolute Discounting model on the test data: 2066.9539694941523
# Perplexity of the 523 Absolute Discounting model on the test data: 1679.3325119642545
# Perplexity of the 524 Absolute Discounting model on the test data: 1139.463712570713
# Perplexity of the 525 Absolute Discounting model on the test data: 1641.9662880212234
# Perplexity of the 526 Absolute Discounting model on the test data: 2964.164315303761
# Perplexity of the 527 Absolute Discounting model on the test data: 1589.5370132895537
# Perplexity of the 528 Absolute Discounting model on the test data: 1590.9414016977153
# Perplexity of the 529 Absolute Discounting model on the test data: 1923.5907953113408
# Perplexity of the 530 Absolute Discounting model on the test data: 1445.2952751130808
# Perplexity of the 531 Absolute Discounting model on the test data: 1025.4932041114957
# Perplexity of the 532 Absolute Discounting model on the test data: 1164.2600802888865
# Perplexity of the 533 Absolute Discounting model on the test data: 1846.4185313771527
# Perplexity of the 534 Absolute Discounting model on the test data: 1525.7484834152003
# Perplexity of the 535 Absolute Discounting model on the test data: 937.2294936270071
# Perplexity of the 536 Absolute Discounting model on the test data: 1605.0373331120552
# Perplexity of the 537 Absolute Discounting model on the test data: 2022.3220182879504
# Perplexity of the 538 Absolute Discounting model on the test data: 1551.7690067395683
# Perplexity of the 539 Absolute Discounting model on the test data: 2386.2758381094886
# Perplexity of the 540 Absolute Discounting model on the test data: 1258.690203371914
# Perplexity of the 541 Absolute Discounting model on the test data: 1760.0324635904374
# Perplexity of the 542 Absolute Discounting model on the test data: 950.3952125650595
# Perplexity of the 543 Absolute Discounting model on the test data: 1228.0919709653526
# Perplexity of the 544 Absolute Discounting model on the test data: 1642.3373150258872
# Perplexity of the 545 Absolute Discounting model on the test data: 1487.3863883886706
# Perplexity of the 546 Absolute Discounting model on the test data: 1710.2380280938346
# Perplexity of the 547 Absolute Discounting model on the test data: 1796.308311851133
# Perplexity of the 548 Absolute Discounting model on the test data: 1826.1147367610465
# Perplexity of the 549 Absolute Discounting model on the test data: 1449.7623675433558
# Perplexity of the 550 Absolute Discounting model on the test data: 1121.9482356310452
# Perplexity of the 551 Absolute Discounting model on the test data: 2238.7757994720782
# Perplexity of the 552 Absolute Discounting model on the test data: 1651.6097299003693
# Perplexity of the 553 Absolute Discounting model on the test data: 737.9439655281445
# Perplexity of the 554 Absolute Discounting model on the test data: 1328.893935969608
# Perplexity of the 555 Absolute Discounting model on the test data: 1157.0459144102956
# Perplexity of the 556 Absolute Discounting model on the test data: 1173.632617589421
# Perplexity of the 557 Absolute Discounting model on the test data: 1609.4626053783443
# Perplexity of the 558 Absolute Discounting model on the test data: 1033.04223021923
# Perplexity of the 559 Absolute Discounting model on the test data: 1152.4084527313898
# Perplexity of the 560 Absolute Discounting model on the test data: 1333.7726442696219
# ...
# Perplexity of the 1460 Absolute Discounting model on the test data: 1022.5809233996704
# Perplexity of the 1461 Absolute Discounting model on the test data: 1498.4662966811627
# Perplexity of the 1462 Absolute Discounting model on the test data: 1244.7787540805066
# Perplexity of the 1463 Absolute Discounting model on the test data: 1056.2702623547996
# Perplexity of the 1464 Absolute Discounting model on the test data: 1612.5246468922364
# Perplexity of the 1465 Absolute Discounting model on the test data: 1485.9157023255002
# Perplexity of the 1466 Absolute Discounting model on the test data: 10623.761052855592
# Perplexity of the 1467 Absolute Discounting model on the test data: 2305.1186586129074
# Perplexity of the 1468 Absolute Discounting model on the test data: 1975.2046884872964
# Perplexity of the 1469 Absolute Discounting model on the test data: 1928.1525894065376
# Perplexity of the 1470 Absolute Discounting model on the test data: 1726.5479951349573
# Perplexity of the 1471 Absolute Discounting model on the test data: 1180.2414478533449
# Perplexity of the 1472 Absolute Discounting model on the test data: 1415.26298620295
# Perplexity of the 1473 Absolute Discounting model on the test data: 1339.5154664190886
# Perplexity of the 1474 Absolute Discounting model on the test data: 1485.5018097360328
# Perplexity of the 1475 Absolute Discounting model on the test data: 1008.7725015135318
# Perplexity of the 1476 Absolute Discounting model on the test data: 1025.0675280577163
# Perplexity of the 1477 Absolute Discounting model on the test data: 1403.9798884654876
# Perplexity of the 1478 Absolute Discounting model on the test data: 1426.633007581807
# Perplexity of the 1479 Absolute Discounting model on the test data: 1589.355859037297
# Perplexity of the 1480 Absolute Discounting model on the test data: 2150.8162333621385
# Perplexity of the 1481 Absolute Discounting model on the test data: 1294.4843183745957
# Perplexity of the 1482 Absolute Discounting model on the test data: 1513.579095661056
# Perplexity of the 1483 Absolute Discounting model on the test data: 1206.3935206019537
# Perplexity of the 1484 Absolute Discounting model on the test data: 1189.1107804246308
# Perplexity of the 1485 Absolute Discounting model on the test data: 1230.2546067538929
# Perplexity of the 1486 Absolute Discounting model on the test data: 1822.5366723959987
# Perplexity of the 1487 Absolute Discounting model on the test data: 1367.3084869094457
# Perplexity of the 1488 Absolute Discounting model on the test data: 1857.9127195203957
# Perplexity of the 1489 Absolute Discounting model on the test data: 1251.2122419396935
# Perplexity of the 1490 Absolute Discounting model on the test data: 1496.374976479981
# Perplexity of the 1491 Absolute Discounting model on the test data: 1309.3127211132614
# Perplexity of the 1492 Absolute Discounting model on the test data: 1623.056050360757
# Perplexity of the 1493 Absolute Discounting model on the test data: 1219.0340812999088
# Perplexity of the 1494 Absolute Discounting model on the test data: 1666.9574662594443
# Perplexity of the 1495 Absolute Discounting model on the test data: 1088.3606924845833
# Perplexity of the 1496 Absolute Discounting model on the test data: 1460.724636840254
# Perplexity of the 1497 Absolute Discounting model on the test data: 1945.4873839798602
# Perplexity of the 1498 Absolute Discounting model on the test data: 1285.4905379505756
# Perplexity of the 1499 Absolute Discounting model on the test data: 1674.6799809437928
# Perplexity of the 1500 Absolute Discounting model on the test data: 1394.3298544774875
# Perplexity of the 1501 Absolute Discounting model on the test data: 943.0465459689657
# Perplexity of the 1502 Absolute Discounting model on the test data: 1364.7388088835824
# Perplexity of the 1503 Absolute Discounting model on the test data: 1989.9179588512004
# Perplexity of the 1504 Absolute Discounting model on the test data: 1152.674409287282
# Perplexity of the 1505 Absolute Discounting model on the test data: 1851.3465015346903
# Perplexity of the 1506 Absolute Discounting model on the test data: 2374.4052107595644
# Perplexity of the 1507 Absolute Discounting model on the test data: 972.25497100182
# Perplexity of the 1508 Absolute Discounting model on the test data: 1192.3279979688725
# Perplexity of the 1509 Absolute Discounting model on the test data: 1724.952147437883
# Perplexity of the 1510 Absolute Discounting model on the test data: 1785.6000486712915
# Perplexity of the 1511 Absolute Discounting model on the test data: 1663.0283465712364
# Perplexity of the 1512 Absolute Discounting model on the test data: 1720.5002893100032
# Perplexity of the 1513 Absolute Discounting model on the test data: 1227.62995805726
# Perplexity of the 1514 Absolute Discounting model on the test data: 1287.0839187583585
# Perplexity of the 1515 Absolute Discounting model on the test data: 948.6012726426926
# Perplexity of the 1516 Absolute Discounting model on the test data: 1422.1216719212616
# Perplexity of the 1517 Absolute Discounting model on the test data: 2060.3615989096693
# Perplexity of the 1518 Absolute Discounting model on the test data: 1621.193984812085
# Perplexity of the 1519 Absolute Discounting model on the test data: 1615.9135973298091
# Perplexity of the 1520 Absolute Discounting model on the test data: 2143.3202475693934
# Perplexity of the 1521 Absolute Discounting model on the test data: 957.5381597983225
# Perplexity of the 1522 Absolute Discounting model on the test data: 2279.7927873998337
# Perplexity of the 1523 Absolute Discounting model on the test data: 1869.4668173369146
# Perplexity of the 1524 Absolute Discounting model on the test data: 1608.1733278029553
# Perplexity of the 1525 Absolute Discounting model on the test data: 1392.666127106457
# Perplexity of the 1526 Absolute Discounting model on the test data: 2611.44073165161
# Perplexity of the 1527 Absolute Discounting model on the test data: 1942.524516636832
# Perplexity of the 1528 Absolute Discounting model on the test data: 1952.9776695207127
# Perplexity of the 1529 Absolute Discounting model on the test data: 850.7004759205278
# Perplexity of the 1530 Absolute Discounting model on the test data: 1633.8711355969238
# Perplexity of the 1531 Absolute Discounting model on the test data: 1286.0719396247716
# Perplexity of the 1532 Absolute Discounting model on the test data: 1955.9265305275055
# Perplexity of the 1533 Absolute Discounting model on the test data: 1915.618829102398
# Perplexity of the 1534 Absolute Discounting model on the test data: 1175.912176570173
# Perplexity of the 1535 Absolute Discounting model on the test data: 1743.63934858221
# Perplexity of the 1536 Absolute Discounting model on the test data: 1734.6549144173525
# Perplexity of the 1537 Absolute Discounting model on the test data: 1688.8111085010923
# Perplexity of the 1538 Absolute Discounting model on the test data: 1511.8394659731514
# Perplexity of the 1539 Absolute Discounting model on the test data: 1286.0947442529073
# Perplexity of the 1540 Absolute Discounting model on the test data: 1329.6403686764784
# Perplexity of the 1541 Absolute Discounting model on the test data: 1553.2588309488822
# Perplexity of the 1542 Absolute Discounting model on the test data: 1942.021763149928
# Perplexity of the 1543 Absolute Discounting model on the test data: 1295.9603003042387
# Perplexity of the 1544 Absolute Discounting model on the test data: 1011.6533798946523
# Perplexity of the 1545 Absolute Discounting model on the test data: 1758.4190619973938
# Perplexity of the 1546 Absolute Discounting model on the test data: 1206.283626513799
# Perplexity of the 1547 Absolute Discounting model on the test data: 1227.318943410065
# Perplexity of the 1548 Absolute Discounting model on the test data: 1844.1269166588013
# Perplexity of the 1549 Absolute Discounting model on the test data: 1029.6595879855347
# Perplexity of the 1550 Absolute Discounting model on the test data: 3097.613967566197
# Perplexity of the 1551 Absolute Discounting model on the test data: 1493.1210715567083
# Perplexity of the 1552 Absolute Discounting model on the test data: 2003.5055508503426
# Perplexity of the 1553 Absolute Discounting model on the test data: 1955.2185383047583
# Perplexity of the 1554 Absolute Discounting model on the test data: 1779.070615317651
# Perplexity of the 1555 Absolute Discounting model on the test data: 1504.8384481122014
# Perplexity of the 1556 Absolute Discounting model on the test data: 1986.294142968252
# Perplexity of the 1557 Absolute Discounting model on the test data: 983.3711681751631
# Perplexity of the 1558 Absolute Discounting model on the test data: 1803.4373691866965
# Perplexity of the 1559 Absolute Discounting model on the test data: 1220.6993449816048
# Perplexity of the 1560 Absolute Discounting model on the test data: 1414.2231562282043
# Perplexity of the 1561 Absolute Discounting model on the test data: 3175.2167720569455
# Perplexity of the 1562 Absolute Discounting model on the test data: 1190.0250595754633
# Perplexity of the 1563 Absolute Discounting model on the test data: 1819.9552706315892
# Perplexity of the 1564 Absolute Discounting model on the test data: 1233.2863836159654
# Perplexity of the 1565 Absolute Discounting model on the test data: 904.6358605859031
# Perplexity of the 1566 Absolute Discounting model on the test data: 1651.1281717856405
# Perplexity of the 1567 Absolute Discounting model on the test data: 1352.495770653666
# Perplexity of the 1568 Absolute Discounting model on the test data: 1651.042920287265
# Perplexity of the 1569 Absolute Discounting model on the test data: 1038.0908530922095
# Perplexity of the 1570 Absolute Discounting model on the test data: 1099.1314628977912
# Perplexity of the 1571 Absolute Discounting model on the test data: 1761.8545709729135
# Perplexity of the 1572 Absolute Discounting model on the test data: 1711.9780117280563
# Perplexity of the 1573 Absolute Discounting model on the test data: 1477.6610124402416
# Perplexity of the 1574 Absolute Discounting model on the test data: 1335.2244996330028
# Perplexity of the 1575 Absolute Discounting model on the test data: 1536.422880341981
# Perplexity of the 1576 Absolute Discounting model on the test data: 1189.6218795139005
# Perplexity of the 1577 Absolute Discounting model on the test data: 1573.1180501024537
# Perplexity of the 1578 Absolute Discounting model on the test data: 2028.2767926886115
# Perplexity of the 1579 Absolute Discounting model on the test data: 1881.7033803898155
# Perplexity of the 1580 Absolute Discounting model on the test data: 1052.8534757182408
# Perplexity of the 1581 Absolute Discounting model on the test data: 1838.638386079603
# Perplexity of the 1582 Absolute Discounting model on the test data: 1758.1618455829082
# Perplexity of the 1583 Absolute Discounting model on the test data: 1148.7195465886089
# Perplexity of the 1584 Absolute Discounting model on the test data: 1309.2542989089645
# Perplexity of the 1585 Absolute Discounting model on the test data: 1905.3548353875562
# Perplexity of the 1586 Absolute Discounting model on the test data: 1778.5947785426717
# Perplexity of the 1587 Absolute Discounting model on the test data: 1202.5389219800131
# Perplexity of the 1588 Absolute Discounting model on the test data: 1555.8757401817086
# Perplexity of the 1589 Absolute Discounting model on the test data: 2102.4629959484405
# Perplexity of the 1590 Absolute Discounting model on the test data: 1045.0686252197777
# Perplexity of the 1591 Absolute Discounting model on the test data: 1721.7636490482307
# Perplexity of the 1592 Absolute Discounting model on the test data: 1285.5904943838993
# Perplexity of the 1593 Absolute Discounting model on the test data: 1827.720184773127
# Perplexity of the 1594 Absolute Discounting model on the test data: 1224.0899916986814
# Perplexity of the 1595 Absolute Discounting model on the test data: 1390.4664368914391
# Perplexity of the 1596 Absolute Discounting model on the test data: 1365.6738261614619
# Perplexity of the 1597 Absolute Discounting model on the test data: 1197.6112867971267
# Perplexity of the 1598 Absolute Discounting model on the test data: 1562.4046888877954
# Perplexity of the 1599 Absolute Discounting model on the test data: 1575.0072562930739
# Perplexity of the 1600 Absolute Discounting model on the test data: 2050.7631693592116
# Perplexity of the 1601 Absolute Discounting model on the test data: 2780.83483521669
# Perplexity of the 1602 Absolute Discounting model on the test data: 939.3771200886947
# Perplexity of the 1603 Absolute Discounting model on the test data: 1839.2169134301662
# Perplexity of the 1604 Absolute Discounting model on the test data: 1757.900514891093
# Perplexity of the 1605 Absolute Discounting model on the test data: 1103.162871919602
# Perplexity of the 1606 Absolute Discounting model on the test data: 1457.1691708223805
# Perplexity of the 1607 Absolute Discounting model on the test data: 2860.365219315519
# Perplexity of the 1608 Absolute Discounting model on the test data: 1283.7431150750124
# Perplexity of the 1609 Absolute Discounting model on the test data: 1113.4162490339002
# Perplexity of the 1610 Absolute Discounting model on the test data: 1541.4620220262543
# Perplexity of the 1611 Absolute Discounting model on the test data: 1102.3933561846957
# Perplexity of the 1612 Absolute Discounting model on the test data: 2024.951347591555
# Perplexity of the 1613 Absolute Discounting model on the test data: 1201.417988909929
# Perplexity of the 1614 Absolute Discounting model on the test data: 1980.220008087309
# Perplexity of the 1615 Absolute Discounting model on the test data: 1435.872232781735
# Perplexity of the 1616 Absolute Discounting model on the test data: 1395.105166781413
# Perplexity of the 1617 Absolute Discounting model on the test data: 1443.2408145894974
# Perplexity of the 1618 Absolute Discounting model on the test data: 1275.5991656611204
# Perplexity of the 1619 Absolute Discounting model on the test data: 1148.1378377066235
# Perplexity of the 1620 Absolute Discounting model on the test data: 1594.1505614924934
# Perplexity of the 1621 Absolute Discounting model on the test data: 1718.3330327652002
# Perplexity of the 1622 Absolute Discounting model on the test data: 1517.5201883796667
# Perplexity of the 1623 Absolute Discounting model on the test data: 894.7547275179481
# Perplexity of the 1624 Absolute Discounting model on the test data: 1905.1508797597915
# Perplexity of the 1625 Absolute Discounting model on the test data: 1263.3158841247405
# Perplexity of the 1626 Absolute Discounting model on the test data: 1537.6914410324887
# Perplexity of the 1627 Absolute Discounting model on the test data: 2200.036286120213
# Perplexity of the 1628 Absolute Discounting model on the test data: 2858.0115482453734
# Perplexity of the 1629 Absolute Discounting model on the test data: 1183.6642714941195
# Perplexity of the 1630 Absolute Discounting model on the test data: 1655.9376026261177
# Perplexity of the 1631 Absolute Discounting model on the test data: 1436.0703521883365
# Perplexity of the 1632 Absolute Discounting model on the test data: 1617.2734426627062
# Perplexity of the 1633 Absolute Discounting model on the test data: 1659.0463830505607
# Perplexity of the 1634 Absolute Discounting model on the test data: 1690.867363108527
# Perplexity of the 1635 Absolute Discounting model on the test data: 1876.3709269644514
# Perplexity of the 1636 Absolute Discounting model on the test data: 1287.14354716146
# Perplexity of the 1637 Absolute Discounting model on the test data: 1295.1280019603666
# Perplexity of the 1638 Absolute Discounting model on the test data: 1291.160629637237
# Perplexity of the 1639 Absolute Discounting model on the test data: 1777.57678860319
# Perplexity of the 1640 Absolute Discounting model on the test data: 1232.474295426674
# Perplexity of the 1641 Absolute Discounting model on the test data: 2386.1901588634305
# Perplexity of the 1642 Absolute Discounting model on the test data: 3792.75027145952
# Perplexity of the 1643 Absolute Discounting model on the test data: 1063.9579350892907

# %%
# bigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(2)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1, 0.3, 0.5, 0.7]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 361.5870623553146
# Perplexity of the 1 Absolute Discounting model on the test data: 178.28973847252095
# Perplexity of the 2 Absolute Discounting model on the test data: 394.9783983441004
# Perplexity of the 3 Absolute Discounting model on the test data: 150.69564663244472
# Perplexity of the 4 Absolute Discounting model on the test data: 1213.4809363214974
# Perplexity of the 5 Absolute Discounting model on the test data: 416.25436268517154
# Perplexity of the 6 Absolute Discounting model on the test data: 373.5340530280333
# Perplexity of the 7 Absolute Discounting model on the test data: 211.63045742508186
# Perplexity of the 8 Absolute Discounting model on the test data: 147.79795302976225
# Perplexity of the 9 Absolute Discounting model on the test data: 1020.7200122980078
# Perplexity of the 10 Absolute Discounting model on the test data: 543.8299577784982
# Perplexity of the 11 Absolute Discounting model on the test data: 252.23170387607237
# Perplexity of the 12 Absolute Discounting model on the test data: 288.0944946635557
# Perplexity of the 13 Absolute Discounting model on the test data: 440.4048516671273
# Perplexity of the 14 Absolute Discounting model on the test data: 639.0730094093186
# Perplexity of the 15 Absolute Discounting model on the test data: 385.70899348188533
# Perplexity of the 16 Absolute Discounting model on the test data: 332.40435275488596
# Perplexity of the 17 Absolute Discounting model on the test data: 499.63498075882904
# Perplexity of the 18 Absolute Discounting model on the test data: 371.261951244714
# Perplexity of the 19 Absolute Discounting model on the test data: 325.55390767459096
# Perplexity of the 20 Absolute Discounting model on the test data: 270.243350889941
# Perplexity of the 21 Absolute Discounting model on the test data: 446.5467180525136
# Perplexity of the 22 Absolute Discounting model on the test data: 327.2286236097981
# Perplexity of the 23 Absolute Discounting model on the test data: 302.39161428459255
# Perplexity of the 24 Absolute Discounting model on the test data: 112.55705090922842
# Perplexity of the 25 Absolute Discounting model on the test data: 229.64768755044327
# Perplexity of the 26 Absolute Discounting model on the test data: 256.95479219222943
# Perplexity of the 27 Absolute Discounting model on the test data: 163.8557848916437
# Perplexity of the 28 Absolute Discounting model on the test data: 343.4501454250061
# Perplexity of the 29 Absolute Discounting model on the test data: 156.15676122190257
# Perplexity of the 30 Absolute Discounting model on the test data: 206.39856196052358
# Perplexity of the 31 Absolute Discounting model on the test data: 194.9324787905057
# Perplexity of the 32 Absolute Discounting model on the test data: 636.115257988729
# Perplexity of the 33 Absolute Discounting model on the test data: 4807.87318542689
# Perplexity of the 34 Absolute Discounting model on the test data: 623.8736068466749
# Perplexity of the 35 Absolute Discounting model on the test data: 1535.1232339685223
# Perplexity of the 36 Absolute Discounting model on the test data: 93.41135519674012
# Perplexity of the 37 Absolute Discounting model on the test data: 1585.3817475891917
# Perplexity of the 38 Absolute Discounting model on the test data: 314.2871958804869
# Perplexity of the 39 Absolute Discounting model on the test data: 213.3452297863852
# Perplexity of the 40 Absolute Discounting model on the test data: 245.62569712881788
# Perplexity of the 41 Absolute Discounting model on the test data: 440.9661707692455
# Perplexity of the 42 Absolute Discounting model on the test data: 113.88295613788682
# Perplexity of the 43 Absolute Discounting model on the test data: 173.66864142948646
# Perplexity of the 44 Absolute Discounting model on the test data: 348.0958618165463
# Perplexity of the 45 Absolute Discounting model on the test data: 285.8537915504657
# Perplexity of the 46 Absolute Discounting model on the test data: 216.24334359580556
# Perplexity of the 47 Absolute Discounting model on the test data: 375.33383604086265
# Perplexity of the 48 Absolute Discounting model on the test data: 248.19651547331398
# Perplexity of the 49 Absolute Discounting model on the test data: 529.9758559696887
# Perplexity of the 50 Absolute Discounting model on the test data: 119.77451894381679
# Perplexity of the 51 Absolute Discounting model on the test data: 572.3461779874283
# Perplexity of the 52 Absolute Discounting model on the test data: 254.35515217699907
# Perplexity of the 53 Absolute Discounting model on the test data: 209.34629438811638
# Perplexity of the 54 Absolute Discounting model on the test data: 211.08328669817365
# Perplexity of the 55 Absolute Discounting model on the test data: 773.4684304910277
# Perplexity of the 56 Absolute Discounting model on the test data: 568.3258355351169
# Perplexity of the 57 Absolute Discounting model on the test data: 154.400279119901
# Perplexity of the 58 Absolute Discounting model on the test data: 192.16815219140034
# Perplexity of the 59 Absolute Discounting model on the test data: 191.15346909267456
# Perplexity of the 60 Absolute Discounting model on the test data: 461.84208303358815
# Perplexity of the 61 Absolute Discounting model on the test data: 185.8183714082572
# Perplexity of the 62 Absolute Discounting model on the test data: 426.32457781761804
# Perplexity of the 63 Absolute Discounting model on the test data: 151.2621949516489
# Perplexity of the 64 Absolute Discounting model on the test data: 168.90841001565707
# Perplexity of the 65 Absolute Discounting model on the test data: 145.10506743395098
# Perplexity of the 66 Absolute Discounting model on the test data: 343.28692716951866
# Perplexity of the 67 Absolute Discounting model on the test data: 301.0732055088129
# Perplexity of the 68 Absolute Discounting model on the test data: 140.3128554152137
# Perplexity of the 69 Absolute Discounting model on the test data: 564.9574957273716
# Perplexity of the 70 Absolute Discounting model on the test data: 182.74061708223525
# Perplexity of the 71 Absolute Discounting model on the test data: 376.01368318534395
# Perplexity of the 72 Absolute Discounting model on the test data: 843.0629405360331
# Perplexity of the 73 Absolute Discounting model on the test data: 214.03220501945898
# Perplexity of the 74 Absolute Discounting model on the test data: 123.99380475646038
# Perplexity of the 75 Absolute Discounting model on the test data: 141.09285322757913
# Perplexity of the 76 Absolute Discounting model on the test data: 241.46313490776063
# Perplexity of the 77 Absolute Discounting model on the test data: 271.3303760082719
# Perplexity of the 78 Absolute Discounting model on the test data: 162.1458517678619
# Perplexity of the 79 Absolute Discounting model on the test data: 145.7349775162212
# Perplexity of the 80 Absolute Discounting model on the test data: 152.8046989165236
# Perplexity of the 81 Absolute Discounting model on the test data: 207.72578010907915
# Perplexity of the 82 Absolute Discounting model on the test data: 182.12557180143116
# Perplexity of the 83 Absolute Discounting model on the test data: 121.19390250918777
# Perplexity of the 84 Absolute Discounting model on the test data: 99.62086583284324
# Perplexity of the 85 Absolute Discounting model on the test data: 340.19219130443435
# Perplexity of the 86 Absolute Discounting model on the test data: 134.2781914921646
# Perplexity of the 87 Absolute Discounting model on the test data: 271.78398538181494
# Perplexity of the 88 Absolute Discounting model on the test data: 456.44285395722227
# Perplexity of the 89 Absolute Discounting model on the test data: 317.0533952331933
# Perplexity of the 90 Absolute Discounting model on the test data: 273.60352350818977
# Perplexity of the 91 Absolute Discounting model on the test data: 478.20099113688156
# Perplexity of the 92 Absolute Discounting model on the test data: 268.59414908130185
# Perplexity of the 93 Absolute Discounting model on the test data: 561.810321448979
# Perplexity of the 94 Absolute Discounting model on the test data: 144.4563037390366
# Perplexity of the 95 Absolute Discounting model on the test data: 134.71656230393893
# Perplexity of the 96 Absolute Discounting model on the test data: 634.974476643005
# Perplexity of the 97 Absolute Discounting model on the test data: 160.37056763557155
# Perplexity of the 98 Absolute Discounting model on the test data: 174.69219935872306
# Perplexity of the 99 Absolute Discounting model on the test data: 204.82901156179346
# Perplexity of the 100 Absolute Discounting model on the test data: 56.909931886200134
# Perplexity of the 101 Absolute Discounting model on the test data: 75.34686554069118
# Perplexity of the 102 Absolute Discounting model on the test data: 829.2271528491115
# Perplexity of the 103 Absolute Discounting model on the test data: 223.42188294754567
# Perplexity of the 104 Absolute Discounting model on the test data: 565.2712691296789
# Perplexity of the 105 Absolute Discounting model on the test data: 311.89516229968865
# Perplexity of the 106 Absolute Discounting model on the test data: 335.806377360853
# Perplexity of the 107 Absolute Discounting model on the test data: 460.7823326783133
# Perplexity of the 108 Absolute Discounting model on the test data: 127.53008251600156
# Perplexity of the 109 Absolute Discounting model on the test data: 200.10543536754028
# Perplexity of the 110 Absolute Discounting model on the test data: 144.52867752292056
# Perplexity of the 111 Absolute Discounting model on the test data: 96.03062720945528
# Perplexity of the 112 Absolute Discounting model on the test data: 212.92207265149392
# Perplexity of the 113 Absolute Discounting model on the test data: 238.02492853571803
# Perplexity of the 114 Absolute Discounting model on the test data: 101.9631620667175
# Perplexity of the 115 Absolute Discounting model on the test data: 664.077166178667
# Perplexity of the 116 Absolute Discounting model on the test data: 178.37497649700333
# Perplexity of the 117 Absolute Discounting model on the test data: 441.5105559335916
# Perplexity of the 118 Absolute Discounting model on the test data: 210.85262087505546
# Perplexity of the 119 Absolute Discounting model on the test data: 119.64274257667019
# Perplexity of the 120 Absolute Discounting model on the test data: 247.16756678663182
# Perplexity of the 121 Absolute Discounting model on the test data: 432.94242902933144
# Perplexity of the 122 Absolute Discounting model on the test data: 357.11955767655644
# Perplexity of the 123 Absolute Discounting model on the test data: 251.8417211446863
# Perplexity of the 124 Absolute Discounting model on the test data: 212.9349361287935
# Perplexity of the 125 Absolute Discounting model on the test data: 207.12943025251752
# Perplexity of the 126 Absolute Discounting model on the test data: 354.62224878517463
# Perplexity of the 127 Absolute Discounting model on the test data: 152.04144021808125
# Perplexity of the 128 Absolute Discounting model on the test data: 379.0539041238019
# Perplexity of the 129 Absolute Discounting model on the test data: 320.8514194020014
# Perplexity of the 130 Absolute Discounting model on the test data: 265.0514682019222
# Perplexity of the 131 Absolute Discounting model on the test data: 320.9501385462498
# Perplexity of the 132 Absolute Discounting model on the test data: 322.85314493207017
# Perplexity of the 133 Absolute Discounting model on the test data: 217.6763992056864
# Perplexity of the 134 Absolute Discounting model on the test data: 271.7486144101089
# Perplexity of the 135 Absolute Discounting model on the test data: 673.1171123475705
# Perplexity of the 136 Absolute Discounting model on the test data: 169.54239464476225
# Perplexity of the 137 Absolute Discounting model on the test data: 213.79010816165007
# Perplexity of the 138 Absolute Discounting model on the test data: 1254.610163873801
# Perplexity of the 139 Absolute Discounting model on the test data: 290.7642781968247
# Perplexity of the 140 Absolute Discounting model on the test data: 473.15495012557494
# Perplexity of the 141 Absolute Discounting model on the test data: 376.78597813951745
# Perplexity of the 142 Absolute Discounting model on the test data: 209.565191072274
# Perplexity of the 143 Absolute Discounting model on the test data: 1913.8593071191601
# Perplexity of the 144 Absolute Discounting model on the test data: 183.01241684115948
# Perplexity of the 145 Absolute Discounting model on the test data: 213.16493562982762
# Perplexity of the 146 Absolute Discounting model on the test data: 725.8359591562712
# Perplexity of the 147 Absolute Discounting model on the test data: 323.02874986311855
# Perplexity of the 148 Absolute Discounting model on the test data: 141.16369941523672
# Perplexity of the 149 Absolute Discounting model on the test data: 182.0045700032505
# Perplexity of the 150 Absolute Discounting model on the test data: 354.0696378975522
# Perplexity of the 151 Absolute Discounting model on the test data: 548.451995751549
# Perplexity of the 152 Absolute Discounting model on the test data: 693.2044208346175
# Perplexity of the 153 Absolute Discounting model on the test data: 147.6757023286634
# Perplexity of the 154 Absolute Discounting model on the test data: 211.45789933709113
# Perplexity of the 155 Absolute Discounting model on the test data: 501.5956120825887
# Perplexity of the 156 Absolute Discounting model on the test data: 542.9442547353211
# Perplexity of the 157 Absolute Discounting model on the test data: 341.8862852844847
# Perplexity of the 158 Absolute Discounting model on the test data: 294.9887735062106
# Perplexity of the 159 Absolute Discounting model on the test data: 646.1484237499708
# Perplexity of the 160 Absolute Discounting model on the test data: 540.7780276916894
# Perplexity of the 161 Absolute Discounting model on the test data: 841.5175483589142
# Perplexity of the 162 Absolute Discounting model on the test data: 462.3016550484526
# Perplexity of the 163 Absolute Discounting model on the test data: 367.58246862556797
# Perplexity of the 164 Absolute Discounting model on the test data: 275.0279558237831
# Perplexity of the 165 Absolute Discounting model on the test data: 639.5480988283178
# Perplexity of the 166 Absolute Discounting model on the test data: 405.9784434515809
# Perplexity of the 167 Absolute Discounting model on the test data: 484.6197042678938
# Perplexity of the 168 Absolute Discounting model on the test data: 178.77571932471028
# Perplexity of the 169 Absolute Discounting model on the test data: 514.1918798840612
# Perplexity of the 170 Absolute Discounting model on the test data: 298.49746439995954
# Perplexity of the 171 Absolute Discounting model on the test data: 177.30781236948653
# Perplexity of the 172 Absolute Discounting model on the test data: 165.4329287616486
# Perplexity of the 173 Absolute Discounting model on the test data: 519.9288420288981
# Perplexity of the 174 Absolute Discounting model on the test data: 224.92220211532128
# Perplexity of the 175 Absolute Discounting model on the test data: 421.573134779267
# Perplexity of the 176 Absolute Discounting model on the test data: 366.87612727694125
# Perplexity of the 177 Absolute Discounting model on the test data: 569.0607179321212
# Perplexity of the 178 Absolute Discounting model on the test data: 241.99388419977547
# Perplexity of the 179 Absolute Discounting model on the test data: 446.1898647778185
# Perplexity of the 180 Absolute Discounting model on the test data: 797.9134238209369
# Perplexity of the 181 Absolute Discounting model on the test data: 243.99107806338085
# Perplexity of the 182 Absolute Discounting model on the test data: 490.5925021871558
# Perplexity of the 183 Absolute Discounting model on the test data: 181.21562782860806
# Perplexity of the 184 Absolute Discounting model on the test data: 333.81836302370857
# Perplexity of the 185 Absolute Discounting model on the test data: 80.4877030275149
# Perplexity of the 186 Absolute Discounting model on the test data: 325.5917549090626
# Perplexity of the 187 Absolute Discounting model on the test data: 203.7019319800787
# Perplexity of the 188 Absolute Discounting model on the test data: 212.27189484913637
# Perplexity of the 189 Absolute Discounting model on the test data: 129.8218861018863
# Perplexity of the 190 Absolute Discounting model on the test data: 333.40760904642946
# Perplexity of the 191 Absolute Discounting model on the test data: 776.3636684859216
# Perplexity of the 192 Absolute Discounting model on the test data: 127.27602958731956
# Perplexity of the 193 Absolute Discounting model on the test data: 168.0565385056523
# Perplexity of the 194 Absolute Discounting model on the test data: 438.5969999373851
# Perplexity of the 195 Absolute Discounting model on the test data: 321.65497730954047
# Perplexity of the 196 Absolute Discounting model on the test data: 204.3483365224231
# Perplexity of the 197 Absolute Discounting model on the test data: 469.30818395647634
# Perplexity of the 198 Absolute Discounting model on the test data: 97.31887348084324
# Perplexity of the 199 Absolute Discounting model on the test data: 780.9310302022733
# Perplexity of the 200 Absolute Discounting model on the test data: 441.33809137960407
# Perplexity of the 201 Absolute Discounting model on the test data: 181.23227152117883
# Perplexity of the 202 Absolute Discounting model on the test data: 321.9999018052132
# Perplexity of the 203 Absolute Discounting model on the test data: 891.9274854919058
# Perplexity of the 204 Absolute Discounting model on the test data: 348.222694802023
# Perplexity of the 205 Absolute Discounting model on the test data: 802.7579639674723
# Perplexity of the 206 Absolute Discounting model on the test data: 90.11873147967054
# Perplexity of the 207 Absolute Discounting model on the test data: 479.5409416024469
# Perplexity of the 208 Absolute Discounting model on the test data: 80.10546177979671
# Perplexity of the 209 Absolute Discounting model on the test data: 234.96150026896765
# Perplexity of the 210 Absolute Discounting model on the test data: 263.1182616796783
# Perplexity of the 211 Absolute Discounting model on the test data: 175.50846968245568
# Perplexity of the 212 Absolute Discounting model on the test data: 299.3316372424941
# Perplexity of the 213 Absolute Discounting model on the test data: 337.2584852346332
# Perplexity of the 214 Absolute Discounting model on the test data: 324.519192086115
# Perplexity of the 215 Absolute Discounting model on the test data: 131.9328480809895
# Perplexity of the 216 Absolute Discounting model on the test data: 391.597580230974
# Perplexity of the 217 Absolute Discounting model on the test data: 184.89504913539957
# Perplexity of the 218 Absolute Discounting model on the test data: 358.5188276340537
# Perplexity of the 219 Absolute Discounting model on the test data: 128.7017671760821
# Perplexity of the 220 Absolute Discounting model on the test data: 501.14684963203257
# Perplexity of the 221 Absolute Discounting model on the test data: 200.29187203409785
# Perplexity of the 222 Absolute Discounting model on the test data: 71.57447509479861
# Perplexity of the 223 Absolute Discounting model on the test data: 368.67329433084166
# Perplexity of the 224 Absolute Discounting model on the test data: 127.947730415219
# Perplexity of the 225 Absolute Discounting model on the test data: 227.6422332160948
# Perplexity of the 226 Absolute Discounting model on the test data: 189.95140378612072
# Perplexity of the 227 Absolute Discounting model on the test data: 269.413241028827
# Perplexity of the 228 Absolute Discounting model on the test data: 340.8818744521908
# Perplexity of the 229 Absolute Discounting model on the test data: 293.16774772925777
# Perplexity of the 230 Absolute Discounting model on the test data: 220.91828584733227
# Perplexity of the 231 Absolute Discounting model on the test data: 391.9377016109936
# Perplexity of the 232 Absolute Discounting model on the test data: 112.52958842698649
# Perplexity of the 233 Absolute Discounting model on the test data: 246.0962121636365
# Perplexity of the 234 Absolute Discounting model on the test data: 233.24568215748963
# Perplexity of the 235 Absolute Discounting model on the test data: 327.90667527420953
# Perplexity of the 236 Absolute Discounting model on the test data: 1284.9292416875394
# Perplexity of the 237 Absolute Discounting model on the test data: 413.89982606339527
# Perplexity of the 238 Absolute Discounting model on the test data: 522.1217802846229
# Perplexity of the 239 Absolute Discounting model on the test data: 458.04411145496556
# Perplexity of the 240 Absolute Discounting model on the test data: 208.50462580268197
# Perplexity of the 241 Absolute Discounting model on the test data: 185.01187726324156
# Perplexity of the 242 Absolute Discounting model on the test data: 152.3258513504643
# Perplexity of the 243 Absolute Discounting model on the test data: 189.65519938612738
# Perplexity of the 244 Absolute Discounting model on the test data: 191.9409288330809
# Perplexity of the 245 Absolute Discounting model on the test data: 265.35640330418164
# Perplexity of the 246 Absolute Discounting model on the test data: 199.7804954091468
# Perplexity of the 247 Absolute Discounting model on the test data: 250.27929891537386
# Perplexity of the 248 Absolute Discounting model on the test data: 328.0674427911147
# Perplexity of the 249 Absolute Discounting model on the test data: 236.29497785506712
# Perplexity of the 250 Absolute Discounting model on the test data: 401.4104650396174
# Perplexity of the 251 Absolute Discounting model on the test data: 371.580868150053
# Perplexity of the 252 Absolute Discounting model on the test data: 337.49460650331156
# Perplexity of the 253 Absolute Discounting model on the test data: 552.0664503101464
# Perplexity of the 254 Absolute Discounting model on the test data: 902.5714961164178
# Perplexity of the 255 Absolute Discounting model on the test data: 628.8935590721392
# Perplexity of the 256 Absolute Discounting model on the test data: 508.3836684236454
# Perplexity of the 257 Absolute Discounting model on the test data: 830.48511394765
# Perplexity of the 258 Absolute Discounting model on the test data: 190.15280625248894
# Perplexity of the 259 Absolute Discounting model on the test data: 382.20939077192844
# Perplexity of the 260 Absolute Discounting model on the test data: 155.8508809518249
# Perplexity of the 261 Absolute Discounting model on the test data: 144.38866986619337
# Perplexity of the 262 Absolute Discounting model on the test data: 181.14128269358588
# Perplexity of the 263 Absolute Discounting model on the test data: 327.2720643138646
# Perplexity of the 264 Absolute Discounting model on the test data: 71.7102410276665
# Perplexity of the 265 Absolute Discounting model on the test data: 117.22181062181517
# Perplexity of the 266 Absolute Discounting model on the test data: 405.8694264628632
# Perplexity of the 267 Absolute Discounting model on the test data: 608.7647915290629
# Perplexity of the 268 Absolute Discounting model on the test data: 4714.450233714597
# Perplexity of the 269 Absolute Discounting model on the test data: 97.0630505592834
# Perplexity of the 270 Absolute Discounting model on the test data: 296.45890608915175
# Perplexity of the 271 Absolute Discounting model on the test data: 170.72713024769212
# Perplexity of the 272 Absolute Discounting model on the test data: 891.7598724069782
# Perplexity of the 273 Absolute Discounting model on the test data: 401.6722333944604
# Perplexity of the 274 Absolute Discounting model on the test data: 338.36523391222175
# Perplexity of the 275 Absolute Discounting model on the test data: 158.61808316972397
# Perplexity of the 276 Absolute Discounting model on the test data: 420.10609377569455
# Perplexity of the 277 Absolute Discounting model on the test data: 173.33093420112922
# Perplexity of the 278 Absolute Discounting model on the test data: 240.43187523440378
# Perplexity of the 279 Absolute Discounting model on the test data: 279.03173429941353
# Perplexity of the 280 Absolute Discounting model on the test data: 126.84650621576152
# Perplexity of the 281 Absolute Discounting model on the test data: 142.31152838095426
# Perplexity of the 282 Absolute Discounting model on the test data: 245.19232192164128
# Perplexity of the 283 Absolute Discounting model on the test data: 94.30678118583774
# Perplexity of the 284 Absolute Discounting model on the test data: 116.41516616466046
# Perplexity of the 285 Absolute Discounting model on the test data: 467.13238681994085
# Perplexity of the 286 Absolute Discounting model on the test data: 315.45153806835384
# Perplexity of the 287 Absolute Discounting model on the test data: 400.5602880099595
# Perplexity of the 288 Absolute Discounting model on the test data: 581.5448986038381
# Perplexity of the 289 Absolute Discounting model on the test data: 549.7829739930636
# Perplexity of the 290 Absolute Discounting model on the test data: 1278.555394809011
# Perplexity of the 291 Absolute Discounting model on the test data: 32.88090721689637
# Perplexity of the 292 Absolute Discounting model on the test data: 682.4203255652754
# Perplexity of the 293 Absolute Discounting model on the test data: 811.3490321009073
# Perplexity of the 294 Absolute Discounting model on the test data: 79.32181388942504
# Perplexity of the 295 Absolute Discounting model on the test data: 739.4807515785355
# Perplexity of the 296 Absolute Discounting model on the test data: 103.89289407419697
# Perplexity of the 297 Absolute Discounting model on the test data: 345.7712962149665
# Perplexity of the 298 Absolute Discounting model on the test data: 393.7530925999196
# Perplexity of the 299 Absolute Discounting model on the test data: 136.5646043649993
# Perplexity of the 300 Absolute Discounting model on the test data: 457.4663232361983
# Perplexity of the 301 Absolute Discounting model on the test data: 1003.4639891006492
# Perplexity of the 302 Absolute Discounting model on the test data: 104.76122716712587
# Perplexity of the 303 Absolute Discounting model on the test data: 465.8338671463587
# Perplexity of the 304 Absolute Discounting model on the test data: 491.30170145701345
# Perplexity of the 305 Absolute Discounting model on the test data: 124.47023030933066
# Perplexity of the 306 Absolute Discounting model on the test data: 378.7095434461102
# Perplexity of the 307 Absolute Discounting model on the test data: 269.59605434542954
# Perplexity of the 308 Absolute Discounting model on the test data: 376.81116408614133
# Perplexity of the 309 Absolute Discounting model on the test data: 234.2720006600006
# Perplexity of the 310 Absolute Discounting model on the test data: 155.83632830861222
# Perplexity of the 311 Absolute Discounting model on the test data: 194.212744905
# Perplexity of the 312 Absolute Discounting model on the test data: 613.1039596576793
# Perplexity of the 313 Absolute Discounting model on the test data: 498.0319169516249
# Perplexity of the 314 Absolute Discounting model on the test data: 123.37954592893936
# Perplexity of the 315 Absolute Discounting model on the test data: 453.73596965933626
# Perplexity of the 316 Absolute Discounting model on the test data: 203.13061312063041
# Perplexity of the 317 Absolute Discounting model on the test data: 191.3773654432345
# Perplexity of the 318 Absolute Discounting model on the test data: 280.1220154095878
# Perplexity of the 319 Absolute Discounting model on the test data: 581.0097993632576
# Perplexity of the 320 Absolute Discounting model on the test data: 370.45596767696355
# Perplexity of the 321 Absolute Discounting model on the test data: 374.3083294227173
# Perplexity of the 322 Absolute Discounting model on the test data: 254.76651984576475
# Perplexity of the 323 Absolute Discounting model on the test data: 177.49146636224893
# Perplexity of the 324 Absolute Discounting model on the test data: 376.2412535665538
# Perplexity of the 325 Absolute Discounting model on the test data: 141.69127126140287
# Perplexity of the 326 Absolute Discounting model on the test data: 582.1275465477688
# Perplexity of the 327 Absolute Discounting model on the test data: 179.77540942125822
# Perplexity of the 328 Absolute Discounting model on the test data: 262.8492119351485
# Perplexity of the 329 Absolute Discounting model on the test data: 517.2073705985317
# Perplexity of the 330 Absolute Discounting model on the test data: 308.830860796379
# Perplexity of the 331 Absolute Discounting model on the test data: 777.3661598600481
# Perplexity of the 332 Absolute Discounting model on the test data: 431.5138865164434
# Perplexity of the 333 Absolute Discounting model on the test data: 189.87369431745043
# Perplexity of the 334 Absolute Discounting model on the test data: 165.1252295084273
# Perplexity of the 335 Absolute Discounting model on the test data: 540.3123038266677
# Perplexity of the 336 Absolute Discounting model on the test data: 243.15939618031052
# Perplexity of the 337 Absolute Discounting model on the test data: 510.34467140837353
# Perplexity of the 338 Absolute Discounting model on the test data: 111.60766243605264
# Perplexity of the 339 Absolute Discounting model on the test data: 196.3629747446065
# Perplexity of the 340 Absolute Discounting model on the test data: 401.6574607720838
# Perplexity of the 341 Absolute Discounting model on the test data: 206.52520734824367
# Perplexity of the 342 Absolute Discounting model on the test data: 220.4987629761464
# Perplexity of the 343 Absolute Discounting model on the test data: 149.80593380092742
# Perplexity of the 344 Absolute Discounting model on the test data: 340.5254438227565
# Perplexity of the 345 Absolute Discounting model on the test data: 853.4032431090892
# Perplexity of the 346 Absolute Discounting model on the test data: 372.77382726390647
# Perplexity of the 347 Absolute Discounting model on the test data: 415.55277524268826
# Perplexity of the 348 Absolute Discounting model on the test data: 222.72525159148526
# Perplexity of the 349 Absolute Discounting model on the test data: 134.49765178452114
# Perplexity of the 350 Absolute Discounting model on the test data: 697.2407525664927
# Perplexity of the 351 Absolute Discounting model on the test data: 271.43161497255767
# Perplexity of the 352 Absolute Discounting model on the test data: 226.17147825190028
# Perplexity of the 353 Absolute Discounting model on the test data: 116.9503489745369
# Perplexity of the 354 Absolute Discounting model on the test data: 271.08539377909136
# Perplexity of the 355 Absolute Discounting model on the test data: 172.14174006801417
# Perplexity of the 356 Absolute Discounting model on the test data: 162.07267112717315
# Perplexity of the 357 Absolute Discounting model on the test data: 168.2608558341464
# Perplexity of the 358 Absolute Discounting model on the test data: 178.59098870711824
# Perplexity of the 359 Absolute Discounting model on the test data: 197.0168907265686
# Perplexity of the 360 Absolute Discounting model on the test data: 607.6916451793885
# Perplexity of the 361 Absolute Discounting model on the test data: 122.76865883551547
# Perplexity of the 362 Absolute Discounting model on the test data: 365.1640012288966
# Perplexity of the 363 Absolute Discounting model on the test data: 349.05366532271233
# Perplexity of the 364 Absolute Discounting model on the test data: 241.71237152587642
# Perplexity of the 365 Absolute Discounting model on the test data: 730.0434827882581
# Perplexity of the 366 Absolute Discounting model on the test data: 652.3278588929464
# Perplexity of the 367 Absolute Discounting model on the test data: 540.8318758570169
# Perplexity of the 368 Absolute Discounting model on the test data: 130.13970595105098
# Perplexity of the 369 Absolute Discounting model on the test data: 308.7972083017596
# Perplexity of the 370 Absolute Discounting model on the test data: 220.9667472310936
# Perplexity of the 371 Absolute Discounting model on the test data: 717.0634691887
# Perplexity of the 372 Absolute Discounting model on the test data: 211.4956780140939
# Perplexity of the 373 Absolute Discounting model on the test data: 482.94003100402927
# Perplexity of the 374 Absolute Discounting model on the test data: 318.2836498327023
# Perplexity of the 375 Absolute Discounting model on the test data: 3286.574404121515
# Perplexity of the 376 Absolute Discounting model on the test data: 445.76821106634804
# Perplexity of the 377 Absolute Discounting model on the test data: 741.0864779765689
# Perplexity of the 378 Absolute Discounting model on the test data: 245.0272455216625
# Perplexity of the 379 Absolute Discounting model on the test data: 252.87078438687251
# Perplexity of the 380 Absolute Discounting model on the test data: 261.37610264916697
# Perplexity of the 381 Absolute Discounting model on the test data: 196.92452636165586
# Perplexity of the 382 Absolute Discounting model on the test data: 192.4808825392032
# Perplexity of the 383 Absolute Discounting model on the test data: 118.13990432637581
# Perplexity of the 384 Absolute Discounting model on the test data: 248.0581223700449
# Perplexity of the 385 Absolute Discounting model on the test data: 106.3997944971615
# Perplexity of the 386 Absolute Discounting model on the test data: 200.92437594741585
# Perplexity of the 387 Absolute Discounting model on the test data: 384.057817235718
# Perplexity of the 388 Absolute Discounting model on the test data: 744.2576028822567
# Perplexity of the 389 Absolute Discounting model on the test data: 233.51465526810804
# Perplexity of the 390 Absolute Discounting model on the test data: 468.4218553491217
# Perplexity of the 391 Absolute Discounting model on the test data: 316.7261076228221
# Perplexity of the 392 Absolute Discounting model on the test data: 339.8003144936966
# Perplexity of the 393 Absolute Discounting model on the test data: 195.6287322034527
# Perplexity of the 394 Absolute Discounting model on the test data: 245.613207700009
# Perplexity of the 395 Absolute Discounting model on the test data: 327.1073252648238
# Perplexity of the 396 Absolute Discounting model on the test data: 94.40641214740236
# Perplexity of the 397 Absolute Discounting model on the test data: 138.68269645600307
# Perplexity of the 398 Absolute Discounting model on the test data: 464.4290152536942
# Perplexity of the 399 Absolute Discounting model on the test data: 609.1467512730715
# Perplexity of the 400 Absolute Discounting model on the test data: 169.46937216021817
# Perplexity of the 401 Absolute Discounting model on the test data: 241.72790053980313
# Perplexity of the 402 Absolute Discounting model on the test data: 538.178981669913
# Perplexity of the 403 Absolute Discounting model on the test data: 252.11402241600274
# Perplexity of the 404 Absolute Discounting model on the test data: 168.8935347665367
# Perplexity of the 405 Absolute Discounting model on the test data: 211.88858895305552
# Perplexity of the 406 Absolute Discounting model on the test data: 612.4167680932482
# Perplexity of the 407 Absolute Discounting model on the test data: 309.76226824016715
# Perplexity of the 408 Absolute Discounting model on the test data: 262.994535219187
# Perplexity of the 409 Absolute Discounting model on the test data: 235.71900660894167
# Perplexity of the 410 Absolute Discounting model on the test data: 275.5601141246622
# Perplexity of the 411 Absolute Discounting model on the test data: 786.4865650452089
# Perplexity of the 412 Absolute Discounting model on the test data: 479.18861153744916
# Perplexity of the 413 Absolute Discounting model on the test data: 171.63498067572183
# Perplexity of the 414 Absolute Discounting model on the test data: 468.87310187185795
# Perplexity of the 415 Absolute Discounting model on the test data: 150.66502697131187
# Perplexity of the 416 Absolute Discounting model on the test data: 725.9713226057179
# Perplexity of the 417 Absolute Discounting model on the test data: 200.38965620205403
# Perplexity of the 418 Absolute Discounting model on the test data: 392.62177511554677
# Perplexity of the 419 Absolute Discounting model on the test data: 447.32967231872885
# Perplexity of the 420 Absolute Discounting model on the test data: 725.472889991342
# Perplexity of the 421 Absolute Discounting model on the test data: 214.70146793701625
# Perplexity of the 422 Absolute Discounting model on the test data: 383.6167180804045
# Perplexity of the 423 Absolute Discounting model on the test data: 277.0119368317991
# Perplexity of the 424 Absolute Discounting model on the test data: 258.22795727240594
# Perplexity of the 425 Absolute Discounting model on the test data: 419.78598713014935
# Perplexity of the 426 Absolute Discounting model on the test data: 296.9087970799644
# Perplexity of the 427 Absolute Discounting model on the test data: 157.9375806083837
# Perplexity of the 428 Absolute Discounting model on the test data: 164.73831113662007
# Perplexity of the 429 Absolute Discounting model on the test data: 353.21599239789765
# Perplexity of the 430 Absolute Discounting model on the test data: 476.93728033792667
# Perplexity of the 431 Absolute Discounting model on the test data: 146.28485077333016
# Perplexity of the 432 Absolute Discounting model on the test data: 312.2681294446711
# Perplexity of the 433 Absolute Discounting model on the test data: 169.1897798010276
# Perplexity of the 434 Absolute Discounting model on the test data: 186.5539124610025
# Perplexity of the 435 Absolute Discounting model on the test data: 311.60285684587427
# Perplexity of the 436 Absolute Discounting model on the test data: 297.5157805523535
# Perplexity of the 437 Absolute Discounting model on the test data: 211.8871964983301
# Perplexity of the 438 Absolute Discounting model on the test data: 406.4759575501564
# Perplexity of the 439 Absolute Discounting model on the test data: 627.2101037364872
# Perplexity of the 440 Absolute Discounting model on the test data: 111.52952775358183
# Perplexity of the 441 Absolute Discounting model on the test data: 208.8629844324967
# Perplexity of the 442 Absolute Discounting model on the test data: 161.32851830593728
# Perplexity of the 443 Absolute Discounting model on the test data: 194.8247351195771
# Perplexity of the 444 Absolute Discounting model on the test data: 140.82186484953124
# Perplexity of the 445 Absolute Discounting model on the test data: 322.16266408604054
# Perplexity of the 446 Absolute Discounting model on the test data: 689.1398906647548
# Perplexity of the 447 Absolute Discounting model on the test data: 304.78260808563573
# Perplexity of the 448 Absolute Discounting model on the test data: 116.26399701715788
# Perplexity of the 449 Absolute Discounting model on the test data: 354.5313571844733
# Perplexity of the 450 Absolute Discounting model on the test data: 152.04768832937054
# Perplexity of the 451 Absolute Discounting model on the test data: 188.1242923284949
# Perplexity of the 452 Absolute Discounting model on the test data: 1083.4715864060595
# Perplexity of the 453 Absolute Discounting model on the test data: 205.3409767583172
# Perplexity of the 454 Absolute Discounting model on the test data: 302.87699009527796
# Perplexity of the 455 Absolute Discounting model on the test data: 664.5920123964413
# Perplexity of the 456 Absolute Discounting model on the test data: 524.9861543574486
# Perplexity of the 457 Absolute Discounting model on the test data: 244.18939566578183
# Perplexity of the 458 Absolute Discounting model on the test data: 206.63216884751571
# Perplexity of the 459 Absolute Discounting model on the test data: 444.14217097288434
# Perplexity of the 460 Absolute Discounting model on the test data: 288.02026928574475
# Perplexity of the 461 Absolute Discounting model on the test data: 867.314773182956
# Perplexity of the 462 Absolute Discounting model on the test data: 483.3271672690543
# Perplexity of the 463 Absolute Discounting model on the test data: 170.34060035103317
# Perplexity of the 464 Absolute Discounting model on the test data: 339.94159336481357
# Perplexity of the 465 Absolute Discounting model on the test data: 205.4506888111007
# Perplexity of the 466 Absolute Discounting model on the test data: 365.99420648135134
# Perplexity of the 467 Absolute Discounting model on the test data: 135.27223025705075
# Perplexity of the 468 Absolute Discounting model on the test data: 326.23173655885506
# Perplexity of the 469 Absolute Discounting model on the test data: 159.03963218062208
# Perplexity of the 470 Absolute Discounting model on the test data: 360.8516315832699
# Perplexity of the 471 Absolute Discounting model on the test data: 694.14725050523
# Perplexity of the 472 Absolute Discounting model on the test data: 918.452421142285
# Perplexity of the 473 Absolute Discounting model on the test data: 206.86057601193386
# Perplexity of the 474 Absolute Discounting model on the test data: 154.75680047969524
# Perplexity of the 475 Absolute Discounting model on the test data: 225.32711294947939
# Perplexity of the 476 Absolute Discounting model on the test data: 175.15193417553954
# Perplexity of the 477 Absolute Discounting model on the test data: 197.66778911513396
# Perplexity of the 478 Absolute Discounting model on the test data: 827.6199910214198
# Perplexity of the 479 Absolute Discounting model on the test data: 218.91968705637333
# Perplexity of the 480 Absolute Discounting model on the test data: 346.83639936671165
# Perplexity of the 481 Absolute Discounting model on the test data: 261.27867649064183
# Perplexity of the 482 Absolute Discounting model on the test data: 279.9488199840116
# Perplexity of the 483 Absolute Discounting model on the test data: 177.83644845497795
# Perplexity of the 484 Absolute Discounting model on the test data: 375.6508595542186
# Perplexity of the 485 Absolute Discounting model on the test data: 295.9687678513177
# Perplexity of the 486 Absolute Discounting model on the test data: 130.9119811026015
# Perplexity of the 487 Absolute Discounting model on the test data: 323.65208141397414
# Perplexity of the 488 Absolute Discounting model on the test data: 396.88990203545126
# Perplexity of the 489 Absolute Discounting model on the test data: 155.34979494967882
# Perplexity of the 490 Absolute Discounting model on the test data: 411.972123851074
# Perplexity of the 491 Absolute Discounting model on the test data: 147.76147197770112
# Perplexity of the 492 Absolute Discounting model on the test data: 199.69785867247802
# Perplexity of the 493 Absolute Discounting model on the test data: 1361.0488426765623
# Perplexity of the 494 Absolute Discounting model on the test data: 237.5115483440341
# Perplexity of the 495 Absolute Discounting model on the test data: 262.8074034093655
# Perplexity of the 496 Absolute Discounting model on the test data: 342.1614407840204
# Perplexity of the 497 Absolute Discounting model on the test data: 279.56166871120763
# Perplexity of the 498 Absolute Discounting model on the test data: 232.47584184928354
# Perplexity of the 499 Absolute Discounting model on the test data: 285.0417371266553
# Perplexity of the 500 Absolute Discounting model on the test data: 581.913975075003
# Perplexity of the 501 Absolute Discounting model on the test data: 245.96944676243038
# Perplexity of the 502 Absolute Discounting model on the test data: 319.18781798962544
# Perplexity of the 503 Absolute Discounting model on the test data: 309.7077127244956
# Perplexity of the 504 Absolute Discounting model on the test data: 177.28164128419613
# Perplexity of the 505 Absolute Discounting model on the test data: 322.40920479127374
# Perplexity of the 506 Absolute Discounting model on the test data: 275.50951565459417
# Perplexity of the 507 Absolute Discounting model on the test data: 411.72881487716387
# Perplexity of the 508 Absolute Discounting model on the test data: 135.4699024120437
# Perplexity of the 509 Absolute Discounting model on the test data: 487.8373802835212
# Perplexity of the 510 Absolute Discounting model on the test data: 342.2720624217175
# Perplexity of the 511 Absolute Discounting model on the test data: 244.52295749994744
# Perplexity of the 512 Absolute Discounting model on the test data: 404.6371141545561
# Perplexity of the 513 Absolute Discounting model on the test data: 282.72630149043937
# Perplexity of the 514 Absolute Discounting model on the test data: 109.96699573578384
# Perplexity of the 515 Absolute Discounting model on the test data: 149.63735974561965
# Perplexity of the 516 Absolute Discounting model on the test data: 169.40163702386408
# Perplexity of the 517 Absolute Discounting model on the test data: 235.83524618470634
# Perplexity of the 518 Absolute Discounting model on the test data: 305.8501204754512
# Perplexity of the 519 Absolute Discounting model on the test data: 244.0806791156397
# Perplexity of the 520 Absolute Discounting model on the test data: 408.0459604817162
# Perplexity of the 521 Absolute Discounting model on the test data: 172.11093052639802
# Perplexity of the 522 Absolute Discounting model on the test data: 327.99298779914017
# Perplexity of the 523 Absolute Discounting model on the test data: 439.38416545480413
# Perplexity of the 524 Absolute Discounting model on the test data: 201.70128269892723
# Perplexity of the 525 Absolute Discounting model on the test data: 406.82019059825063
# Perplexity of the 526 Absolute Discounting model on the test data: 548.3672017354977
# Perplexity of the 527 Absolute Discounting model on the test data: 316.38558848839523
# Perplexity of the 528 Absolute Discounting model on the test data: 157.81339490255286
# Perplexity of the 529 Absolute Discounting model on the test data: 785.5325840343119
# Perplexity of the 530 Absolute Discounting model on the test data: 285.33350101008443
# Perplexity of the 531 Absolute Discounting model on the test data: 129.4296718427251
# Perplexity of the 532 Absolute Discounting model on the test data: 123.69941142077124
# Perplexity of the 533 Absolute Discounting model on the test data: 502.7803453602356
# Perplexity of the 534 Absolute Discounting model on the test data: 160.501988572931
# Perplexity of the 535 Absolute Discounting model on the test data: 107.8234804085863
# Perplexity of the 536 Absolute Discounting model on the test data: 639.5041479925362
# Perplexity of the 537 Absolute Discounting model on the test data: 147.58519581153573
# Perplexity of the 538 Absolute Discounting model on the test data: 200.81176925242755
# Perplexity of the 539 Absolute Discounting model on the test data: 562.1265705975133
# Perplexity of the 540 Absolute Discounting model on the test data: 191.02666837237496
# Perplexity of the 541 Absolute Discounting model on the test data: 1013.4836831019041
# Perplexity of the 542 Absolute Discounting model on the test data: 178.45265211577708
# Perplexity of the 543 Absolute Discounting model on the test data: 384.52518379698427
# Perplexity of the 544 Absolute Discounting model on the test data: 313.8805235818588
# Perplexity of the 545 Absolute Discounting model on the test data: 251.88999162536297
# Perplexity of the 546 Absolute Discounting model on the test data: 648.6422818753091
# Perplexity of the 547 Absolute Discounting model on the test data: 314.6669999095838
# Perplexity of the 548 Absolute Discounting model on the test data: 279.0035617014223
# Perplexity of the 549 Absolute Discounting model on the test data: 134.03488635951857
# Perplexity of the 550 Absolute Discounting model on the test data: 178.45041306246907
# Perplexity of the 551 Absolute Discounting model on the test data: 608.6192265500558
# Perplexity of the 552 Absolute Discounting model on the test data: 292.7680410280176
# Perplexity of the 553 Absolute Discounting model on the test data: 172.0074273119796
# Perplexity of the 554 Absolute Discounting model on the test data: 121.49355571975777
# Perplexity of the 555 Absolute Discounting model on the test data: 161.87427240950421
# Perplexity of the 556 Absolute Discounting model on the test data: 291.2549674842961
# Perplexity of the 557 Absolute Discounting model on the test data: 872.8984775251884
# Perplexity of the 558 Absolute Discounting model on the test data: 226.9490102605687
# Perplexity of the 559 Absolute Discounting model on the test data: 231.38829435032972
# Perplexity of the 560 Absolute Discounting model on the test data: 234.27112385194778
# Perplexity of the 561 Absolute Discounting model on the test data: 1009.2091404437056
# Perplexity of the 562 Absolute Discounting model on the test data: 411.8031406689525
# ...
# Perplexity of the 1459 Absolute Discounting model on the test data: 265.19988830709264
# Perplexity of the 1460 Absolute Discounting model on the test data: 158.18649368241776
# Perplexity of the 1461 Absolute Discounting model on the test data: 353.5523002303238
# Perplexity of the 1462 Absolute Discounting model on the test data: 118.29675018448688
# Perplexity of the 1463 Absolute Discounting model on the test data: 141.20893927015152
# Perplexity of the 1464 Absolute Discounting model on the test data: 343.06832448589194
# Perplexity of the 1465 Absolute Discounting model on the test data: 216.0001879683449
# Perplexity of the 1466 Absolute Discounting model on the test data: 6842.269768032162
# Perplexity of the 1467 Absolute Discounting model on the test data: 468.6421062013477
# Perplexity of the 1468 Absolute Discounting model on the test data: 834.1770630806412
# Perplexity of the 1469 Absolute Discounting model on the test data: 438.75759984152324
# Perplexity of the 1470 Absolute Discounting model on the test data: 265.9313465388695
# Perplexity of the 1471 Absolute Discounting model on the test data: 303.7298461265079
# Perplexity of the 1472 Absolute Discounting model on the test data: 143.46468456368345
# Perplexity of the 1473 Absolute Discounting model on the test data: 202.18051717304778
# Perplexity of the 1474 Absolute Discounting model on the test data: 289.34185865448336
# Perplexity of the 1475 Absolute Discounting model on the test data: 247.54173882622254
# Perplexity of the 1476 Absolute Discounting model on the test data: 178.35989562272
# Perplexity of the 1477 Absolute Discounting model on the test data: 243.14752068771767
# Perplexity of the 1478 Absolute Discounting model on the test data: 408.8576767683047
# Perplexity of the 1479 Absolute Discounting model on the test data: 184.9705443459113
# Perplexity of the 1480 Absolute Discounting model on the test data: 898.2882313713015
# Perplexity of the 1481 Absolute Discounting model on the test data: 176.88999989580054
# Perplexity of the 1482 Absolute Discounting model on the test data: 160.61997652323228
# Perplexity of the 1483 Absolute Discounting model on the test data: 243.62699022158202
# Perplexity of the 1484 Absolute Discounting model on the test data: 140.6644469249925
# Perplexity of the 1485 Absolute Discounting model on the test data: 108.9033846291145
# Perplexity of the 1486 Absolute Discounting model on the test data: 421.162788655792
# Perplexity of the 1487 Absolute Discounting model on the test data: 259.06322083531694
# Perplexity of the 1488 Absolute Discounting model on the test data: 746.660864619867
# Perplexity of the 1489 Absolute Discounting model on the test data: 593.1294566993312
# Perplexity of the 1490 Absolute Discounting model on the test data: 274.5787168631066
# Perplexity of the 1491 Absolute Discounting model on the test data: 368.92203541040806
# Perplexity of the 1492 Absolute Discounting model on the test data: 349.4922837624545
# Perplexity of the 1493 Absolute Discounting model on the test data: 211.55820137656428
# Perplexity of the 1494 Absolute Discounting model on the test data: 308.5732506730737
# Perplexity of the 1495 Absolute Discounting model on the test data: 163.234585421439
# Perplexity of the 1496 Absolute Discounting model on the test data: 269.0906186784027
# Perplexity of the 1497 Absolute Discounting model on the test data: 719.7543956666349
# Perplexity of the 1498 Absolute Discounting model on the test data: 530.1181488347406
# Perplexity of the 1499 Absolute Discounting model on the test data: 389.5066006990698
# Perplexity of the 1500 Absolute Discounting model on the test data: 276.5773651079475
# Perplexity of the 1501 Absolute Discounting model on the test data: 76.36149701137418
# Perplexity of the 1502 Absolute Discounting model on the test data: 227.35030545266602
# Perplexity of the 1503 Absolute Discounting model on the test data: 256.53068880731104
# Perplexity of the 1504 Absolute Discounting model on the test data: 139.49920257937515
# Perplexity of the 1505 Absolute Discounting model on the test data: 246.86256402745377
# Perplexity of the 1506 Absolute Discounting model on the test data: 739.6650362334346
# Perplexity of the 1507 Absolute Discounting model on the test data: 200.43616143740067
# Perplexity of the 1508 Absolute Discounting model on the test data: 235.78854715500697
# Perplexity of the 1509 Absolute Discounting model on the test data: 235.00935992759116
# Perplexity of the 1510 Absolute Discounting model on the test data: 376.6957146117277
# Perplexity of the 1511 Absolute Discounting model on the test data: 416.67016066813585
# Perplexity of the 1512 Absolute Discounting model on the test data: 252.89871217837947
# Perplexity of the 1513 Absolute Discounting model on the test data: 207.94539258917436
# Perplexity of the 1514 Absolute Discounting model on the test data: 497.8201143082219
# Perplexity of the 1515 Absolute Discounting model on the test data: 149.92231627946578
# Perplexity of the 1516 Absolute Discounting model on the test data: 351.8743787719836
# Perplexity of the 1517 Absolute Discounting model on the test data: 318.22954324349627
# Perplexity of the 1518 Absolute Discounting model on the test data: 159.53839886514177
# Perplexity of the 1519 Absolute Discounting model on the test data: 363.15428021901926
# Perplexity of the 1520 Absolute Discounting model on the test data: 326.45412629905724
# Perplexity of the 1521 Absolute Discounting model on the test data: 191.41086890750785
# Perplexity of the 1522 Absolute Discounting model on the test data: 653.2931965718466
# Perplexity of the 1523 Absolute Discounting model on the test data: 174.69350704652672
# Perplexity of the 1524 Absolute Discounting model on the test data: 479.8590895332765
# Perplexity of the 1525 Absolute Discounting model on the test data: 278.93331476170187
# Perplexity of the 1526 Absolute Discounting model on the test data: 510.56508162142137
# Perplexity of the 1527 Absolute Discounting model on the test data: 305.7263417424028
# Perplexity of the 1528 Absolute Discounting model on the test data: 572.037784485291
# Perplexity of the 1529 Absolute Discounting model on the test data: 118.34390243940332
# Perplexity of the 1530 Absolute Discounting model on the test data: 322.23898666915386
# Perplexity of the 1531 Absolute Discounting model on the test data: 222.17258270905546
# Perplexity of the 1532 Absolute Discounting model on the test data: 720.5123609419942
# Perplexity of the 1533 Absolute Discounting model on the test data: 673.9850667027359
# Perplexity of the 1534 Absolute Discounting model on the test data: 152.05155565328246
# Perplexity of the 1535 Absolute Discounting model on the test data: 342.41130984782006
# Perplexity of the 1536 Absolute Discounting model on the test data: 304.38942448128364
# Perplexity of the 1537 Absolute Discounting model on the test data: 284.97678066199484
# Perplexity of the 1538 Absolute Discounting model on the test data: 427.89513446900753
# Perplexity of the 1539 Absolute Discounting model on the test data: 201.06129168303116
# Perplexity of the 1540 Absolute Discounting model on the test data: 332.6265903338936
# Perplexity of the 1541 Absolute Discounting model on the test data: 405.74063095604356
# Perplexity of the 1542 Absolute Discounting model on the test data: 250.0551439956697
# Perplexity of the 1543 Absolute Discounting model on the test data: 96.10243731665894
# Perplexity of the 1544 Absolute Discounting model on the test data: 72.20379981474173
# Perplexity of the 1545 Absolute Discounting model on the test data: 276.8497959870452
# Perplexity of the 1546 Absolute Discounting model on the test data: 152.96028694729284
# Perplexity of the 1547 Absolute Discounting model on the test data: 337.0229348777566
# Perplexity of the 1548 Absolute Discounting model on the test data: 460.4789708455132
# Perplexity of the 1549 Absolute Discounting model on the test data: 301.4493976688518
# Perplexity of the 1550 Absolute Discounting model on the test data: 648.4541240688262
# Perplexity of the 1551 Absolute Discounting model on the test data: 278.50514331933675
# Perplexity of the 1552 Absolute Discounting model on the test data: 560.6540773314463
# Perplexity of the 1553 Absolute Discounting model on the test data: 550.198706583689
# Perplexity of the 1554 Absolute Discounting model on the test data: 700.1494257551273
# Perplexity of the 1555 Absolute Discounting model on the test data: 197.98972075301796
# Perplexity of the 1556 Absolute Discounting model on the test data: 139.42805917921382
# Perplexity of the 1557 Absolute Discounting model on the test data: 249.01051461916052
# Perplexity of the 1558 Absolute Discounting model on the test data: 373.14942706520765
# Perplexity of the 1559 Absolute Discounting model on the test data: 96.90389961812396
# Perplexity of the 1560 Absolute Discounting model on the test data: 264.2284028934735
# Perplexity of the 1561 Absolute Discounting model on the test data: 2658.7043289361623
# Perplexity of the 1562 Absolute Discounting model on the test data: 146.44293929764436
# Perplexity of the 1563 Absolute Discounting model on the test data: 302.2385310970126
# Perplexity of the 1564 Absolute Discounting model on the test data: 379.2170954675353
# Perplexity of the 1565 Absolute Discounting model on the test data: 261.8438915414798
# Perplexity of the 1566 Absolute Discounting model on the test data: 304.97934131157587
# Perplexity of the 1567 Absolute Discounting model on the test data: 354.833399058672
# Perplexity of the 1568 Absolute Discounting model on the test data: 198.44811965430358
# Perplexity of the 1569 Absolute Discounting model on the test data: 189.9886113578744
# Perplexity of the 1570 Absolute Discounting model on the test data: 154.7308953478931
# Perplexity of the 1571 Absolute Discounting model on the test data: 188.4889716396537
# Perplexity of the 1572 Absolute Discounting model on the test data: 228.662423922024
# Perplexity of the 1573 Absolute Discounting model on the test data: 123.09502637384136
# Perplexity of the 1574 Absolute Discounting model on the test data: 203.77074176004103
# Perplexity of the 1575 Absolute Discounting model on the test data: 187.5714285679683
# Perplexity of the 1576 Absolute Discounting model on the test data: 278.58190383114857
# Perplexity of the 1577 Absolute Discounting model on the test data: 378.6430380979656
# Perplexity of the 1578 Absolute Discounting model on the test data: 446.08807944747105
# Perplexity of the 1579 Absolute Discounting model on the test data: 421.463926720262
# Perplexity of the 1580 Absolute Discounting model on the test data: 169.22221631899376
# Perplexity of the 1581 Absolute Discounting model on the test data: 947.1146704381865
# Perplexity of the 1582 Absolute Discounting model on the test data: 244.86016244920475
# Perplexity of the 1583 Absolute Discounting model on the test data: 212.93186250685412
# Perplexity of the 1584 Absolute Discounting model on the test data: 173.73103956312372
# Perplexity of the 1585 Absolute Discounting model on the test data: 1120.6566613508066
# Perplexity of the 1586 Absolute Discounting model on the test data: 288.4678573368694
# Perplexity of the 1587 Absolute Discounting model on the test data: 174.5691555668914
# Perplexity of the 1588 Absolute Discounting model on the test data: 642.4609263380225
# Perplexity of the 1589 Absolute Discounting model on the test data: 228.1837425092735
# Perplexity of the 1590 Absolute Discounting model on the test data: 188.38174245213168
# Perplexity of the 1591 Absolute Discounting model on the test data: 780.3674038543186
# Perplexity of the 1592 Absolute Discounting model on the test data: 138.68984681375704
# Perplexity of the 1593 Absolute Discounting model on the test data: 313.02990228349205
# Perplexity of the 1594 Absolute Discounting model on the test data: 102.83710097523395
# Perplexity of the 1595 Absolute Discounting model on the test data: 153.68749732797778
# Perplexity of the 1596 Absolute Discounting model on the test data: 260.42864586065303
# Perplexity of the 1597 Absolute Discounting model on the test data: 135.80736476260122
# Perplexity of the 1598 Absolute Discounting model on the test data: 315.5895035493961
# Perplexity of the 1599 Absolute Discounting model on the test data: 362.4664138570224
# Perplexity of the 1600 Absolute Discounting model on the test data: 448.7998603682905
# Perplexity of the 1601 Absolute Discounting model on the test data: 406.5389436868126
# Perplexity of the 1602 Absolute Discounting model on the test data: 159.89750474838146
# Perplexity of the 1603 Absolute Discounting model on the test data: 389.31130863310545
# Perplexity of the 1604 Absolute Discounting model on the test data: 658.4876197070645
# Perplexity of the 1605 Absolute Discounting model on the test data: 153.3229563876218
# Perplexity of the 1606 Absolute Discounting model on the test data: 119.59871045816084
# Perplexity of the 1607 Absolute Discounting model on the test data: 375.5054945226923
# Perplexity of the 1608 Absolute Discounting model on the test data: 258.5605373024381
# Perplexity of the 1609 Absolute Discounting model on the test data: 303.04152803531315
# Perplexity of the 1610 Absolute Discounting model on the test data: 450.67782283950794
# Perplexity of the 1611 Absolute Discounting model on the test data: 154.78594823676522
# Perplexity of the 1612 Absolute Discounting model on the test data: 571.3610075110767
# Perplexity of the 1613 Absolute Discounting model on the test data: 123.6508544500811
# Perplexity of the 1614 Absolute Discounting model on the test data: 479.826938658705
# Perplexity of the 1615 Absolute Discounting model on the test data: 151.55241718151177
# Perplexity of the 1616 Absolute Discounting model on the test data: 154.89217557282998
# Perplexity of the 1617 Absolute Discounting model on the test data: 375.907381595182
# Perplexity of the 1618 Absolute Discounting model on the test data: 295.08150073758856
# Perplexity of the 1619 Absolute Discounting model on the test data: 290.72765456290927
# Perplexity of the 1620 Absolute Discounting model on the test data: 279.28438042243937
# Perplexity of the 1621 Absolute Discounting model on the test data: 266.58385730564953
# Perplexity of the 1622 Absolute Discounting model on the test data: 268.5766728860507
# Perplexity of the 1623 Absolute Discounting model on the test data: 128.15520352987272
# Perplexity of the 1624 Absolute Discounting model on the test data: 737.0724680461012
# Perplexity of the 1625 Absolute Discounting model on the test data: 237.65478079731946
# Perplexity of the 1626 Absolute Discounting model on the test data: 486.38788476486417
# Perplexity of the 1627 Absolute Discounting model on the test data: 360.4456118261212
# Perplexity of the 1628 Absolute Discounting model on the test data: 599.0355172157214
# Perplexity of the 1629 Absolute Discounting model on the test data: 226.35919650335197
# Perplexity of the 1630 Absolute Discounting model on the test data: 341.2578063079189
# Perplexity of the 1631 Absolute Discounting model on the test data: 214.61577471681562
# Perplexity of the 1632 Absolute Discounting model on the test data: 568.7786746451638
# Perplexity of the 1633 Absolute Discounting model on the test data: 220.59178091748794
# Perplexity of the 1634 Absolute Discounting model on the test data: 364.8121269965031
# Perplexity of the 1635 Absolute Discounting model on the test data: 640.7728326006147
# Perplexity of the 1636 Absolute Discounting model on the test data: 136.71890783320384
# Perplexity of the 1637 Absolute Discounting model on the test data: 146.90749184004162
# Perplexity of the 1638 Absolute Discounting model on the test data: 202.65603384627315
# Perplexity of the 1639 Absolute Discounting model on the test data: 331.1648113692783
# Perplexity of the 1640 Absolute Discounting model on the test data: 272.4836821695674
# Perplexity of the 1641 Absolute Discounting model on the test data: 656.3067482647314
# Perplexity of the 1642 Absolute Discounting model on the test data: 3764.2977022641167
# Perplexity of the 1643 Absolute Discounting model on the test data: 239.2206936946199

# %%
# trigram
# Train the model with AbsoluteDiscounting
absolute_discounting_model = AbsoluteDiscounting(3)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
background_prob = [0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009, 0.01, 0.1]
discounts = [0.001, 0.01, 0.1, 0.3, 0.5 , 0.7]
perplexity_dict = {}
for p_bg in background_prob:
    for discount in discounts:
        absolute_discounting_model.p_bg = p_bg
        absolute_discounting_model.discount = discount
        perplexity_dict[(p_bg, discount)] = absolute_discounting_model.perplexity(validation_tokens)

#choose the best hyperparameter
best_p_bg, best_discount = min(perplexity_dict, key=perplexity_dict.get)
absolute_discounting_model.p_bg = best_p_bg
absolute_discounting_model.discount = best_discount
# Evaluate the model
for i, content in enumerate(test['content']):
    test_tokens = [token for token in content]  # Flatten the list of tokens
    print(f"Perplexity of the {i} Absolute Discounting model on the test data: {absolute_discounting_model.perplexity(test_tokens)}")
    absolute_discounting_model.applied_discounting = 1
# Out:
# Perplexity of the 0 Absolute Discounting model on the test data: 2150.4315914078875
# Perplexity of the 1 Absolute Discounting model on the test data: 2098.495944177024
# Perplexity of the 2 Absolute Discounting model on the test data: 1486.912549239702
# Perplexity of the 3 Absolute Discounting model on the test data: 1185.7213742271306
# Perplexity of the 4 Absolute Discounting model on the test data: 764.9289356711624
# Perplexity of the 5 Absolute Discounting model on the test data: 1126.1579314836176
# Perplexity of the 6 Absolute Discounting model on the test data: 2442.8637723690345
# Perplexity of the 7 Absolute Discounting model on the test data: 2192.6780002709115
# Perplexity of the 8 Absolute Discounting model on the test data: 268.40202449398487
# Perplexity of the 9 Absolute Discounting model on the test data: 2007.7476674454715
# Perplexity of the 10 Absolute Discounting model on the test data: 2363.4207098698166
# Perplexity of the 11 Absolute Discounting model on the test data: 687.571963405928
# Perplexity of the 12 Absolute Discounting model on the test data: 1395.056104663067
# Perplexity of the 13 Absolute Discounting model on the test data: 1147.524442184954
# Perplexity of the 14 Absolute Discounting model on the test data: 1125.0176199343507
# Perplexity of the 15 Absolute Discounting model on the test data: 1582.2259151024452
# Perplexity of the 16 Absolute Discounting model on the test data: 1414.9589451546487
# Perplexity of the 17 Absolute Discounting model on the test data: 3358.354109799976
# Perplexity of the 18 Absolute Discounting model on the test data: 2488.414137531625
# Perplexity of the 19 Absolute Discounting model on the test data: 2387.827219486474
# Perplexity of the 20 Absolute Discounting model on the test data: 1767.0036825466182
# Perplexity of the 21 Absolute Discounting model on the test data: 1019.8211308185195
# Perplexity of the 22 Absolute Discounting model on the test data: 693.5901756468575
# Perplexity of the 23 Absolute Discounting model on the test data: 966.6979829477638
# Perplexity of the 24 Absolute Discounting model on the test data: 1704.6561422880104
# Perplexity of the 25 Absolute Discounting model on the test data: 1172.837711403227
# Perplexity of the 26 Absolute Discounting model on the test data: 2287.944418584452
# Perplexity of the 27 Absolute Discounting model on the test data: 1301.2277460723924
# Perplexity of the 28 Absolute Discounting model on the test data: 1134.8757273874678
# Perplexity of the 29 Absolute Discounting model on the test data: 702.2103258256304
# Perplexity of the 30 Absolute Discounting model on the test data: 894.5624762173093
# Perplexity of the 31 Absolute Discounting model on the test data: 628.267996264447
# Perplexity of the 32 Absolute Discounting model on the test data: 3739.541063130944
# Perplexity of the 33 Absolute Discounting model on the test data: 188.3686406262653
# Perplexity of the 34 Absolute Discounting model on the test data: 2412.0146943077707
# Perplexity of the 35 Absolute Discounting model on the test data: 1329.1054528687037
# Perplexity of the 36 Absolute Discounting model on the test data: 297.51265556415166
# Perplexity of the 37 Absolute Discounting model on the test data: 1216.8721967934566
# Perplexity of the 38 Absolute Discounting model on the test data: 1389.37164721778
# Perplexity of the 39 Absolute Discounting model on the test data: 435.6921262658934
# Perplexity of the 40 Absolute Discounting model on the test data: 1056.692268426144
# Perplexity of the 41 Absolute Discounting model on the test data: 1276.342174093633
# Perplexity of the 42 Absolute Discounting model on the test data: 250.9791899165396
# Perplexity of the 43 Absolute Discounting model on the test data: 3163.4804710717804
# Perplexity of the 44 Absolute Discounting model on the test data: 822.3479491385809
# Perplexity of the 45 Absolute Discounting model on the test data: 2267.017412529302
# Perplexity of the 46 Absolute Discounting model on the test data: 886.0815499000561
# Perplexity of the 47 Absolute Discounting model on the test data: 2664.286562944042
# Perplexity of the 48 Absolute Discounting model on the test data: 1091.3131188254606
# Perplexity of the 49 Absolute Discounting model on the test data: 4656.8917417260145
# Perplexity of the 50 Absolute Discounting model on the test data: 216.35314389221722
# Perplexity of the 51 Absolute Discounting model on the test data: 1439.3175133222258
# Perplexity of the 52 Absolute Discounting model on the test data: 1750.932205329153
# Perplexity of the 53 Absolute Discounting model on the test data: 2171.530486439373
# Perplexity of the 54 Absolute Discounting model on the test data: 1302.0901708503325
# Perplexity of the 55 Absolute Discounting model on the test data: 1991.8841766252451
# Perplexity of the 56 Absolute Discounting model on the test data: 1929.2507050844467
# Perplexity of the 57 Absolute Discounting model on the test data: 378.8172640426234
# Perplexity of the 58 Absolute Discounting model on the test data: 1896.5950013408356
# Perplexity of the 59 Absolute Discounting model on the test data: 2272.1634913865933
# Perplexity of the 60 Absolute Discounting model on the test data: 1501.5963283801868
# Perplexity of the 61 Absolute Discounting model on the test data: 1077.1744137913201
# Perplexity of the 62 Absolute Discounting model on the test data: 1313.2300119341555
# Perplexity of the 63 Absolute Discounting model on the test data: 1828.7238139256397
# Perplexity of the 64 Absolute Discounting model on the test data: 2846.6173105155412
# Perplexity of the 65 Absolute Discounting model on the test data: 734.9275810555531
# Perplexity of the 66 Absolute Discounting model on the test data: 2682.911592064465
# Perplexity of the 67 Absolute Discounting model on the test data: 1226.3950607606184
# Perplexity of the 68 Absolute Discounting model on the test data: 612.1012199424125
# Perplexity of the 69 Absolute Discounting model on the test data: 3705.089413695375
# Perplexity of the 70 Absolute Discounting model on the test data: 295.25213489428444
# Perplexity of the 71 Absolute Discounting model on the test data: 810.3297176774416
# Perplexity of the 72 Absolute Discounting model on the test data: 4080.475398061573
# Perplexity of the 73 Absolute Discounting model on the test data: 2928.465427747343
# Perplexity of the 74 Absolute Discounting model on the test data: 555.850820337324
# Perplexity of the 75 Absolute Discounting model on the test data: 581.6887183239135
# Perplexity of the 76 Absolute Discounting model on the test data: 1614.3670976116096
# Perplexity of the 77 Absolute Discounting model on the test data: 2062.376980549939
# Perplexity of the 78 Absolute Discounting model on the test data: 973.1552323381674
# Perplexity of the 79 Absolute Discounting model on the test data: 241.19113260822905
# Perplexity of the 80 Absolute Discounting model on the test data: 952.4502501747784
# Perplexity of the 81 Absolute Discounting model on the test data: 1039.1538379434512
# Perplexity of the 82 Absolute Discounting model on the test data: 1293.740730622699
# Perplexity of the 83 Absolute Discounting model on the test data: 989.618052861829
# Perplexity of the 84 Absolute Discounting model on the test data: 825.2242980233394
# Perplexity of the 85 Absolute Discounting model on the test data: 738.306743694346
# Perplexity of the 86 Absolute Discounting model on the test data: 207.26875849011628
# Perplexity of the 87 Absolute Discounting model on the test data: 814.012982349676
# Perplexity of the 88 Absolute Discounting model on the test data: 1619.5710344147442
# Perplexity of the 89 Absolute Discounting model on the test data: 867.9262224798116
# Perplexity of the 90 Absolute Discounting model on the test data: 1248.9623288486387
# Perplexity of the 91 Absolute Discounting model on the test data: 2321.836744668522
# Perplexity of the 92 Absolute Discounting model on the test data: 1638.3308965404676
# Perplexity of the 93 Absolute Discounting model on the test data: 3070.10687988869
# Perplexity of the 94 Absolute Discounting model on the test data: 1635.0085046441495
# Perplexity of the 95 Absolute Discounting model on the test data: 414.7267528321768
# Perplexity of the 96 Absolute Discounting model on the test data: 2650.5055594138194
# Perplexity of the 97 Absolute Discounting model on the test data: 1393.731624559979
# Perplexity of the 98 Absolute Discounting model on the test data: 1256.088675307531
# Perplexity of the 99 Absolute Discounting model on the test data: 2609.7485949905713
# Perplexity of the 100 Absolute Discounting model on the test data: 24.452364358227406
# Perplexity of the 101 Absolute Discounting model on the test data: 43.264342974237415
# Perplexity of the 102 Absolute Discounting model on the test data: 2612.7935529396977
# Perplexity of the 103 Absolute Discounting model on the test data: 1565.847238543056
# Perplexity of the 104 Absolute Discounting model on the test data: 1171.9228557871454
# Perplexity of the 105 Absolute Discounting model on the test data: 2093.1586215960806
# Perplexity of the 106 Absolute Discounting model on the test data: 2033.2899357346996
# Perplexity of the 107 Absolute Discounting model on the test data: 2136.173606785252
# Perplexity of the 108 Absolute Discounting model on the test data: 942.0713290798006
# Perplexity of the 109 Absolute Discounting model on the test data: 980.9105474498627
# Perplexity of the 110 Absolute Discounting model on the test data: 1331.0236948125123
# Perplexity of the 111 Absolute Discounting model on the test data: 636.5938731580341
# Perplexity of the 112 Absolute Discounting model on the test data: 838.4924634699919
# Perplexity of the 113 Absolute Discounting model on the test data: 1565.5267736556627
# Perplexity of the 114 Absolute Discounting model on the test data: 251.23271771934563
# Perplexity of the 115 Absolute Discounting model on the test data: 1250.0007262614752
# Perplexity of the 116 Absolute Discounting model on the test data: 1093.9277615434296
# Perplexity of the 117 Absolute Discounting model on the test data: 1028.2977537523777
# Perplexity of the 118 Absolute Discounting model on the test data: 1127.8924658168166
# Perplexity of the 119 Absolute Discounting model on the test data: 923.796664564582
# Perplexity of the 120 Absolute Discounting model on the test data: 1783.7382293295823
# Perplexity of the 121 Absolute Discounting model on the test data: 3149.5025331031425
# Perplexity of the 122 Absolute Discounting model on the test data: 2275.313153809455
# Perplexity of the 123 Absolute Discounting model on the test data: 1341.4615018283164
# Perplexity of the 124 Absolute Discounting model on the test data: 284.6316838360242
# Perplexity of the 125 Absolute Discounting model on the test data: 1538.238480813386
# Perplexity of the 126 Absolute Discounting model on the test data: 1525.2528423567378
# Perplexity of the 127 Absolute Discounting model on the test data: 1316.4618691610463
# Perplexity of the 128 Absolute Discounting model on the test data: 645.881677668926
# Perplexity of the 129 Absolute Discounting model on the test data: 1021.6205146335999
# Perplexity of the 130 Absolute Discounting model on the test data: 4367.52218379479
# Perplexity of the 131 Absolute Discounting model on the test data: 366.3019931991933
# Perplexity of the 132 Absolute Discounting model on the test data: 1820.7917164613596
# Perplexity of the 133 Absolute Discounting model on the test data: 1590.5902713380458
# Perplexity of the 134 Absolute Discounting model on the test data: 1981.9655062986458
# Perplexity of the 135 Absolute Discounting model on the test data: 3115.039657226992
# Perplexity of the 136 Absolute Discounting model on the test data: 1044.940934212457
# Perplexity of the 137 Absolute Discounting model on the test data: 707.4312049859625
# Perplexity of the 138 Absolute Discounting model on the test data: 2114.909206091351
# Perplexity of the 139 Absolute Discounting model on the test data: 453.79785497180944
# Perplexity of the 140 Absolute Discounting model on the test data: 2320.158628734818
# Perplexity of the 141 Absolute Discounting model on the test data: 5856.561778722308
# Perplexity of the 142 Absolute Discounting model on the test data: 785.2976959758079
# Perplexity of the 143 Absolute Discounting model on the test data: 2976.977552827601
# Perplexity of the 144 Absolute Discounting model on the test data: 1099.3253024784508
# Perplexity of the 145 Absolute Discounting model on the test data: 2216.9701363145186
# Perplexity of the 146 Absolute Discounting model on the test data: 1502.8232180672467
# Perplexity of the 147 Absolute Discounting model on the test data: 985.4868750089606
# Perplexity of the 148 Absolute Discounting model on the test data: 1390.7991332639779
# Perplexity of the 149 Absolute Discounting model on the test data: 653.8846142903744
# Perplexity of the 150 Absolute Discounting model on the test data: 3519.3941989337886
# Perplexity of the 151 Absolute Discounting model on the test data: 954.7557925881308
# Perplexity of the 152 Absolute Discounting model on the test data: 1136.140751097852
# Perplexity of the 153 Absolute Discounting model on the test data: 1286.0434308270928
# Perplexity of the 154 Absolute Discounting model on the test data: 2737.5813693854616
# Perplexity of the 155 Absolute Discounting model on the test data: 1634.3211738788693
# Perplexity of the 156 Absolute Discounting model on the test data: 675.0725886744851
# Perplexity of the 157 Absolute Discounting model on the test data: 1993.27728391828
# Perplexity of the 158 Absolute Discounting model on the test data: 444.3448229861008
# Perplexity of the 159 Absolute Discounting model on the test data: 1966.5697081869707
# Perplexity of the 160 Absolute Discounting model on the test data: 1804.5036654080077
# Perplexity of the 161 Absolute Discounting model on the test data: 1627.6796934666183
# Perplexity of the 162 Absolute Discounting model on the test data: 2110.506166440553
# Perplexity of the 163 Absolute Discounting model on the test data: 387.32794899069523
# Perplexity of the 164 Absolute Discounting model on the test data: 1896.0850299080319
# Perplexity of the 165 Absolute Discounting model on the test data: 2452.3167200340868
# Perplexity of the 166 Absolute Discounting model on the test data: 1675.8827067469804
# Perplexity of the 167 Absolute Discounting model on the test data: 732.5655170244376
# Perplexity of the 168 Absolute Discounting model on the test data: 1953.1453239467537
# Perplexity of the 169 Absolute Discounting model on the test data: 2384.01873956028
# Perplexity of the 170 Absolute Discounting model on the test data: 1460.6892834417897
# Perplexity of the 171 Absolute Discounting model on the test data: 669.29266349869
# Perplexity of the 172 Absolute Discounting model on the test data: 834.4543314573519
# Perplexity of the 173 Absolute Discounting model on the test data: 1825.4593526608296
# Perplexity of the 174 Absolute Discounting model on the test data: 753.7430866517433
# Perplexity of the 175 Absolute Discounting model on the test data: 1779.1730888671273
# Perplexity of the 176 Absolute Discounting model on the test data: 2439.5245215036443
# Perplexity of the 177 Absolute Discounting model on the test data: 1319.2940640961208
# Perplexity of the 178 Absolute Discounting model on the test data: 1306.6674486690506
# Perplexity of the 179 Absolute Discounting model on the test data: 4337.225483875444
# Perplexity of the 180 Absolute Discounting model on the test data: 1486.2857534660218
# Perplexity of the 181 Absolute Discounting model on the test data: 744.7248076163426
# Perplexity of the 182 Absolute Discounting model on the test data: 951.5294537427217
# Perplexity of the 183 Absolute Discounting model on the test data: 4083.762238851217
# Perplexity of the 184 Absolute Discounting model on the test data: 2994.2928385182745
# Perplexity of the 185 Absolute Discounting model on the test data: 397.2476215788095
# Perplexity of the 186 Absolute Discounting model on the test data: 1361.3881486546688
# Perplexity of the 187 Absolute Discounting model on the test data: 2127.4363486867333
# Perplexity of the 188 Absolute Discounting model on the test data: 940.5768131845383
# Perplexity of the 189 Absolute Discounting model on the test data: 937.613193041888
# Perplexity of the 190 Absolute Discounting model on the test data: 1440.7723089141457
# Perplexity of the 191 Absolute Discounting model on the test data: 4618.170031491337
# Perplexity of the 192 Absolute Discounting model on the test data: 718.3954848697307
# Perplexity of the 193 Absolute Discounting model on the test data: 1185.6776739438117
# Perplexity of the 194 Absolute Discounting model on the test data: 1836.2901570234876
# Perplexity of the 195 Absolute Discounting model on the test data: 2224.528980162076
# Perplexity of the 196 Absolute Discounting model on the test data: 690.0216858398202
# Perplexity of the 197 Absolute Discounting model on the test data: 3057.046460932128
# Perplexity of the 198 Absolute Discounting model on the test data: 244.02585524386544
# Perplexity of the 199 Absolute Discounting model on the test data: 2423.977329053036
# Perplexity of the 200 Absolute Discounting model on the test data: 1253.1250440761662
# Perplexity of the 201 Absolute Discounting model on the test data: 294.9463337912831
# Perplexity of the 202 Absolute Discounting model on the test data: 2926.631513530095
# Perplexity of the 203 Absolute Discounting model on the test data: 2768.0144632050424
# Perplexity of the 204 Absolute Discounting model on the test data: 2818.658083881881
# Perplexity of the 205 Absolute Discounting model on the test data: 2254.092072443316
# Perplexity of the 206 Absolute Discounting model on the test data: 311.00874074876526
# Perplexity of the 207 Absolute Discounting model on the test data: 703.960149790548
# Perplexity of the 208 Absolute Discounting model on the test data: 340.8219751051316
# Perplexity of the 209 Absolute Discounting model on the test data: 1932.1930229104019
# Perplexity of the 210 Absolute Discounting model on the test data: 1922.8130883402046
# Perplexity of the 211 Absolute Discounting model on the test data: 581.1352776934311
# Perplexity of the 212 Absolute Discounting model on the test data: 1765.3276831505864
# Perplexity of the 213 Absolute Discounting model on the test data: 1031.1726320108346
# Perplexity of the 214 Absolute Discounting model on the test data: 2364.995360419505
# Perplexity of the 215 Absolute Discounting model on the test data: 718.8123249952083
# Perplexity of the 216 Absolute Discounting model on the test data: 4613.833531163357
# Perplexity of the 217 Absolute Discounting model on the test data: 808.898138820293
# Perplexity of the 218 Absolute Discounting model on the test data: 937.3657588202093
# Perplexity of the 219 Absolute Discounting model on the test data: 843.7481864961127
# Perplexity of the 220 Absolute Discounting model on the test data: 2805.230589570537
# Perplexity of the 221 Absolute Discounting model on the test data: 1717.5903415307855
# Perplexity of the 222 Absolute Discounting model on the test data: 32.67262150020055
# Perplexity of the 223 Absolute Discounting model on the test data: 5618.828321159036
# Perplexity of the 224 Absolute Discounting model on the test data: 780.3983984830707
# Perplexity of the 225 Absolute Discounting model on the test data: 2495.132838375498
# Perplexity of the 226 Absolute Discounting model on the test data: 1340.5527580122537
# Perplexity of the 227 Absolute Discounting model on the test data: 1668.9516376930806
# Perplexity of the 228 Absolute Discounting model on the test data: 1166.2350734766856
# Perplexity of the 229 Absolute Discounting model on the test data: 2327.2771980407606
# Perplexity of the 230 Absolute Discounting model on the test data: 777.0475923704031
# Perplexity of the 231 Absolute Discounting model on the test data: 3635.119133431114
# Perplexity of the 232 Absolute Discounting model on the test data: 707.5034966120347
# Perplexity of the 233 Absolute Discounting model on the test data: 2880.483417487165
# Perplexity of the 234 Absolute Discounting model on the test data: 3922.871643301841
# Perplexity of the 235 Absolute Discounting model on the test data: 1884.8361477546955
# Perplexity of the 236 Absolute Discounting model on the test data: 2596.215014877525
# Perplexity of the 237 Absolute Discounting model on the test data: 1818.0080218419146
# Perplexity of the 238 Absolute Discounting model on the test data: 1424.6797829288528
# Perplexity of the 239 Absolute Discounting model on the test data: 1760.175329289236
# Perplexity of the 240 Absolute Discounting model on the test data: 1852.9976586979483
# Perplexity of the 241 Absolute Discounting model on the test data: 1041.0209846625842
# Perplexity of the 242 Absolute Discounting model on the test data: 964.9466425253972
# Perplexity of the 243 Absolute Discounting model on the test data: 488.5035162465014
# Perplexity of the 244 Absolute Discounting model on the test data: 2086.8021848179637
# Perplexity of the 245 Absolute Discounting model on the test data: 1564.9546073351944
# Perplexity of the 246 Absolute Discounting model on the test data: 2801.206876209104
# Perplexity of the 247 Absolute Discounting model on the test data: 1698.5262266394875
# Perplexity of the 248 Absolute Discounting model on the test data: 688.6305108884433
# Perplexity of the 249 Absolute Discounting model on the test data: 1582.8349658605646
# Perplexity of the 250 Absolute Discounting model on the test data: 2790.5377827552734
# Perplexity of the 251 Absolute Discounting model on the test data: 2531.6009137891942
# Perplexity of the 252 Absolute Discounting model on the test data: 1589.2283504446975
# Perplexity of the 253 Absolute Discounting model on the test data: 1479.4208622082504
# Perplexity of the 254 Absolute Discounting model on the test data: 3856.122447616327
# Perplexity of the 255 Absolute Discounting model on the test data: 1901.4698977895061
# Perplexity of the 256 Absolute Discounting model on the test data: 1799.491883234287
# Perplexity of the 257 Absolute Discounting model on the test data: 1933.8595209977968
# Perplexity of the 258 Absolute Discounting model on the test data: 913.1950171822111
# Perplexity of the 259 Absolute Discounting model on the test data: 2593.9021617132894
# Perplexity of the 260 Absolute Discounting model on the test data: 298.1532609823614
# Perplexity of the 261 Absolute Discounting model on the test data: 1195.4617757175722
# Perplexity of the 262 Absolute Discounting model on the test data: 2226.246404689351
# Perplexity of the 263 Absolute Discounting model on the test data: 3400.283845206493
# Perplexity of the 264 Absolute Discounting model on the test data: 588.1447786058156
# Perplexity of the 265 Absolute Discounting model on the test data: 285.4783343583169
# Perplexity of the 266 Absolute Discounting model on the test data: 1886.2158240713989
# Perplexity of the 267 Absolute Discounting model on the test data: 787.6301605172904
# Perplexity of the 268 Absolute Discounting model on the test data: 151.24387223095653
# Perplexity of the 269 Absolute Discounting model on the test data: 877.5761800844859
# Perplexity of the 270 Absolute Discounting model on the test data: 1704.8029948125509
# Perplexity of the 271 Absolute Discounting model on the test data: 1608.335213580367
# Perplexity of the 272 Absolute Discounting model on the test data: 1121.156310714234
# Perplexity of the 273 Absolute Discounting model on the test data: 880.7871019245855
# Perplexity of the 274 Absolute Discounting model on the test data: 3139.4383586831855
# Perplexity of the 275 Absolute Discounting model on the test data: 613.4789168073828
# Perplexity of the 276 Absolute Discounting model on the test data: 1498.673368046931
# Perplexity of the 277 Absolute Discounting model on the test data: 1621.962333590828
# Perplexity of the 278 Absolute Discounting model on the test data: 1256.4721845241756
# Perplexity of the 279 Absolute Discounting model on the test data: 3496.029284721657
# Perplexity of the 280 Absolute Discounting model on the test data: 2930.5044961179888
# Perplexity of the 281 Absolute Discounting model on the test data: 625.4344383839776
# Perplexity of the 282 Absolute Discounting model on the test data: 702.3687388688802
# Perplexity of the 283 Absolute Discounting model on the test data: 709.2203600037548
# Perplexity of the 284 Absolute Discounting model on the test data: 538.4400327377913
# Perplexity of the 285 Absolute Discounting model on the test data: 1553.946427126195
# Perplexity of the 286 Absolute Discounting model on the test data: 1453.522545766068
# Perplexity of the 287 Absolute Discounting model on the test data: 1048.717579128165
# Perplexity of the 288 Absolute Discounting model on the test data: 979.5605169867029
# Perplexity of the 289 Absolute Discounting model on the test data: 3149.2211313711673
# Perplexity of the 290 Absolute Discounting model on the test data: 1364.5685046283008
# Perplexity of the 291 Absolute Discounting model on the test data: 21.701875660389362
# Perplexity of the 292 Absolute Discounting model on the test data: 2355.035787185122
# Perplexity of the 293 Absolute Discounting model on the test data: 1723.0040184884049
# Perplexity of the 294 Absolute Discounting model on the test data: 197.65431126400364
# Perplexity of the 295 Absolute Discounting model on the test data: 2335.426760384891
# Perplexity of the 296 Absolute Discounting model on the test data: 370.0987482037948
# Perplexity of the 297 Absolute Discounting model on the test data: 1618.0881341883824
# Perplexity of the 298 Absolute Discounting model on the test data: 1537.297607123716
# Perplexity of the 299 Absolute Discounting model on the test data: 1786.6102171250852
# Perplexity of the 300 Absolute Discounting model on the test data: 2314.8642254512592
# Perplexity of the 301 Absolute Discounting model on the test data: 1105.4248446911124
# Perplexity of the 302 Absolute Discounting model on the test data: 242.00713836159872
# Perplexity of the 303 Absolute Discounting model on the test data: 1670.2620201880509
# Perplexity of the 304 Absolute Discounting model on the test data: 1211.8729838111242
# Perplexity of the 305 Absolute Discounting model on the test data: 174.38397545686934
# Perplexity of the 306 Absolute Discounting model on the test data: 2211.659014694666
# Perplexity of the 307 Absolute Discounting model on the test data: 1669.8546770753308
# Perplexity of the 308 Absolute Discounting model on the test data: 710.1679032544141
# Perplexity of the 309 Absolute Discounting model on the test data: 1491.6790553859873
# Perplexity of the 310 Absolute Discounting model on the test data: 885.9814762210814
# Perplexity of the 311 Absolute Discounting model on the test data: 895.2999773166797
# Perplexity of the 312 Absolute Discounting model on the test data: 2017.4625659488138
# Perplexity of the 313 Absolute Discounting model on the test data: 3759.846011608952
# Perplexity of the 314 Absolute Discounting model on the test data: 450.62463726882146
# Perplexity of the 315 Absolute Discounting model on the test data: 1723.1672532636442
# Perplexity of the 316 Absolute Discounting model on the test data: 1506.8428982927137
# Perplexity of the 317 Absolute Discounting model on the test data: 894.2856533938088
# Perplexity of the 318 Absolute Discounting model on the test data: 1802.3104374426491
# Perplexity of the 319 Absolute Discounting model on the test data: 2823.9071636343624
# Perplexity of the 320 Absolute Discounting model on the test data: 1656.9084574432748
# Perplexity of the 321 Absolute Discounting model on the test data: 1547.004494730677
# Perplexity of the 322 Absolute Discounting model on the test data: 1498.5176845504327
# Perplexity of the 323 Absolute Discounting model on the test data: 2517.0664185658516
# Perplexity of the 324 Absolute Discounting model on the test data: 1512.837570347961
# Perplexity of the 325 Absolute Discounting model on the test data: 842.3821731350039
# Perplexity of the 326 Absolute Discounting model on the test data: 1111.1849276401003
# Perplexity of the 327 Absolute Discounting model on the test data: 2893.0390791051827
# Perplexity of the 328 Absolute Discounting model on the test data: 1418.2351838261475
# Perplexity of the 329 Absolute Discounting model on the test data: 862.0261890511575
# Perplexity of the 330 Absolute Discounting model on the test data: 3964.887361783622
# Perplexity of the 331 Absolute Discounting model on the test data: 2597.6879472560095
# Perplexity of the 332 Absolute Discounting model on the test data: 3058.859959503156
# Perplexity of the 333 Absolute Discounting model on the test data: 625.1115345632558
# Perplexity of the 334 Absolute Discounting model on the test data: 2418.622254064804
# Perplexity of the 335 Absolute Discounting model on the test data: 3232.438292251547
# Perplexity of the 336 Absolute Discounting model on the test data: 876.3892129056176
# Perplexity of the 337 Absolute Discounting model on the test data: 807.1738957981981
# Perplexity of the 338 Absolute Discounting model on the test data: 842.2262690618104
# Perplexity of the 339 Absolute Discounting model on the test data: 1081.5118609602994
# Perplexity of the 340 Absolute Discounting model on the test data: 3077.9494696031247
# Perplexity of the 341 Absolute Discounting model on the test data: 931.6107459684808
# Perplexity of the 342 Absolute Discounting model on the test data: 1906.4957175470122
# Perplexity of the 343 Absolute Discounting model on the test data: 662.3994709291155
# Perplexity of the 344 Absolute Discounting model on the test data: 2272.983941252789
# Perplexity of the 345 Absolute Discounting model on the test data: 2666.3326796947867
# Perplexity of the 346 Absolute Discounting model on the test data: 2551.7255753513386
# Perplexity of the 347 Absolute Discounting model on the test data: 1425.7411283086235
# Perplexity of the 348 Absolute Discounting model on the test data: 955.6074751568808
# Perplexity of the 349 Absolute Discounting model on the test data: 959.2800198589293
# Perplexity of the 350 Absolute Discounting model on the test data: 2700.787060111406
# Perplexity of the 351 Absolute Discounting model on the test data: 2345.849892556501
# Perplexity of the 352 Absolute Discounting model on the test data: 1515.6954140955534
# Perplexity of the 353 Absolute Discounting model on the test data: 723.244304618578
# Perplexity of the 354 Absolute Discounting model on the test data: 1849.7101239966598
# Perplexity of the 355 Absolute Discounting model on the test data: 395.72744276049366
# Perplexity of the 356 Absolute Discounting model on the test data: 959.3136275838754
# Perplexity of the 357 Absolute Discounting model on the test data: 581.7728878130955
# Perplexity of the 358 Absolute Discounting model on the test data: 422.8339991626924
# Perplexity of the 359 Absolute Discounting model on the test data: 615.4165196830145
# Perplexity of the 360 Absolute Discounting model on the test data: 3327.7933750353354
# Perplexity of the 361 Absolute Discounting model on the test data: 703.356295065747
# Perplexity of the 362 Absolute Discounting model on the test data: 2364.6834507576873
# Perplexity of the 363 Absolute Discounting model on the test data: 1997.185042731417
# Perplexity of the 364 Absolute Discounting model on the test data: 1351.8467693283274
# Perplexity of the 365 Absolute Discounting model on the test data: 1796.383828677049
# Perplexity of the 366 Absolute Discounting model on the test data: 5700.692246340516
# Perplexity of the 367 Absolute Discounting model on the test data: 1232.0122177845283
# Perplexity of the 368 Absolute Discounting model on the test data: 794.21177456179
# Perplexity of the 369 Absolute Discounting model on the test data: 1707.0339017361734
# Perplexity of the 370 Absolute Discounting model on the test data: 2042.3891552212594
# Perplexity of the 371 Absolute Discounting model on the test data: 1298.9407822870367
# Perplexity of the 372 Absolute Discounting model on the test data: 820.6252949792654
# Perplexity of the 373 Absolute Discounting model on the test data: 3308.229473467157
# Perplexity of the 374 Absolute Discounting model on the test data: 1941.7657164511384
# Perplexity of the 375 Absolute Discounting model on the test data: 2879.2120853595084
# Perplexity of the 376 Absolute Discounting model on the test data: 2912.377590483432
# Perplexity of the 377 Absolute Discounting model on the test data: 2505.5166047011185
# Perplexity of the 378 Absolute Discounting model on the test data: 1591.2141226296196
# Perplexity of the 379 Absolute Discounting model on the test data: 1775.5162942843858
# Perplexity of the 380 Absolute Discounting model on the test data: 1382.7360740551328
# Perplexity of the 381 Absolute Discounting model on the test data: 652.1484671038063
# Perplexity of the 382 Absolute Discounting model on the test data: 2619.554579007387
# Perplexity of the 383 Absolute Discounting model on the test data: 297.6388070256046
# Perplexity of the 384 Absolute Discounting model on the test data: 2561.010428140501
# Perplexity of the 385 Absolute Discounting model on the test data: 530.2197582619466
# Perplexity of the 386 Absolute Discounting model on the test data: 1578.5716768998361
# Perplexity of the 387 Absolute Discounting model on the test data: 3474.636259971725
# Perplexity of the 388 Absolute Discounting model on the test data: 1963.2294791129868
# Perplexity of the 389 Absolute Discounting model on the test data: 826.646143896878
# Perplexity of the 390 Absolute Discounting model on the test data: 2966.0475843984477
# Perplexity of the 391 Absolute Discounting model on the test data: 1287.4197836261778
# Perplexity of the 392 Absolute Discounting model on the test data: 1263.4043972855125
# Perplexity of the 393 Absolute Discounting model on the test data: 608.4257756171136
# Perplexity of the 394 Absolute Discounting model on the test data: 1678.4311769075134
# Perplexity of the 395 Absolute Discounting model on the test data: 1020.2377063534723
# Perplexity of the 396 Absolute Discounting model on the test data: 541.7353805114099
# Perplexity of the 397 Absolute Discounting model on the test data: 762.0184380278954
# Perplexity of the 398 Absolute Discounting model on the test data: 2475.4740886379245
# Perplexity of the 399 Absolute Discounting model on the test data: 583.2317856010766
# Perplexity of the 400 Absolute Discounting model on the test data: 1526.6468660600694
# Perplexity of the 401 Absolute Discounting model on the test data: 851.5521186018232
# Perplexity of the 402 Absolute Discounting model on the test data: 1497.1779865118788
# Perplexity of the 403 Absolute Discounting model on the test data: 996.8281417269066
# Perplexity of the 404 Absolute Discounting model on the test data: 1468.902251276264
# Perplexity of the 405 Absolute Discounting model on the test data: 1487.6188852168384
# Perplexity of the 406 Absolute Discounting model on the test data: 1064.8049176649974
# Perplexity of the 407 Absolute Discounting model on the test data: 2805.243638704694
# Perplexity of the 408 Absolute Discounting model on the test data: 1460.5663058904681
# Perplexity of the 409 Absolute Discounting model on the test data: 915.01672711449
# Perplexity of the 410 Absolute Discounting model on the test data: 1688.6544599307776
# Perplexity of the 411 Absolute Discounting model on the test data: 2264.1468978000266
# Perplexity of the 412 Absolute Discounting model on the test data: 1575.9166398523996
# Perplexity of the 413 Absolute Discounting model on the test data: 745.7494838765375
# Perplexity of the 414 Absolute Discounting model on the test data: 6309.531903790356
# Perplexity of the 415 Absolute Discounting model on the test data: 2956.5572795875373
# Perplexity of the 416 Absolute Discounting model on the test data: 561.9768878084436
# Perplexity of the 417 Absolute Discounting model on the test data: 1550.4458471312769
# Perplexity of the 418 Absolute Discounting model on the test data: 2722.9263040712503
# Perplexity of the 419 Absolute Discounting model on the test data: 8277.047177958562
# Perplexity of the 420 Absolute Discounting model on the test data: 1724.6145981929512
# Perplexity of the 421 Absolute Discounting model on the test data: 1477.2537197342785
# Perplexity of the 422 Absolute Discounting model on the test data: 1281.7557144257503
# Perplexity of the 423 Absolute Discounting model on the test data: 1879.0634233429791
# Perplexity of the 424 Absolute Discounting model on the test data: 2152.752067600939
# Perplexity of the 425 Absolute Discounting model on the test data: 3041.5656671203005
# Perplexity of the 426 Absolute Discounting model on the test data: 1943.921523008911
# Perplexity of the 427 Absolute Discounting model on the test data: 1660.208411538024
# Perplexity of the 428 Absolute Discounting model on the test data: 1421.9264707312166
# Perplexity of the 429 Absolute Discounting model on the test data: 1850.0566603013424
# Perplexity of the 430 Absolute Discounting model on the test data: 1905.5333306639395
# Perplexity of the 431 Absolute Discounting model on the test data: 899.8261906366716
# Perplexity of the 432 Absolute Discounting model on the test data: 2106.392871215446
# Perplexity of the 433 Absolute Discounting model on the test data: 625.9799829511772
# Perplexity of the 434 Absolute Discounting model on the test data: 1623.0694100805852
# Perplexity of the 435 Absolute Discounting model on the test data: 1803.62516681519
# Perplexity of the 436 Absolute Discounting model on the test data: 2307.3153712136714
# Perplexity of the 437 Absolute Discounting model on the test data: 5296.764164369427
# Perplexity of the 438 Absolute Discounting model on the test data: 2244.084134513063
# Perplexity of the 439 Absolute Discounting model on the test data: 1669.7238533655482
# Perplexity of the 440 Absolute Discounting model on the test data: 718.6627086403774
# Perplexity of the 441 Absolute Discounting model on the test data: 857.0631134395971
# Perplexity of the 442 Absolute Discounting model on the test data: 1603.481570643385
# Perplexity of the 443 Absolute Discounting model on the test data: 446.0404566740122
# Perplexity of the 444 Absolute Discounting model on the test data: 1632.90827757401
# Perplexity of the 445 Absolute Discounting model on the test data: 3238.8953642732745
# Perplexity of the 446 Absolute Discounting model on the test data: 3538.481246929853
# Perplexity of the 447 Absolute Discounting model on the test data: 569.1963907946517
# Perplexity of the 448 Absolute Discounting model on the test data: 932.8877572235048
# Perplexity of the 449 Absolute Discounting model on the test data: 2096.200213658558
# Perplexity of the 450 Absolute Discounting model on the test data: 1157.1291042170483
# Perplexity of the 451 Absolute Discounting model on the test data: 713.2784121166919
# Perplexity of the 452 Absolute Discounting model on the test data: 3540.056796283868
# Perplexity of the 453 Absolute Discounting model on the test data: 811.1084055141403
# Perplexity of the 454 Absolute Discounting model on the test data: 2125.3372830740354
# Perplexity of the 455 Absolute Discounting model on the test data: 3172.7472448489366
# Perplexity of the 456 Absolute Discounting model on the test data: 3844.476742674005
# Perplexity of the 457 Absolute Discounting model on the test data: 1191.1865585159167
# Perplexity of the 458 Absolute Discounting model on the test data: 1036.3482400225482
# Perplexity of the 459 Absolute Discounting model on the test data: 2033.3423270664437
# Perplexity of the 460 Absolute Discounting model on the test data: 1642.7845489877168
# Perplexity of the 461 Absolute Discounting model on the test data: 2983.7653368742294
# Perplexity of the 462 Absolute Discounting model on the test data: 444.45963652685737
# Perplexity of the 463 Absolute Discounting model on the test data: 1599.2073018105402
# Perplexity of the 464 Absolute Discounting model on the test data: 487.91332613740354
# Perplexity of the 465 Absolute Discounting model on the test data: 229.65656237014764
# Perplexity of the 466 Absolute Discounting model on the test data: 4072.3272861336623
# Perplexity of the 467 Absolute Discounting model on the test data: 106.66038837176771
# Perplexity of the 468 Absolute Discounting model on the test data: 2997.422463456044
# Perplexity of the 469 Absolute Discounting model on the test data: 724.6683314787593
# Perplexity of the 470 Absolute Discounting model on the test data: 3697.518002295201
# Perplexity of the 471 Absolute Discounting model on the test data: 338.4331841131862
# Perplexity of the 472 Absolute Discounting model on the test data: 923.0125368972883
# Perplexity of the 473 Absolute Discounting model on the test data: 803.0169492624274
# Perplexity of the 474 Absolute Discounting model on the test data: 1383.6074371309646
# Perplexity of the 475 Absolute Discounting model on the test data: 2006.8447858480909
# Perplexity of the 476 Absolute Discounting model on the test data: 1972.5246219836706
# Perplexity of the 477 Absolute Discounting model on the test data: 1558.4704039301175
# Perplexity of the 478 Absolute Discounting model on the test data: 3514.5997715578064
# Perplexity of the 479 Absolute Discounting model on the test data: 826.4934197129799
# Perplexity of the 480 Absolute Discounting model on the test data: 1827.163953994399
# Perplexity of the 481 Absolute Discounting model on the test data: 545.292919783919
# Perplexity of the 482 Absolute Discounting model on the test data: 1720.94386549404
# Perplexity of the 483 Absolute Discounting model on the test data: 977.0814551160186
# Perplexity of the 484 Absolute Discounting model on the test data: 2452.7575894875995
# Perplexity of the 485 Absolute Discounting model on the test data: 1011.0108717005816
# Perplexity of the 486 Absolute Discounting model on the test data: 1078.7260845157393
# Perplexity of the 487 Absolute Discounting model on the test data: 1608.204567058023
# Perplexity of the 488 Absolute Discounting model on the test data: 413.48496457588453
# Perplexity of the 489 Absolute Discounting model on the test data: 928.7994263244434
# Perplexity of the 490 Absolute Discounting model on the test data: 1723.5070978164067
# Perplexity of the 491 Absolute Discounting model on the test data: 828.4212734262858
# Perplexity of the 492 Absolute Discounting model on the test data: 522.7278469209547
# Perplexity of the 493 Absolute Discounting model on the test data: 927.3264038660113
# Perplexity of the 494 Absolute Discounting model on the test data: 1801.6305608879552
# Perplexity of the 495 Absolute Discounting model on the test data: 736.0893251869971
# Perplexity of the 496 Absolute Discounting model on the test data: 1118.7341583128095
# Perplexity of the 497 Absolute Discounting model on the test data: 2265.4625582134117
# Perplexity of the 498 Absolute Discounting model on the test data: 2934.2706915611748
# Perplexity of the 499 Absolute Discounting model on the test data: 1774.2594766624125
# Perplexity of the 500 Absolute Discounting model on the test data: 5274.543653385606
# Perplexity of the 501 Absolute Discounting model on the test data: 2140.237903903537
# Perplexity of the 502 Absolute Discounting model on the test data: 1191.953889633609
# Perplexity of the 503 Absolute Discounting model on the test data: 1242.1351769684939
# Perplexity of the 504 Absolute Discounting model on the test data: 538.5692490723139
# Perplexity of the 505 Absolute Discounting model on the test data: 1855.7786993221555
# Perplexity of the 506 Absolute Discounting model on the test data: 1849.5724347267403
# Perplexity of the 507 Absolute Discounting model on the test data: 1311.3437742013691
# Perplexity of the 508 Absolute Discounting model on the test data: 2107.1567711566677
# Perplexity of the 509 Absolute Discounting model on the test data: 1948.515392033595
# Perplexity of the 510 Absolute Discounting model on the test data: 963.6225291078401
# Perplexity of the 511 Absolute Discounting model on the test data: 741.110342676965
# Perplexity of the 512 Absolute Discounting model on the test data: 2860.201226335367
# Perplexity of the 513 Absolute Discounting model on the test data: 2207.9192411693566
# Perplexity of the 514 Absolute Discounting model on the test data: 111.57028091243188
# Perplexity of the 515 Absolute Discounting model on the test data: 1493.95761220843
# Perplexity of the 516 Absolute Discounting model on the test data: 962.923736930523
# Perplexity of the 517 Absolute Discounting model on the test data: 790.1661778716111
# Perplexity of the 518 Absolute Discounting model on the test data: 1343.5931132140158
# Perplexity of the 519 Absolute Discounting model on the test data: 1014.4674820829089
# Perplexity of the 520 Absolute Discounting model on the test data: 3016.177302110533
# Perplexity of the 521 Absolute Discounting model on the test data: 2595.9350713103318
# Perplexity of the 522 Absolute Discounting model on the test data: 1019.0690810194346
# Perplexity of the 523 Absolute Discounting model on the test data: 1875.8731692192127
# Perplexity of the 524 Absolute Discounting model on the test data: 1333.743488668823
# Perplexity of the 525 Absolute Discounting model on the test data: 5648.17183886989
# Perplexity of the 526 Absolute Discounting model on the test data: 2750.320775174561
# Perplexity of the 527 Absolute Discounting model on the test data: 2058.771570758822
# Perplexity of the 528 Absolute Discounting model on the test data: 562.6387142056348
# Perplexity of the 529 Absolute Discounting model on the test data: 4210.502975693941
# Perplexity of the 530 Absolute Discounting model on the test data: 2017.6792473609294
# Perplexity of the 531 Absolute Discounting model on the test data: 1015.1871238537769
# Perplexity of the 532 Absolute Discounting model on the test data: 774.159170160753
# Perplexity of the 533 Absolute Discounting model on the test data: 4138.386356737376
# Perplexity of the 534 Absolute Discounting model on the test data: 552.0154873954164
# Perplexity of the 535 Absolute Discounting model on the test data: 2055.4240277166778
# Perplexity of the 536 Absolute Discounting model on the test data: 3967.89006925778
# Perplexity of the 537 Absolute Discounting model on the test data: 567.303857828701
# Perplexity of the 538 Absolute Discounting model on the test data: 2534.4483804939837
# Perplexity of the 539 Absolute Discounting model on the test data: 1608.3267121679687
# Perplexity of the 540 Absolute Discounting model on the test data: 2610.162719904618
# Perplexity of the 541 Absolute Discounting model on the test data: 993.695267749728
# Perplexity of the 542 Absolute Discounting model on the test data: 1668.646798358932
# Perplexity of the 543 Absolute Discounting model on the test data: 5144.7969840315245
# Perplexity of the 544 Absolute Discounting model on the test data: 971.1360330329977
# Perplexity of the 545 Absolute Discounting model on the test data: 1008.0705944743846
# Perplexity of the 546 Absolute Discounting model on the test data: 2852.9110327396916
# Perplexity of the 547 Absolute Discounting model on the test data: 361.0883860652189
# Perplexity of the 548 Absolute Discounting model on the test data: 2207.5021484529366
# Perplexity of the 549 Absolute Discounting model on the test data: 1617.0309025422625
# Perplexity of the 550 Absolute Discounting model on the test data: 1496.9903635370101
# Perplexity of the 551 Absolute Discounting model on the test data: 3355.1470769375946
# Perplexity of the 552 Absolute Discounting model on the test data: 1586.9328620188317
# Perplexity of the 553 Absolute Discounting model on the test data: 475.91051730639134
# Perplexity of the 554 Absolute Discounting model on the test data: 1043.8063647923905
# Perplexity of the 555 Absolute Discounting model on the test data: 656.8571391275335
# Perplexity of the 556 Absolute Discounting model on the test data: 1817.259634277566
# Perplexity of the 557 Absolute Discounting model on the test data: 3598.4072938110926
# Perplexity of the 558 Absolute Discounting model on the test data: 1575.1142136048834
# Perplexity of the 559 Absolute Discounting model on the test data: 2668.1030737506358
# Perplexity of the 560 Absolute Discounting model on the test data: 1574.5662653537881
# Perplexity of the 561 Absolute Discounting model on the test data: 3380.1380041530024
# Perplexity of the 562 Absolute Discounting model on the test data: 2721.365799353923
# ...
# Perplexity of the 1459 Absolute Discounting model on the test data: 1049.6705790165508
# Perplexity of the 1460 Absolute Discounting model on the test data: 558.3876558078634
# Perplexity of the 1461 Absolute Discounting model on the test data: 2286.4034193650136
# Perplexity of the 1462 Absolute Discounting model on the test data: 626.5294233844228
# Perplexity of the 1463 Absolute Discounting model on the test data: 801.4482126560653
# Perplexity of the 1464 Absolute Discounting model on the test data: 2462.7627031720112
# Perplexity of the 1465 Absolute Discounting model on the test data: 1399.7979523702456
# Perplexity of the 1466 Absolute Discounting model on the test data: 213.11956978383765
# Perplexity of the 1467 Absolute Discounting model on the test data: 1237.9555392605637
# Perplexity of the 1468 Absolute Discounting model on the test data: 1237.253880112501
# Perplexity of the 1469 Absolute Discounting model on the test data: 1542.928726850016
# Perplexity of the 1470 Absolute Discounting model on the test data: 2056.097275556441
# Perplexity of the 1471 Absolute Discounting model on the test data: 2066.677925860614
# Perplexity of the 1472 Absolute Discounting model on the test data: 612.0055024991899
# Perplexity of the 1473 Absolute Discounting model on the test data: 1159.6520943081662
# Perplexity of the 1474 Absolute Discounting model on the test data: 954.3394077722888
# Perplexity of the 1475 Absolute Discounting model on the test data: 1567.3341280507223
# Perplexity of the 1476 Absolute Discounting model on the test data: 665.2401460132021
# Perplexity of the 1477 Absolute Discounting model on the test data: 919.5185513323153
# Perplexity of the 1478 Absolute Discounting model on the test data: 611.2976113665131
# Perplexity of the 1479 Absolute Discounting model on the test data: 1797.5001459026018
# Perplexity of the 1480 Absolute Discounting model on the test data: 1382.8515127200676
# Perplexity of the 1481 Absolute Discounting model on the test data: 1638.0639507385074
# Perplexity of the 1482 Absolute Discounting model on the test data: 160.107596113958
# Perplexity of the 1483 Absolute Discounting model on the test data: 2868.6300856084536
# Perplexity of the 1484 Absolute Discounting model on the test data: 1081.9780015022445
# Perplexity of the 1485 Absolute Discounting model on the test data: 133.62311581379262
# Perplexity of the 1486 Absolute Discounting model on the test data: 2675.6560327177767
# Perplexity of the 1487 Absolute Discounting model on the test data: 2292.158622258973
# Perplexity of the 1488 Absolute Discounting model on the test data: 1760.2614743754846
# Perplexity of the 1489 Absolute Discounting model on the test data: 2193.728484715261
# Perplexity of the 1490 Absolute Discounting model on the test data: 6861.812038828586
# Perplexity of the 1491 Absolute Discounting model on the test data: 2526.435487004167
# Perplexity of the 1492 Absolute Discounting model on the test data: 1547.8861686254545
# Perplexity of the 1493 Absolute Discounting model on the test data: 935.6964745177526
# Perplexity of the 1494 Absolute Discounting model on the test data: 1075.5282120281433
# Perplexity of the 1495 Absolute Discounting model on the test data: 1082.8217610708853
# Perplexity of the 1496 Absolute Discounting model on the test data: 3889.961189394333
# Perplexity of the 1497 Absolute Discounting model on the test data: 2815.9597319208633
# Perplexity of the 1498 Absolute Discounting model on the test data: 1954.3740836186312
# Perplexity of the 1499 Absolute Discounting model on the test data: 1733.885210308342
# Perplexity of the 1500 Absolute Discounting model on the test data: 3105.3486381014923
# Perplexity of the 1501 Absolute Discounting model on the test data: 484.8182894862198
# Perplexity of the 1502 Absolute Discounting model on the test data: 1682.864725555972
# Perplexity of the 1503 Absolute Discounting model on the test data: 959.5461371375532
# Perplexity of the 1504 Absolute Discounting model on the test data: 261.5226208424448
# Perplexity of the 1505 Absolute Discounting model on the test data: 2149.61459376257
# Perplexity of the 1506 Absolute Discounting model on the test data: 1670.8239532641232
# Perplexity of the 1507 Absolute Discounting model on the test data: 1434.0366350254344
# Perplexity of the 1508 Absolute Discounting model on the test data: 2807.560664696942
# Perplexity of the 1509 Absolute Discounting model on the test data: 1618.169788150209
# Perplexity of the 1510 Absolute Discounting model on the test data: 3389.1218730386704
# Perplexity of the 1511 Absolute Discounting model on the test data: 1931.020065654839
# Perplexity of the 1512 Absolute Discounting model on the test data: 1830.4440770641786
# Perplexity of the 1513 Absolute Discounting model on the test data: 1747.7843840447845
# Perplexity of the 1514 Absolute Discounting model on the test data: 2554.7265608909456
# Perplexity of the 1515 Absolute Discounting model on the test data: 1311.526574420248
# Perplexity of the 1516 Absolute Discounting model on the test data: 4406.430527834367
# Perplexity of the 1517 Absolute Discounting model on the test data: 1020.8711403837666
# Perplexity of the 1518 Absolute Discounting model on the test data: 1060.9944480515355
# Perplexity of the 1519 Absolute Discounting model on the test data: 944.4285104639845
# Perplexity of the 1520 Absolute Discounting model on the test data: 1087.2787899580321
# Perplexity of the 1521 Absolute Discounting model on the test data: 1040.9931813277117
# Perplexity of the 1522 Absolute Discounting model on the test data: 1304.3112039845212
# Perplexity of the 1523 Absolute Discounting model on the test data: 212.2872490110942
# Perplexity of the 1524 Absolute Discounting model on the test data: 1213.010063077842
# Perplexity of the 1525 Absolute Discounting model on the test data: 852.0263131560458
# Perplexity of the 1526 Absolute Discounting model on the test data: 1810.3799518932506
# Perplexity of the 1527 Absolute Discounting model on the test data: 7522.716587992021
# Perplexity of the 1528 Absolute Discounting model on the test data: 801.2076118579877
# Perplexity of the 1529 Absolute Discounting model on the test data: 1105.1202642854096
# Perplexity of the 1530 Absolute Discounting model on the test data: 1238.2660700371846
# Perplexity of the 1531 Absolute Discounting model on the test data: 236.63975117884019
# Perplexity of the 1532 Absolute Discounting model on the test data: 1453.5582660080618
# Perplexity of the 1533 Absolute Discounting model on the test data: 2066.3784097180564
# Perplexity of the 1534 Absolute Discounting model on the test data: 890.3549267886032
# Perplexity of the 1535 Absolute Discounting model on the test data: 602.5076178943859
# Perplexity of the 1536 Absolute Discounting model on the test data: 440.57501837158947
# Perplexity of the 1537 Absolute Discounting model on the test data: 2712.003274360209
# Perplexity of the 1538 Absolute Discounting model on the test data: 1382.2161452245314
# Perplexity of the 1539 Absolute Discounting model on the test data: 1866.465112093322
# Perplexity of the 1540 Absolute Discounting model on the test data: 2753.6206983691973
# Perplexity of the 1541 Absolute Discounting model on the test data: 1310.7958534580018
# Perplexity of the 1542 Absolute Discounting model on the test data: 2155.713224506964
# Perplexity of the 1543 Absolute Discounting model on the test data: 350.0296321896477
# Perplexity of the 1544 Absolute Discounting model on the test data: 258.5572710121026
# Perplexity of the 1545 Absolute Discounting model on the test data: 2038.008314092154
# Perplexity of the 1546 Absolute Discounting model on the test data: 543.5576546748862
# Perplexity of the 1547 Absolute Discounting model on the test data: 3133.882803909992
# Perplexity of the 1548 Absolute Discounting model on the test data: 3765.1164202368336
# Perplexity of the 1549 Absolute Discounting model on the test data: 2027.7154164280207
# Perplexity of the 1550 Absolute Discounting model on the test data: 1460.6249015812173
# Perplexity of the 1551 Absolute Discounting model on the test data: 2584.255333615658
# Perplexity of the 1552 Absolute Discounting model on the test data: 2402.7439454995724
# Perplexity of the 1553 Absolute Discounting model on the test data: 763.9970836989316
# Perplexity of the 1554 Absolute Discounting model on the test data: 2689.0347783549187
# Perplexity of the 1555 Absolute Discounting model on the test data: 649.6852994602698
# Perplexity of the 1556 Absolute Discounting model on the test data: 696.6896361177986
# Perplexity of the 1557 Absolute Discounting model on the test data: 2572.6479136109197
# Perplexity of the 1558 Absolute Discounting model on the test data: 620.6116422463747
# Perplexity of the 1559 Absolute Discounting model on the test data: 238.75841777415673
# Perplexity of the 1560 Absolute Discounting model on the test data: 912.2399005180984
# Perplexity of the 1561 Absolute Discounting model on the test data: 554.5364108776071
# Perplexity of the 1562 Absolute Discounting model on the test data: 524.4884336506425
# Perplexity of the 1563 Absolute Discounting model on the test data: 2901.2368415129395
# Perplexity of the 1564 Absolute Discounting model on the test data: 926.1538956404072
# Perplexity of the 1565 Absolute Discounting model on the test data: 3130.7362810064183
# Perplexity of the 1566 Absolute Discounting model on the test data: 2091.974203064371
# Perplexity of the 1567 Absolute Discounting model on the test data: 4344.246010419097
# Perplexity of the 1568 Absolute Discounting model on the test data: 743.1187558712671
# Perplexity of the 1569 Absolute Discounting model on the test data: 1305.172539207286
# Perplexity of the 1570 Absolute Discounting model on the test data: 1439.1405801148821
# Perplexity of the 1571 Absolute Discounting model on the test data: 640.5784654848892
# Perplexity of the 1572 Absolute Discounting model on the test data: 1682.7369315932326
# Perplexity of the 1573 Absolute Discounting model on the test data: 738.9740430205563
# Perplexity of the 1574 Absolute Discounting model on the test data: 2069.508963839513
# Perplexity of the 1575 Absolute Discounting model on the test data: 754.2653115757023
# Perplexity of the 1576 Absolute Discounting model on the test data: 573.2373690898437
# Perplexity of the 1577 Absolute Discounting model on the test data: 1404.8726312298136
# Perplexity of the 1578 Absolute Discounting model on the test data: 3480.0841071619816
# Perplexity of the 1579 Absolute Discounting model on the test data: 2471.26705933135
# Perplexity of the 1580 Absolute Discounting model on the test data: 1523.290884289304
# Perplexity of the 1581 Absolute Discounting model on the test data: 1977.597238290991
# Perplexity of the 1582 Absolute Discounting model on the test data: 2299.213172297612
# Perplexity of the 1583 Absolute Discounting model on the test data: 573.8429306976275
# Perplexity of the 1584 Absolute Discounting model on the test data: 917.6286921926359
# Perplexity of the 1585 Absolute Discounting model on the test data: 2167.9137470693863
# Perplexity of the 1586 Absolute Discounting model on the test data: 1598.308712479526
# Perplexity of the 1587 Absolute Discounting model on the test data: 1362.1242051752747
# Perplexity of the 1588 Absolute Discounting model on the test data: 1024.2288031632222
# Perplexity of the 1589 Absolute Discounting model on the test data: 1181.9817102829666
# Perplexity of the 1590 Absolute Discounting model on the test data: 431.19962072075947
# Perplexity of the 1591 Absolute Discounting model on the test data: 2664.0076759063168
# Perplexity of the 1592 Absolute Discounting model on the test data: 1507.2694085845371
# Perplexity of the 1593 Absolute Discounting model on the test data: 1570.6018872797108
# Perplexity of the 1594 Absolute Discounting model on the test data: 1025.23884651199
# Perplexity of the 1595 Absolute Discounting model on the test data: 1567.5476558630044
# Perplexity of the 1596 Absolute Discounting model on the test data: 3493.82150846847
# Perplexity of the 1597 Absolute Discounting model on the test data: 1106.8218627371411
# Perplexity of the 1598 Absolute Discounting model on the test data: 1793.1718224247916
# Perplexity of the 1599 Absolute Discounting model on the test data: 2452.8533768968105
# Perplexity of the 1600 Absolute Discounting model on the test data: 9219.482939939335
# Perplexity of the 1601 Absolute Discounting model on the test data: 1219.8508822954768
# Perplexity of the 1602 Absolute Discounting model on the test data: 968.9647241887283
# Perplexity of the 1603 Absolute Discounting model on the test data: 2710.025639552081
# Perplexity of the 1604 Absolute Discounting model on the test data: 2270.7082456898484
# Perplexity of the 1605 Absolute Discounting model on the test data: 1303.325685520754
# Perplexity of the 1606 Absolute Discounting model on the test data: 259.55507729622536
# Perplexity of the 1607 Absolute Discounting model on the test data: 2207.7821980205263
# Perplexity of the 1608 Absolute Discounting model on the test data: 2046.3758802110979
# Perplexity of the 1609 Absolute Discounting model on the test data: 1744.0551793647192
# Perplexity of the 1610 Absolute Discounting model on the test data: 4885.886056499414
# Perplexity of the 1611 Absolute Discounting model on the test data: 906.4610730844145
# Perplexity of the 1612 Absolute Discounting model on the test data: 3646.5572107195585
# Perplexity of the 1613 Absolute Discounting model on the test data: 1741.4500646348897
# Perplexity of the 1614 Absolute Discounting model on the test data: 6550.011157457094
# Perplexity of the 1615 Absolute Discounting model on the test data: 1501.821735049725
# Perplexity of the 1616 Absolute Discounting model on the test data: 476.88494518450926
# Perplexity of the 1617 Absolute Discounting model on the test data: 2067.740960679735
# Perplexity of the 1618 Absolute Discounting model on the test data: 1322.0461117188265
# Perplexity of the 1619 Absolute Discounting model on the test data: 1122.820560412232
# Perplexity of the 1620 Absolute Discounting model on the test data: 621.2330389120532
# Perplexity of the 1621 Absolute Discounting model on the test data: 2395.61134430176
# Perplexity of the 1622 Absolute Discounting model on the test data: 172.47442935777505
# Perplexity of the 1623 Absolute Discounting model on the test data: 825.3621822566197
# Perplexity of the 1624 Absolute Discounting model on the test data: 1398.4151443008482
# Perplexity of the 1625 Absolute Discounting model on the test data: 1367.0732087597262
# Perplexity of the 1626 Absolute Discounting model on the test data: 2024.5745164365271
# Perplexity of the 1627 Absolute Discounting model on the test data: 1109.3114374964862
# Perplexity of the 1628 Absolute Discounting model on the test data: 1344.9714580077894
# Perplexity of the 1629 Absolute Discounting model on the test data: 1248.5173920334444
# Perplexity of the 1630 Absolute Discounting model on the test data: 731.232071469531
# Perplexity of the 1631 Absolute Discounting model on the test data: 971.052917178055
# Perplexity of the 1632 Absolute Discounting model on the test data: 2011.228167240157
# Perplexity of the 1633 Absolute Discounting model on the test data: 1911.2559797152178
# Perplexity of the 1634 Absolute Discounting model on the test data: 2179.7628292187055
# Perplexity of the 1635 Absolute Discounting model on the test data: 2164.4488185325927
# Perplexity of the 1636 Absolute Discounting model on the test data: 3320.3924314953056
# Perplexity of the 1637 Absolute Discounting model on the test data: 427.15077539331503
# Perplexity of the 1638 Absolute Discounting model on the test data: 2385.618771658702
# Perplexity of the 1639 Absolute Discounting model on the test data: 4329.609414300683
# Perplexity of the 1640 Absolute Discounting model on the test data: 2723.1723052458215
# Perplexity of the 1641 Absolute Discounting model on the test data: 6246.441509252282
# Perplexity of the 1642 Absolute Discounting model on the test data: 361.45074787675895
# Perplexity of the 1643 Absolute Discounting model on the test data: 2482.063931553439

# %%
labels = list(range(0, 8))
test_class_tokens = {}
for i in labels:
    test_label = test[test['label'] == i]
    test_tokens = []
    for j, content in enumerate(test_label['content']):
        for token in content:
            test_tokens.append(token)
    test_class_tokens[i] = test_tokens

# %%
best_pg = backoff_model.p_bg
backoff_model = BackoffSmoothing(1, best_pg)
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with unigram: {backoff_model.perplexity(test_tokens)}")

backoff_model = BackoffSmoothing(2, best_pg)
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with bigram: {backoff_model.perplexity(test_tokens)}")

backoff_model = BackoffSmoothing(3, best_pg)
for tokens in train['content']:
    backoff_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} BackoffSmoothing model on the test data with trigram: {backoff_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the class 0 BackoffSmoothing model on the test data with unigram: 1542.8926711581457
# Perplexity of the class 1 BackoffSmoothing model on the test data with unigram: 1532.953566968718
# Perplexity of the class 2 BackoffSmoothing model on the test data with unigram: 1472.0811466477771
# Perplexity of the class 3 BackoffSmoothing model on the test data with unigram: 1407.9579632140478
# Perplexity of the class 4 BackoffSmoothing model on the test data with unigram: 1794.698318055619
# Perplexity of the class 5 BackoffSmoothing model on the test data with unigram: 1661.640768213993
# Perplexity of the class 6 BackoffSmoothing model on the test data with unigram: 1585.387790135717
# Perplexity of the class 7 BackoffSmoothing model on the test data with unigram: 1499.954491517723
# Perplexity of the class 0 BackoffSmoothing model on the test data with bigram: 56.68213315685762
# Perplexity of the class 1 BackoffSmoothing model on the test data with bigram: 53.88316560411561
# Perplexity of the class 2 BackoffSmoothing model on the test data with bigram: 60.37978734350282
# Perplexity of the class 3 BackoffSmoothing model on the test data with bigram: 59.59687057936534
# Perplexity of the class 4 BackoffSmoothing model on the test data with bigram: 60.629069572613176
# Perplexity of the class 5 BackoffSmoothing model on the test data with bigram: 55.33387665704807
# Perplexity of the class 6 BackoffSmoothing model on the test data with bigram: 57.48375385422127
# Perplexity of the class 7 BackoffSmoothing model on the test data with bigram: 58.72718173248872
# Perplexity of the class 0 BackoffSmoothing model on the test data with trigram: 11.034032875448188
# Perplexity of the class 1 BackoffSmoothing model on the test data with trigram: 10.140965909552628
# Perplexity of the class 2 BackoffSmoothing model on the test data with trigram: 11.41679192101374
# Perplexity of the class 3 BackoffSmoothing model on the test data with trigram: 11.47190111986754
# Perplexity of the class 4 BackoffSmoothing model on the test data with trigram: 11.730435264340004
# Perplexity of the class 5 BackoffSmoothing model on the test data with trigram: 11.176922243466613
# Perplexity of the class 6 BackoffSmoothing model on the test data with trigram: 11.447511036218364
# Perplexity of the class 7 BackoffSmoothing model on the test data with trigram: 11.287732088498048

# %%
best_pg = absolute_discounting_model.p_bg
best_discount = 0.75
absolute_discounting_model = AbsoluteDiscounting(1,best_discount, best_discount)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with unigram: {absolute_discounting_model.perplexity(test_tokens)}")

absolute_discounting_model = AbsoluteDiscounting(2,best_discount, best_discount)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with bigram: {absolute_discounting_model.perplexity(test_tokens)}")

absolute_discounting_model = AbsoluteDiscounting(3,best_discount, best_discount)
for tokens in train['content']:
    absolute_discounting_model.update_counts(tokens)
for i in labels:
    test_tokens = [token for token in test_class_tokens[i]]  # Flatten the list of tokens
    print(f"Perplexity of the class {i} absolute discounting model on the test data with trigram: {absolute_discounting_model.perplexity(test_tokens)}")
# Out:
# Perplexity of the class 0 absolute discounting model on the test data with unigram: 1509.462758026619
# Perplexity of the class 1 absolute discounting model on the test data with unigram: 1492.8817388604186
# Perplexity of the class 2 absolute discounting model on the test data with unigram: 1432.0579462140952
# Perplexity of the class 3 absolute discounting model on the test data with unigram: 1380.7551107375364
# Perplexity of the class 4 absolute discounting model on the test data with unigram: 1730.5980756779888
# Perplexity of the class 5 absolute discounting model on the test data with unigram: 1584.5291751243863
# Perplexity of the class 6 absolute discounting model on the test data with unigram: 1543.3112467043977
# Perplexity of the class 7 absolute discounting model on the test data with unigram: 1472.3280618481779
# Perplexity of the class 0 absolute discounting model on the test data with bigram: 136.32575731513438
# Perplexity of the class 1 absolute discounting model on the test data with bigram: 114.8476926340882
# Perplexity of the class 2 absolute discounting model on the test data with bigram: 134.31743386477729
# Perplexity of the class 3 absolute discounting model on the test data with bigram: 122.00519813590334
# Perplexity of the class 4 absolute discounting model on the test data with bigram: 199.77117472949598
# Perplexity of the class 5 absolute discounting model on the test data with bigram: 184.15880350023605
# Perplexity of the class 6 absolute discounting model on the test data with bigram: 145.994065693024
# Perplexity of the class 7 absolute discounting model on the test data with bigram: 134.55255200514083
# Perplexity of the class 0 absolute discounting model on the test data with trigram: 442.61781338675206
# Perplexity of the class 1 absolute discounting model on the test data with trigram: 293.39479344420903
# Perplexity of the class 2 absolute discounting model on the test data with trigram: 545.2975815933171
# Perplexity of the class 3 absolute discounting model on the test data with trigram: 489.09196533509675
# Perplexity of the class 4 absolute discounting model on the test data with trigram: 542.0826011284618
# Perplexity of the class 5 absolute discounting model on the test data with trigram: 409.1698117215197
# Perplexity of the class 6 absolute discounting model on the test data with trigram: 487.7485630210677
# Perplexity of the class 7 absolute discounting model on the test data with trigram: 516.1759752244685
